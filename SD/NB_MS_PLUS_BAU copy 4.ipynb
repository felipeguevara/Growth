# %%
#//----------------------------
#//LIBRARIES
    #Math
import math
    #Numeric Python
import numpy as np
    #Pandas (dataframes)
import pandas as pd
    #datetime for fate manipulation
from datetime import date, datetime, timedelta  
    #Regex for advanced string matching
import re
    #for time related stuff
import time
    #json library
import json
    #Analyst tools
import sys
sys.path.append('../')
from analysts_tools.growth import *
    #Procurement tools
from analysts_tools.redash_methods import *
    #Frubana libraries
from procurement_lib import redash, dw, send_message, send_slack_notification, GoogleSheet, logging

# %%
#//---------------------------------------------------------------------------------------------------------------------------
#// Parametros
"""Todays date should be the first day of the next month which is going to begin with SD"""

city_code = 'CMX'

# Set today's date to the first day of the next month
today = datetime.today()
first_day_next_month = (today.replace(day=1) + timedelta(days=32)).replace(day=1)

# Calculate non_buyers_date (todays date - 1 month)
non_buyers_date = (first_day_next_month - timedelta(days=1)).replace(day=1)
customer_date_desde = (first_day_next_month - timedelta(days=1)).replace(day=1)

# Calculate sku_date_desde (todays date - 2 months)
sku_date_desde = (first_day_next_month - timedelta(days=60)).replace(day=1)

# Convert the dates to strings in the desired format
todays_date = first_day_next_month.strftime('%Y-%m-%d')
non_buyers_date = non_buyers_date.strftime('%Y-%m-%d')
customer_date_desde = customer_date_desde.strftime('%Y-%m-%d')
sku_date_desde = sku_date_desde.strftime('%Y-%m-%d')

print(todays_date) # Output: e.g. 2023-04-01
print(non_buyers_date) # Output: e.g. 2023-03-01
print(sku_date_desde) # Output: e.g. 2023-02-01

tasas = {'BOG': 3776,
         'BAQ': 3776,
         'MDE': 3776,
         'CMX': 19.65,
         'GDL': 19.65,
         'PBC': 19.65,
         'SPO': 4.75,
         'BHZ': 4.75,
         'CWB': 4.75,
         'VCP': 4.75}

t_cambio = tasas[city_code]
# Out:
# 2023-07-01
# 2023-06-01
# 2023-05-01

# %%
query="""
With microsegment as (

SELECT DISTINCT c.customer_id AS user_id,
                c.site_type AS region_code_ms,
                
                (case 
                    -- Colombia
                    when m.microsegment_id not in (1,3,4,28,5,6,7,8,2) and c.site_type = 'BOG' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1,3,4,28,5,11,10,9,2,12) and c.site_type = 'BAQ' then 'Sin Microsegmento'
                    when m.microsegment_id not in (3,4,28,1,24,11,5,2,27) and c.site_type = 'MDE' then 'Sin Microsegmento'
    
                    -- Mexico
                    when m.microsegment_id not in (1,13,14,30,15,16,29,17,6,7,2) and c.site_type = 'CMX' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1, 13,14,30, 15,16,29, 6, 33, 2, 31) and c.site_type = 'GDL' then 'Sin Microsegmento'
                    when m.microsegment_id not in (13,14,30, 15,16,29, 32,2,6,33) and c.site_type = 'PBC' then 'Sin Microsegmento'
                    
                    -- Brasil
                    when m.microsegment_id not in (21,34,38,37,35,36,39,26) and c.site_type in ('SPO','BHZ','CWB','VCP') then 'Sin Microsegmento'
                        
                else m.description end) as microsegment_ok,
                
                m.microsegment_id,
                mo.name as ms_method
                
                
FROM postgres_main_federate."growth_microsegmentation.customer_microsegment" AS cm
INNER JOIN postgres_main_federate."growth_microsegmentation.microsegment" m ON cm.microsegment_id = m.id
INNER JOIN postgres_main_federate."growth_microsegmentation.customer" c ON cm.customer_id = c.id
INNER JOIN postgres_main_federate."growth_microsegmentation.models" mo ON mo.id = cm.model_type_id


)

select m.user_id,
m.region_code_ms,
--m.microsegment_id,

(case 
        when m.microsegment_ok in ('Corrientazo c/desayuno','Corrientazo s/desayuno','Tienda/Restaurante') then 'Corrientazo' 
        when m.microsegment_ok in ('Fonda c/desayuno','Fonda s/desayuno') then 'Fonda'
        when m.microsegment_ok in ('Taquería en calle','Taquería en local') then 'Taquería'

else m.microsegment_ok end) as microsegment,

m.ms_method

from microsegment m
where m.microsegment_ok != 'Sin Microsegmento'
"""

segmentos_fulll = read_connection_data_warehouse.runQuery(query)

segmentos_fulll.columns = ['customer_id', 'city', 'microsegment','NA']
segmentos_fulll = segmentos_fulll[['customer_id', 'city', 'microsegment']]

# %% [markdown]
# ### Loading COSTUMERS INFO

# %%
users_eliminar_kam = get_fresh_query_result("https://internal-redash.federate.frubana.com/",150812,'SeoGHWmDUaaBi7VXje1s9zYNiMD1VHQ1K1DYOxiF',{},20)
users_eliminar = users_eliminar_kam.loc[users_eliminar_kam.registered_city == city_code]['customer_id'].unique().tolist()
# Out:
# 200

# %% [markdown]
# ### Loading FORCED_SKUS // Cleaning SEGMENT_NAMES

# %% [markdown]
# ### Loading DATA_VENTAS // Removing SKUs /\ CUSTOMERS_ID

# %%
#//Remove skus 
#It is used because some SKUs can get in trouble with supplier for the SD or to exclude them for another activity   
skus_remove = GoogleSheet("1Z0T_c36oRHmOHIgEG8_ANcwFykaHgXGAizYAYCKCqtY")
skus_remove = skus_remove.get_as_dataframe('SKUS')

skus_remove = skus_remove['sku_id'].unique().astype(int).tolist()

# %%
query = """
SELECT DISTINCT
    split_part(bs.upc, '-', 1) as region,
    bs.sku_id

FROM postgres_broadleaf_federate."broadleaf.blc_sku"            bs 
LEFT JOIN postgres_broadleaf_federate."broadleaf.blc_product"   bp ON bp.product_id = bs.addl_product_id

WHERE bs.archived = 'N'
    AND bs.sndbx_id is NULL
    AND bp.archived = 'N'
    AND bs.catalog_disc < 0
    AND ((bp.archived = 'N' AND bp.sndbx_id is NULL) OR (bp.archived is NULL))
"""
frida_products = read_connection_data_warehouse.runQuery(query)

# %%
good_skus = frida_products.sku_id.unique()

# %%
#Loading SELL'S DATA from a function
data_ventas = data_ventas_query(ciudad=city_code, tipo_cambio=t_cambio, desde=customer_date_desde, hasta = todays_date, tipo_negocio=1)

# %%
data_ventas = data_ventas[(~data_ventas['sku_id'].isin(skus_remove)) & (data_ventas['sku_id'].isin(good_skus))]

# %%
segmentos_full = segmentos_fulll[segmentos_fulll.city == city_code].copy()

# %%
#//customers for offers */(has further uses)*/
microsegmentacion_df = segmentos_full[(~segmentos_full['customer_id'].isin(users_eliminar))]
data_ventas = data_ventas[(~data_ventas['customer_id'].isin(users_eliminar))]

# %% [markdown]
# ### Create the MS "Other" for BAU

# %%
data_full = data_ventas.merge(microsegmentacion_df[['customer_id','microsegment']], how = 'left', on = 'customer_id')

# %%
data_full['microsegment'] = data_full['microsegment'].fillna('Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                 microsegment  customer_id
# 0                  Cafetería          445
# 1       Comida especializada          738
# 2              Comida rápida         1133
# 3                      Fonda         2632
# 4  Juguería/Comida saludable          863
# 5                      Other          629
# 6       Panadería/Pastelería         1050
# 7                   Taquería         2212

# %%
segments_validation = data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()

# %%
for ms in segments_validation[segments_validation.customer_id < 180]['microsegment'].unique():
    data_full['microsegment'] = data_full['microsegment'].str.replace(ms,'Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                 microsegment  customer_id
# 0                  Cafetería          445
# 1       Comida especializada          738
# 2              Comida rápida         1133
# 3                      Fonda         2632
# 4  Juguería/Comida saludable          863
# 5                      Other          629
# 6       Panadería/Pastelería         1050
# 7                   Taquería         2212

# %%
#Get the same variable to do the process job
data_ventas = data_full

# %% [markdown]
# ### PARAMETERS // SOME FUNCTIONS - GET READY TO PROCESSING

# %%
def ms_data(city_code):
  
    paramss_csv=GoogleSheet("1k0ckgkLddxc5lY8NUVGCkvDLTuulLaJm-N535oMNZNw")
    city_paramss = paramss_csv.get_as_dataframe(city_code)
    
    parametros = {}
    parametros[city_code] = {}
    
    for i,ms in enumerate(city_paramss.iloc[:,4:].columns):
        parametros[city_code][ms] = [(value[1],value[2],value[3],value[4+i]) for value in city_paramss.values if value[4+i]>0]
        
    return parametros

# %%
parametros = ms_data(city_code)

# %%
def normalize_text(raw_text):
    """
    Removes common accent characters and normalize text.
    """
    raw_text = raw_text.replace(" ", "")
    raw_text = raw_text.replace("�", "")
    raw_text = raw_text.replace("/", "")
    raw_text = re.sub(r'\s*', '', raw_text)
    raw_text = re.sub(r"[àáâãäå]", 'a', raw_text)
    raw_text = re.sub(r"[èéêë]", 'e', raw_text)
    raw_text = re.sub(r"[ìíîï]", 'i', raw_text) 
    raw_text = re.sub(r"[òóôõö]", 'o', raw_text)
    raw_text = re.sub(r"[ùúûü]", 'u', raw_text)
    raw_text = re.sub(r"[ýÿ]", 'y', raw_text)
    raw_text = re.sub(r"[ß]", 'ss', raw_text)
    raw_text = re.sub(r"[ñ]", 'n', raw_text)
    raw_text = re.sub(r"[ç]", 'c', raw_text)
    raw_text = raw_text.lower()
    return raw_text

# %%
#Sacar de aca los microsegmentos
msg = data_full.microsegment.unique()
msg
# Out:
# array(['Comida especializada', 'Comida rápida', 'Fonda', 'Taquería',
#        'Juguería/Comida saludable', 'Other', 'Panadería/Pastelería',
#        'Cafetería'], dtype=object)

# %% [markdown]
# ### END

# %% [markdown]
# # Aca Empieza la Experimentacion

# %%
from sklearn.model_selection import train_test_split

# %%
#//Variables to store all the segments and offers of the city
global_offer_csv = pd.DataFrame()
global_segment_list = [] #//for procesing

# %%
#//----------------------------------------------------------------------------
#//Big loop for creating each city segments/offers files
aux_df = pd.DataFrame()
aux_df['aux']=6000*[0]

for microsegment in msg:
    print('//-------------------------------------------------------------------------------')
    print(microsegment)

    #//Customers per microsegment
    customers_ms = data_ventas[(data_ventas['microsegment'] == microsegment)]['customer_id'].unique()
    #//Customers to give them the skus
    customers_for_skus_ms =  data_ventas[['microsegment','customer_id']][(data_ventas.microsegment == microsegment) & (~data_ventas.customer_id.isin(users_eliminar))]['customer_id'].unique()
    
    #----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_PILOTO" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    rand=1
    customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state=rand)
    
    while abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())) > 0.05:
        #print(data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean(),data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean(),abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())))
        rand+=1
        customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state = rand)
        
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_1)].copy() #le quite la s!!
    
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()
    
    subcats = list(map(lambda x: x[0], parametros[city_code][microsegment]))
    max_uses = list(map(lambda x: int(x[1]), parametros[city_code][microsegment]))
    max_order = list(map(lambda x: int(x[2]), parametros[city_code][microsegment]))
    discount = list(map(lambda x: int(x[3]), parametros[city_code][microsegment]))

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    a, b, c = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
            non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                        limite=0.75, data_ventas_skus = data_skus)

    print(b.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(a)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in b.columns:
        id_list = b[seg].dropna().astype(int)
        d = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)

        lst.append(d)
        
    #//appending to global list    
        global_segment_list.append(d)
    
    print(f'Done {city_code} {ms_name}')

#----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------


#----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_CONTROL" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_2)].copy() #le quite la s!!
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    print('//-------------------------------------------------------------------------------')
    print(f'{microsegment} Experimento50%')
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    e, f, g = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
                non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                          limite=0.75, data_ventas_skus = data_skus)
      
    print(f.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(e)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in f.columns:
        id_list = f[seg].dropna().astype(int)
        h = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)
        
        lst.append(h)
        
        
    #//appending to global list    
        global_segment_list.append(h)
    
    print(f'Done {city_code} {ms_name}')
    #----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#//End of big loop and start of data bundle
# Out:
# //-------------------------------------------------------------------------------
# Comida especializada
# 591
# Uso de data externa
# 20230701_CMX_comidaespecializada_piloto_NB_azucaryendulzantes_W26                355
# 20230701_CMX_comidaespecializada_piloto_NB_aceitesygrasas_W26                    413
# 20230701_CMX_comidaespecializada_piloto_NB_cafechocolateeinfusiones_W26          540
# 20230701_CMX_comidaespecializada_piloto_NB_enlatados_W26                         511
# 20230701_CMX_comidaespecializada_piloto_NB_salsas_W26                            462
# 20230701_CMX_comidaespecializada_piloto_NB_arroz_W26                             479
# 20230701_CMX_comidaespecializada_piloto_NB_frutossecos_W26                       517
# 20230701_CMX_comidaespecializada_piloto_NB_panaderiaytortilleria_W26             555
# 20230701_CMX_comidaespecializada_piloto_NB_granos_W26                            538
# 20230701_CMX_comidaespecializada_piloto_NB_pasta_W26                             531
# 20230701_CMX_comidaespecializada_piloto_NB_salysazonadores_W26                   496
# 20230701_CMX_comidaespecializada_piloto_NB_chilessecos_W26                       514
# 20230701_CMX_comidaespecializada_piloto_NB_mermeladasyconfituras_W26             584
# 20230701_CMX_comidaespecializada_piloto_NB_papelytoallas_W26                     453
# 20230701_CMX_comidaespecializada_piloto_NB_detergentejabonylavatrastes_W26       465
# 20230701_CMX_comidaespecializada_piloto_NB_desinfectantesysanitizantes_W26       496
# 20230701_CMX_comidaespecializada_piloto_NB_implementosdeaseo_W26                 536
# 20230701_CMX_comidaespecializada_piloto_NB_refrescos_W26                         441
# 20230701_CMX_comidaespecializada_piloto_NB_jugos_W26                             562
# 20230701_CMX_comidaespecializada_piloto_NB_bebidasenergeticasehidratantes_W26    588
# 20230701_CMX_comidaespecializada_piloto_NB_pollo_W26                             544
# 20230701_CMX_comidaespecializada_piloto_NB_embutidos_W26                         532
# 20230701_CMX_comidaespecializada_piloto_NB_cerdo_W26                             548
# 20230701_CMX_comidaespecializada_piloto_NB_res_W26                               540
# 20230701_CMX_comidaespecializada_piloto_NB_alimentoscongelados_W26               535
# 20230701_CMX_comidaespecializada_piloto_NB_vasoscontenedoresyplatos_W26          398
# 20230701_CMX_comidaespecializada_piloto_NB_empaqueyenvoltura_W26                 538
# 20230701_CMX_comidaespecializada_piloto_NB_bolsas_W26                            558
# 20230701_CMX_comidaespecializada_piloto_NB_cubiertos_W26                         540
# 20230701_CMX_comidaespecializada_piloto_NB_verduras_W26                          252
# 20230701_CMX_comidaespecializada_piloto_NB_frutas_W26                            341
# 20230701_CMX_comidaespecializada_piloto_NB_tuberculos_W26                        443
# 20230701_CMX_comidaespecializada_piloto_NB_leches_W26                            490
# 20230701_CMX_comidaespecializada_piloto_NB_derivadoslacteos_W26                  519
# 20230701_CMX_comidaespecializada_piloto_NB_huevos_W26                            524
# 20230701_CMX_comidaespecializada_piloto_NB_cremas_W26                            496
# 20230701_CMX_comidaespecializada_piloto_NB_quesos_W26                            540
# 20230701_CMX_comidaespecializada_piloto_NB_mantequillasymargarinas_W26           558
# dtype: int64
# Done CMX comidaespecializada_PILOTO
# //-------------------------------------------------------------------------------
# Comida especializada Experimento50%
# 147
# Uso de data externa
# 20230701_CMX_comidaespecializada_control_NB_azucaryendulzantes_W26                 92
# 20230701_CMX_comidaespecializada_control_NB_aceitesygrasas_W26                    107
# 20230701_CMX_comidaespecializada_control_NB_cafechocolateeinfusiones_W26          140
# 20230701_CMX_comidaespecializada_control_NB_enlatados_W26                         131
# 20230701_CMX_comidaespecializada_control_NB_salsas_W26                            121
# 20230701_CMX_comidaespecializada_control_NB_arroz_W26                             112
# 20230701_CMX_comidaespecializada_control_NB_frutossecos_W26                       127
# 20230701_CMX_comidaespecializada_control_NB_panaderiaytortilleria_W26             140
# 20230701_CMX_comidaespecializada_control_NB_granos_W26                            134
# 20230701_CMX_comidaespecializada_control_NB_pasta_W26                             131
# 20230701_CMX_comidaespecializada_control_NB_salysazonadores_W26                   127
# 20230701_CMX_comidaespecializada_control_NB_chilessecos_W26                       120
# 20230701_CMX_comidaespecializada_control_NB_mermeladasyconfituras_W26             145
# 20230701_CMX_comidaespecializada_control_NB_papelytoallas_W26                     121
# 20230701_CMX_comidaespecializada_control_NB_detergentejabonylavatrastes_W26       119
# 20230701_CMX_comidaespecializada_control_NB_desinfectantesysanitizantes_W26       124
# 20230701_CMX_comidaespecializada_control_NB_implementosdeaseo_W26                 125
# 20230701_CMX_comidaespecializada_control_NB_refrescos_W26                         116
# 20230701_CMX_comidaespecializada_control_NB_jugos_W26                             141
# 20230701_CMX_comidaespecializada_control_NB_bebidasenergeticasehidratantes_W26    147
# 20230701_CMX_comidaespecializada_control_NB_pollo_W26                             135
# 20230701_CMX_comidaespecializada_control_NB_embutidos_W26                         139
# 20230701_CMX_comidaespecializada_control_NB_cerdo_W26                             136
# 20230701_CMX_comidaespecializada_control_NB_res_W26                               137
# 20230701_CMX_comidaespecializada_control_NB_alimentoscongelados_W26               138
# 20230701_CMX_comidaespecializada_control_NB_vasoscontenedoresyplatos_W26          106
# 20230701_CMX_comidaespecializada_control_NB_empaqueyenvoltura_W26                 132
# 20230701_CMX_comidaespecializada_control_NB_bolsas_W26                            141
# 20230701_CMX_comidaespecializada_control_NB_cubiertos_W26                         135
# 20230701_CMX_comidaespecializada_control_NB_verduras_W26                           69
# 20230701_CMX_comidaespecializada_control_NB_frutas_W26                             91
# 20230701_CMX_comidaespecializada_control_NB_tuberculos_W26                        115
# 20230701_CMX_comidaespecializada_control_NB_leches_W26                            128
# 20230701_CMX_comidaespecializada_control_NB_derivadoslacteos_W26                  128
# 20230701_CMX_comidaespecializada_control_NB_huevos_W26                            129
# 20230701_CMX_comidaespecializada_control_NB_cremas_W26                            118
# 20230701_CMX_comidaespecializada_control_NB_quesos_W26                            133
# 20230701_CMX_comidaespecializada_control_NB_mantequillasymargarinas_W26           139
# dtype: int64
# Done CMX comidaespecializada_CONTROL
# //-------------------------------------------------------------------------------
# Comida rápida
# 907
# Uso de data externa
# 20230701_CMX_comidarapida_piloto_NB_azucaryendulzantes_W26                646
# 20230701_CMX_comidarapida_piloto_NB_aceitesygrasas_W26                    657
# 20230701_CMX_comidarapida_piloto_NB_cafechocolateeinfusiones_W26          844
# 20230701_CMX_comidarapida_piloto_NB_enlatados_W26                         743
# 20230701_CMX_comidarapida_piloto_NB_salsas_W26                            698
# 20230701_CMX_comidarapida_piloto_NB_arroz_W26                             789
# 20230701_CMX_comidarapida_piloto_NB_frutossecos_W26                       812
# 20230701_CMX_comidarapida_piloto_NB_panaderiaytortilleria_W26             795
# 20230701_CMX_comidarapida_piloto_NB_granos_W26                            837
# 20230701_CMX_comidarapida_piloto_NB_pasta_W26                             818
# 20230701_CMX_comidarapida_piloto_NB_salysazonadores_W26                   782
# 20230701_CMX_comidarapida_piloto_NB_chilessecos_W26                       805
# 20230701_CMX_comidarapida_piloto_NB_mermeladasyconfituras_W26             892
# 20230701_CMX_comidarapida_piloto_NB_papelytoallas_W26                     711
# 20230701_CMX_comidarapida_piloto_NB_detergentejabonylavatrastes_W26       743
# 20230701_CMX_comidarapida_piloto_NB_desinfectantesysanitizantes_W26       789
# 20230701_CMX_comidarapida_piloto_NB_implementosdeaseo_W26                 824
# 20230701_CMX_comidarapida_piloto_NB_refrescos_W26                         633
# 20230701_CMX_comidarapida_piloto_NB_jugos_W26                             880
# 20230701_CMX_comidarapida_piloto_NB_bebidasenergeticasehidratantes_W26    906
# 20230701_CMX_comidarapida_piloto_NB_pollo_W26                             797
# 20230701_CMX_comidarapida_piloto_NB_embutidos_W26                         781
# 20230701_CMX_comidarapida_piloto_NB_cerdo_W26                             831
# 20230701_CMX_comidarapida_piloto_NB_res_W26                               790
# 20230701_CMX_comidarapida_piloto_NB_alimentoscongelados_W26               755
# 20230701_CMX_comidarapida_piloto_NB_vasoscontenedoresyplatos_W26          636
# 20230701_CMX_comidarapida_piloto_NB_empaqueyenvoltura_W26                 852
# 20230701_CMX_comidarapida_piloto_NB_bolsas_W26                            870
# 20230701_CMX_comidarapida_piloto_NB_cubiertos_W26                         827
# 20230701_CMX_comidarapida_piloto_NB_verduras_W26                          378
# 20230701_CMX_comidarapida_piloto_NB_frutas_W26                            509
# 20230701_CMX_comidarapida_piloto_NB_tuberculos_W26                        641
# 20230701_CMX_comidarapida_piloto_NB_leches_W26                            759
# 20230701_CMX_comidarapida_piloto_NB_derivadoslacteos_W26                  804
# 20230701_CMX_comidarapida_piloto_NB_huevos_W26                            809
# 20230701_CMX_comidarapida_piloto_NB_cremas_W26                            766
# 20230701_CMX_comidarapida_piloto_NB_quesos_W26                            815
# 20230701_CMX_comidarapida_piloto_NB_mantequillasymargarinas_W26           862
# dtype: int64
# Done CMX comidarapida_PILOTO
# //-------------------------------------------------------------------------------
# Comida rápida Experimento50%
# 226
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)
# Uso de data externa
# 20230701_CMX_comidarapida_control_NB_azucaryendulzantes_W26                170
# 20230701_CMX_comidarapida_control_NB_aceitesygrasas_W26                    167
# 20230701_CMX_comidarapida_control_NB_cafechocolateeinfusiones_W26          203
# 20230701_CMX_comidarapida_control_NB_enlatados_W26                         184
# 20230701_CMX_comidarapida_control_NB_salsas_W26                            167
# 20230701_CMX_comidarapida_control_NB_arroz_W26                             201
# 20230701_CMX_comidarapida_control_NB_frutossecos_W26                       212
# 20230701_CMX_comidarapida_control_NB_panaderiaytortilleria_W26             196
# 20230701_CMX_comidarapida_control_NB_granos_W26                            210
# 20230701_CMX_comidarapida_control_NB_pasta_W26                             201
# 20230701_CMX_comidarapida_control_NB_salysazonadores_W26                   196
# 20230701_CMX_comidarapida_control_NB_chilessecos_W26                       200
# 20230701_CMX_comidarapida_control_NB_mermeladasyconfituras_W26             224
# 20230701_CMX_comidarapida_control_NB_papelytoallas_W26                     179
# 20230701_CMX_comidarapida_control_NB_detergentejabonylavatrastes_W26       178
# 20230701_CMX_comidarapida_control_NB_desinfectantesysanitizantes_W26       199
# 20230701_CMX_comidarapida_control_NB_implementosdeaseo_W26                 199
# 20230701_CMX_comidarapida_control_NB_refrescos_W26                         155
# 20230701_CMX_comidarapida_control_NB_jugos_W26                             219
# 20230701_CMX_comidarapida_control_NB_bebidasenergeticasehidratantes_W26    226
# 20230701_CMX_comidarapida_control_NB_pollo_W26                             210
# 20230701_CMX_comidarapida_control_NB_embutidos_W26                         205
# 20230701_CMX_comidarapida_control_NB_cerdo_W26                             210
# 20230701_CMX_comidarapida_control_NB_res_W26                               201
# 20230701_CMX_comidarapida_control_NB_alimentoscongelados_W26               186
# 20230701_CMX_comidarapida_control_NB_vasoscontenedoresyplatos_W26          152
# 20230701_CMX_comidarapida_control_NB_empaqueyenvoltura_W26                 211
# 20230701_CMX_comidarapida_control_NB_bolsas_W26                            221
# 20230701_CMX_comidarapida_control_NB_cubiertos_W26                         204
# 20230701_CMX_comidarapida_control_NB_verduras_W26                          113
# 20230701_CMX_comidarapida_control_NB_frutas_W26                            141
# 20230701_CMX_comidarapida_control_NB_tuberculos_W26                        175
# 20230701_CMX_comidarapida_control_NB_leches_W26                            178
# 20230701_CMX_comidarapida_control_NB_derivadoslacteos_W26                  197
# 20230701_CMX_comidarapida_control_NB_huevos_W26                            191
# 20230701_CMX_comidarapida_control_NB_cremas_W26                            197
# 20230701_CMX_comidarapida_control_NB_quesos_W26                            205
# 20230701_CMX_comidarapida_control_NB_mantequillasymargarinas_W26           221
# dtype: int64
# Done CMX comidarapida_CONTROL
# //-------------------------------------------------------------------------------
# Fonda
# 2106
# Uso de data externa
# 20230701_CMX_fonda_piloto_NB_azucaryendulzantes_W26                1377
# 20230701_CMX_fonda_piloto_NB_aceitesygrasas_W26                    1474
# 20230701_CMX_fonda_piloto_NB_cafechocolateeinfusiones_W26          1941
# 20230701_CMX_fonda_piloto_NB_enlatados_W26                         1821
# 20230701_CMX_fonda_piloto_NB_salsas_W26                            1826
# 20230701_CMX_fonda_piloto_NB_arroz_W26                             1290
# 20230701_CMX_fonda_piloto_NB_frutossecos_W26                       1793
# 20230701_CMX_fonda_piloto_NB_panaderiaytortilleria_W26             1866
# 20230701_CMX_fonda_piloto_NB_granos_W26                            1725
# 20230701_CMX_fonda_piloto_NB_pasta_W26                             1541
# 20230701_CMX_fonda_piloto_NB_salysazonadores_W26                   1676
# 20230701_CMX_fonda_piloto_NB_chilessecos_W26                       1643
# 20230701_CMX_fonda_piloto_NB_mermeladasyconfituras_W26             2081
# 20230701_CMX_fonda_piloto_NB_papelytoallas_W26                     1601
# 20230701_CMX_fonda_piloto_NB_detergentejabonylavatrastes_W26       1660
# 20230701_CMX_fonda_piloto_NB_desinfectantesysanitizantes_W26       1831
# 20230701_CMX_fonda_piloto_NB_implementosdeaseo_W26                 1925
# 20230701_CMX_fonda_piloto_NB_refrescos_W26                         1695
# 20230701_CMX_fonda_piloto_NB_jugos_W26                             2071
# 20230701_CMX_fonda_piloto_NB_bebidasenergeticasehidratantes_W26    2104
# 20230701_CMX_fonda_piloto_NB_pollo_W26                             1930
# 20230701_CMX_fonda_piloto_NB_embutidos_W26                         1930
# 20230701_CMX_fonda_piloto_NB_cerdo_W26                             1929
# 20230701_CMX_fonda_piloto_NB_res_W26                               1918
# 20230701_CMX_fonda_piloto_NB_alimentoscongelados_W26               1929
# 20230701_CMX_fonda_piloto_NB_vasoscontenedoresyplatos_W26          1338
# 20230701_CMX_fonda_piloto_NB_empaqueyenvoltura_W26                 1952
# 20230701_CMX_fonda_piloto_NB_bolsas_W26                            2036
# 20230701_CMX_fonda_piloto_NB_cubiertos_W26                         1791
# 20230701_CMX_fonda_piloto_NB_verduras_W26                           759
# 20230701_CMX_fonda_piloto_NB_frutas_W26                            1113
# 20230701_CMX_fonda_piloto_NB_tuberculos_W26                        1391
# 20230701_CMX_fonda_piloto_NB_leches_W26                            1720
# 20230701_CMX_fonda_piloto_NB_derivadoslacteos_W26                  1875
# 20230701_CMX_fonda_piloto_NB_huevos_W26                            1756
# 20230701_CMX_fonda_piloto_NB_cremas_W26                            1543
# 20230701_CMX_fonda_piloto_NB_quesos_W26                            1902
# 20230701_CMX_fonda_piloto_NB_mantequillasymargarinas_W26           1971
# dtype: int64
# Done CMX fonda_PILOTO
# //-------------------------------------------------------------------------------
# Fonda Experimento50%
# 526
# Uso de data externa
# 20230701_CMX_fonda_control_NB_azucaryendulzantes_W26                345
# 20230701_CMX_fonda_control_NB_aceitesygrasas_W26                    369
# 20230701_CMX_fonda_control_NB_cafechocolateeinfusiones_W26          485
# 20230701_CMX_fonda_control_NB_enlatados_W26                         443
# 20230701_CMX_fonda_control_NB_salsas_W26                            448
# 20230701_CMX_fonda_control_NB_arroz_W26                             315
# 20230701_CMX_fonda_control_NB_frutossecos_W26                       446
# 20230701_CMX_fonda_control_NB_panaderiaytortilleria_W26             459
# 20230701_CMX_fonda_control_NB_granos_W26                            421
# 20230701_CMX_fonda_control_NB_pasta_W26                             378
# 20230701_CMX_fonda_control_NB_salysazonadores_W26                   420
# 20230701_CMX_fonda_control_NB_chilessecos_W26                       413
# 20230701_CMX_fonda_control_NB_mermeladasyconfituras_W26             523
# 20230701_CMX_fonda_control_NB_papelytoallas_W26                     402
# 20230701_CMX_fonda_control_NB_detergentejabonylavatrastes_W26       400
# 20230701_CMX_fonda_control_NB_desinfectantesysanitizantes_W26       461
# 20230701_CMX_fonda_control_NB_implementosdeaseo_W26                 481
# 20230701_CMX_fonda_control_NB_refrescos_W26                         410
# 20230701_CMX_fonda_control_NB_jugos_W26                             512
# 20230701_CMX_fonda_control_NB_bebidasenergeticasehidratantes_W26    526
# 20230701_CMX_fonda_control_NB_pollo_W26                             475
# 20230701_CMX_fonda_control_NB_embutidos_W26                         469
# 20230701_CMX_fonda_control_NB_cerdo_W26                             475
# 20230701_CMX_fonda_control_NB_res_W26                               470
# 20230701_CMX_fonda_control_NB_alimentoscongelados_W26               475
# 20230701_CMX_fonda_control_NB_vasoscontenedoresyplatos_W26          332
# 20230701_CMX_fonda_control_NB_empaqueyenvoltura_W26                 480
# 20230701_CMX_fonda_control_NB_bolsas_W26                            501
# 20230701_CMX_fonda_control_NB_cubiertos_W26                         454
# 20230701_CMX_fonda_control_NB_verduras_W26                          181
# 20230701_CMX_fonda_control_NB_frutas_W26                            286
# 20230701_CMX_fonda_control_NB_tuberculos_W26                        346
# 20230701_CMX_fonda_control_NB_leches_W26                            426
# 20230701_CMX_fonda_control_NB_derivadoslacteos_W26                  447
# 20230701_CMX_fonda_control_NB_huevos_W26                            415
# 20230701_CMX_fonda_control_NB_cremas_W26                            376
# 20230701_CMX_fonda_control_NB_quesos_W26                            465
# 20230701_CMX_fonda_control_NB_mantequillasymargarinas_W26           494
# dtype: int64
# Done CMX fonda_CONTROL
# //-------------------------------------------------------------------------------
# Taquería
# 1770
# Uso de data externa
# 20230701_CMX_taqueria_piloto_NB_azucaryendulzantes_W26                1284
# 20230701_CMX_taqueria_piloto_NB_aceitesygrasas_W26                    1287
# 20230701_CMX_taqueria_piloto_NB_cafechocolateeinfusiones_W26          1622
# 20230701_CMX_taqueria_piloto_NB_enlatados_W26                         1601
# 20230701_CMX_taqueria_piloto_NB_salsas_W26                            1578
# 20230701_CMX_taqueria_piloto_NB_arroz_W26                             1404
# 20230701_CMX_taqueria_piloto_NB_frutossecos_W26                       1543
# 20230701_CMX_taqueria_piloto_NB_panaderiaytortilleria_W26             1625
# 20230701_CMX_taqueria_piloto_NB_granos_W26                            1569
# 20230701_CMX_taqueria_piloto_NB_pasta_W26                             1595
# 20230701_CMX_taqueria_piloto_NB_salysazonadores_W26                   1370
# 20230701_CMX_taqueria_piloto_NB_chilessecos_W26                       1243
# 20230701_CMX_taqueria_piloto_NB_mermeladasyconfituras_W26             1750
# 20230701_CMX_taqueria_piloto_NB_papelytoallas_W26                     1267
# 20230701_CMX_taqueria_piloto_NB_detergentejabonylavatrastes_W26       1359
# 20230701_CMX_taqueria_piloto_NB_desinfectantesysanitizantes_W26       1552
# 20230701_CMX_taqueria_piloto_NB_implementosdeaseo_W26                 1599
# 20230701_CMX_taqueria_piloto_NB_refrescos_W26                         1306
# 20230701_CMX_taqueria_piloto_NB_jugos_W26                             1727
# 20230701_CMX_taqueria_piloto_NB_bebidasenergeticasehidratantes_W26    1765
# 20230701_CMX_taqueria_piloto_NB_pollo_W26                             1640
# 20230701_CMX_taqueria_piloto_NB_embutidos_W26                         1624
# 20230701_CMX_taqueria_piloto_NB_cerdo_W26                             1648
# 20230701_CMX_taqueria_piloto_NB_res_W26                               1636
# 20230701_CMX_taqueria_piloto_NB_alimentoscongelados_W26               1675
# 20230701_CMX_taqueria_piloto_NB_vasoscontenedoresyplatos_W26          1076
# 20230701_CMX_taqueria_piloto_NB_empaqueyenvoltura_W26                 1652
# 20230701_CMX_taqueria_piloto_NB_bolsas_W26                            1704
# 20230701_CMX_taqueria_piloto_NB_cubiertos_W26                         1561
# 20230701_CMX_taqueria_piloto_NB_verduras_W26                           502
# 20230701_CMX_taqueria_piloto_NB_frutas_W26                             822
# 20230701_CMX_taqueria_piloto_NB_tuberculos_W26                        1154
# 20230701_CMX_taqueria_piloto_NB_leches_W26                            1483
# 20230701_CMX_taqueria_piloto_NB_derivadoslacteos_W26                  1553
# 20230701_CMX_taqueria_piloto_NB_huevos_W26                            1567
# 20230701_CMX_taqueria_piloto_NB_cremas_W26                            1436
# 20230701_CMX_taqueria_piloto_NB_quesos_W26                            1607
# 20230701_CMX_taqueria_piloto_NB_mantequillasymargarinas_W26           1732
# dtype: int64
# Done CMX taqueria_PILOTO
# //-------------------------------------------------------------------------------
# Taquería Experimento50%
# 442
# Uso de data externa
# 20230701_CMX_taqueria_control_NB_azucaryendulzantes_W26                328
# 20230701_CMX_taqueria_control_NB_aceitesygrasas_W26                    309
# 20230701_CMX_taqueria_control_NB_cafechocolateeinfusiones_W26          413
# 20230701_CMX_taqueria_control_NB_enlatados_W26                         399
# 20230701_CMX_taqueria_control_NB_salsas_W26                            393
# 20230701_CMX_taqueria_control_NB_arroz_W26                             345
# 20230701_CMX_taqueria_control_NB_frutossecos_W26                       374
# 20230701_CMX_taqueria_control_NB_panaderiaytortilleria_W26             408
# 20230701_CMX_taqueria_control_NB_granos_W26                            388
# 20230701_CMX_taqueria_control_NB_pasta_W26                             399
# 20230701_CMX_taqueria_control_NB_salysazonadores_W26                   344
# 20230701_CMX_taqueria_control_NB_chilessecos_W26                       305
# 20230701_CMX_taqueria_control_NB_mermeladasyconfituras_W26             437
# 20230701_CMX_taqueria_control_NB_papelytoallas_W26                     312
# 20230701_CMX_taqueria_control_NB_detergentejabonylavatrastes_W26       331
# 20230701_CMX_taqueria_control_NB_desinfectantesysanitizantes_W26       375
# 20230701_CMX_taqueria_control_NB_implementosdeaseo_W26                 391
# 20230701_CMX_taqueria_control_NB_refrescos_W26                         314
# 20230701_CMX_taqueria_control_NB_jugos_W26                             428
# 20230701_CMX_taqueria_control_NB_bebidasenergeticasehidratantes_W26    441
# 20230701_CMX_taqueria_control_NB_pollo_W26                             416
# 20230701_CMX_taqueria_control_NB_embutidos_W26                         407
# 20230701_CMX_taqueria_control_NB_cerdo_W26                             403
# 20230701_CMX_taqueria_control_NB_res_W26                               413
# 20230701_CMX_taqueria_control_NB_alimentoscongelados_W26               408
# 20230701_CMX_taqueria_control_NB_vasoscontenedoresyplatos_W26          277
# 20230701_CMX_taqueria_control_NB_empaqueyenvoltura_W26                 402
# 20230701_CMX_taqueria_control_NB_bolsas_W26                            422
# 20230701_CMX_taqueria_control_NB_cubiertos_W26                         391
# 20230701_CMX_taqueria_control_NB_verduras_W26                          116
# 20230701_CMX_taqueria_control_NB_frutas_W26                            206
# 20230701_CMX_taqueria_control_NB_tuberculos_W26                        282
# 20230701_CMX_taqueria_control_NB_leches_W26                            368
# 20230701_CMX_taqueria_control_NB_derivadoslacteos_W26                  389
# 20230701_CMX_taqueria_control_NB_huevos_W26                            401
# 20230701_CMX_taqueria_control_NB_cremas_W26                            344
# 20230701_CMX_taqueria_control_NB_quesos_W26                            402
# 20230701_CMX_taqueria_control_NB_mantequillasymargarinas_W26           426
# dtype: int64
# Done CMX taqueria_CONTROL
# //-------------------------------------------------------------------------------
# Juguería/Comida saludable
# 691
# Uso de data externa
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_azucaryendulzantes_W26                243
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_aceitesygrasas_W26                    591
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_cafechocolateeinfusiones_W26          627
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_enlatados_W26                         613
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_salsas_W26                            600
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_arroz_W26                             610
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_frutossecos_W26                       566
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_panaderiaytortilleria_W26             665
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_granos_W26                            635
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_pasta_W26                             630
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_salysazonadores_W26                   632
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_chilessecos_W26                       638
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_mermeladasyconfituras_W26             679
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_papelytoallas_W26                     544
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_detergentejabonylavatrastes_W26       556
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_desinfectantesysanitizantes_W26       586
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_implementosdeaseo_W26                 630
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_refrescos_W26                         577
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_jugos_W26                             671
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_bebidasenergeticasehidratantes_W26    688
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_pollo_W26                             661
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_embutidos_W26                         660
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_cerdo_W26                             670
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_res_W26                               662
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_alimentoscongelados_W26               650
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_vasoscontenedoresyplatos_W26          416
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_empaqueyenvoltura_W26                 670
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_bolsas_W26                            668
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_cubiertos_W26                         633
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_verduras_W26                          410
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_frutas_W26                            431
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_tuberculos_W26                        572
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_leches_W26                            519
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_derivadoslacteos_W26                  578
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_huevos_W26                            636
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_cremas_W26                            623
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_quesos_W26                            654
# 20230701_CMX_jugueriacomidasaludable_piloto_NB_mantequillasymargarinas_W26           677
# dtype: int64
# Done CMX jugueriacomidasaludable_PILOTO
# //-------------------------------------------------------------------------------
# Juguería/Comida saludable Experimento50%
# 172
# Uso de data externa
# 20230701_CMX_jugueriacomidasaludable_control_NB_azucaryendulzantes_W26                 79
# 20230701_CMX_jugueriacomidasaludable_control_NB_aceitesygrasas_W26                    147
# 20230701_CMX_jugueriacomidasaludable_control_NB_cafechocolateeinfusiones_W26          158
# 20230701_CMX_jugueriacomidasaludable_control_NB_enlatados_W26                         145
# 20230701_CMX_jugueriacomidasaludable_control_NB_salsas_W26                            146
# 20230701_CMX_jugueriacomidasaludable_control_NB_arroz_W26                             155
# 20230701_CMX_jugueriacomidasaludable_control_NB_frutossecos_W26                       141
# 20230701_CMX_jugueriacomidasaludable_control_NB_panaderiaytortilleria_W26             163
# 20230701_CMX_jugueriacomidasaludable_control_NB_granos_W26                            154
# 20230701_CMX_jugueriacomidasaludable_control_NB_pasta_W26                             158
# 20230701_CMX_jugueriacomidasaludable_control_NB_salysazonadores_W26                   155
# 20230701_CMX_jugueriacomidasaludable_control_NB_chilessecos_W26                       157
# 20230701_CMX_jugueriacomidasaludable_control_NB_mermeladasyconfituras_W26             167
# 20230701_CMX_jugueriacomidasaludable_control_NB_papelytoallas_W26                     139
# 20230701_CMX_jugueriacomidasaludable_control_NB_detergentejabonylavatrastes_W26       149
# 20230701_CMX_jugueriacomidasaludable_control_NB_desinfectantesysanitizantes_W26       154
# 20230701_CMX_jugueriacomidasaludable_control_NB_implementosdeaseo_W26                 158
# 20230701_CMX_jugueriacomidasaludable_control_NB_refrescos_W26                         138
# 20230701_CMX_jugueriacomidasaludable_control_NB_jugos_W26                             170
# 20230701_CMX_jugueriacomidasaludable_control_NB_bebidasenergeticasehidratantes_W26    172
# 20230701_CMX_jugueriacomidasaludable_control_NB_pollo_W26                             162
# 20230701_CMX_jugueriacomidasaludable_control_NB_embutidos_W26                         161
# 20230701_CMX_jugueriacomidasaludable_control_NB_cerdo_W26                             170
# 20230701_CMX_jugueriacomidasaludable_control_NB_res_W26                               167
# 20230701_CMX_jugueriacomidasaludable_control_NB_alimentoscongelados_W26               164
# 20230701_CMX_jugueriacomidasaludable_control_NB_vasoscontenedoresyplatos_W26          109
# 20230701_CMX_jugueriacomidasaludable_control_NB_empaqueyenvoltura_W26                 167
# 20230701_CMX_jugueriacomidasaludable_control_NB_bolsas_W26                            167
# 20230701_CMX_jugueriacomidasaludable_control_NB_cubiertos_W26                         163
# 20230701_CMX_jugueriacomidasaludable_control_NB_verduras_W26                           97
# 20230701_CMX_jugueriacomidasaludable_control_NB_frutas_W26                            111
# 20230701_CMX_jugueriacomidasaludable_control_NB_tuberculos_W26                        144
# 20230701_CMX_jugueriacomidasaludable_control_NB_leches_W26                            138
# 20230701_CMX_jugueriacomidasaludable_control_NB_derivadoslacteos_W26                  135
# 20230701_CMX_jugueriacomidasaludable_control_NB_huevos_W26                            152
# 20230701_CMX_jugueriacomidasaludable_control_NB_cremas_W26                            152
# 20230701_CMX_jugueriacomidasaludable_control_NB_quesos_W26                            163
# 20230701_CMX_jugueriacomidasaludable_control_NB_mantequillasymargarinas_W26           168
# dtype: int64
# Done CMX jugueriacomidasaludable_CONTROL
# //-------------------------------------------------------------------------------
# Other
# 504
# Uso de data externa
# 20230701_CMX_other_piloto_NB_azucaryendulzantes_W26                300
# 20230701_CMX_other_piloto_NB_aceitesygrasas_W26                    364
# 20230701_CMX_other_piloto_NB_cafechocolateeinfusiones_W26          459
# 20230701_CMX_other_piloto_NB_enlatados_W26                         422
# 20230701_CMX_other_piloto_NB_salsas_W26                            415
# 20230701_CMX_other_piloto_NB_arroz_W26                             375
# 20230701_CMX_other_piloto_NB_frutossecos_W26                       375
# 20230701_CMX_other_piloto_NB_panaderiaytortilleria_W26             436
# 20230701_CMX_other_piloto_NB_granos_W26                            395
# 20230701_CMX_other_piloto_NB_pasta_W26                             426
# 20230701_CMX_other_piloto_NB_salysazonadores_W26                   400
# 20230701_CMX_other_piloto_NB_chilessecos_W26                       370
# 20230701_CMX_other_piloto_NB_mermeladasyconfituras_W26             497
# 20230701_CMX_other_piloto_NB_papelytoallas_W26                     405
# 20230701_CMX_other_piloto_NB_detergentejabonylavatrastes_W26       388
# 20230701_CMX_other_piloto_NB_desinfectantesysanitizantes_W26       423
# 20230701_CMX_other_piloto_NB_implementosdeaseo_W26                 452
# 20230701_CMX_other_piloto_NB_refrescos_W26                         372
# 20230701_CMX_other_piloto_NB_jugos_W26                             496
# 20230701_CMX_other_piloto_NB_bebidasenergeticasehidratantes_W26    502
# 20230701_CMX_other_piloto_NB_pollo_W26                             450
# 20230701_CMX_other_piloto_NB_embutidos_W26                         436
# 20230701_CMX_other_piloto_NB_cerdo_W26                             461
# 20230701_CMX_other_piloto_NB_res_W26                               439
# 20230701_CMX_other_piloto_NB_alimentoscongelados_W26               431
# 20230701_CMX_other_piloto_NB_vasoscontenedoresyplatos_W26          359
# 20230701_CMX_other_piloto_NB_empaqueyenvoltura_W26                 443
# 20230701_CMX_other_piloto_NB_bolsas_W26                            457
# 20230701_CMX_other_piloto_NB_cubiertos_W26                         445
# 20230701_CMX_other_piloto_NB_verduras_W26                          149
# 20230701_CMX_other_piloto_NB_frutas_W26                            195
# 20230701_CMX_other_piloto_NB_tuberculos_W26                        300
# 20230701_CMX_other_piloto_NB_leches_W26                            388
# 20230701_CMX_other_piloto_NB_derivadoslacteos_W26                  423
# 20230701_CMX_other_piloto_NB_huevos_W26                            389
# 20230701_CMX_other_piloto_NB_cremas_W26                            374
# 20230701_CMX_other_piloto_NB_quesos_W26                            419
# 20230701_CMX_other_piloto_NB_mantequillasymargarinas_W26           444
# dtype: int64
# Done CMX other_PILOTO
# //-------------------------------------------------------------------------------
# Other Experimento50%
# 125
# Uso de data externa
# 20230701_CMX_other_control_NB_azucaryendulzantes_W26                 80
# 20230701_CMX_other_control_NB_aceitesygrasas_W26                     96
# 20230701_CMX_other_control_NB_cafechocolateeinfusiones_W26          115
# 20230701_CMX_other_control_NB_enlatados_W26                         110
# 20230701_CMX_other_control_NB_salsas_W26                            109
# 20230701_CMX_other_control_NB_arroz_W26                              98
# 20230701_CMX_other_control_NB_frutossecos_W26                        92
# 20230701_CMX_other_control_NB_panaderiaytortilleria_W26             109
# 20230701_CMX_other_control_NB_granos_W26                            107
# 20230701_CMX_other_control_NB_pasta_W26                             104
# 20230701_CMX_other_control_NB_salysazonadores_W26                    93
# 20230701_CMX_other_control_NB_chilessecos_W26                        93
# 20230701_CMX_other_control_NB_mermeladasyconfituras_W26             122
# 20230701_CMX_other_control_NB_papelytoallas_W26                     103
# 20230701_CMX_other_control_NB_detergentejabonylavatrastes_W26        95
# 20230701_CMX_other_control_NB_desinfectantesysanitizantes_W26       103
# 20230701_CMX_other_control_NB_implementosdeaseo_W26                 113
# 20230701_CMX_other_control_NB_refrescos_W26                          93
# 20230701_CMX_other_control_NB_jugos_W26                             118
# 20230701_CMX_other_control_NB_bebidasenergeticasehidratantes_W26    124
# 20230701_CMX_other_control_NB_pollo_W26                             108
# 20230701_CMX_other_control_NB_embutidos_W26                         103
# 20230701_CMX_other_control_NB_cerdo_W26                             115
# 20230701_CMX_other_control_NB_res_W26                               109
# 20230701_CMX_other_control_NB_alimentoscongelados_W26               104
# 20230701_CMX_other_control_NB_vasoscontenedoresyplatos_W26           87
# 20230701_CMX_other_control_NB_empaqueyenvoltura_W26                 112
# 20230701_CMX_other_control_NB_bolsas_W26                            117
# 20230701_CMX_other_control_NB_cubiertos_W26                         106
# 20230701_CMX_other_control_NB_verduras_W26                           26
# 20230701_CMX_other_control_NB_frutas_W26                             40
# 20230701_CMX_other_control_NB_tuberculos_W26                         65
# 20230701_CMX_other_control_NB_leches_W26                             97
# 20230701_CMX_other_control_NB_derivadoslacteos_W26                  105
# 20230701_CMX_other_control_NB_huevos_W26                             99
# 20230701_CMX_other_control_NB_cremas_W26                             94
# 20230701_CMX_other_control_NB_quesos_W26                            101
# 20230701_CMX_other_control_NB_mantequillasymargarinas_W26           108
# dtype: int64
# Done CMX other_CONTROL
# //-------------------------------------------------------------------------------
# Panadería/Pastelería
# 840
# Uso de data externa
# 20230701_CMX_panaderiapasteleria_piloto_NB_azucaryendulzantes_W26                336
# 20230701_CMX_panaderiapasteleria_piloto_NB_aceitesygrasas_W26                    650
# 20230701_CMX_panaderiapasteleria_piloto_NB_cafechocolateeinfusiones_W26          780
# 20230701_CMX_panaderiapasteleria_piloto_NB_enlatados_W26                         774
# 20230701_CMX_panaderiapasteleria_piloto_NB_salsas_W26                            786
# 20230701_CMX_panaderiapasteleria_piloto_NB_arroz_W26                             776
# 20230701_CMX_panaderiapasteleria_piloto_NB_frutossecos_W26                       769
# 20230701_CMX_panaderiapasteleria_piloto_NB_panaderiaytortilleria_W26             813
# 20230701_CMX_panaderiapasteleria_piloto_NB_granos_W26                            814
# 20230701_CMX_panaderiapasteleria_piloto_NB_pasta_W26                             783
# 20230701_CMX_panaderiapasteleria_piloto_NB_salysazonadores_W26                   777
# 20230701_CMX_panaderiapasteleria_piloto_NB_chilessecos_W26                       805
# 20230701_CMX_panaderiapasteleria_piloto_NB_mermeladasyconfituras_W26             834
# 20230701_CMX_panaderiapasteleria_piloto_NB_papelytoallas_W26                     704
# 20230701_CMX_panaderiapasteleria_piloto_NB_detergentejabonylavatrastes_W26       690
# 20230701_CMX_panaderiapasteleria_piloto_NB_desinfectantesysanitizantes_W26       736
# 20230701_CMX_panaderiapasteleria_piloto_NB_implementosdeaseo_W26                 742
# 20230701_CMX_panaderiapasteleria_piloto_NB_refrescos_W26                         735
# 20230701_CMX_panaderiapasteleria_piloto_NB_jugos_W26                             827
# 20230701_CMX_panaderiapasteleria_piloto_NB_bebidasenergeticasehidratantes_W26    837
# 20230701_CMX_panaderiapasteleria_piloto_NB_pollo_W26                             806
# 20230701_CMX_panaderiapasteleria_piloto_NB_embutidos_W26                         811
# 20230701_CMX_panaderiapasteleria_piloto_NB_cerdo_W26                             819
# 20230701_CMX_panaderiapasteleria_piloto_NB_res_W26                               817
# 20230701_CMX_panaderiapasteleria_piloto_NB_alimentoscongelados_W26               810
# 20230701_CMX_panaderiapasteleria_piloto_NB_vasoscontenedoresyplatos_W26          728
# 20230701_CMX_panaderiapasteleria_piloto_NB_empaqueyenvoltura_W26                 820
# 20230701_CMX_panaderiapasteleria_piloto_NB_bolsas_W26                            827
# 20230701_CMX_panaderiapasteleria_piloto_NB_cubiertos_W26                         793
# 20230701_CMX_panaderiapasteleria_piloto_NB_verduras_W26                          552
# 20230701_CMX_panaderiapasteleria_piloto_NB_frutas_W26                            587
# 20230701_CMX_panaderiapasteleria_piloto_NB_tuberculos_W26                        758
# 20230701_CMX_panaderiapasteleria_piloto_NB_leches_W26                            627
# 20230701_CMX_panaderiapasteleria_piloto_NB_derivadoslacteos_W26                  701
# 20230701_CMX_panaderiapasteleria_piloto_NB_huevos_W26                            633
# 20230701_CMX_panaderiapasteleria_piloto_NB_cremas_W26                            771
# 20230701_CMX_panaderiapasteleria_piloto_NB_quesos_W26                            798
# 20230701_CMX_panaderiapasteleria_piloto_NB_mantequillasymargarinas_W26           792
# dtype: int64
# Done CMX panaderiapasteleria_PILOTO
# //-------------------------------------------------------------------------------
# Panadería/Pastelería Experimento50%
# 210
# Uso de data externa
# 20230701_CMX_panaderiapasteleria_control_NB_azucaryendulzantes_W26                 86
# 20230701_CMX_panaderiapasteleria_control_NB_aceitesygrasas_W26                    171
# 20230701_CMX_panaderiapasteleria_control_NB_cafechocolateeinfusiones_W26          196
# 20230701_CMX_panaderiapasteleria_control_NB_enlatados_W26                         193
# 20230701_CMX_panaderiapasteleria_control_NB_salsas_W26                            200
# 20230701_CMX_panaderiapasteleria_control_NB_arroz_W26                             191
# 20230701_CMX_panaderiapasteleria_control_NB_frutossecos_W26                       191
# 20230701_CMX_panaderiapasteleria_control_NB_panaderiaytortilleria_W26             205
# 20230701_CMX_panaderiapasteleria_control_NB_granos_W26                            200
# 20230701_CMX_panaderiapasteleria_control_NB_pasta_W26                             198
# 20230701_CMX_panaderiapasteleria_control_NB_salysazonadores_W26                   197
# 20230701_CMX_panaderiapasteleria_control_NB_chilessecos_W26                       200
# 20230701_CMX_panaderiapasteleria_control_NB_mermeladasyconfituras_W26             210
# 20230701_CMX_panaderiapasteleria_control_NB_papelytoallas_W26                     177
# 20230701_CMX_panaderiapasteleria_control_NB_detergentejabonylavatrastes_W26       173
# 20230701_CMX_panaderiapasteleria_control_NB_desinfectantesysanitizantes_W26       181
# 20230701_CMX_panaderiapasteleria_control_NB_implementosdeaseo_W26                 192
# 20230701_CMX_panaderiapasteleria_control_NB_refrescos_W26                         182
# 20230701_CMX_panaderiapasteleria_control_NB_jugos_W26                             210
# 20230701_CMX_panaderiapasteleria_control_NB_bebidasenergeticasehidratantes_W26    209
# 20230701_CMX_panaderiapasteleria_control_NB_pollo_W26                             199
# 20230701_CMX_panaderiapasteleria_control_NB_embutidos_W26                         201
# 20230701_CMX_panaderiapasteleria_control_NB_cerdo_W26                             199
# 20230701_CMX_panaderiapasteleria_control_NB_res_W26                               201
# 20230701_CMX_panaderiapasteleria_control_NB_alimentoscongelados_W26               204
# 20230701_CMX_panaderiapasteleria_control_NB_vasoscontenedoresyplatos_W26          183
# 20230701_CMX_panaderiapasteleria_control_NB_empaqueyenvoltura_W26                 205
# 20230701_CMX_panaderiapasteleria_control_NB_bolsas_W26                            202
# 20230701_CMX_panaderiapasteleria_control_NB_cubiertos_W26                         201
# 20230701_CMX_panaderiapasteleria_control_NB_verduras_W26                          142
# 20230701_CMX_panaderiapasteleria_control_NB_frutas_W26                            153
# 20230701_CMX_panaderiapasteleria_control_NB_tuberculos_W26                        183
# 20230701_CMX_panaderiapasteleria_control_NB_leches_W26                            162
# 20230701_CMX_panaderiapasteleria_control_NB_derivadoslacteos_W26                  177
# 20230701_CMX_panaderiapasteleria_control_NB_huevos_W26                            155
# 20230701_CMX_panaderiapasteleria_control_NB_cremas_W26                            191
# 20230701_CMX_panaderiapasteleria_control_NB_quesos_W26                            191
# 20230701_CMX_panaderiapasteleria_control_NB_mantequillasymargarinas_W26           198
# dtype: int64
# Done CMX panaderiapasteleria_CONTROL
# //-------------------------------------------------------------------------------
# Cafetería
# 356
# Uso de data externa
# 20230701_CMX_cafeteria_piloto_NB_azucaryendulzantes_W26             216
# 20230701_CMX_cafeteria_piloto_NB_aceitesygrasas_W26                 258
# 20230701_CMX_cafeteria_piloto_NB_cafechocolateeinfusiones_W26       303
# 20230701_CMX_cafeteria_piloto_NB_enlatados_W26                      273
# 20230701_CMX_cafeteria_piloto_NB_salsas_W26                         281
# 20230701_CMX_cafeteria_piloto_NB_arroz_W26                          307
# 20230701_CMX_cafeteria_piloto_NB_frutossecos_W26                    294
# 20230701_CMX_cafeteria_piloto_NB_panaderiaytortilleria_W26          311
# 20230701_CMX_cafeteria_piloto_NB_granos_W26                         316
# 20230701_CMX_cafeteria_piloto_NB_pasta_W26                          320
# 20230701_CMX_cafeteria_piloto_NB_salysazonadores_W26                313
# 20230701_CMX_cafeteria_piloto_NB_chilessecos_W26                    331
# 20230701_CMX_cafeteria_piloto_NB_mermeladasyconfituras_W26          346
# 20230701_CMX_cafeteria_piloto_NB_papelytoallas_W26                  271
# 20230701_CMX_cafeteria_piloto_NB_detergentejabonylavatrastes_W26    287
# 20230701_CMX_cafeteria_piloto_NB_desinfectantesysanitizantes_W26    285
# 20230701_CMX_cafeteria_piloto_NB_implementosdeaseo_W26              318
# 20230701_CMX_cafeteria_piloto_NB_refrescos_W26                      224
# 20230701_CMX_cafeteria_piloto_NB_jugos_W26                          350
# 20230701_CMX_cafeteria_piloto_NB_pollo_W26                          321
# 20230701_CMX_cafeteria_piloto_NB_embutidos_W26                      318
# 20230701_CMX_cafeteria_piloto_NB_cerdo_W26                          340
# 20230701_CMX_cafeteria_piloto_NB_res_W26                            326
# 20230701_CMX_cafeteria_piloto_NB_alimentoscongelados_W26            302
# 20230701_CMX_cafeteria_piloto_NB_vasoscontenedoresyplatos_W26       249
# 20230701_CMX_cafeteria_piloto_NB_empaqueyenvoltura_W26              333
# 20230701_CMX_cafeteria_piloto_NB_bolsas_W26                         330
# 20230701_CMX_cafeteria_piloto_NB_cubiertos_W26                      319
# 20230701_CMX_cafeteria_piloto_NB_verduras_W26                       165
# 20230701_CMX_cafeteria_piloto_NB_frutas_W26                         186
# 20230701_CMX_cafeteria_piloto_NB_tuberculos_W26                     267
# 20230701_CMX_cafeteria_piloto_NB_leches_W26                         252
# 20230701_CMX_cafeteria_piloto_NB_derivadoslacteos_W26               288
# 20230701_CMX_cafeteria_piloto_NB_huevos_W26                         286
# 20230701_CMX_cafeteria_piloto_NB_cremas_W26                         272
# 20230701_CMX_cafeteria_piloto_NB_quesos_W26                         306
# 20230701_CMX_cafeteria_piloto_NB_mantequillasymargarinas_W26        321
# dtype: int64
# Done CMX cafeteria_PILOTO
# //-------------------------------------------------------------------------------
# Cafetería Experimento50%
# 89
# Uso de data externa
# 20230701_CMX_cafeteria_control_NB_azucaryendulzantes_W26             52
# 20230701_CMX_cafeteria_control_NB_aceitesygrasas_W26                 67
# 20230701_CMX_cafeteria_control_NB_cafechocolateeinfusiones_W26       74
# 20230701_CMX_cafeteria_control_NB_enlatados_W26                      70
# 20230701_CMX_cafeteria_control_NB_salsas_W26                         71
# 20230701_CMX_cafeteria_control_NB_arroz_W26                          76
# 20230701_CMX_cafeteria_control_NB_frutossecos_W26                    66
# 20230701_CMX_cafeteria_control_NB_panaderiaytortilleria_W26          78
# 20230701_CMX_cafeteria_control_NB_granos_W26                         75
# 20230701_CMX_cafeteria_control_NB_pasta_W26                          77
# 20230701_CMX_cafeteria_control_NB_salysazonadores_W26                74
# 20230701_CMX_cafeteria_control_NB_chilessecos_W26                    82
# 20230701_CMX_cafeteria_control_NB_mermeladasyconfituras_W26          86
# 20230701_CMX_cafeteria_control_NB_papelytoallas_W26                  68
# 20230701_CMX_cafeteria_control_NB_detergentejabonylavatrastes_W26    63
# 20230701_CMX_cafeteria_control_NB_desinfectantesysanitizantes_W26    72
# 20230701_CMX_cafeteria_control_NB_implementosdeaseo_W26              78
# 20230701_CMX_cafeteria_control_NB_refrescos_W26                      61
# 20230701_CMX_cafeteria_control_NB_jugos_W26                          84
# 20230701_CMX_cafeteria_control_NB_pollo_W26                          78
# 20230701_CMX_cafeteria_control_NB_embutidos_W26                      76
# 20230701_CMX_cafeteria_control_NB_cerdo_W26                          85
# 20230701_CMX_cafeteria_control_NB_res_W26                            86
# 20230701_CMX_cafeteria_control_NB_alimentoscongelados_W26            72
# 20230701_CMX_cafeteria_control_NB_vasoscontenedoresyplatos_W26       57
# 20230701_CMX_cafeteria_control_NB_empaqueyenvoltura_W26              81
# 20230701_CMX_cafeteria_control_NB_bolsas_W26                         81
# 20230701_CMX_cafeteria_control_NB_cubiertos_W26                      74
# 20230701_CMX_cafeteria_control_NB_verduras_W26                       35
# 20230701_CMX_cafeteria_control_NB_frutas_W26                         47
# 20230701_CMX_cafeteria_control_NB_tuberculos_W26                     60
# 20230701_CMX_cafeteria_control_NB_leches_W26                         57
# 20230701_CMX_cafeteria_control_NB_derivadoslacteos_W26               69
# 20230701_CMX_cafeteria_control_NB_huevos_W26                         73
# 20230701_CMX_cafeteria_control_NB_cremas_W26                         70
# 20230701_CMX_cafeteria_control_NB_quesos_W26                         74
# 20230701_CMX_cafeteria_control_NB_mantequillasymargarinas_W26        77
# dtype: int64
# Done CMX cafeteria_CONTROL

# %% [markdown]
# ## Aca creo el archivo para R&D

# %%
# customers =  pd.DataFrame()
# for column,i in enumerate(aux_df.columns):
#     #if ('verduras' in i or 'frutas' in i or 'arroz' in i or 'aceitesygrasas' in i or 'harinasymezclas' in i or 'azucaryendulzantes' in i or 'pollo' in i or 'huevos' in i) and not 'frutasjugo' in i:
#     #if ('verduras' in i or 'frutas' in i) and not 'frutasjugo' in i:
#     customers[i] = aux_df[i]

# %%
# customers.iloc[:6000].to_csv(f'SD/export_data/MS/csv_{city_code}_CLIENTS_PRUEBA_R&D.csv', index = False)

# with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
#        json.dump(global_segment_list, outfile)

# %%
# aux_seg = pd.read_csv(f"prueba_tuberculos_BAQ.csv")
# aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

# aux_seg["final_group2"] = ["piloto" if x == "Super Descuentos" else "control" for x in aux_seg.grupos]
# aux_seg['offer_name'] = f"20230301_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W9"

# aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()

# %%
# lst = []
# for x in aux_seg2.values:
#     h = {'name':x[0], 'customersIds': list(x[1])}
#     lst.append(h)
    
# for x in lst:
#     print(x['name'])
#     #break
#     for i,value in enumerate(global_segment_list):
#         if value['name'] == x['name']:
#             global_segment_list[i]['customersIds'] = x['customersIds']
#             print(i)

# %%
aux_seg = pd.read_csv(f"csv_{city_code}_CLIENTS_FINAL_JULIO_R&D.csv")
aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

aux_seg["final_group2"] = ["piloto" if x == "Treatment" else "control" for x in aux_seg.final_group]
aux_seg['offer_name'] = f"20230701_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W26"

aux_seg["quartile"] = ["Q0" if x == "-" else x for x in aux_seg.quartile.values]
aux_seg["quartile_name"] = f"20230701_{city_code}_" + aux_seg.subcategory + "_" + aux_seg.quartile + "_" + aux_seg.case

aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()
aux_seg3 = aux_seg.groupby(by = ["quartile_name"])["customer_source_id"].apply(list).reset_index()

# %%
aux_seg.head()
# Out:
#       subcategory  customer_source_id        ms previous_group        case  \
# 0  aceitesygrasas            52893280     fonda      Treatment  positivity
# 1  aceitesygrasas           128046186     fonda      Treatment  positivity
# 2  aceitesygrasas            48012548     fonda      Treatment  positivity
# 3  aceitesygrasas           265256434  taqueria        Control  positivity
# 4  aceitesygrasas             -262424     fonda      Treatment  positivity
#
#   quartile  random final_group final_group2  \
# 0       Q4       1     Control      control
# 1       Q4       0   Treatment       piloto
# 2       Q4       0   Treatment       piloto
# 3       Q4       0   Treatment       piloto
# 4       Q4       0   Treatment       piloto
#
#                                           offer_name  \
# 0   20230701_CMX_fonda_control_NB_aceitesygrasas_W26
# 1    20230701_CMX_fonda_piloto_NB_aceitesygrasas_W26
# 2    20230701_CMX_fonda_piloto_NB_aceitesygrasas_W26
# 3  20230701_CMX_taqueria_piloto_NB_aceitesygrasas...
# 4    20230701_CMX_fonda_piloto_NB_aceitesygrasas_W26
#
#                                quartile_name
# 0  20230701_CMX_aceitesygrasas_Q4_positivity
# 1  20230701_CMX_aceitesygrasas_Q4_positivity
# 2  20230701_CMX_aceitesygrasas_Q4_positivity
# 3  20230701_CMX_aceitesygrasas_Q4_positivity
# 4  20230701_CMX_aceitesygrasas_Q4_positivity

# %%
lst = []
for x in aux_seg2.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst.append(h)

global_segment_list = lst

# %%
lst2 = []
for x in aux_seg3.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst2.append(h)

# %% [markdown]
# # Aca tengo que volver a cargar el archivo de arriba y dejarlo como lista para traer lo otro

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_CMX_comidaespecializada_piloto_NB_azu...
# 1  20230701_CMX_comidaespecializada_piloto_NB_ace...
# 2  20230701_CMX_comidaespecializada_piloto_NB_caf...
# 3  20230701_CMX_comidaespecializada_piloto_NB_enl...
# 4  20230701_CMX_comidaespecializada_piloto_NB_sal...
#
#                                    offer_description  discount  \
# 0   comidaespecializada_piloto_NB_azucaryendulzantes         4
# 1       comidaespecializada_piloto_NB_aceitesygrasas         6
# 2  comidaespecializada_piloto_NB_cafechocolateein...         8
# 3            comidaespecializada_piloto_NB_enlatados         9
# 4               comidaespecializada_piloto_NB_salsas         7
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                  15
# 1                         true  01-07-2023  31-07-2023                  20
# 2                         true  01-07-2023  31-07-2023                   0
# 3                         true  01-07-2023  31-07-2023                   0
# 4                         true  01-07-2023  31-07-2023                  15
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1                None
# 1                      1                None
# 2                      1                None
# 3                      1                None
# 4                      1                None
#
#                                               sku_id
# 0                                66553#101175#101151
# 1   101239#368168#-303954#117707#117709#622099#54288
# 2                         26031#464689#377839#628110
# 3  359346#134385#359344#359342#359348#359500#3594...
# 4                    92952#56316#37434#342267#440573

# %%
#len_seg =int(len(global_segment_list)/10)
#len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %% [markdown]
# ## Crear segments offers y segments types

# %%
import requests
import json

def create_segments(segment_list):
    
    url = f"https://{city_code}.frubana.com/api/v1/segments/create?api-key=00_growth-team-zzz-qqq_001"

    payload = json.dumps(segment_list)


    headers = {
    'Cookie': 'AWSALB=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALBCORS=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALB=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI; AWSALBCORS=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI',
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.status_code)
    sgt = [(int(x[:6]),x[7:]) for x in list(map(str.strip, response.text[32:].strip('][').replace('"', '').split(',')))]
    time.sleep(40)
    return sgt

# %%
len_seg =int(len(global_segment_list)/10)
len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %%
#offers
sgt=[]

for i in len_seg_list:
    sgt.append(create_segments(i))
    
sgt_end =[item for lista in sgt for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len_seg2 =int(len(lst2)/10)
len_seg_list2 = [lst2[:len_seg2],lst2[len_seg2:len_seg2*2],lst2[len_seg2*2:len_seg2*3],lst2[len_seg2*3:len_seg2*4],lst2[len_seg2*4:len_seg2*5],lst2[len_seg2*5:len_seg2*6],lst2[len_seg2*6:len_seg2*7],lst2[len_seg2*7:len_seg2*8],lst2[len_seg2*8:len_seg2*9],lst2[len_seg2*9:]]

# %%
#types
sgt2=[]

for i in len_seg_list2:
    sgt2.append(create_segments(i))
    
sgt_end2 =[item for lista in sgt2 for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#unir offers con segments
for i in global_offer_csv.offer_name:
    for j,z in sgt_end:
        if z==i:
            global_offer_csv.loc[global_offer_csv.offer_name == i, ('customer_segment_id')] = j

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_CMX_comidaespecializada_piloto_NB_azu...
# 1  20230701_CMX_comidaespecializada_piloto_NB_ace...
# 2  20230701_CMX_comidaespecializada_piloto_NB_caf...
# 3  20230701_CMX_comidaespecializada_piloto_NB_enl...
# 4  20230701_CMX_comidaespecializada_piloto_NB_sal...
#
#                                    offer_description  discount  \
# 0   comidaespecializada_piloto_NB_azucaryendulzantes         4
# 1       comidaespecializada_piloto_NB_aceitesygrasas         6
# 2  comidaespecializada_piloto_NB_cafechocolateein...         8
# 3            comidaespecializada_piloto_NB_enlatados         9
# 4               comidaespecializada_piloto_NB_salsas         7
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                  15
# 1                         true  01-07-2023  31-07-2023                  20
# 2                         true  01-07-2023  31-07-2023                   0
# 3                         true  01-07-2023  31-07-2023                   0
# 4                         true  01-07-2023  31-07-2023                  15
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              181756
# 1                      1              181753
# 2                      1              181759
# 3                      1              181440
# 4                      1              182057
#
#                                               sku_id
# 0                                66553#101175#101151
# 1   101239#368168#-303954#117707#117709#622099#54288
# 2                         26031#464689#377839#628110
# 3  359346#134385#359344#359342#359348#359500#3594...
# 4                    92952#56316#37434#342267#440573

# %%
global_offer_csv = global_offer_csv.loc[~global_offer_csv.customer_segment_id.isnull()].reset_index(drop=True)
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('discount','max_uses_per_order')]=1
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('start_date','end_date')]='01-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('end_date')]='02-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('sku_id')]= global_offer_csv.loc[~global_offer_csv['offer_name'].str.contains("piloto", case=False), ('sku_id')].tolist()

# %%
len_offer =int(len(global_offer_csv)/4)
len_offer = [global_offer_csv[:len_seg],global_offer_csv[len_seg:len_seg*2],global_offer_csv[len_seg*2:len_seg*3],global_offer_csv[len_seg*3:]]

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_CMX_comidaespecializada_piloto_NB_azu...
# 1  20230701_CMX_comidaespecializada_piloto_NB_ace...
# 2  20230701_CMX_comidaespecializada_piloto_NB_caf...
# 3  20230701_CMX_comidaespecializada_piloto_NB_enl...
# 4  20230701_CMX_comidaespecializada_piloto_NB_sal...
#
#                                    offer_description  discount  \
# 0   comidaespecializada_piloto_NB_azucaryendulzantes         4
# 1       comidaespecializada_piloto_NB_aceitesygrasas         6
# 2  comidaespecializada_piloto_NB_cafechocolateein...         8
# 3            comidaespecializada_piloto_NB_enlatados         9
# 4               comidaespecializada_piloto_NB_salsas         7
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                  15
# 1                         true  01-07-2023  31-07-2023                  20
# 2                         true  01-07-2023  31-07-2023                   0
# 3                         true  01-07-2023  31-07-2023                   0
# 4                         true  01-07-2023  31-07-2023                  15
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              181756
# 1                      1              181753
# 2                      1              181759
# 3                      1              181440
# 4                      1              182057
#
#                                               sku_id
# 0                                66553#101175#101151
# 1   101239#368168#-303954#117707#117709#622099#54288
# 2                         26031#464689#377839#628110
# 3  359346#134385#359344#359342#359348#359500#3594...
# 4                    92952#56316#37434#342267#440573

# %%
#//--------------------------------------------
#//Exporting single file data
global_offer_csv.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS.csv', index = False)

for i,offer in enumerate(len_offer):
    offer.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS_{i}.csv', index = False)

with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
        json.dump(global_segment_list, outfile)    
with open(f'SD/export_data/MS/nb_{city_code}_All_MS.json', 'w') as outfile:
        json.dump(global_segment_list, outfile)
print(f'Done {city_code}')
# Out:
# Done CMX
