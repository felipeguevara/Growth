# %%
#//----------------------------
#//LIBRARIES
    #Math
import math
    #Numeric Python
import numpy as np
    #Pandas (dataframes)
import pandas as pd
    #datetime for fate manipulation
from datetime import date, datetime, timedelta  
    #Regex for advanced string matching
import re
    #for time related stuff
import time
    #json library
import json
    #Analyst tools
import sys
sys.path.append('../')
from analysts_tools.growth import *
    #Procurement tools
from analysts_tools.redash_methods import *
    #Frubana libraries
from procurement_lib import redash, dw, send_message, send_slack_notification, GoogleSheet, logging

# %%
query="""
With microsegment as (

SELECT DISTINCT c.customer_id AS user_id,
                c.site_type AS region_code_ms,
                
                (case 
                    -- Colombia
                    when m.microsegment_id not in (1,3,4,28,5,6,7,8,2) and c.site_type = 'BOG' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1,3,4,28,5,11,10,9,2,12) and c.site_type = 'BAQ' then 'Sin Microsegmento'
                    when m.microsegment_id not in (3,4,28,1,24,11,5,2,27) and c.site_type = 'MDE' then 'Sin Microsegmento'
    
                    -- Mexico
                    when m.microsegment_id not in (1,13,14,30,15,16,29,17,6,7,2) and c.site_type = 'CMX' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1, 13,14,30, 15,16,29, 6, 33, 2, 31) and c.site_type = 'GDL' then 'Sin Microsegmento'
                    when m.microsegment_id not in (13,14,30, 15,16,29, 32,2,6,33) and c.site_type = 'PBC' then 'Sin Microsegmento'
                    
                    -- Brasil
                    when m.microsegment_id not in (21,34,38,37,35,36,39,26) and c.site_type in ('SPO','BHZ','CWB','VCP') then 'Sin Microsegmento'
                        
                else m.description end) as microsegment_ok,
                
                m.microsegment_id,
                mo.name as ms_method
                
                
FROM postgres_main_federate."growth_microsegmentation.customer_microsegment" AS cm
INNER JOIN postgres_main_federate."growth_microsegmentation.microsegment" m ON cm.microsegment_id = m.id
INNER JOIN postgres_main_federate."growth_microsegmentation.customer" c ON cm.customer_id = c.id
INNER JOIN postgres_main_federate."growth_microsegmentation.models" mo ON mo.id = cm.model_type_id


)

select m.user_id,
m.region_code_ms,
--m.microsegment_id,

(case 
        when m.microsegment_ok in ('Corrientazo c/desayuno','Corrientazo s/desayuno','Tienda/Restaurante') then 'Corrientazo' 
        when m.microsegment_ok in ('Fonda c/desayuno','Fonda s/desayuno') then 'Fonda'
        when m.microsegment_ok in ('Taquería en calle','Taquería en local') then 'Taquería'

else m.microsegment_ok end) as microsegment,

m.ms_method

from microsegment m
where m.microsegment_ok != 'Sin Microsegmento'
"""

segmentos_fulll = read_connection_data_warehouse.runQuery(query)

segmentos_fulll.columns = ['customer_id', 'city', 'microsegment','NA']
segmentos_fulll = segmentos_fulll[['customer_id', 'city', 'microsegment']]

# %%
#//---------------------------------------------------------------------------------------------------------------------------
#// Parametros
"""Todays date should be the first day of the next month which is going to begin with SD"""

city_code = 'MDE'

# Set today's date to the first day of the next month
today = datetime.today()
first_day_next_month = (today.replace(day=1) + timedelta(days=32)).replace(day=1)

# Calculate non_buyers_date (todays date - 1 month)
non_buyers_date = (first_day_next_month - timedelta(days=1)).replace(day=1)
customer_date_desde = (first_day_next_month - timedelta(days=1)).replace(day=1)

# Calculate sku_date_desde (todays date - 2 months)
sku_date_desde = (first_day_next_month - timedelta(days=60)).replace(day=1)

# Convert the dates to strings in the desired format
todays_date = first_day_next_month.strftime('%Y-%m-%d')
non_buyers_date = non_buyers_date.strftime('%Y-%m-%d')
customer_date_desde = customer_date_desde.strftime('%Y-%m-%d')
sku_date_desde = sku_date_desde.strftime('%Y-%m-%d')

print(todays_date) # Output: e.g. 2023-04-01
print(non_buyers_date) # Output: e.g. 2023-03-01
print(sku_date_desde) # Output: e.g. 2023-02-01

tasas = {'BOG': 3776,
         'BAQ': 3776,
         'MDE': 3776,
         'CMX': 19.65,
         'GDL': 19.65,
         'PBC': 19.65,
         'SPO': 4.75,
         'BHZ': 4.75,
         'CWB': 4.75,
         'VCP': 4.75}

t_cambio = tasas[city_code]
# Out:
# 2023-06-01
# 2023-05-01
# 2023-04-01

# %% [markdown]
# ### Loading COSTUMERS INFO

# %%
users_eliminar_kam = get_fresh_query_result("https://internal-redash.federate.frubana.com/",150812,'SeoGHWmDUaaBi7VXje1s9zYNiMD1VHQ1K1DYOxiF',{},20)
users_eliminar = users_eliminar_kam.loc[users_eliminar_kam.registered_city == city_code]['customer_id'].unique().tolist()
# Out:
# 200

# %% [markdown]
# ### Loading FORCED_SKUS // Cleaning SEGMENT_NAMES

# %% [markdown]
# ### Loading DATA_VENTAS // Removing SKUs /\ CUSTOMERS_ID

# %%
#//Remove skus 
#It is used because some SKUs can get in trouble with supplier for the SD or to exclude them for another activity   
skus_remove = GoogleSheet("1Z0T_c36oRHmOHIgEG8_ANcwFykaHgXGAizYAYCKCqtY")
skus_remove = skus_remove.get_as_dataframe('SKUS')

skus_remove = skus_remove['sku_id'].unique().astype(int).tolist()

# %%
query = """
SELECT DISTINCT
    split_part(bs.upc, '-', 1) as region,
    bs.sku_id

FROM postgres_broadleaf_federate."broadleaf.blc_sku"            bs 
LEFT JOIN postgres_broadleaf_federate."broadleaf.blc_product"   bp ON bp.product_id = bs.addl_product_id

WHERE bs.archived = 'N'
    AND bs.sndbx_id is NULL
    AND bp.archived = 'N'
    AND bs.catalog_disc < 0
    AND ((bp.archived = 'N' AND bp.sndbx_id is NULL) OR (bp.archived is NULL))
"""
frida_products = read_connection_data_warehouse.runQuery(query)

# %%
good_skus = frida_products.sku_id.unique()

# %%
#Loading SELL'S DATA from a function
data_ventas = data_ventas_query(ciudad=city_code, tipo_cambio=t_cambio, desde=customer_date_desde, hasta = todays_date, tipo_negocio=1)

# %%
data_ventas = data_ventas[(~data_ventas['sku_id'].isin(skus_remove)) & (data_ventas['sku_id'].isin(good_skus))]

# %%
segmentos_full = segmentos_fulll[segmentos_fulll.city == city_code].copy()

# %%
#//customers for offers */(has further uses)*/
microsegmentacion_df = segmentos_full[(~segmentos_full['customer_id'].isin(users_eliminar))]
data_ventas = data_ventas[(~data_ventas['customer_id'].isin(users_eliminar))]

# %% [markdown]
# ### Create the MS "Other" for BAU

# %%
data_full = data_ventas.merge(microsegmentacion_df[['customer_id','microsegment']], how = 'left', on = 'customer_id')

# %%
data_full['microsegment'] = data_full['microsegment'].fillna('Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                      microsegment  customer_id
# 0            Comida especializada          147
# 1                   Comida rápida          356
# 2                     Corrientazo         1081
# 3     Frutería/Juguería/Heladería          111
# 4                           Other          183
# 5  Panadería/Pastelería/Cafetería         1567
# 6                Parrilla/Asadero          295
# 7           Pizza/Comida Italiana           40

# %%
segments_validation = data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()

# %%
for ms in segments_validation[segments_validation.customer_id < 180]['microsegment'].unique():
    data_full['microsegment'] = data_full['microsegment'].str.replace(ms,'Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                      microsegment  customer_id
# 0                   Comida rápida          356
# 1                     Corrientazo         1081
# 2                           Other          481
# 3  Panadería/Pastelería/Cafetería         1567
# 4                Parrilla/Asadero          295

# %%
#Get the same variable to do the process job
data_ventas = data_full

# %% [markdown]
# ### PARAMETERS // SOME FUNCTIONS - GET READY TO PROCESSING

# %%
def ms_data(city_code):
  
    paramss_csv=GoogleSheet("1k0ckgkLddxc5lY8NUVGCkvDLTuulLaJm-N535oMNZNw")
    city_paramss = paramss_csv.get_as_dataframe(city_code)
    
    parametros = {}
    parametros[city_code] = {}
    
    for i,ms in enumerate(city_paramss.iloc[:,4:].columns):
        parametros[city_code][ms] = [(value[1],value[2],value[3],value[4+i]) for value in city_paramss.values if value[4+i]>0]
        
    return parametros

# %%
parametros = ms_data(city_code)

# %%
def normalize_text(raw_text):
    """
    Removes common accent characters and normalize text.
    """
    raw_text = raw_text.replace(" ", "")
    raw_text = raw_text.replace("�", "")
    raw_text = raw_text.replace("/", "")
    raw_text = re.sub(r'\s*', '', raw_text)
    raw_text = re.sub(r"[àáâãäå]", 'a', raw_text)
    raw_text = re.sub(r"[èéêë]", 'e', raw_text)
    raw_text = re.sub(r"[ìíîï]", 'i', raw_text) 
    raw_text = re.sub(r"[òóôõö]", 'o', raw_text)
    raw_text = re.sub(r"[ùúûü]", 'u', raw_text)
    raw_text = re.sub(r"[ýÿ]", 'y', raw_text)
    raw_text = re.sub(r"[ß]", 'ss', raw_text)
    raw_text = re.sub(r"[ñ]", 'n', raw_text)
    raw_text = re.sub(r"[ç]", 'c', raw_text)
    raw_text = raw_text.lower()
    return raw_text

# %%
#Sacar de aca los microsegmentos
msg = data_full.microsegment.unique()
msg
# Out:
# array(['Other', 'Panadería/Pastelería/Cafetería', 'Corrientazo',
#        'Parrilla/Asadero', 'Comida rápida'], dtype=object)

# %% [markdown]
# ### END

# %% [markdown]
# # Aca Empieza la Experimentacion

# %%
from sklearn.model_selection import train_test_split

# %%
#//Variables to store all the segments and offers of the city
global_offer_csv = pd.DataFrame()
global_segment_list = [] #//for procesing

# %%
#//----------------------------------------------------------------------------
#//Big loop for creating each city segments/offers files
aux_df = pd.DataFrame()
aux_df['aux']=6000*[0]

for microsegment in msg:
    print('//-------------------------------------------------------------------------------')
    print(microsegment)

    #//Customers per microsegment
    customers_ms = data_ventas[(data_ventas['microsegment'] == microsegment)]['customer_id'].unique()
    #//Customers to give them the skus
    customers_for_skus_ms =  data_ventas[['microsegment','customer_id']][(data_ventas.microsegment == microsegment) & (~data_ventas.customer_id.isin(users_eliminar))]['customer_id'].unique()
    
    #----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_PILOTO" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    rand=1
    customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state=rand)
    
    while abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())) > 0.05:
        #print(data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean(),data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean(),abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())))
        rand+=1
        customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state = rand)
        
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_1)].copy() #le quite la s!!
    
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()
    
    subcats = list(map(lambda x: x[0], parametros[city_code][microsegment]))
    max_uses = list(map(lambda x: int(x[1]), parametros[city_code][microsegment]))
    max_order = list(map(lambda x: int(x[2]), parametros[city_code][microsegment]))
    discount = list(map(lambda x: int(x[3]), parametros[city_code][microsegment]))

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    a, b, c = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
            non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                        limite=0.75, data_ventas_skus = data_skus)

    print(b.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(a)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in b.columns:
        id_list = b[seg].dropna().astype(int)
        d = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)

        lst.append(d)
        
    #//appending to global list    
        global_segment_list.append(d)
    
    print(f'Done {city_code} {ms_name}')

#----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------


#----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_CONTROL" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_2)].copy() #le quite la s!!
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    print('//-------------------------------------------------------------------------------')
    print(f'{microsegment} Experimento50%')
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    e, f, g = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
                non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                          limite=0.75, data_ventas_skus = data_skus)
      
    print(f.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(e)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in f.columns:
        id_list = f[seg].dropna().astype(int)
        h = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)
        
        lst.append(h)
        
        
    #//appending to global list    
        global_segment_list.append(h)
    
    print(f'Done {city_code} {ms_name}')
    #----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#//End of big loop and start of data bundle
# Out:
# //-------------------------------------------------------------------------------
# Other
# 385
# Uso de data externa
# 20230601_MDE_other_piloto_NB_aceitesygrasas_W22                 164
# 20230601_MDE_other_piloto_NB_arroz_W22                          278
# 20230601_MDE_other_piloto_NB_azucaryendulzantes_W22             204
# 20230601_MDE_other_piloto_NB_cafechocolateeinfusiones_W22       341
# 20230601_MDE_other_piloto_NB_granos_W22                         321
# 20230601_MDE_other_piloto_NB_harinasymezclas_W22                350
# 20230601_MDE_other_piloto_NB_pasta_W22                          372
# 20230601_MDE_other_piloto_NB_salsas_W22                         328
# 20230601_MDE_other_piloto_NB_desinfectantesysanitizantes_W22    313
# 20230601_MDE_other_piloto_NB_detergentejabonylavalozas_W22      249
# 20230601_MDE_other_piloto_NB_papelytoallas_W22                  267
# 20230601_MDE_other_piloto_NB_aguas_W22                          344
# 20230601_MDE_other_piloto_NB_cervezasylicores_W22               353
# 20230601_MDE_other_piloto_NB_gaseosas_W22                       281
# 20230601_MDE_other_piloto_NB_jugos_W22                          348
# 20230601_MDE_other_piloto_NB_bolsas_W22                         313
# 20230601_MDE_other_piloto_NB_contenedores_W22                   319
# 20230601_MDE_other_piloto_NB_cubiertosypitillos_W22             327
# 20230601_MDE_other_piloto_NB_empaqueyenvoltura_W22              370
# 20230601_MDE_other_piloto_NB_platosybandejas_W22                379
# 20230601_MDE_other_piloto_NB_vasos_W22                          310
# 20230601_MDE_other_piloto_NB_frutas_W22                         242
# 20230601_MDE_other_piloto_NB_tuberculos_W22                     226
# 20230601_MDE_other_piloto_NB_verduras_W22                       201
# 20230601_MDE_other_piloto_NB_cremas_W22                         336
# 20230601_MDE_other_piloto_NB_huevos_W22                         304
# 20230601_MDE_other_piloto_NB_leches_W22                         305
# dtype: int64
# Done MDE other_PILOTO
# //-------------------------------------------------------------------------------
# Other Experimento50%
# 96
# Uso de data externa
# 20230601_MDE_other_control_NB_aceitesygrasas_W22                 45
# 20230601_MDE_other_control_NB_arroz_W22                          74
# 20230601_MDE_other_control_NB_azucaryendulzantes_W22             50
# 20230601_MDE_other_control_NB_cafechocolateeinfusiones_W22       89
# 20230601_MDE_other_control_NB_granos_W22                         86
# 20230601_MDE_other_control_NB_harinasymezclas_W22                85
# 20230601_MDE_other_control_NB_pasta_W22                          90
# 20230601_MDE_other_control_NB_salsas_W22                         82
# 20230601_MDE_other_control_NB_desinfectantesysanitizantes_W22    85
# 20230601_MDE_other_control_NB_detergentejabonylavalozas_W22      68
# 20230601_MDE_other_control_NB_papelytoallas_W22                  72
# 20230601_MDE_other_control_NB_aguas_W22                          85
# 20230601_MDE_other_control_NB_cervezasylicores_W22               88
# 20230601_MDE_other_control_NB_gaseosas_W22                       77
# 20230601_MDE_other_control_NB_jugos_W22                          92
# 20230601_MDE_other_control_NB_bolsas_W22                         81
# 20230601_MDE_other_control_NB_contenedores_W22                   74
# 20230601_MDE_other_control_NB_cubiertosypitillos_W22             83
# 20230601_MDE_other_control_NB_empaqueyenvoltura_W22              96
# 20230601_MDE_other_control_NB_platosybandejas_W22                94
# 20230601_MDE_other_control_NB_vasos_W22                          82
# 20230601_MDE_other_control_NB_frutas_W22                         57
# 20230601_MDE_other_control_NB_tuberculos_W22                     59
# 20230601_MDE_other_control_NB_verduras_W22                       50
# 20230601_MDE_other_control_NB_cremas_W22                         83
# 20230601_MDE_other_control_NB_huevos_W22                         68
# 20230601_MDE_other_control_NB_leches_W22                         77
# dtype: int64
# Done MDE other_CONTROL
# //-------------------------------------------------------------------------------
# Panadería/Pastelería/Cafetería
# 1254
# Uso de data externa
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_aceitesygrasas_W22                  561
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_arroz_W22                          1015
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_azucaryendulzantes_W22              521
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_cafechocolateeinfusiones_W22       1031
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_granos_W22                         1120
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_harinasymezclas_W22                1138
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_panaderiayreposteria_W22           1246
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_salsas_W22                         1124
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_desinfectantesysanitizantes_W22    1083
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_detergentejabonylavalozas_W22       824
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_papelytoallas_W22                   821
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_aguas_W22                          1101
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_gaseosas_W22                        950
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_jugos_W22                          1068
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_bolsas_W22                          996
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_platosybandejas_W22                1228
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_vasos_W22                           973
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_frutas_W22                          888
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_tuberculos_W22                      843
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_verduras_W22                        772
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_cremas_W22                         1154
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_huevos_W22                         1031
# 20230601_MDE_panaderiapasteleriacafeteria_piloto_NB_leches_W22                         1012
# dtype: int64
# Done MDE panaderiapasteleriacafeteria_PILOTO
# //-------------------------------------------------------------------------------
# Panadería/Pastelería/Cafetería Experimento50%
# 313
# Uso de data externa
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_aceitesygrasas_W22                 133
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_arroz_W22                          251
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_azucaryendulzantes_W22             122
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_cafechocolateeinfusiones_W22       248
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_granos_W22                         272
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_harinasymezclas_W22                287
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_panaderiayreposteria_W22           310
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_salsas_W22                         271
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_desinfectantesysanitizantes_W22    267
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_detergentejabonylavalozas_W22      195
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_papelytoallas_W22                  219
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_aguas_W22                          265
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_gaseosas_W22                       233
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_jugos_W22                          268
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_bolsas_W22                         237
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_platosybandejas_W22                308
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_vasos_W22                          245
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_frutas_W22                         228
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_tuberculos_W22                     198
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_verduras_W22                       178
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_cremas_W22                         291
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_huevos_W22                         267
# 20230601_MDE_panaderiapasteleriacafeteria_control_NB_leches_W22                         251
# dtype: int64
# Done MDE panaderiapasteleriacafeteria_CONTROL
# //-------------------------------------------------------------------------------
# Corrientazo
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)
# 865
# Uso de data externa
# 20230601_MDE_corrientazo_piloto_NB_aceitesygrasas_W22                 313
# 20230601_MDE_corrientazo_piloto_NB_arroz_W22                          564
# 20230601_MDE_corrientazo_piloto_NB_azucaryendulzantes_W22             547
# 20230601_MDE_corrientazo_piloto_NB_cafechocolateeinfusiones_W22       768
# 20230601_MDE_corrientazo_piloto_NB_granos_W22                         661
# 20230601_MDE_corrientazo_piloto_NB_pasta_W22                          816
# 20230601_MDE_corrientazo_piloto_NB_salsas_W22                         688
# 20230601_MDE_corrientazo_piloto_NB_desinfectantesysanitizantes_W22    722
# 20230601_MDE_corrientazo_piloto_NB_detergentejabonylavalozas_W22      469
# 20230601_MDE_corrientazo_piloto_NB_papelytoallas_W22                  609
# 20230601_MDE_corrientazo_piloto_NB_aguas_W22                          757
# 20230601_MDE_corrientazo_piloto_NB_cervezasylicores_W22               795
# 20230601_MDE_corrientazo_piloto_NB_gaseosas_W22                       654
# 20230601_MDE_corrientazo_piloto_NB_jugos_W22                          758
# 20230601_MDE_corrientazo_piloto_NB_bolsas_W22                         668
# 20230601_MDE_corrientazo_piloto_NB_contenedores_W22                   518
# 20230601_MDE_corrientazo_piloto_NB_vasos_W22                          705
# 20230601_MDE_corrientazo_piloto_NB_frutas_W22                         454
# 20230601_MDE_corrientazo_piloto_NB_tuberculos_W22                     366
# 20230601_MDE_corrientazo_piloto_NB_verduras_W22                       304
# 20230601_MDE_corrientazo_piloto_NB_cremas_W22                         752
# 20230601_MDE_corrientazo_piloto_NB_huevos_W22                         614
# 20230601_MDE_corrientazo_piloto_NB_leches_W22                         691
# dtype: int64
# Done MDE corrientazo_PILOTO
# //-------------------------------------------------------------------------------
# Corrientazo Experimento50%
# 216
# Uso de data externa
# 20230601_MDE_corrientazo_control_NB_aceitesygrasas_W22                  77
# 20230601_MDE_corrientazo_control_NB_arroz_W22                          134
# 20230601_MDE_corrientazo_control_NB_azucaryendulzantes_W22             131
# 20230601_MDE_corrientazo_control_NB_cafechocolateeinfusiones_W22       190
# 20230601_MDE_corrientazo_control_NB_granos_W22                         163
# 20230601_MDE_corrientazo_control_NB_pasta_W22                          204
# 20230601_MDE_corrientazo_control_NB_salsas_W22                         184
# 20230601_MDE_corrientazo_control_NB_desinfectantesysanitizantes_W22    178
# 20230601_MDE_corrientazo_control_NB_detergentejabonylavalozas_W22      122
# 20230601_MDE_corrientazo_control_NB_papelytoallas_W22                  149
# 20230601_MDE_corrientazo_control_NB_aguas_W22                          192
# 20230601_MDE_corrientazo_control_NB_cervezasylicores_W22               201
# 20230601_MDE_corrientazo_control_NB_gaseosas_W22                       165
# 20230601_MDE_corrientazo_control_NB_jugos_W22                          196
# 20230601_MDE_corrientazo_control_NB_bolsas_W22                         167
# 20230601_MDE_corrientazo_control_NB_contenedores_W22                   130
# 20230601_MDE_corrientazo_control_NB_vasos_W22                          176
# 20230601_MDE_corrientazo_control_NB_frutas_W22                         116
# 20230601_MDE_corrientazo_control_NB_tuberculos_W22                      99
# 20230601_MDE_corrientazo_control_NB_verduras_W22                        79
# 20230601_MDE_corrientazo_control_NB_cremas_W22                         193
# 20230601_MDE_corrientazo_control_NB_huevos_W22                         154
# 20230601_MDE_corrientazo_control_NB_leches_W22                         177
# dtype: int64
# Done MDE corrientazo_CONTROL
# //-------------------------------------------------------------------------------
# Parrilla/Asadero
# 236
# Uso de data externa
# 20230601_MDE_parrillaasadero_piloto_NB_aceitesygrasas_W22                 120
# 20230601_MDE_parrillaasadero_piloto_NB_arroz_W22                          157
# 20230601_MDE_parrillaasadero_piloto_NB_azucaryendulzantes_W22             152
# 20230601_MDE_parrillaasadero_piloto_NB_cafechocolateeinfusiones_W22       211
# 20230601_MDE_parrillaasadero_piloto_NB_granos_W22                         188
# 20230601_MDE_parrillaasadero_piloto_NB_harinasymezclas_W22                213
# 20230601_MDE_parrillaasadero_piloto_NB_salsas_W22                         192
# 20230601_MDE_parrillaasadero_piloto_NB_desinfectantesysanitizantes_W22    194
# 20230601_MDE_parrillaasadero_piloto_NB_detergentejabonylavalozas_W22      137
# 20230601_MDE_parrillaasadero_piloto_NB_papelytoallas_W22                  161
# 20230601_MDE_parrillaasadero_piloto_NB_aguas_W22                          208
# 20230601_MDE_parrillaasadero_piloto_NB_cervezasylicores_W22               216
# 20230601_MDE_parrillaasadero_piloto_NB_gaseosas_W22                       176
# 20230601_MDE_parrillaasadero_piloto_NB_jugos_W22                          206
# 20230601_MDE_parrillaasadero_piloto_NB_contenedores_W22                   169
# 20230601_MDE_parrillaasadero_piloto_NB_cubiertosypitillos_W22             178
# 20230601_MDE_parrillaasadero_piloto_NB_frutas_W22                         139
# 20230601_MDE_parrillaasadero_piloto_NB_tuberculos_W22                     134
# 20230601_MDE_parrillaasadero_piloto_NB_verduras_W22                       117
# 20230601_MDE_parrillaasadero_piloto_NB_cremas_W22                         201
# 20230601_MDE_parrillaasadero_piloto_NB_huevos_W22                         184
# 20230601_MDE_parrillaasadero_piloto_NB_leches_W22                         207
# dtype: int64
# Done MDE parrillaasadero_PILOTO
# //-------------------------------------------------------------------------------
# Parrilla/Asadero Experimento50%
# 59
# Uso de data externa
# 20230601_MDE_parrillaasadero_control_NB_aceitesygrasas_W22                 32
# 20230601_MDE_parrillaasadero_control_NB_arroz_W22                          45
# 20230601_MDE_parrillaasadero_control_NB_azucaryendulzantes_W22             35
# 20230601_MDE_parrillaasadero_control_NB_cafechocolateeinfusiones_W22       59
# 20230601_MDE_parrillaasadero_control_NB_granos_W22                         47
# 20230601_MDE_parrillaasadero_control_NB_harinasymezclas_W22                54
# 20230601_MDE_parrillaasadero_control_NB_salsas_W22                         44
# 20230601_MDE_parrillaasadero_control_NB_desinfectantesysanitizantes_W22    51
# 20230601_MDE_parrillaasadero_control_NB_detergentejabonylavalozas_W22      33
# 20230601_MDE_parrillaasadero_control_NB_papelytoallas_W22                  37
# 20230601_MDE_parrillaasadero_control_NB_aguas_W22                          49
# 20230601_MDE_parrillaasadero_control_NB_cervezasylicores_W22               54
# 20230601_MDE_parrillaasadero_control_NB_gaseosas_W22                       45
# 20230601_MDE_parrillaasadero_control_NB_jugos_W22                          52
# 20230601_MDE_parrillaasadero_control_NB_contenedores_W22                   38
# 20230601_MDE_parrillaasadero_control_NB_cubiertosypitillos_W22             48
# 20230601_MDE_parrillaasadero_control_NB_frutas_W22                         35
# 20230601_MDE_parrillaasadero_control_NB_tuberculos_W22                     35
# 20230601_MDE_parrillaasadero_control_NB_verduras_W22                       26
# 20230601_MDE_parrillaasadero_control_NB_cremas_W22                         51
# 20230601_MDE_parrillaasadero_control_NB_huevos_W22                         52
# 20230601_MDE_parrillaasadero_control_NB_leches_W22                         49
# dtype: int64
# Done MDE parrillaasadero_CONTROL
# //-------------------------------------------------------------------------------
# Comida rápida
# 285
# Uso de data externa
# 20230601_MDE_comidarapida_piloto_NB_aceitesygrasas_W22                 127
# 20230601_MDE_comidarapida_piloto_NB_arroz_W22                          220
# 20230601_MDE_comidarapida_piloto_NB_azucaryendulzantes_W22             187
# 20230601_MDE_comidarapida_piloto_NB_cafechocolateeinfusiones_W22       262
# 20230601_MDE_comidarapida_piloto_NB_harinasymezclas_W22                265
# 20230601_MDE_comidarapida_piloto_NB_salsas_W22                         220
# 20230601_MDE_comidarapida_piloto_NB_desinfectantesysanitizantes_W22    231
# 20230601_MDE_comidarapida_piloto_NB_detergentejabonylavalozas_W22      179
# 20230601_MDE_comidarapida_piloto_NB_papelytoallas_W22                  201
# 20230601_MDE_comidarapida_piloto_NB_aguas_W22                          250
# 20230601_MDE_comidarapida_piloto_NB_cervezasylicores_W22               253
# 20230601_MDE_comidarapida_piloto_NB_gaseosas_W22                       199
# 20230601_MDE_comidarapida_piloto_NB_jugos_W22                          250
# 20230601_MDE_comidarapida_piloto_NB_bolsas_W22                         213
# 20230601_MDE_comidarapida_piloto_NB_contenedores_W22                   207
# 20230601_MDE_comidarapida_piloto_NB_cubiertosypitillos_W22             230
# 20230601_MDE_comidarapida_piloto_NB_empaqueyenvoltura_W22              269
# 20230601_MDE_comidarapida_piloto_NB_platosybandejas_W22                274
# 20230601_MDE_comidarapida_piloto_NB_vasos_W22                          237
# 20230601_MDE_comidarapida_piloto_NB_frutas_W22                         158
# 20230601_MDE_comidarapida_piloto_NB_tuberculos_W22                     152
# 20230601_MDE_comidarapida_piloto_NB_verduras_W22                       108
# 20230601_MDE_comidarapida_piloto_NB_cremas_W22                         254
# 20230601_MDE_comidarapida_piloto_NB_huevos_W22                         213
# 20230601_MDE_comidarapida_piloto_NB_leches_W22                         233
# dtype: int64
# Done MDE comidarapida_PILOTO
# //-------------------------------------------------------------------------------
# Comida rápida Experimento50%
# 71
# Uso de data externa
# 20230601_MDE_comidarapida_control_NB_aceitesygrasas_W22                 30
# 20230601_MDE_comidarapida_control_NB_arroz_W22                          57
# 20230601_MDE_comidarapida_control_NB_azucaryendulzantes_W22             49
# 20230601_MDE_comidarapida_control_NB_cafechocolateeinfusiones_W22       63
# 20230601_MDE_comidarapida_control_NB_harinasymezclas_W22                64
# 20230601_MDE_comidarapida_control_NB_salsas_W22                         55
# 20230601_MDE_comidarapida_control_NB_desinfectantesysanitizantes_W22    59
# 20230601_MDE_comidarapida_control_NB_detergentejabonylavalozas_W22      47
# 20230601_MDE_comidarapida_control_NB_papelytoallas_W22                  46
# 20230601_MDE_comidarapida_control_NB_aguas_W22                          58
# 20230601_MDE_comidarapida_control_NB_cervezasylicores_W22               69
# 20230601_MDE_comidarapida_control_NB_gaseosas_W22                       48
# 20230601_MDE_comidarapida_control_NB_jugos_W22                          58
# 20230601_MDE_comidarapida_control_NB_bolsas_W22                         61
# 20230601_MDE_comidarapida_control_NB_contenedores_W22                   56
# 20230601_MDE_comidarapida_control_NB_cubiertosypitillos_W22             62
# 20230601_MDE_comidarapida_control_NB_empaqueyenvoltura_W22              71
# 20230601_MDE_comidarapida_control_NB_platosybandejas_W22                70
# 20230601_MDE_comidarapida_control_NB_vasos_W22                          63
# 20230601_MDE_comidarapida_control_NB_frutas_W22                         42
# 20230601_MDE_comidarapida_control_NB_tuberculos_W22                     42
# 20230601_MDE_comidarapida_control_NB_verduras_W22                       31
# 20230601_MDE_comidarapida_control_NB_cremas_W22                         59
# 20230601_MDE_comidarapida_control_NB_huevos_W22                         52
# 20230601_MDE_comidarapida_control_NB_leches_W22                         60
# dtype: int64
# Done MDE comidarapida_CONTROL

# %% [markdown]
# ## Aca creo el archivo para R&D

# %%
# customers =  pd.DataFrame()
# for column,i in enumerate(aux_df.columns):
#     #if ('verduras' in i or 'frutas' in i or 'arroz' in i or 'aceitesygrasas' in i or 'harinasymezclas' in i or 'azucaryendulzantes' in i or 'pollo' in i or 'huevos' in i) and not 'frutasjugo' in i:
#     #if ('verduras' in i or 'frutas' in i) and not 'frutasjugo' in i:
#     customers[i] = aux_df[i]

# %%
# customers.iloc[:6000].to_csv(f'SD/export_data/MS/csv_{city_code}_CLIENTS_PRUEBA_R&D.csv', index = False)

# with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
#        json.dump(global_segment_list, outfile)

# %%
# aux_seg = pd.read_csv(f"prueba_tuberculos_BAQ.csv")
# aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

# aux_seg["final_group2"] = ["piloto" if x == "Super Descuentos" else "control" for x in aux_seg.grupos]
# aux_seg['offer_name'] = f"20230301_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W9"

# aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()

# %%
# lst = []
# for x in aux_seg2.values:
#     h = {'name':x[0], 'customersIds': list(x[1])}
#     lst.append(h)
    
# for x in lst:
#     print(x['name'])
#     #break
#     for i,value in enumerate(global_segment_list):
#         if value['name'] == x['name']:
#             global_segment_list[i]['customersIds'] = x['customersIds']
#             print(i)

# %%
aux_seg = pd.read_csv(f"csv_{city_code}_CLIENTS_FINAL_JUNIO_R&D.csv")
aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

aux_seg["final_group2"] = ["piloto" if x == "Treatment" else "control" for x in aux_seg.final_group]
aux_seg['offer_name'] = f"20230601_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W22"

aux_seg["quartile"] = ["Q0" if x == "-" else x for x in aux_seg.quartile.values]
aux_seg["quartile_name"] = f"20230601_{city_code}_" + aux_seg.subcategory + "_" + aux_seg.quartile + "_" + aux_seg.case

aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()
aux_seg3 = aux_seg.groupby(by = ["quartile_name"])["customer_source_id"].apply(list).reset_index()

# %%
aux_seg.head()
# Out:
#       subcategory  customer_source_id                            ms  \
# 0  aceitesygrasas           290760656                   corrientazo
# 1  aceitesygrasas           287502394  panaderiapasteleriacafeteria
# 2  aceitesygrasas           138619354                         other
# 3  aceitesygrasas           160612467               parrillaasadero
# 4  aceitesygrasas           244155121               parrillaasadero
#
#   previous_group        case quartile  random final_group final_group2  \
# 0      Treatment  positivity       Q4       0   Treatment       piloto
# 1      Treatment  positivity       Q4       0   Treatment       piloto
# 2      Treatment  positivity       Q4       1     Control      control
# 3      Treatment  positivity       Q4       0   Treatment       piloto
# 4      Treatment  positivity       Q4       0   Treatment       piloto
#
#                                           offer_name  \
# 0  20230601_MDE_corrientazo_piloto_NB_aceitesygra...
# 1  20230601_MDE_panaderiapasteleriacafeteria_pilo...
# 2   20230601_MDE_other_control_NB_aceitesygrasas_W22
# 3  20230601_MDE_parrillaasadero_piloto_NB_aceites...
# 4  20230601_MDE_parrillaasadero_piloto_NB_aceites...
#
#                                quartile_name
# 0  20230601_MDE_aceitesygrasas_Q4_positivity
# 1  20230601_MDE_aceitesygrasas_Q4_positivity
# 2  20230601_MDE_aceitesygrasas_Q4_positivity
# 3  20230601_MDE_aceitesygrasas_Q4_positivity
# 4  20230601_MDE_aceitesygrasas_Q4_positivity

# %%
lst = []
for x in aux_seg2.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst.append(h)

global_segment_list = lst

# %%
lst2 = []
for x in aux_seg3.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst2.append(h)

# %% [markdown]
# # Aca tengo que volver a cargar el archivo de arriba y dejarlo como lista para traer lo otro

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0    20230601_MDE_other_piloto_NB_aceitesygrasas_W22
# 1             20230601_MDE_other_piloto_NB_arroz_W22
# 2  20230601_MDE_other_piloto_NB_azucaryendulzante...
# 3  20230601_MDE_other_piloto_NB_cafechocolateeinf...
# 4            20230601_MDE_other_piloto_NB_granos_W22
#
#                           offer_description  discount  \
# 0            other_piloto_NB_aceitesygrasas         4
# 1                     other_piloto_NB_arroz         4
# 2        other_piloto_NB_azucaryendulzantes         5
# 3  other_piloto_NB_cafechocolateeinfusiones         4
# 4                    other_piloto_NB_granos         5
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                   0
# 1                         true  01-06-2023  30-06-2023                   7
# 2                         true  01-06-2023  30-06-2023                   5
# 3                         true  01-06-2023  30-06-2023                  30
# 4                         true  01-06-2023  30-06-2023                  50
#
#    max_uses_per_customer customer_segment_id                       sku_id
# 0                      1                None         598051#626691#604413
# 1                      1                None                       366840
# 2                      1                None  366859#606502#384189#606500
# 3                      1                None                534571#438871
# 4                      1                None                371215#367084

# %%
#len_seg =int(len(global_segment_list)/10)
#len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %% [markdown]
# ## Crear segments offers y segments types

# %%
import requests
import json

def create_segments(segment_list):
    
    url = f"https://{city_code}.frubana.com/api/v1/segments/create?api-key=00_growth-team-zzz-qqq_001"

    payload = json.dumps(segment_list)


    headers = {
    'Cookie': 'AWSALB=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALBCORS=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALB=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI; AWSALBCORS=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI',
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.status_code)
    sgt = [(int(x[:6]),x[7:]) for x in list(map(str.strip, response.text[32:].strip('][').replace('"', '').split(',')))]
    time.sleep(40)
    return sgt

# %%
len_seg =int(len(global_segment_list)/10)
len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %%
#offers
sgt=[]

for i in len_seg_list:
    sgt.append(create_segments(i))
    
sgt_end =[item for lista in sgt for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len_seg2 =int(len(lst2)/10)
len_seg_list2 = [lst2[:len_seg2],lst2[len_seg2:len_seg2*2],lst2[len_seg2*2:len_seg2*3],lst2[len_seg2*3:len_seg2*4],lst2[len_seg2*4:len_seg2*5],lst2[len_seg2*5:len_seg2*6],lst2[len_seg2*6:len_seg2*7],lst2[len_seg2*7:len_seg2*8],lst2[len_seg2*8:len_seg2*9],lst2[len_seg2*9:]]

# %%
#types
sgt2=[]

for i in len_seg_list2:
    sgt2.append(create_segments(i))
    
sgt_end2 =[item for lista in sgt2 for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#unir offers con segments
for i in global_offer_csv.offer_name:
    for j,z in sgt_end:
        if z==i:
            global_offer_csv.loc[global_offer_csv.offer_name == i, ('customer_segment_id')] = j

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0    20230601_MDE_other_piloto_NB_aceitesygrasas_W22
# 1             20230601_MDE_other_piloto_NB_arroz_W22
# 2  20230601_MDE_other_piloto_NB_azucaryendulzante...
# 3  20230601_MDE_other_piloto_NB_cafechocolateeinf...
# 4            20230601_MDE_other_piloto_NB_granos_W22
#
#                           offer_description  discount  \
# 0            other_piloto_NB_aceitesygrasas         4
# 1                     other_piloto_NB_arroz         4
# 2        other_piloto_NB_azucaryendulzantes         5
# 3  other_piloto_NB_cafechocolateeinfusiones         4
# 4                    other_piloto_NB_granos         5
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                   0
# 1                         true  01-06-2023  30-06-2023                   7
# 2                         true  01-06-2023  30-06-2023                   5
# 3                         true  01-06-2023  30-06-2023                  30
# 4                         true  01-06-2023  30-06-2023                  50
#
#    max_uses_per_customer customer_segment_id                       sku_id
# 0                      1              167251         598051#626691#604413
# 1                      1              167252                       366840
# 2                      1              167254  366859#606502#384189#606500
# 3                      1              167256                534571#438871
# 4                      1              167266                371215#367084

# %%
global_offer_csv = global_offer_csv.loc[~global_offer_csv.customer_segment_id.isnull()].reset_index(drop=True)
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('discount','max_uses_per_order')]=1
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('start_date','end_date')]='01-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('end_date')]='02-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('sku_id')]= global_offer_csv.loc[~global_offer_csv['offer_name'].str.contains("piloto", case=False), ('sku_id')].tolist()

# %%
len_offer =int(len(global_offer_csv)/4)
len_offer = [global_offer_csv[:len_seg],global_offer_csv[len_seg:len_seg*2],global_offer_csv[len_seg*2:len_seg*3],global_offer_csv[len_seg*3:]]

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0    20230601_MDE_other_piloto_NB_aceitesygrasas_W22
# 1             20230601_MDE_other_piloto_NB_arroz_W22
# 2  20230601_MDE_other_piloto_NB_azucaryendulzante...
# 3  20230601_MDE_other_piloto_NB_cafechocolateeinf...
# 4            20230601_MDE_other_piloto_NB_granos_W22
#
#                           offer_description  discount  \
# 0            other_piloto_NB_aceitesygrasas         4
# 1                     other_piloto_NB_arroz         4
# 2        other_piloto_NB_azucaryendulzantes         5
# 3  other_piloto_NB_cafechocolateeinfusiones         4
# 4                    other_piloto_NB_granos         5
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                   0
# 1                         true  01-06-2023  30-06-2023                   7
# 2                         true  01-06-2023  30-06-2023                   5
# 3                         true  01-06-2023  30-06-2023                  30
# 4                         true  01-06-2023  30-06-2023                  50
#
#    max_uses_per_customer customer_segment_id                       sku_id
# 0                      1              167251         598051#626691#604413
# 1                      1              167252                       366840
# 2                      1              167254  366859#606502#384189#606500
# 3                      1              167256                534571#438871
# 4                      1              167266                371215#367084

# %%
#//--------------------------------------------
#//Exporting single file data
global_offer_csv.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS.csv', index = False)

for i,offer in enumerate(len_offer):
    offer.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS_{i}.csv', index = False)

with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
        json.dump(global_segment_list, outfile)    
with open(f'SD/export_data/MS/nb_{city_code}_All_MS.json', 'w') as outfile:
        json.dump(global_segment_list, outfile)
print(f'Done {city_code}')
# Out:
# Done MDE
