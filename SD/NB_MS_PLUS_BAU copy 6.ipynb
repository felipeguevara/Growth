# %%
#//----------------------------
#//LIBRARIES
    #Math
import math
    #Numeric Python
import numpy as np
    #Pandas (dataframes)
import pandas as pd
    #datetime for fate manipulation
from datetime import date, datetime, timedelta  
    #Regex for advanced string matching
import re
    #for time related stuff
import time
    #json library
import json
    #Analyst tools
import sys
sys.path.append('../')
from analysts_tools.growth import *
    #Procurement tools
from analysts_tools.redash_methods import *
    #Frubana libraries
from procurement_lib import redash, dw, send_message, send_slack_notification, GoogleSheet, logging

# %%
#//---------------------------------------------------------------------------------------------------------------------------
#// Parametros
"""Todays date should be the first day of the next month which is going to begin with SD"""

city_code = 'BHZ'

# Set today's date to the first day of the next month
today = datetime.today()
first_day_next_month = (today.replace(day=1) + timedelta(days=32)).replace(day=1)

# Calculate non_buyers_date (todays date - 1 month)
non_buyers_date = (first_day_next_month - timedelta(days=1)).replace(day=1)
customer_date_desde = (first_day_next_month - timedelta(days=1)).replace(day=1)

# Calculate sku_date_desde (todays date - 2 months)
sku_date_desde = (first_day_next_month - timedelta(days=60)).replace(day=1)

# Convert the dates to strings in the desired format
todays_date = first_day_next_month.strftime('%Y-%m-%d')
non_buyers_date = non_buyers_date.strftime('%Y-%m-%d')
customer_date_desde = customer_date_desde.strftime('%Y-%m-%d')
sku_date_desde = sku_date_desde.strftime('%Y-%m-%d')

print(todays_date) # Output: e.g. 2023-04-01
print(non_buyers_date) # Output: e.g. 2023-03-01
print(sku_date_desde) # Output: e.g. 2023-02-01

tasas = {'BOG': 3776,
         'BAQ': 3776,
         'MDE': 3776,
         'CMX': 19.65,
         'GDL': 19.65,
         'PBC': 19.65,
         'SPO': 4.75,
         'BHZ': 4.75,
         'CWB': 4.75,
         'VCP': 4.75}

t_cambio = tasas[city_code]
# Out:
# 2023-07-01
# 2023-06-01
# 2023-05-01

# %%
query="""
With microsegment as (

SELECT DISTINCT c.customer_id AS user_id,
                c.site_type AS region_code_ms,
                
                (case 
                    -- Colombia
                    when m.microsegment_id not in (1,3,4,28,5,6,7,8,2) and c.site_type = 'BOG' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1,3,4,28,5,11,10,9,2,12) and c.site_type = 'BAQ' then 'Sin Microsegmento'
                    when m.microsegment_id not in (3,4,28,1,24,11,5,2,27) and c.site_type = 'MDE' then 'Sin Microsegmento'
    
                    -- Mexico
                    when m.microsegment_id not in (1,13,14,30,15,16,29,17,6,7,2) and c.site_type = 'CMX' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1, 13,14,30, 15,16,29, 6, 33, 2, 31) and c.site_type = 'GDL' then 'Sin Microsegmento'
                    when m.microsegment_id not in (13,14,30, 15,16,29, 32,2,6,33) and c.site_type = 'PBC' then 'Sin Microsegmento'
                    
                    -- Brasil
                    when m.microsegment_id not in (21,34,38,37,35,36,39,26) and c.site_type in ('SPO','BHZ','CWB','VCP') then 'Sin Microsegmento'
                        
                else m.description end) as microsegment_ok,
                
                m.microsegment_id,
                mo.name as ms_method
                
                
FROM postgres_main_federate."growth_microsegmentation.customer_microsegment" AS cm
INNER JOIN postgres_main_federate."growth_microsegmentation.microsegment" m ON cm.microsegment_id = m.id
INNER JOIN postgres_main_federate."growth_microsegmentation.customer" c ON cm.customer_id = c.id
INNER JOIN postgres_main_federate."growth_microsegmentation.models" mo ON mo.id = cm.model_type_id


)

select m.user_id,
m.region_code_ms,
--m.microsegment_id,

(case 
        when m.microsegment_ok in ('Corrientazo c/desayuno','Corrientazo s/desayuno','Tienda/Restaurante') then 'Corrientazo' 
        when m.microsegment_ok in ('Fonda c/desayuno','Fonda s/desayuno') then 'Fonda'
        when m.microsegment_ok in ('Taquería en calle','Taquería en local') then 'Taquería'

else m.microsegment_ok end) as microsegment,

m.ms_method

from microsegment m
where m.microsegment_ok != 'Sin Microsegmento'
"""

segmentos_fulll = read_connection_data_warehouse.runQuery(query)

segmentos_fulll.columns = ['customer_id', 'city', 'microsegment','NA']
segmentos_fulll = segmentos_fulll[['customer_id', 'city', 'microsegment']]

# %% [markdown]
# ### Loading COSTUMERS INFO

# %%
users_eliminar_kam = get_fresh_query_result("https://internal-redash.federate.frubana.com/",150812,'SeoGHWmDUaaBi7VXje1s9zYNiMD1VHQ1K1DYOxiF',{},20)
users_eliminar = users_eliminar_kam.loc[users_eliminar_kam.registered_city == city_code]['customer_id'].unique().tolist()
# Out:
# 200

# %% [markdown]
# ### Loading FORCED_SKUS // Cleaning SEGMENT_NAMES

# %% [markdown]
# ### Loading DATA_VENTAS // Removing SKUs /\ CUSTOMERS_ID

# %%
#//Remove skus 
#It is used because some SKUs can get in trouble with supplier for the SD or to exclude them for another activity   
skus_remove = GoogleSheet("1Z0T_c36oRHmOHIgEG8_ANcwFykaHgXGAizYAYCKCqtY")
skus_remove = skus_remove.get_as_dataframe('SKUS')

skus_remove = skus_remove['sku_id'].unique().astype(int).tolist()

# %%
query = """
SELECT DISTINCT
    split_part(bs.upc, '-', 1) as region,
    bs.sku_id

FROM postgres_broadleaf_federate."broadleaf.blc_sku"            bs 
LEFT JOIN postgres_broadleaf_federate."broadleaf.blc_product"   bp ON bp.product_id = bs.addl_product_id

WHERE bs.archived = 'N'
    AND bs.sndbx_id is NULL
    AND bp.archived = 'N'
    AND bs.catalog_disc < 0
    AND ((bp.archived = 'N' AND bp.sndbx_id is NULL) OR (bp.archived is NULL))
"""
frida_products = read_connection_data_warehouse.runQuery(query)

# %%
good_skus = frida_products.sku_id.unique()

# %%
#Loading SELL'S DATA from a function
data_ventas = data_ventas_query(ciudad=city_code, tipo_cambio=t_cambio, desde=customer_date_desde, hasta = todays_date, tipo_negocio=1)

# %%
data_ventas = data_ventas[(~data_ventas['sku_id'].isin(skus_remove)) & (data_ventas['sku_id'].isin(good_skus))]

# %%
segmentos_full = segmentos_fulll[segmentos_fulll.city == city_code].copy()

# %%
#//customers for offers */(has further uses)*/
microsegmentacion_df = segmentos_full[(~segmentos_full['customer_id'].isin(users_eliminar))]
data_ventas = data_ventas[(~data_ventas['customer_id'].isin(users_eliminar))]

# %% [markdown]
# ### Create the MS "Other" for BAU

# %%
data_full = data_ventas.merge(microsegmentacion_df[['customer_id','microsegment']], how = 'left', on = 'customer_id')

# %%
data_full['microsegment'] = data_full['microsegment'].fillna('Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                    microsegment  customer_id
# 0                        Boteco          325
# 1  Grill/Churrascaria/Espetinho          166
# 2        Japonesa/Internacional           49
# 3                       Lanches          852
# 4                         Other          486
# 5            Padaria/Cafe/Bolos          741
# 6  Pizzaria/Pastelaria/Italiano          142
# 7              Pratos/Refeições         1008
# 8                    Sucos/Açaí          204

# %%
segments_validation = data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()

# %%
for ms in segments_validation[segments_validation.customer_id < 180]['microsegment'].unique():
    data_full['microsegment'] = data_full['microsegment'].str.replace(ms,'Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#          microsegment  customer_id
# 0              Boteco          325
# 1             Lanches          852
# 2               Other          843
# 3  Padaria/Cafe/Bolos          741
# 4    Pratos/Refeições         1008
# 5          Sucos/Açaí          204

# %%
#Get the same variable to do the process job
data_ventas = data_full

# %% [markdown]
# ### PARAMETERS // SOME FUNCTIONS - GET READY TO PROCESSING

# %%
def ms_data(city_code):
  
    paramss_csv=GoogleSheet("1k0ckgkLddxc5lY8NUVGCkvDLTuulLaJm-N535oMNZNw")
    city_paramss = paramss_csv.get_as_dataframe(city_code)
    
    parametros = {}
    parametros[city_code] = {}
    
    for i,ms in enumerate(city_paramss.iloc[:,4:].columns):
        parametros[city_code][ms] = [(value[1],value[2],value[3],value[4+i]) for value in city_paramss.values if value[4+i]>0]
        
    return parametros

# %%
parametros = ms_data(city_code)

# %%
def normalize_text(raw_text):
    """
    Removes common accent characters and normalize text.
    """
    raw_text = raw_text.replace(" ", "")
    raw_text = raw_text.replace("�", "")
    raw_text = raw_text.replace("/", "")
    raw_text = re.sub(r'\s*', '', raw_text)
    raw_text = re.sub(r"[àáâãäå]", 'a', raw_text)
    raw_text = re.sub(r"[èéêë]", 'e', raw_text)
    raw_text = re.sub(r"[ìíîï]", 'i', raw_text) 
    raw_text = re.sub(r"[òóôõö]", 'o', raw_text)
    raw_text = re.sub(r"[ùúûü]", 'u', raw_text)
    raw_text = re.sub(r"[ýÿ]", 'y', raw_text)
    raw_text = re.sub(r"[ß]", 'ss', raw_text)
    raw_text = re.sub(r"[ñ]", 'n', raw_text)
    raw_text = re.sub(r"[ç]", 'c', raw_text)
    raw_text = raw_text.lower()
    return raw_text

# %%
#Sacar de aca los microsegmentos
msg = data_full.microsegment.unique()
msg
# Out:
# array(['Lanches', 'Pratos/Refeições', 'Other', 'Padaria/Cafe/Bolos',
#        'Boteco', 'Sucos/Açaí'], dtype=object)

# %% [markdown]
# ### END

# %% [markdown]
# # Aca Empieza la Experimentacion

# %%
from sklearn.model_selection import train_test_split

# %%
#//Variables to store all the segments and offers of the city
global_offer_csv = pd.DataFrame()
global_segment_list = [] #//for procesing

# %%
#//----------------------------------------------------------------------------
#//Big loop for creating each city segments/offers files
aux_df = pd.DataFrame()
aux_df['aux']=6000*[0]

for microsegment in msg:
    print('//-------------------------------------------------------------------------------')
    print(microsegment)

    #//Customers per microsegment
    customers_ms = data_ventas[(data_ventas['microsegment'] == microsegment)]['customer_id'].unique()
    #//Customers to give them the skus
    customers_for_skus_ms =  data_ventas[['microsegment','customer_id']][(data_ventas.microsegment == microsegment) & (~data_ventas.customer_id.isin(users_eliminar))]['customer_id'].unique()
    
    #----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_PILOTO" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    rand=1
    customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state=rand)
    
    while abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())) > 0.05:
        #print(data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean(),data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean(),abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())))
        rand+=1
        customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state = rand)
        
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_1)].copy() #le quite la s!!
    
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()
    
    subcats = list(map(lambda x: x[0], parametros[city_code][microsegment]))
    max_uses = list(map(lambda x: int(x[1]), parametros[city_code][microsegment]))
    max_order = list(map(lambda x: int(x[2]), parametros[city_code][microsegment]))
    discount = list(map(lambda x: int(x[3]), parametros[city_code][microsegment]))

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    a, b, c = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
            non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                        limite=0.75, data_ventas_skus = data_skus)

    print(b.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(a)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in b.columns:
        id_list = b[seg].dropna().astype(int)
        d = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)

        lst.append(d)
        
    #//appending to global list    
        global_segment_list.append(d)
    
    print(f'Done {city_code} {ms_name}')

#----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------


#----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_CONTROL" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_2)].copy() #le quite la s!!
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    print('//-------------------------------------------------------------------------------')
    print(f'{microsegment} Experimento50%')
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    e, f, g = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
                non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                          limite=0.75, data_ventas_skus = data_skus)
      
    print(f.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(e)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in f.columns:
        id_list = f[seg].dropna().astype(int)
        h = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)
        
        lst.append(h)
        
        
    #//appending to global list    
        global_segment_list.append(h)
    
    print(f'Done {city_code} {ms_name}')
    #----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#//End of big loop and start of data bundle
# Out:
# //-------------------------------------------------------------------------------
# Lanches
# 682
# Uso de data externa
# 20230701_BHZ_lanches_piloto_NB_aguaseisotonicos_W26              569
# 20230701_BHZ_lanches_piloto_NB_cervejas_W26                      514
# 20230701_BHZ_lanches_piloto_NB_refrigeranteseenergeticos_W26     441
# 20230701_BHZ_lanches_piloto_NB_sucosechas_W26                    566
# 20230701_BHZ_lanches_piloto_NB_destilados_W26                    668
# 20230701_BHZ_lanches_piloto_NB_alimentoscongelados_W26           634
# 20230701_BHZ_lanches_piloto_NB_batataspre-fritas_W26             555
# 20230701_BHZ_lanches_piloto_NB_polpaseaai_W26                    651
# 20230701_BHZ_lanches_piloto_NB_embalagens_W26                    678
# 20230701_BHZ_lanches_piloto_NB_papeis_W26                        578
# 20230701_BHZ_lanches_piloto_NB_sacos_W26                         671
# 20230701_BHZ_lanches_piloto_NB_utensilios_W26                    664
# 20230701_BHZ_lanches_piloto_NB_frutas_W26                        312
# 20230701_BHZ_lanches_piloto_NB_legumes_W26                       350
# 20230701_BHZ_lanches_piloto_NB_tuberculos_W26                    444
# 20230701_BHZ_lanches_piloto_NB_verduras_W26                      465
# 20230701_BHZ_lanches_piloto_NB_laticinios_W26                    593
# 20230701_BHZ_lanches_piloto_NB_leite_W26                         443
# 20230701_BHZ_lanches_piloto_NB_manteigasemargarinas_W26          623
# 20230701_BHZ_lanches_piloto_NB_ovos_W26                          592
# 20230701_BHZ_lanches_piloto_NB_queijos_W26                       550
# 20230701_BHZ_lanches_piloto_NB_desengordurantes_W26              664
# 20230701_BHZ_lanches_piloto_NB_desinfetantesesanitizantes_W26    580
# 20230701_BHZ_lanches_piloto_NB_detergentesabaoelava-louas_W26    520
# 20230701_BHZ_lanches_piloto_NB_outroslimpadores_W26              608
# 20230701_BHZ_lanches_piloto_NB_utensiliosdelimpeza_W26           616
# 20230701_BHZ_lanches_piloto_NB_aucaradoantesedoces_W26           516
# 20230701_BHZ_lanches_piloto_NB_arroz_W26                         580
# 20230701_BHZ_lanches_piloto_NB_azeitesoleosevinagres_W26         352
# 20230701_BHZ_lanches_piloto_NB_cafechocolateseinfusoes_W26       565
# 20230701_BHZ_lanches_piloto_NB_condimentos_W26                   572
# 20230701_BHZ_lanches_piloto_NB_conservaseenlatados_W26           645
# 20230701_BHZ_lanches_piloto_NB_docesesobremesas_W26              672
# 20230701_BHZ_lanches_piloto_NB_farinhasemisturas_W26             608
# 20230701_BHZ_lanches_piloto_NB_feijao_W26                        599
# 20230701_BHZ_lanches_piloto_NB_massasemolhos_W26                 574
# 20230701_BHZ_lanches_piloto_NB_temperos_W26                      581
# 20230701_BHZ_lanches_piloto_NB_carnevermelha_W26                 650
# 20230701_BHZ_lanches_piloto_NB_embutidos_W26                     611
# 20230701_BHZ_lanches_piloto_NB_frango_W26                        529
# 20230701_BHZ_lanches_piloto_NB_peixesefrutosdomar_W26            669
# 20230701_BHZ_lanches_piloto_NB_suinos_W26                        651
# dtype: int64
# Done BHZ lanches_PILOTO
# //-------------------------------------------------------------------------------
# Lanches Experimento50%
# 170
# Uso de data externa
# 20230701_BHZ_lanches_control_NB_aguaseisotonicos_W26              142
# 20230701_BHZ_lanches_control_NB_cervejas_W26                      128
# 20230701_BHZ_lanches_control_NB_refrigeranteseenergeticos_W26     120
# 20230701_BHZ_lanches_control_NB_sucosechas_W26                    140
# 20230701_BHZ_lanches_control_NB_destilados_W26                    166
# 20230701_BHZ_lanches_control_NB_alimentoscongelados_W26           167
# 20230701_BHZ_lanches_control_NB_batataspre-fritas_W26             146
# 20230701_BHZ_lanches_control_NB_polpaseaai_W26                    168
# 20230701_BHZ_lanches_control_NB_embalagens_W26                    170
# 20230701_BHZ_lanches_control_NB_papeis_W26                        152
# 20230701_BHZ_lanches_control_NB_sacos_W26                         167
# 20230701_BHZ_lanches_control_NB_utensilios_W26                    168
# 20230701_BHZ_lanches_control_NB_frutas_W26                         84
# 20230701_BHZ_lanches_control_NB_legumes_W26                        94
# 20230701_BHZ_lanches_control_NB_tuberculos_W26                    110
# 20230701_BHZ_lanches_control_NB_verduras_W26                      122
# 20230701_BHZ_lanches_control_NB_laticinios_W26                    153
# 20230701_BHZ_lanches_control_NB_leite_W26                         114
# 20230701_BHZ_lanches_control_NB_manteigasemargarinas_W26          154
# 20230701_BHZ_lanches_control_NB_ovos_W26                          148
# 20230701_BHZ_lanches_control_NB_queijos_W26                       143
# 20230701_BHZ_lanches_control_NB_desengordurantes_W26              166
# 20230701_BHZ_lanches_control_NB_desinfetantesesanitizantes_W26    149
# 20230701_BHZ_lanches_control_NB_detergentesabaoelava-louas_W26    134
# 20230701_BHZ_lanches_control_NB_outroslimpadores_W26              157
# 20230701_BHZ_lanches_control_NB_utensiliosdelimpeza_W26           154
# 20230701_BHZ_lanches_control_NB_aucaradoantesedoces_W26           131
# 20230701_BHZ_lanches_control_NB_arroz_W26                         143
# 20230701_BHZ_lanches_control_NB_azeitesoleosevinagres_W26          94
# 20230701_BHZ_lanches_control_NB_cafechocolateseinfusoes_W26       145
# 20230701_BHZ_lanches_control_NB_condimentos_W26                   151
# 20230701_BHZ_lanches_control_NB_conservaseenlatados_W26           161
# 20230701_BHZ_lanches_control_NB_docesesobremesas_W26              167
# 20230701_BHZ_lanches_control_NB_farinhasemisturas_W26             149
# 20230701_BHZ_lanches_control_NB_feijao_W26                        139
# 20230701_BHZ_lanches_control_NB_massasemolhos_W26                 145
# 20230701_BHZ_lanches_control_NB_temperos_W26                      146
# 20230701_BHZ_lanches_control_NB_carnevermelha_W26                 165
# 20230701_BHZ_lanches_control_NB_embutidos_W26                     158
# 20230701_BHZ_lanches_control_NB_frango_W26                        131
# 20230701_BHZ_lanches_control_NB_peixesefrutosdomar_W26            169
# 20230701_BHZ_lanches_control_NB_suinos_W26                        162
# dtype: int64
# Done BHZ lanches_CONTROL
# //-------------------------------------------------------------------------------
# Pratos/Refeições
# 807
# Uso de data externa
# 20230701_BHZ_pratosrefeicoes_piloto_NB_aguaseisotonicos_W26              703
# 20230701_BHZ_pratosrefeicoes_piloto_NB_cervejas_W26                      666
# 20230701_BHZ_pratosrefeicoes_piloto_NB_refrigeranteseenergeticos_W26     568
# 20230701_BHZ_pratosrefeicoes_piloto_NB_sucosechas_W26                    715
# 20230701_BHZ_pratosrefeicoes_piloto_NB_destilados_W26                    795
# 20230701_BHZ_pratosrefeicoes_piloto_NB_alimentoscongelados_W26           769
# 20230701_BHZ_pratosrefeicoes_piloto_NB_batataspre-fritas_W26             636
# 20230701_BHZ_pratosrefeicoes_piloto_NB_polpaseaai_W26                    761
# 20230701_BHZ_pratosrefeicoes_piloto_NB_embalagens_W26                    800
# 20230701_BHZ_pratosrefeicoes_piloto_NB_papeis_W26                        689
# 20230701_BHZ_pratosrefeicoes_piloto_NB_sacos_W26                         795
# 20230701_BHZ_pratosrefeicoes_piloto_NB_utensilios_W26                    785
# 20230701_BHZ_pratosrefeicoes_piloto_NB_frutas_W26                        256
# 20230701_BHZ_pratosrefeicoes_piloto_NB_legumes_W26                       234
# 20230701_BHZ_pratosrefeicoes_piloto_NB_tuberculos_W26                    308
# 20230701_BHZ_pratosrefeicoes_piloto_NB_verduras_W26                      464
# 20230701_BHZ_pratosrefeicoes_piloto_NB_laticinios_W26                    637
# 20230701_BHZ_pratosrefeicoes_piloto_NB_leite_W26                         583
# 20230701_BHZ_pratosrefeicoes_piloto_NB_manteigasemargarinas_W26          717
# 20230701_BHZ_pratosrefeicoes_piloto_NB_ovos_W26                          654
# 20230701_BHZ_pratosrefeicoes_piloto_NB_queijos_W26                       692
# 20230701_BHZ_pratosrefeicoes_piloto_NB_desengordurantes_W26              784
# 20230701_BHZ_pratosrefeicoes_piloto_NB_desinfetantesesanitizantes_W26    679
# 20230701_BHZ_pratosrefeicoes_piloto_NB_detergentesabaoelava-louas_W26    586
# 20230701_BHZ_pratosrefeicoes_piloto_NB_outroslimpadores_W26              730
# 20230701_BHZ_pratosrefeicoes_piloto_NB_utensiliosdelimpeza_W26           712
# 20230701_BHZ_pratosrefeicoes_piloto_NB_aucaradoantesedoces_W26           655
# 20230701_BHZ_pratosrefeicoes_piloto_NB_arroz_W26                         528
# 20230701_BHZ_pratosrefeicoes_piloto_NB_azeitesoleosevinagres_W26         279
# 20230701_BHZ_pratosrefeicoes_piloto_NB_cafechocolateseinfusoes_W26       666
# 20230701_BHZ_pratosrefeicoes_piloto_NB_condimentos_W26                   607
# 20230701_BHZ_pratosrefeicoes_piloto_NB_conservaseenlatados_W26           740
# 20230701_BHZ_pratosrefeicoes_piloto_NB_docesesobremesas_W26              803
# 20230701_BHZ_pratosrefeicoes_piloto_NB_farinhasemisturas_W26             652
# 20230701_BHZ_pratosrefeicoes_piloto_NB_feijao_W26                        554
# 20230701_BHZ_pratosrefeicoes_piloto_NB_massasemolhos_W26                 553
# 20230701_BHZ_pratosrefeicoes_piloto_NB_temperos_W26                      559
# 20230701_BHZ_pratosrefeicoes_piloto_NB_carnevermelha_W26                 760
# 20230701_BHZ_pratosrefeicoes_piloto_NB_embutidos_W26                     711
# 20230701_BHZ_pratosrefeicoes_piloto_NB_frango_W26                        633
# 20230701_BHZ_pratosrefeicoes_piloto_NB_peixesefrutosdomar_W26            795
# 20230701_BHZ_pratosrefeicoes_piloto_NB_suinos_W26                        768
# dtype: int64
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)
# Done BHZ pratosrefeicoes_PILOTO
# //-------------------------------------------------------------------------------
# Pratos/Refeições Experimento50%
# 201
# Uso de data externa
# 20230701_BHZ_pratosrefeicoes_control_NB_aguaseisotonicos_W26              166
# 20230701_BHZ_pratosrefeicoes_control_NB_cervejas_W26                      167
# 20230701_BHZ_pratosrefeicoes_control_NB_refrigeranteseenergeticos_W26     131
# 20230701_BHZ_pratosrefeicoes_control_NB_sucosechas_W26                    171
# 20230701_BHZ_pratosrefeicoes_control_NB_destilados_W26                    199
# 20230701_BHZ_pratosrefeicoes_control_NB_alimentoscongelados_W26           188
# 20230701_BHZ_pratosrefeicoes_control_NB_batataspre-fritas_W26             155
# 20230701_BHZ_pratosrefeicoes_control_NB_polpaseaai_W26                    192
# 20230701_BHZ_pratosrefeicoes_control_NB_embalagens_W26                    199
# 20230701_BHZ_pratosrefeicoes_control_NB_papeis_W26                        167
# 20230701_BHZ_pratosrefeicoes_control_NB_sacos_W26                         196
# 20230701_BHZ_pratosrefeicoes_control_NB_utensilios_W26                    188
# 20230701_BHZ_pratosrefeicoes_control_NB_frutas_W26                         62
# 20230701_BHZ_pratosrefeicoes_control_NB_legumes_W26                        54
# 20230701_BHZ_pratosrefeicoes_control_NB_tuberculos_W26                     78
# 20230701_BHZ_pratosrefeicoes_control_NB_verduras_W26                      107
# 20230701_BHZ_pratosrefeicoes_control_NB_laticinios_W26                    159
# 20230701_BHZ_pratosrefeicoes_control_NB_leite_W26                         125
# 20230701_BHZ_pratosrefeicoes_control_NB_manteigasemargarinas_W26          182
# 20230701_BHZ_pratosrefeicoes_control_NB_ovos_W26                          163
# 20230701_BHZ_pratosrefeicoes_control_NB_queijos_W26                       170
# 20230701_BHZ_pratosrefeicoes_control_NB_desengordurantes_W26              194
# 20230701_BHZ_pratosrefeicoes_control_NB_desinfetantesesanitizantes_W26    157
# 20230701_BHZ_pratosrefeicoes_control_NB_detergentesabaoelava-louas_W26    136
# 20230701_BHZ_pratosrefeicoes_control_NB_outroslimpadores_W26              182
# 20230701_BHZ_pratosrefeicoes_control_NB_utensiliosdelimpeza_W26           170
# 20230701_BHZ_pratosrefeicoes_control_NB_aucaradoantesedoces_W26           153
# 20230701_BHZ_pratosrefeicoes_control_NB_arroz_W26                         117
# 20230701_BHZ_pratosrefeicoes_control_NB_azeitesoleosevinagres_W26          71
# 20230701_BHZ_pratosrefeicoes_control_NB_cafechocolateseinfusoes_W26       157
# 20230701_BHZ_pratosrefeicoes_control_NB_condimentos_W26                   149
# 20230701_BHZ_pratosrefeicoes_control_NB_conservaseenlatados_W26           185
# 20230701_BHZ_pratosrefeicoes_control_NB_docesesobremesas_W26              201
# 20230701_BHZ_pratosrefeicoes_control_NB_farinhasemisturas_W26             151
# 20230701_BHZ_pratosrefeicoes_control_NB_feijao_W26                        122
# 20230701_BHZ_pratosrefeicoes_control_NB_massasemolhos_W26                 143
# 20230701_BHZ_pratosrefeicoes_control_NB_temperos_W26                      142
# 20230701_BHZ_pratosrefeicoes_control_NB_carnevermelha_W26                 187
# 20230701_BHZ_pratosrefeicoes_control_NB_embutidos_W26                     178
# 20230701_BHZ_pratosrefeicoes_control_NB_frango_W26                        149
# 20230701_BHZ_pratosrefeicoes_control_NB_peixesefrutosdomar_W26            195
# 20230701_BHZ_pratosrefeicoes_control_NB_suinos_W26                        189
# dtype: int64
# Done BHZ pratosrefeicoes_CONTROL
# //-------------------------------------------------------------------------------
# Other
# 675
# Uso de data externa
# 20230701_BHZ_other_piloto_NB_aguaseisotonicos_W26              560
# 20230701_BHZ_other_piloto_NB_cervejas_W26                      479
# 20230701_BHZ_other_piloto_NB_refrigeranteseenergeticos_W26     423
# 20230701_BHZ_other_piloto_NB_sucosechas_W26                    583
# 20230701_BHZ_other_piloto_NB_destilados_W26                    654
# 20230701_BHZ_other_piloto_NB_alimentoscongelados_W26           644
# 20230701_BHZ_other_piloto_NB_batataspre-fritas_W26             540
# 20230701_BHZ_other_piloto_NB_polpaseaai_W26                    645
# 20230701_BHZ_other_piloto_NB_embalagens_W26                    667
# 20230701_BHZ_other_piloto_NB_papeis_W26                        579
# 20230701_BHZ_other_piloto_NB_sacos_W26                         662
# 20230701_BHZ_other_piloto_NB_utensilios_W26                    645
# 20230701_BHZ_other_piloto_NB_frutas_W26                        287
# 20230701_BHZ_other_piloto_NB_legumes_W26                       298
# 20230701_BHZ_other_piloto_NB_tuberculos_W26                    383
# 20230701_BHZ_other_piloto_NB_verduras_W26                      431
# 20230701_BHZ_other_piloto_NB_laticinios_W26                    561
# 20230701_BHZ_other_piloto_NB_leite_W26                         467
# 20230701_BHZ_other_piloto_NB_manteigasemargarinas_W26          614
# 20230701_BHZ_other_piloto_NB_ovos_W26                          567
# 20230701_BHZ_other_piloto_NB_queijos_W26                       550
# 20230701_BHZ_other_piloto_NB_desengordurantes_W26              652
# 20230701_BHZ_other_piloto_NB_desinfetantesesanitizantes_W26    553
# 20230701_BHZ_other_piloto_NB_detergentesabaoelava-louas_W26    495
# 20230701_BHZ_other_piloto_NB_outroslimpadores_W26              601
# 20230701_BHZ_other_piloto_NB_utensiliosdelimpeza_W26           600
# 20230701_BHZ_other_piloto_NB_aucaradoantesedoces_W26           503
# 20230701_BHZ_other_piloto_NB_arroz_W26                         503
# 20230701_BHZ_other_piloto_NB_azeitesoleosevinagres_W26         280
# 20230701_BHZ_other_piloto_NB_cafechocolateseinfusoes_W26       547
# 20230701_BHZ_other_piloto_NB_condimentos_W26                   554
# 20230701_BHZ_other_piloto_NB_conservaseenlatados_W26           635
# 20230701_BHZ_other_piloto_NB_docesesobremesas_W26              662
# 20230701_BHZ_other_piloto_NB_farinhasemisturas_W26             539
# 20230701_BHZ_other_piloto_NB_feijao_W26                        517
# 20230701_BHZ_other_piloto_NB_massasemolhos_W26                 535
# 20230701_BHZ_other_piloto_NB_temperos_W26                      529
# 20230701_BHZ_other_piloto_NB_carnevermelha_W26                 637
# 20230701_BHZ_other_piloto_NB_embutidos_W26                     575
# 20230701_BHZ_other_piloto_NB_frango_W26                        537
# 20230701_BHZ_other_piloto_NB_peixesefrutosdomar_W26            659
# 20230701_BHZ_other_piloto_NB_suinos_W26                        633
# dtype: int64
# Done BHZ other_PILOTO
# //-------------------------------------------------------------------------------
# Other Experimento50%
# 168
# Uso de data externa
# 20230701_BHZ_other_control_NB_aguaseisotonicos_W26              144
# 20230701_BHZ_other_control_NB_cervejas_W26                      119
# 20230701_BHZ_other_control_NB_refrigeranteseenergeticos_W26     124
# 20230701_BHZ_other_control_NB_sucosechas_W26                    143
# 20230701_BHZ_other_control_NB_destilados_W26                    165
# 20230701_BHZ_other_control_NB_alimentoscongelados_W26           160
# 20230701_BHZ_other_control_NB_batataspre-fritas_W26             134
# 20230701_BHZ_other_control_NB_polpaseaai_W26                    160
# 20230701_BHZ_other_control_NB_embalagens_W26                    168
# 20230701_BHZ_other_control_NB_papeis_W26                        138
# 20230701_BHZ_other_control_NB_sacos_W26                         163
# 20230701_BHZ_other_control_NB_utensilios_W26                    160
# 20230701_BHZ_other_control_NB_frutas_W26                         81
# 20230701_BHZ_other_control_NB_legumes_W26                        78
# 20230701_BHZ_other_control_NB_tuberculos_W26                    103
# 20230701_BHZ_other_control_NB_verduras_W26                      105
# 20230701_BHZ_other_control_NB_laticinios_W26                    142
# 20230701_BHZ_other_control_NB_leite_W26                         120
# 20230701_BHZ_other_control_NB_manteigasemargarinas_W26          155
# 20230701_BHZ_other_control_NB_ovos_W26                          146
# 20230701_BHZ_other_control_NB_queijos_W26                       138
# 20230701_BHZ_other_control_NB_desengordurantes_W26              161
# 20230701_BHZ_other_control_NB_desinfetantesesanitizantes_W26    136
# 20230701_BHZ_other_control_NB_detergentesabaoelava-louas_W26    124
# 20230701_BHZ_other_control_NB_outroslimpadores_W26              153
# 20230701_BHZ_other_control_NB_utensiliosdelimpeza_W26           154
# 20230701_BHZ_other_control_NB_aucaradoantesedoces_W26           123
# 20230701_BHZ_other_control_NB_arroz_W26                         133
# 20230701_BHZ_other_control_NB_azeitesoleosevinagres_W26          82
# 20230701_BHZ_other_control_NB_cafechocolateseinfusoes_W26       139
# 20230701_BHZ_other_control_NB_condimentos_W26                   136
# 20230701_BHZ_other_control_NB_conservaseenlatados_W26           156
# 20230701_BHZ_other_control_NB_docesesobremesas_W26              164
# 20230701_BHZ_other_control_NB_farinhasemisturas_W26             138
# 20230701_BHZ_other_control_NB_feijao_W26                        128
# 20230701_BHZ_other_control_NB_massasemolhos_W26                 123
# 20230701_BHZ_other_control_NB_temperos_W26                      118
# 20230701_BHZ_other_control_NB_carnevermelha_W26                 163
# 20230701_BHZ_other_control_NB_embutidos_W26                     143
# 20230701_BHZ_other_control_NB_frango_W26                        134
# 20230701_BHZ_other_control_NB_peixesefrutosdomar_W26            165
# 20230701_BHZ_other_control_NB_suinos_W26                        160
# dtype: int64
# Done BHZ other_CONTROL
# //-------------------------------------------------------------------------------
# Padaria/Cafe/Bolos
# 593
# Uso de data externa
# 20230701_BHZ_padariacafebolos_piloto_NB_aguaseisotonicos_W26              526
# 20230701_BHZ_padariacafebolos_piloto_NB_cervejas_W26                      414
# 20230701_BHZ_padariacafebolos_piloto_NB_refrigeranteseenergeticos_W26     471
# 20230701_BHZ_padariacafebolos_piloto_NB_sucosechas_W26                    492
# 20230701_BHZ_padariacafebolos_piloto_NB_destilados_W26                    572
# 20230701_BHZ_padariacafebolos_piloto_NB_alimentoscongelados_W26           581
# 20230701_BHZ_padariacafebolos_piloto_NB_batataspre-fritas_W26             550
# 20230701_BHZ_padariacafebolos_piloto_NB_polpaseaai_W26                    579
# 20230701_BHZ_padariacafebolos_piloto_NB_embalagens_W26                    591
# 20230701_BHZ_padariacafebolos_piloto_NB_papeis_W26                        529
# 20230701_BHZ_padariacafebolos_piloto_NB_sacos_W26                         586
# 20230701_BHZ_padariacafebolos_piloto_NB_utensilios_W26                    575
# 20230701_BHZ_padariacafebolos_piloto_NB_frutas_W26                        327
# 20230701_BHZ_padariacafebolos_piloto_NB_legumes_W26                       327
# 20230701_BHZ_padariacafebolos_piloto_NB_tuberculos_W26                    379
# 20230701_BHZ_padariacafebolos_piloto_NB_verduras_W26                      431
# 20230701_BHZ_padariacafebolos_piloto_NB_laticinios_W26                    503
# 20230701_BHZ_padariacafebolos_piloto_NB_leite_W26                         306
# 20230701_BHZ_padariacafebolos_piloto_NB_manteigasemargarinas_W26          553
# 20230701_BHZ_padariacafebolos_piloto_NB_ovos_W26                          546
# 20230701_BHZ_padariacafebolos_piloto_NB_queijos_W26                       503
# 20230701_BHZ_padariacafebolos_piloto_NB_desengordurantes_W26              583
# 20230701_BHZ_padariacafebolos_piloto_NB_desinfetantesesanitizantes_W26    502
# 20230701_BHZ_padariacafebolos_piloto_NB_detergentesabaoelava-louas_W26    482
# 20230701_BHZ_padariacafebolos_piloto_NB_outroslimpadores_W26              557
# 20230701_BHZ_padariacafebolos_piloto_NB_utensiliosdelimpeza_W26           553
# 20230701_BHZ_padariacafebolos_piloto_NB_aucaradoantesedoces_W26           302
# 20230701_BHZ_padariacafebolos_piloto_NB_arroz_W26                         537
# 20230701_BHZ_padariacafebolos_piloto_NB_azeitesoleosevinagres_W26         237
# 20230701_BHZ_padariacafebolos_piloto_NB_cafechocolateseinfusoes_W26       505
# 20230701_BHZ_padariacafebolos_piloto_NB_condimentos_W26                   546
# 20230701_BHZ_padariacafebolos_piloto_NB_conservaseenlatados_W26           575
# 20230701_BHZ_padariacafebolos_piloto_NB_docesesobremesas_W26              577
# 20230701_BHZ_padariacafebolos_piloto_NB_farinhasemisturas_W26             526
# 20230701_BHZ_padariacafebolos_piloto_NB_feijao_W26                        517
# 20230701_BHZ_padariacafebolos_piloto_NB_massasemolhos_W26                 519
# 20230701_BHZ_padariacafebolos_piloto_NB_temperos_W26                      493
# 20230701_BHZ_padariacafebolos_piloto_NB_carnevermelha_W26                 564
# 20230701_BHZ_padariacafebolos_piloto_NB_embutidos_W26                     533
# 20230701_BHZ_padariacafebolos_piloto_NB_frango_W26                        507
# 20230701_BHZ_padariacafebolos_piloto_NB_peixesefrutosdomar_W26            580
# 20230701_BHZ_padariacafebolos_piloto_NB_suinos_W26                        568
# dtype: int64
# Done BHZ padariacafebolos_PILOTO
# //-------------------------------------------------------------------------------
# Padaria/Cafe/Bolos Experimento50%
# 148
# Uso de data externa
# 20230701_BHZ_padariacafebolos_control_NB_aguaseisotonicos_W26              133
# 20230701_BHZ_padariacafebolos_control_NB_cervejas_W26                      109
# 20230701_BHZ_padariacafebolos_control_NB_refrigeranteseenergeticos_W26     114
# 20230701_BHZ_padariacafebolos_control_NB_sucosechas_W26                    126
# 20230701_BHZ_padariacafebolos_control_NB_destilados_W26                    145
# 20230701_BHZ_padariacafebolos_control_NB_alimentoscongelados_W26           146
# 20230701_BHZ_padariacafebolos_control_NB_batataspre-fritas_W26             136
# 20230701_BHZ_padariacafebolos_control_NB_polpaseaai_W26                    146
# 20230701_BHZ_padariacafebolos_control_NB_embalagens_W26                    147
# 20230701_BHZ_padariacafebolos_control_NB_papeis_W26                        135
# 20230701_BHZ_padariacafebolos_control_NB_sacos_W26                         146
# 20230701_BHZ_padariacafebolos_control_NB_utensilios_W26                    142
# 20230701_BHZ_padariacafebolos_control_NB_frutas_W26                         81
# 20230701_BHZ_padariacafebolos_control_NB_legumes_W26                        95
# 20230701_BHZ_padariacafebolos_control_NB_tuberculos_W26                     95
# 20230701_BHZ_padariacafebolos_control_NB_verduras_W26                      110
# 20230701_BHZ_padariacafebolos_control_NB_laticinios_W26                    135
# 20230701_BHZ_padariacafebolos_control_NB_leite_W26                          76
# 20230701_BHZ_padariacafebolos_control_NB_manteigasemargarinas_W26          141
# 20230701_BHZ_padariacafebolos_control_NB_ovos_W26                          139
# 20230701_BHZ_padariacafebolos_control_NB_queijos_W26                       127
# 20230701_BHZ_padariacafebolos_control_NB_desengordurantes_W26              147
# 20230701_BHZ_padariacafebolos_control_NB_desinfetantesesanitizantes_W26    126
# 20230701_BHZ_padariacafebolos_control_NB_detergentesabaoelava-louas_W26    125
# 20230701_BHZ_padariacafebolos_control_NB_outroslimpadores_W26              141
# 20230701_BHZ_padariacafebolos_control_NB_utensiliosdelimpeza_W26           144
# 20230701_BHZ_padariacafebolos_control_NB_aucaradoantesedoces_W26            77
# 20230701_BHZ_padariacafebolos_control_NB_arroz_W26                         131
# 20230701_BHZ_padariacafebolos_control_NB_azeitesoleosevinagres_W26          58
# 20230701_BHZ_padariacafebolos_control_NB_cafechocolateseinfusoes_W26       129
# 20230701_BHZ_padariacafebolos_control_NB_condimentos_W26                   138
# 20230701_BHZ_padariacafebolos_control_NB_conservaseenlatados_W26           145
# 20230701_BHZ_padariacafebolos_control_NB_docesesobremesas_W26              147
# 20230701_BHZ_padariacafebolos_control_NB_farinhasemisturas_W26             128
# 20230701_BHZ_padariacafebolos_control_NB_feijao_W26                        132
# 20230701_BHZ_padariacafebolos_control_NB_massasemolhos_W26                 134
# 20230701_BHZ_padariacafebolos_control_NB_temperos_W26                      130
# 20230701_BHZ_padariacafebolos_control_NB_carnevermelha_W26                 139
# 20230701_BHZ_padariacafebolos_control_NB_embutidos_W26                     138
# 20230701_BHZ_padariacafebolos_control_NB_frango_W26                        130
# 20230701_BHZ_padariacafebolos_control_NB_peixesefrutosdomar_W26            148
# 20230701_BHZ_padariacafebolos_control_NB_suinos_W26                        145
# dtype: int64
# Done BHZ padariacafebolos_CONTROL
# //-------------------------------------------------------------------------------
# Boteco
# 260
# Uso de data externa
# 20230701_BHZ_boteco_piloto_NB_aguaseisotonicos_W26              226
# 20230701_BHZ_boteco_piloto_NB_cervejas_W26                      136
# 20230701_BHZ_boteco_piloto_NB_refrigeranteseenergeticos_W26     191
# 20230701_BHZ_boteco_piloto_NB_sucosechas_W26                    229
# 20230701_BHZ_boteco_piloto_NB_destilados_W26                    238
# 20230701_BHZ_boteco_piloto_NB_alimentoscongelados_W26           250
# 20230701_BHZ_boteco_piloto_NB_batataspre-fritas_W26             230
# 20230701_BHZ_boteco_piloto_NB_polpaseaai_W26                    254
# 20230701_BHZ_boteco_piloto_NB_embalagens_W26                    259
# 20230701_BHZ_boteco_piloto_NB_papeis_W26                        228
# 20230701_BHZ_boteco_piloto_NB_sacos_W26                         254
# 20230701_BHZ_boteco_piloto_NB_utensilios_W26                    255
# 20230701_BHZ_boteco_piloto_NB_frutas_W26                        143
# 20230701_BHZ_boteco_piloto_NB_legumes_W26                       156
# 20230701_BHZ_boteco_piloto_NB_tuberculos_W26                    171
# 20230701_BHZ_boteco_piloto_NB_verduras_W26                      189
# 20230701_BHZ_boteco_piloto_NB_laticinios_W26                    235
# 20230701_BHZ_boteco_piloto_NB_leite_W26                         191
# 20230701_BHZ_boteco_piloto_NB_manteigasemargarinas_W26          248
# 20230701_BHZ_boteco_piloto_NB_ovos_W26                          227
# 20230701_BHZ_boteco_piloto_NB_queijos_W26                       228
# 20230701_BHZ_boteco_piloto_NB_desengordurantes_W26              254
# 20230701_BHZ_boteco_piloto_NB_desinfetantesesanitizantes_W26    228
# 20230701_BHZ_boteco_piloto_NB_detergentesabaoelava-louas_W26    209
# 20230701_BHZ_boteco_piloto_NB_outroslimpadores_W26              238
# 20230701_BHZ_boteco_piloto_NB_utensiliosdelimpeza_W26           242
# 20230701_BHZ_boteco_piloto_NB_aucaradoantesedoces_W26           214
# 20230701_BHZ_boteco_piloto_NB_arroz_W26                         222
# 20230701_BHZ_boteco_piloto_NB_azeitesoleosevinagres_W26         150
# 20230701_BHZ_boteco_piloto_NB_cafechocolateseinfusoes_W26       225
# 20230701_BHZ_boteco_piloto_NB_condimentos_W26                   229
# 20230701_BHZ_boteco_piloto_NB_conservaseenlatados_W26           254
# 20230701_BHZ_boteco_piloto_NB_docesesobremesas_W26              258
# 20230701_BHZ_boteco_piloto_NB_farinhasemisturas_W26             228
# 20230701_BHZ_boteco_piloto_NB_feijao_W26                        220
# 20230701_BHZ_boteco_piloto_NB_massasemolhos_W26                 221
# 20230701_BHZ_boteco_piloto_NB_temperos_W26                      223
# 20230701_BHZ_boteco_piloto_NB_carnevermelha_W26                 252
# 20230701_BHZ_boteco_piloto_NB_embutidos_W26                     242
# 20230701_BHZ_boteco_piloto_NB_frango_W26                        221
# 20230701_BHZ_boteco_piloto_NB_peixesefrutosdomar_W26            253
# 20230701_BHZ_boteco_piloto_NB_suinos_W26                        247
# dtype: int64
# Done BHZ boteco_PILOTO
# //-------------------------------------------------------------------------------
# Boteco Experimento50%
# 65
# Uso de data externa
# 20230701_BHZ_boteco_control_NB_aguaseisotonicos_W26              54
# 20230701_BHZ_boteco_control_NB_cervejas_W26                      34
# 20230701_BHZ_boteco_control_NB_refrigeranteseenergeticos_W26     48
# 20230701_BHZ_boteco_control_NB_sucosechas_W26                    58
# 20230701_BHZ_boteco_control_NB_destilados_W26                    60
# 20230701_BHZ_boteco_control_NB_alimentoscongelados_W26           63
# 20230701_BHZ_boteco_control_NB_batataspre-fritas_W26             55
# 20230701_BHZ_boteco_control_NB_polpaseaai_W26                    62
# 20230701_BHZ_boteco_control_NB_embalagens_W26                    65
# 20230701_BHZ_boteco_control_NB_papeis_W26                        52
# 20230701_BHZ_boteco_control_NB_sacos_W26                         65
# 20230701_BHZ_boteco_control_NB_utensilios_W26                    61
# 20230701_BHZ_boteco_control_NB_frutas_W26                        33
# 20230701_BHZ_boteco_control_NB_legumes_W26                       33
# 20230701_BHZ_boteco_control_NB_tuberculos_W26                    40
# 20230701_BHZ_boteco_control_NB_verduras_W26                      45
# 20230701_BHZ_boteco_control_NB_laticinios_W26                    58
# 20230701_BHZ_boteco_control_NB_leite_W26                         45
# 20230701_BHZ_boteco_control_NB_manteigasemargarinas_W26          60
# 20230701_BHZ_boteco_control_NB_ovos_W26                          59
# 20230701_BHZ_boteco_control_NB_queijos_W26                       51
# 20230701_BHZ_boteco_control_NB_desengordurantes_W26              63
# 20230701_BHZ_boteco_control_NB_desinfetantesesanitizantes_W26    58
# 20230701_BHZ_boteco_control_NB_detergentesabaoelava-louas_W26    53
# 20230701_BHZ_boteco_control_NB_outroslimpadores_W26              61
# 20230701_BHZ_boteco_control_NB_utensiliosdelimpeza_W26           61
# 20230701_BHZ_boteco_control_NB_aucaradoantesedoces_W26           50
# 20230701_BHZ_boteco_control_NB_arroz_W26                         50
# 20230701_BHZ_boteco_control_NB_azeitesoleosevinagres_W26         36
# 20230701_BHZ_boteco_control_NB_cafechocolateseinfusoes_W26       57
# 20230701_BHZ_boteco_control_NB_condimentos_W26                   51
# 20230701_BHZ_boteco_control_NB_conservaseenlatados_W26           60
# 20230701_BHZ_boteco_control_NB_docesesobremesas_W26              63
# 20230701_BHZ_boteco_control_NB_farinhasemisturas_W26             55
# 20230701_BHZ_boteco_control_NB_feijao_W26                        55
# 20230701_BHZ_boteco_control_NB_massasemolhos_W26                 55
# 20230701_BHZ_boteco_control_NB_temperos_W26                      51
# 20230701_BHZ_boteco_control_NB_carnevermelha_W26                 61
# 20230701_BHZ_boteco_control_NB_embutidos_W26                     56
# 20230701_BHZ_boteco_control_NB_frango_W26                        51
# 20230701_BHZ_boteco_control_NB_peixesefrutosdomar_W26            61
# 20230701_BHZ_boteco_control_NB_suinos_W26                        58
# dtype: int64
# Done BHZ boteco_CONTROL
# //-------------------------------------------------------------------------------
# Sucos/Açaí
# 164
# Uso de data externa
# 20230701_BHZ_sucosacai_piloto_NB_aguaseisotonicos_W26              127
# 20230701_BHZ_sucosacai_piloto_NB_refrigeranteseenergeticos_W26     121
# 20230701_BHZ_sucosacai_piloto_NB_sucosechas_W26                    136
# 20230701_BHZ_sucosacai_piloto_NB_alimentoscongelados_W26           155
# 20230701_BHZ_sucosacai_piloto_NB_polpaseaai_W26                    158
# 20230701_BHZ_sucosacai_piloto_NB_embalagens_W26                    163
# 20230701_BHZ_sucosacai_piloto_NB_papeis_W26                        144
# 20230701_BHZ_sucosacai_piloto_NB_sacos_W26                         164
# 20230701_BHZ_sucosacai_piloto_NB_utensilios_W26                    163
# 20230701_BHZ_sucosacai_piloto_NB_frutas_W26                         72
# 20230701_BHZ_sucosacai_piloto_NB_legumes_W26                       109
# 20230701_BHZ_sucosacai_piloto_NB_tuberculos_W26                    117
# 20230701_BHZ_sucosacai_piloto_NB_verduras_W26                      127
# 20230701_BHZ_sucosacai_piloto_NB_laticinios_W26                    142
# 20230701_BHZ_sucosacai_piloto_NB_leite_W26                          89
# 20230701_BHZ_sucosacai_piloto_NB_manteigasemargarinas_W26          152
# 20230701_BHZ_sucosacai_piloto_NB_desengordurantes_W26              164
# 20230701_BHZ_sucosacai_piloto_NB_desinfetantesesanitizantes_W26    139
# 20230701_BHZ_sucosacai_piloto_NB_detergentesabaoelava-louas_W26    125
# 20230701_BHZ_sucosacai_piloto_NB_outroslimpadores_W26              157
# 20230701_BHZ_sucosacai_piloto_NB_utensiliosdelimpeza_W26           152
# 20230701_BHZ_sucosacai_piloto_NB_aucaradoantesedoces_W26           103
# 20230701_BHZ_sucosacai_piloto_NB_azeitesoleosevinagres_W26         106
# 20230701_BHZ_sucosacai_piloto_NB_cafechocolateseinfusoes_W26       131
# 20230701_BHZ_sucosacai_piloto_NB_docesesobremesas_W26              154
# dtype: int64
# Done BHZ sucosacai_PILOTO
# //-------------------------------------------------------------------------------
# Sucos/Açaí Experimento50%
# 40
# Uso de data externa
# 20230701_BHZ_sucosacai_control_NB_aguaseisotonicos_W26              31
# 20230701_BHZ_sucosacai_control_NB_refrigeranteseenergeticos_W26     24
# 20230701_BHZ_sucosacai_control_NB_sucosechas_W26                    31
# 20230701_BHZ_sucosacai_control_NB_alimentoscongelados_W26           39
# 20230701_BHZ_sucosacai_control_NB_polpaseaai_W26                    37
# 20230701_BHZ_sucosacai_control_NB_embalagens_W26                    40
# 20230701_BHZ_sucosacai_control_NB_papeis_W26                        37
# 20230701_BHZ_sucosacai_control_NB_sacos_W26                         39
# 20230701_BHZ_sucosacai_control_NB_utensilios_W26                    40
# 20230701_BHZ_sucosacai_control_NB_frutas_W26                        14
# 20230701_BHZ_sucosacai_control_NB_legumes_W26                       23
# 20230701_BHZ_sucosacai_control_NB_tuberculos_W26                    25
# 20230701_BHZ_sucosacai_control_NB_verduras_W26                      27
# 20230701_BHZ_sucosacai_control_NB_laticinios_W26                    35
# 20230701_BHZ_sucosacai_control_NB_leite_W26                         20
# 20230701_BHZ_sucosacai_control_NB_manteigasemargarinas_W26          37
# 20230701_BHZ_sucosacai_control_NB_desengordurantes_W26              39
# 20230701_BHZ_sucosacai_control_NB_desinfetantesesanitizantes_W26    36
# 20230701_BHZ_sucosacai_control_NB_detergentesabaoelava-louas_W26    33
# 20230701_BHZ_sucosacai_control_NB_outroslimpadores_W26              39
# 20230701_BHZ_sucosacai_control_NB_utensiliosdelimpeza_W26           37
# 20230701_BHZ_sucosacai_control_NB_aucaradoantesedoces_W26           23
# 20230701_BHZ_sucosacai_control_NB_azeitesoleosevinagres_W26         31
# 20230701_BHZ_sucosacai_control_NB_cafechocolateseinfusoes_W26       36
# 20230701_BHZ_sucosacai_control_NB_docesesobremesas_W26              39
# dtype: int64
# Done BHZ sucosacai_CONTROL

# %% [markdown]
# ## Aca creo el archivo para R&D

# %%
# customers =  pd.DataFrame()
# for column,i in enumerate(aux_df.columns):
#     #if ('verduras' in i or 'frutas' in i or 'arroz' in i or 'aceitesygrasas' in i or 'harinasymezclas' in i or 'azucaryendulzantes' in i or 'pollo' in i or 'huevos' in i) and not 'frutasjugo' in i:
#     #if ('verduras' in i or 'frutas' in i) and not 'frutasjugo' in i:
#     customers[i] = aux_df[i]

# %%
# customers.iloc[:6000].to_csv(f'SD/export_data/MS/csv_{city_code}_CLIENTS_PRUEBA_R&D.csv', index = False)

# with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
#        json.dump(global_segment_list, outfile)

# %%
# aux_seg = pd.read_csv(f"prueba_tuberculos_BAQ.csv")
# aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

# aux_seg["final_group2"] = ["piloto" if x == "Super Descuentos" else "control" for x in aux_seg.grupos]
# aux_seg['offer_name'] = f"20230301_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W9"

# aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()

# %%
# lst = []
# for x in aux_seg2.values:
#     h = {'name':x[0], 'customersIds': list(x[1])}
#     lst.append(h)
    
# for x in lst:
#     print(x['name'])
#     #break
#     for i,value in enumerate(global_segment_list):
#         if value['name'] == x['name']:
#             global_segment_list[i]['customersIds'] = x['customersIds']
#             print(i)

# %%
aux_seg = pd.read_csv(f"csv_{city_code}_CLIENTS_FINAL_JULIO_R&D.csv")
aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

aux_seg["final_group2"] = ["piloto" if x == "Treatment" else "control" for x in aux_seg.final_group]
aux_seg['offer_name'] = f"20230701_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W26"

aux_seg["quartile"] = ["Q0" if x == "-" else x for x in aux_seg.quartile.values]
aux_seg["quartile_name"] = f"20230701_{city_code}_" + aux_seg.subcategory + "_" + aux_seg.quartile + "_" + aux_seg.case

aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()
aux_seg3 = aux_seg.groupby(by = ["quartile_name"])["customer_source_id"].apply(list).reset_index()

# %%
aux_seg.head()
# Out:
#         subcategory  customer_source_id               ms previous_group  \
# 0  aguaseisotonicos            67992602  pratosrefeicoes      Treatment
# 1  aguaseisotonicos           184408681  pratosrefeicoes      Treatment
# 2  aguaseisotonicos           192864028            other      Treatment
# 3  aguaseisotonicos           219056799          lanches      Treatment
# 4  aguaseisotonicos            73582996  pratosrefeicoes      Treatment
#
#          case quartile  random final_group final_group2  \
# 0  positivity       Q4       0   Treatment       piloto
# 1  positivity       Q4       1     Control      control
# 2  positivity       Q4       0   Treatment       piloto
# 3  positivity       Q4       0   Treatment       piloto
# 4  positivity       Q4       0   Treatment       piloto
#
#                                           offer_name  \
# 0  20230701_BHZ_pratosrefeicoes_piloto_NB_aguasei...
# 1  20230701_BHZ_pratosrefeicoes_control_NB_aguase...
# 2  20230701_BHZ_other_piloto_NB_aguaseisotonicos_W26
# 3  20230701_BHZ_lanches_piloto_NB_aguaseisotonico...
# 4  20230701_BHZ_pratosrefeicoes_piloto_NB_aguasei...
#
#                                  quartile_name
# 0  20230701_BHZ_aguaseisotonicos_Q4_positivity
# 1  20230701_BHZ_aguaseisotonicos_Q4_positivity
# 2  20230701_BHZ_aguaseisotonicos_Q4_positivity
# 3  20230701_BHZ_aguaseisotonicos_Q4_positivity
# 4  20230701_BHZ_aguaseisotonicos_Q4_positivity

# %%
lst = []
for x in aux_seg2.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst.append(h)

global_segment_list = lst

# %%
lst2 = []
for x in aux_seg3.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst2.append(h)

# %% [markdown]
# # Aca tengo que volver a cargar el archivo de arriba y dejarlo como lista para traer lo otro

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_BHZ_lanches_piloto_NB_aguaseisotonico...
# 1        20230701_BHZ_lanches_piloto_NB_cervejas_W26
# 2  20230701_BHZ_lanches_piloto_NB_refrigerantesee...
# 3      20230701_BHZ_lanches_piloto_NB_sucosechas_W26
# 4      20230701_BHZ_lanches_piloto_NB_destilados_W26
#
#                              offer_description  discount  \
# 0           lanches_piloto_NB_aguaseisotonicos         7
# 1                   lanches_piloto_NB_cervejas         5
# 2  lanches_piloto_NB_refrigeranteseenergeticos         5
# 3                 lanches_piloto_NB_sucosechas         6
# 4                 lanches_piloto_NB_destilados         5
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                   9
# 1                         true  01-07-2023  31-07-2023                   9
# 2                         true  01-07-2023  31-07-2023                   9
# 3                         true  01-07-2023  31-07-2023                   9
# 4                         true  01-07-2023  31-07-2023                   9
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1                None
# 1                      1                None
# 2                      1                None
# 3                      1                None
# 4                      1                None
#
#                                               sku_id
# 0                                      616555#616553
# 1  363897#363896#460763#460764#460765#324004#3240...
# 2  453798#453800#453799#258149#258148#304090#4533...
# 3  258191#258190#258185#258184#258178#258179#2581...
# 4                                      589445#589447

# %%
#len_seg =int(len(global_segment_list)/10)
#len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %% [markdown]
# ## Crear segments offers y segments types

# %%
import requests
import json

def create_segments(segment_list):
    
    url = f"https://{city_code}.frubana.com/api/v1/segments/create?api-key=00_growth-team-zzz-qqq_001"

    payload = json.dumps(segment_list)


    headers = {
    'Cookie': 'AWSALB=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALBCORS=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALB=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI; AWSALBCORS=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI',
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.status_code)
    sgt = [(int(x[:6]),x[7:]) for x in list(map(str.strip, response.text[32:].strip('][').replace('"', '').split(',')))]
    time.sleep(40)
    return sgt

# %%
len_seg =int(len(global_segment_list)/10)
len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %%
#offers
sgt=[]

for i in len_seg_list:
    sgt.append(create_segments(i))
    
sgt_end =[item for lista in sgt for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len_seg2 =int(len(lst2)/10)
len_seg_list2 = [lst2[:len_seg2],lst2[len_seg2:len_seg2*2],lst2[len_seg2*2:len_seg2*3],lst2[len_seg2*3:len_seg2*4],lst2[len_seg2*4:len_seg2*5],lst2[len_seg2*5:len_seg2*6],lst2[len_seg2*6:len_seg2*7],lst2[len_seg2*7:len_seg2*8],lst2[len_seg2*8:len_seg2*9],lst2[len_seg2*9:]]

# %%
#types
sgt2=[]

for i in len_seg_list2:
    sgt2.append(create_segments(i))
    
sgt_end2 =[item for lista in sgt2 for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#unir offers con segments
for i in global_offer_csv.offer_name:
    for j,z in sgt_end:
        if z==i:
            global_offer_csv.loc[global_offer_csv.offer_name == i, ('customer_segment_id')] = j

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_BHZ_lanches_piloto_NB_aguaseisotonico...
# 1        20230701_BHZ_lanches_piloto_NB_cervejas_W26
# 2  20230701_BHZ_lanches_piloto_NB_refrigerantesee...
# 3      20230701_BHZ_lanches_piloto_NB_sucosechas_W26
# 4      20230701_BHZ_lanches_piloto_NB_destilados_W26
#
#                              offer_description  discount  \
# 0           lanches_piloto_NB_aguaseisotonicos         7
# 1                   lanches_piloto_NB_cervejas         5
# 2  lanches_piloto_NB_refrigeranteseenergeticos         5
# 3                 lanches_piloto_NB_sucosechas         6
# 4                 lanches_piloto_NB_destilados         5
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                   9
# 1                         true  01-07-2023  31-07-2023                   9
# 2                         true  01-07-2023  31-07-2023                   9
# 3                         true  01-07-2023  31-07-2023                   9
# 4                         true  01-07-2023  31-07-2023                   9
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              182157
# 1                      1              182165
# 2                      1              182501
# 3                      1              182503
# 4                      1                None
#
#                                               sku_id
# 0                                      616555#616553
# 1  363897#363896#460763#460764#460765#324004#3240...
# 2  453798#453800#453799#258149#258148#304090#4533...
# 3  258191#258190#258185#258184#258178#258179#2581...
# 4                                      589445#589447

# %%
global_offer_csv = global_offer_csv.loc[~global_offer_csv.customer_segment_id.isnull()].reset_index(drop=True)
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('discount','max_uses_per_order')]=1
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('start_date','end_date')]='01-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('end_date')]='02-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('sku_id')]= global_offer_csv.loc[~global_offer_csv['offer_name'].str.contains("piloto", case=False), ('sku_id')].tolist()

# %%
len_offer =int(len(global_offer_csv)/4)
len_offer = [global_offer_csv[:len_seg],global_offer_csv[len_seg:len_seg*2],global_offer_csv[len_seg*2:len_seg*3],global_offer_csv[len_seg*3:]]

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_BHZ_lanches_piloto_NB_aguaseisotonico...
# 1        20230701_BHZ_lanches_piloto_NB_cervejas_W26
# 2  20230701_BHZ_lanches_piloto_NB_refrigerantesee...
# 3      20230701_BHZ_lanches_piloto_NB_sucosechas_W26
# 4  20230701_BHZ_lanches_piloto_NB_alimentoscongel...
#
#                              offer_description  discount  \
# 0           lanches_piloto_NB_aguaseisotonicos         7
# 1                   lanches_piloto_NB_cervejas         5
# 2  lanches_piloto_NB_refrigeranteseenergeticos         5
# 3                 lanches_piloto_NB_sucosechas         6
# 4        lanches_piloto_NB_alimentoscongelados        13
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                   9
# 1                         true  01-07-2023  31-07-2023                   9
# 2                         true  01-07-2023  31-07-2023                   9
# 3                         true  01-07-2023  31-07-2023                   9
# 4                         true  01-07-2023  31-07-2023                  15
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              182157
# 1                      1              182165
# 2                      1              182501
# 3                      1              182503
# 4                      1              182158
#
#                                               sku_id
# 0                                      616555#616553
# 1  363897#363896#460763#460764#460765#324004#3240...
# 2  453798#453800#453799#258149#258148#304090#4533...
# 3  258191#258190#258185#258184#258178#258179#2581...
# 4                               356887#263667#527270

# %%
#//--------------------------------------------
#//Exporting single file data
global_offer_csv.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS.csv', index = False)

for i,offer in enumerate(len_offer):
    offer.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS_{i}.csv', index = False)

with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
        json.dump(global_segment_list, outfile)    
with open(f'SD/export_data/MS/nb_{city_code}_All_MS.json', 'w') as outfile:
        json.dump(global_segment_list, outfile)
print(f'Done {city_code}')
# Out:
# Done BHZ
