# %%
#//----------------------------
#//LIBRARIES
    #Math
import math
    #Numeric Python
import numpy as np
    #Pandas (dataframes)
import pandas as pd
    #datetime for fate manipulation
from datetime import date, datetime, timedelta  
    #Regex for advanced string matching
import re
    #for time related stuff
import time
    #json library
import json
    #Analyst tools
import sys
sys.path.append('../')
from analysts_tools.growth import *
    #Procurement tools
from analysts_tools.redash_methods import *
    #Frubana libraries
from procurement_lib import redash, dw, send_message, send_slack_notification, GoogleSheet, logging

# %%
query="""
With microsegment as (

SELECT DISTINCT c.customer_id AS user_id,
                c.site_type AS region_code_ms,
                
                (case 
                    -- Colombia
                    when m.microsegment_id not in (1,3,4,28,5,6,7,8,2) and c.site_type = 'BOG' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1,3,4,28,5,11,10,9,2,12) and c.site_type = 'BAQ' then 'Sin Microsegmento'
                    when m.microsegment_id not in (3,4,28,1,24,11,5,2,27) and c.site_type = 'MDE' then 'Sin Microsegmento'
    
                    -- Mexico
                    when m.microsegment_id not in (1,13,14,30,15,16,29,17,6,7,2) and c.site_type = 'CMX' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1, 13,14,30, 15,16,29, 6, 33, 2, 31) and c.site_type = 'GDL' then 'Sin Microsegmento'
                    when m.microsegment_id not in (13,14,30, 15,16,29, 32,2,6,33) and c.site_type = 'PBC' then 'Sin Microsegmento'
                    
                    -- Brasil
                    when m.microsegment_id not in (21,34,38,37,35,36,39,26) and c.site_type in ('SPO','BHZ','CWB','VCP') then 'Sin Microsegmento'
                        
                else m.description end) as microsegment_ok,
                
                m.microsegment_id,
                mo.name as ms_method
                
                
FROM postgres_main_federate."growth_microsegmentation.customer_microsegment" AS cm
INNER JOIN postgres_main_federate."growth_microsegmentation.microsegment" m ON cm.microsegment_id = m.id
INNER JOIN postgres_main_federate."growth_microsegmentation.customer" c ON cm.customer_id = c.id
INNER JOIN postgres_main_federate."growth_microsegmentation.models" mo ON mo.id = cm.model_type_id


)

select m.user_id,
m.region_code_ms,
--m.microsegment_id,

(case 
        when m.microsegment_ok in ('Corrientazo c/desayuno','Corrientazo s/desayuno','Tienda/Restaurante') then 'Corrientazo' 
        when m.microsegment_ok in ('Fonda c/desayuno','Fonda s/desayuno') then 'Fonda'
        when m.microsegment_ok in ('Taquería en calle','Taquería en local') then 'Taquería'

else m.microsegment_ok end) as microsegment,

m.ms_method

from microsegment m
where m.microsegment_ok != 'Sin Microsegmento'
"""

segmentos_fulll = read_connection_data_warehouse.runQuery(query)

segmentos_fulll.columns = ['customer_id', 'city', 'microsegment','NA']
segmentos_fulll = segmentos_fulll[['customer_id', 'city', 'microsegment']]

# %%
#//---------------------------------------------------------------------------------------------------------------------------
#// Parametros
"""Todays date should be the first day of the next month which is going to begin with SD"""

city_code = 'BHZ'

# Set today's date to the first day of the next month
today = datetime.today()
first_day_next_month = (today.replace(day=1) + timedelta(days=32)).replace(day=1)

# Calculate non_buyers_date (todays date - 1 month)
non_buyers_date = (first_day_next_month - timedelta(days=1)).replace(day=1)
customer_date_desde = (first_day_next_month - timedelta(days=1)).replace(day=1)

# Calculate sku_date_desde (todays date - 2 months)
sku_date_desde = (first_day_next_month - timedelta(days=60)).replace(day=1)

# Convert the dates to strings in the desired format
todays_date = first_day_next_month.strftime('%Y-%m-%d')
non_buyers_date = non_buyers_date.strftime('%Y-%m-%d')
customer_date_desde = customer_date_desde.strftime('%Y-%m-%d')
sku_date_desde = sku_date_desde.strftime('%Y-%m-%d')

print(todays_date) # Output: e.g. 2023-04-01
print(non_buyers_date) # Output: e.g. 2023-03-01
print(sku_date_desde) # Output: e.g. 2023-02-01

tasas = {'BOG': 3776,
         'BAQ': 3776,
         'MDE': 3776,
         'CMX': 19.65,
         'GDL': 19.65,
         'PBC': 19.65,
         'SPO': 4.75,
         'BHZ': 4.75,
         'CWB': 4.75,
         'VCP': 4.75}

t_cambio = tasas[city_code]
# Out:
# 2023-06-01
# 2023-05-01
# 2023-04-01

# %% [markdown]
# ### Loading COSTUMERS INFO

# %%
users_eliminar_kam = get_fresh_query_result("https://internal-redash.federate.frubana.com/",150812,'SeoGHWmDUaaBi7VXje1s9zYNiMD1VHQ1K1DYOxiF',{},20)
users_eliminar = users_eliminar_kam.loc[users_eliminar_kam.registered_city == city_code]['customer_id'].unique().tolist()
# Out:
# 200

# %% [markdown]
# ### Loading FORCED_SKUS // Cleaning SEGMENT_NAMES

# %% [markdown]
# ### Loading DATA_VENTAS // Removing SKUs /\ CUSTOMERS_ID

# %%
#//Remove skus 
#It is used because some SKUs can get in trouble with supplier for the SD or to exclude them for another activity   
skus_remove = GoogleSheet("1Z0T_c36oRHmOHIgEG8_ANcwFykaHgXGAizYAYCKCqtY")
skus_remove = skus_remove.get_as_dataframe('SKUS')

skus_remove = skus_remove['sku_id'].unique().astype(int).tolist()

# %%
query = """
SELECT DISTINCT
    split_part(bs.upc, '-', 1) as region,
    bs.sku_id

FROM postgres_broadleaf_federate."broadleaf.blc_sku"            bs 
LEFT JOIN postgres_broadleaf_federate."broadleaf.blc_product"   bp ON bp.product_id = bs.addl_product_id

WHERE bs.archived = 'N'
    AND bs.sndbx_id is NULL
    AND bp.archived = 'N'
    AND bs.catalog_disc < 0
    AND ((bp.archived = 'N' AND bp.sndbx_id is NULL) OR (bp.archived is NULL))
"""
frida_products = read_connection_data_warehouse.runQuery(query)

# %%
good_skus = frida_products.sku_id.unique()

# %%
#Loading SELL'S DATA from a function
data_ventas = data_ventas_query(ciudad=city_code, tipo_cambio=t_cambio, desde=customer_date_desde, hasta = todays_date, tipo_negocio=1)

# %%
data_ventas = data_ventas[(~data_ventas['sku_id'].isin(skus_remove)) & (data_ventas['sku_id'].isin(good_skus))]

# %%
segmentos_full = segmentos_fulll[segmentos_fulll.city == city_code].copy()

# %%
#//customers for offers */(has further uses)*/
microsegmentacion_df = segmentos_full[(~segmentos_full['customer_id'].isin(users_eliminar))]
data_ventas = data_ventas[(~data_ventas['customer_id'].isin(users_eliminar))]

# %% [markdown]
# ### Create the MS "Other" for BAU

# %%
data_full = data_ventas.merge(microsegmentacion_df[['customer_id','microsegment']], how = 'left', on = 'customer_id')

# %%
data_full['microsegment'] = data_full['microsegment'].fillna('Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                    microsegment  customer_id
# 0                        Boteco          318
# 1  Grill/Churrascaria/Espetinho          154
# 2        Japonesa/Internacional           45
# 3                       Lanches          831
# 4                         Other          501
# 5            Padaria/Cafe/Bolos          735
# 6  Pizzaria/Pastelaria/Italiano          151
# 7              Pratos/Refeições          990
# 8                    Sucos/Açaí          196

# %%
segments_validation = data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()

# %%
for ms in segments_validation[segments_validation.customer_id < 180]['microsegment'].unique():
    data_full['microsegment'] = data_full['microsegment'].str.replace(ms,'Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#          microsegment  customer_id
# 0              Boteco          318
# 1             Lanches          831
# 2               Other          851
# 3  Padaria/Cafe/Bolos          735
# 4    Pratos/Refeições          990
# 5          Sucos/Açaí          196

# %%
#Get the same variable to do the process job
data_ventas = data_full

# %% [markdown]
# ### PARAMETERS // SOME FUNCTIONS - GET READY TO PROCESSING

# %%
def ms_data(city_code):
  
    paramss_csv=GoogleSheet("1k0ckgkLddxc5lY8NUVGCkvDLTuulLaJm-N535oMNZNw")
    city_paramss = paramss_csv.get_as_dataframe(city_code)
    
    parametros = {}
    parametros[city_code] = {}
    
    for i,ms in enumerate(city_paramss.iloc[:,4:].columns):
        parametros[city_code][ms] = [(value[1],value[2],value[3],value[4+i]) for value in city_paramss.values if value[4+i]>0]
        
    return parametros

# %%
parametros = ms_data(city_code)

# %%
def normalize_text(raw_text):
    """
    Removes common accent characters and normalize text.
    """
    raw_text = raw_text.replace(" ", "")
    raw_text = raw_text.replace("�", "")
    raw_text = raw_text.replace("/", "")
    raw_text = re.sub(r'\s*', '', raw_text)
    raw_text = re.sub(r"[àáâãäå]", 'a', raw_text)
    raw_text = re.sub(r"[èéêë]", 'e', raw_text)
    raw_text = re.sub(r"[ìíîï]", 'i', raw_text) 
    raw_text = re.sub(r"[òóôõö]", 'o', raw_text)
    raw_text = re.sub(r"[ùúûü]", 'u', raw_text)
    raw_text = re.sub(r"[ýÿ]", 'y', raw_text)
    raw_text = re.sub(r"[ß]", 'ss', raw_text)
    raw_text = re.sub(r"[ñ]", 'n', raw_text)
    raw_text = re.sub(r"[ç]", 'c', raw_text)
    raw_text = raw_text.lower()
    return raw_text

# %%
#Sacar de aca los microsegmentos
msg = data_full.microsegment.unique()
msg
# Out:
# array(['Padaria/Cafe/Bolos', 'Lanches', 'Other', 'Pratos/Refeições',
#        'Sucos/Açaí', 'Boteco'], dtype=object)

# %% [markdown]
# ### END

# %% [markdown]
# # Aca Empieza la Experimentacion

# %%
from sklearn.model_selection import train_test_split

# %%
#//Variables to store all the segments and offers of the city
global_offer_csv = pd.DataFrame()
global_segment_list = [] #//for procesing

# %%
#//----------------------------------------------------------------------------
#//Big loop for creating each city segments/offers files
aux_df = pd.DataFrame()
aux_df['aux']=6000*[0]

for microsegment in msg:
    print('//-------------------------------------------------------------------------------')
    print(microsegment)

    #//Customers per microsegment
    customers_ms = data_ventas[(data_ventas['microsegment'] == microsegment)]['customer_id'].unique()
    #//Customers to give them the skus
    customers_for_skus_ms =  data_ventas[['microsegment','customer_id']][(data_ventas.microsegment == microsegment) & (~data_ventas.customer_id.isin(users_eliminar))]['customer_id'].unique()
    
    #----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_PILOTO" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    rand=1
    customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state=rand)
    
    while abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())) > 0.05:
        #print(data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean(),data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean(),abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())))
        rand+=1
        customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state = rand)
        
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_1)].copy() #le quite la s!!
    
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()
    
    subcats = list(map(lambda x: x[0], parametros[city_code][microsegment]))
    max_uses = list(map(lambda x: int(x[1]), parametros[city_code][microsegment]))
    max_order = list(map(lambda x: int(x[2]), parametros[city_code][microsegment]))
    discount = list(map(lambda x: int(x[3]), parametros[city_code][microsegment]))

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    a, b, c = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
            non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                        limite=0.75, data_ventas_skus = data_skus)

    print(b.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(a)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in b.columns:
        id_list = b[seg].dropna().astype(int)
        d = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)

        lst.append(d)
        
    #//appending to global list    
        global_segment_list.append(d)
    
    print(f'Done {city_code} {ms_name}')

#----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------


#----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_CONTROL" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_2)].copy() #le quite la s!!
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    print('//-------------------------------------------------------------------------------')
    print(f'{microsegment} Experimento50%')
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    e, f, g = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
                non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                          limite=0.75, data_ventas_skus = data_skus)
      
    print(f.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(e)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in f.columns:
        id_list = f[seg].dropna().astype(int)
        h = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)
        
        lst.append(h)
        
        
    #//appending to global list    
        global_segment_list.append(h)
    
    print(f'Done {city_code} {ms_name}')
    #----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#//End of big loop and start of data bundle
# Out:
# //-------------------------------------------------------------------------------
# Padaria/Cafe/Bolos
# 588
# Uso de data externa
# 20230601_BHZ_padariacafebolos_piloto_NB_aguaseisotonicos_W22              517
# 20230601_BHZ_padariacafebolos_piloto_NB_cervejas_W22                      439
# 20230601_BHZ_padariacafebolos_piloto_NB_refrigeranteseenergeticos_W22     473
# 20230601_BHZ_padariacafebolos_piloto_NB_sucosechas_W22                    492
# 20230601_BHZ_padariacafebolos_piloto_NB_destilados_W22                    581
# 20230601_BHZ_padariacafebolos_piloto_NB_alimentoscongelados_W22           568
# 20230601_BHZ_padariacafebolos_piloto_NB_batataspre-fritas_W22             553
# 20230601_BHZ_padariacafebolos_piloto_NB_polpaseaai_W22                    568
# 20230601_BHZ_padariacafebolos_piloto_NB_coposrecipientesepratos_W22       584
# 20230601_BHZ_padariacafebolos_piloto_NB_embalagens_W22                    587
# 20230601_BHZ_padariacafebolos_piloto_NB_papeis_W22                        518
# 20230601_BHZ_padariacafebolos_piloto_NB_sacos_W22                         578
# 20230601_BHZ_padariacafebolos_piloto_NB_utensilios_W22                    569
# 20230601_BHZ_padariacafebolos_piloto_NB_frutas_W22                        334
# 20230601_BHZ_padariacafebolos_piloto_NB_legumes_W22                       353
# 20230601_BHZ_padariacafebolos_piloto_NB_tuberculos_W22                    377
# 20230601_BHZ_padariacafebolos_piloto_NB_verduras_W22                      430
# 20230601_BHZ_padariacafebolos_piloto_NB_laticinios_W22                    502
# 20230601_BHZ_padariacafebolos_piloto_NB_leite_W22                         300
# 20230601_BHZ_padariacafebolos_piloto_NB_manteigasemargarinas_W22          544
# 20230601_BHZ_padariacafebolos_piloto_NB_ovos_W22                          537
# 20230601_BHZ_padariacafebolos_piloto_NB_queijos_W22                       502
# 20230601_BHZ_padariacafebolos_piloto_NB_desengordurantes_W22              585
# 20230601_BHZ_padariacafebolos_piloto_NB_desinfetantesesanitizantes_W22    493
# 20230601_BHZ_padariacafebolos_piloto_NB_detergentesabaoelava-louas_W22    463
# 20230601_BHZ_padariacafebolos_piloto_NB_outroslimpadores_W22              550
# 20230601_BHZ_padariacafebolos_piloto_NB_utensiliosdelimpeza_W22           544
# 20230601_BHZ_padariacafebolos_piloto_NB_aucaradoantesedoces_W22           305
# 20230601_BHZ_padariacafebolos_piloto_NB_arroz_W22                         524
# 20230601_BHZ_padariacafebolos_piloto_NB_azeitesoleosevinagres_W22         190
# 20230601_BHZ_padariacafebolos_piloto_NB_cafechocolateseinfusoes_W22       507
# 20230601_BHZ_padariacafebolos_piloto_NB_condimentos_W22                   536
# 20230601_BHZ_padariacafebolos_piloto_NB_conservaseenlatados_W22           551
# 20230601_BHZ_padariacafebolos_piloto_NB_docesesobremesas_W22              566
# 20230601_BHZ_padariacafebolos_piloto_NB_farinhasemisturas_W22             541
# 20230601_BHZ_padariacafebolos_piloto_NB_feijao_W22                        513
# 20230601_BHZ_padariacafebolos_piloto_NB_massasemolhos_W22                 499
# 20230601_BHZ_padariacafebolos_piloto_NB_temperos_W22                      491
# 20230601_BHZ_padariacafebolos_piloto_NB_carnevermelha_W22                 562
# 20230601_BHZ_padariacafebolos_piloto_NB_embutidos_W22                     531
# 20230601_BHZ_padariacafebolos_piloto_NB_frango_W22                        494
# 20230601_BHZ_padariacafebolos_piloto_NB_peixesefrutosdomar_W22            571
# 20230601_BHZ_padariacafebolos_piloto_NB_suinos_W22                        573
# dtype: int64
# Done BHZ padariacafebolos_PILOTO
# //-------------------------------------------------------------------------------
# Padaria/Cafe/Bolos Experimento50%
# 147
# Uso de data externa
# 20230601_BHZ_padariacafebolos_control_NB_aguaseisotonicos_W22              133
# 20230601_BHZ_padariacafebolos_control_NB_cervejas_W22                      109
# 20230601_BHZ_padariacafebolos_control_NB_refrigeranteseenergeticos_W22     115
# 20230601_BHZ_padariacafebolos_control_NB_sucosechas_W22                    124
# 20230601_BHZ_padariacafebolos_control_NB_destilados_W22                    146
# 20230601_BHZ_padariacafebolos_control_NB_alimentoscongelados_W22           140
# 20230601_BHZ_padariacafebolos_control_NB_batataspre-fritas_W22             128
# 20230601_BHZ_padariacafebolos_control_NB_polpaseaai_W22                    143
# 20230601_BHZ_padariacafebolos_control_NB_coposrecipientesepratos_W22       147
# 20230601_BHZ_padariacafebolos_control_NB_embalagens_W22                    147
# 20230601_BHZ_padariacafebolos_control_NB_papeis_W22                        133
# 20230601_BHZ_padariacafebolos_control_NB_sacos_W22                         147
# 20230601_BHZ_padariacafebolos_control_NB_utensilios_W22                    146
# 20230601_BHZ_padariacafebolos_control_NB_frutas_W22                         80
# 20230601_BHZ_padariacafebolos_control_NB_legumes_W22                        85
# 20230601_BHZ_padariacafebolos_control_NB_tuberculos_W22                     91
# 20230601_BHZ_padariacafebolos_control_NB_verduras_W22                      108
# 20230601_BHZ_padariacafebolos_control_NB_laticinios_W22                    126
# 20230601_BHZ_padariacafebolos_control_NB_leite_W22                          79
# 20230601_BHZ_padariacafebolos_control_NB_manteigasemargarinas_W22          140
# 20230601_BHZ_padariacafebolos_control_NB_ovos_W22                          135
# 20230601_BHZ_padariacafebolos_control_NB_queijos_W22                       118
# 20230601_BHZ_padariacafebolos_control_NB_desengordurantes_W22              145
# 20230601_BHZ_padariacafebolos_control_NB_desinfetantesesanitizantes_W22    129
# 20230601_BHZ_padariacafebolos_control_NB_detergentesabaoelava-louas_W22    124
# 20230601_BHZ_padariacafebolos_control_NB_outroslimpadores_W22              138
# 20230601_BHZ_padariacafebolos_control_NB_utensiliosdelimpeza_W22           137
# 20230601_BHZ_padariacafebolos_control_NB_aucaradoantesedoces_W22            86
# 20230601_BHZ_padariacafebolos_control_NB_arroz_W22                         134
# 20230601_BHZ_padariacafebolos_control_NB_azeitesoleosevinagres_W22          64
# 20230601_BHZ_padariacafebolos_control_NB_cafechocolateseinfusoes_W22       129
# 20230601_BHZ_padariacafebolos_control_NB_condimentos_W22                   139
# 20230601_BHZ_padariacafebolos_control_NB_conservaseenlatados_W22           138
# 20230601_BHZ_padariacafebolos_control_NB_docesesobremesas_W22              142
# 20230601_BHZ_padariacafebolos_control_NB_farinhasemisturas_W22             133
# 20230601_BHZ_padariacafebolos_control_NB_feijao_W22                        134
# 20230601_BHZ_padariacafebolos_control_NB_massasemolhos_W22                 122
# 20230601_BHZ_padariacafebolos_control_NB_temperos_W22                      127
# 20230601_BHZ_padariacafebolos_control_NB_carnevermelha_W22                 140
# 20230601_BHZ_padariacafebolos_control_NB_embutidos_W22                     133
# 20230601_BHZ_padariacafebolos_control_NB_frango_W22                        128
# 20230601_BHZ_padariacafebolos_control_NB_peixesefrutosdomar_W22            146
# 20230601_BHZ_padariacafebolos_control_NB_suinos_W22                        141
# dtype: int64
# Done BHZ padariacafebolos_CONTROL
# //-------------------------------------------------------------------------------
# Lanches
# 665
# Uso de data externa
# 20230601_BHZ_lanches_piloto_NB_aguaseisotonicos_W22              557
# 20230601_BHZ_lanches_piloto_NB_cervejas_W22                      512
# 20230601_BHZ_lanches_piloto_NB_refrigeranteseenergeticos_W22     445
# 20230601_BHZ_lanches_piloto_NB_sucosechas_W22                    550
# 20230601_BHZ_lanches_piloto_NB_destilados_W22                    663
# 20230601_BHZ_lanches_piloto_NB_alimentoscongelados_W22           621
# 20230601_BHZ_lanches_piloto_NB_batataspre-fritas_W22             552
# 20230601_BHZ_lanches_piloto_NB_polpaseaai_W22                    638
# 20230601_BHZ_lanches_piloto_NB_coposrecipientesepratos_W22       647
# 20230601_BHZ_lanches_piloto_NB_embalagens_W22                    660
# 20230601_BHZ_lanches_piloto_NB_papeis_W22                        569
# 20230601_BHZ_lanches_piloto_NB_sacos_W22                         656
# 20230601_BHZ_lanches_piloto_NB_utensilios_W22                    655
# 20230601_BHZ_lanches_piloto_NB_frutas_W22                        282
# 20230601_BHZ_lanches_piloto_NB_legumes_W22                       315
# 20230601_BHZ_lanches_piloto_NB_tuberculos_W22                    396
# 20230601_BHZ_lanches_piloto_NB_verduras_W22                      442
# 20230601_BHZ_lanches_piloto_NB_laticinios_W22                    584
# 20230601_BHZ_lanches_piloto_NB_leite_W22                         452
# 20230601_BHZ_lanches_piloto_NB_manteigasemargarinas_W22          605
# 20230601_BHZ_lanches_piloto_NB_ovos_W22                          566
# 20230601_BHZ_lanches_piloto_NB_queijos_W22                       529
# 20230601_BHZ_lanches_piloto_NB_desengordurantes_W22              647
# 20230601_BHZ_lanches_piloto_NB_desinfetantesesanitizantes_W22    557
# 20230601_BHZ_lanches_piloto_NB_detergentesabaoelava-louas_W22    504
# 20230601_BHZ_lanches_piloto_NB_outroslimpadores_W22              591
# 20230601_BHZ_lanches_piloto_NB_utensiliosdelimpeza_W22           588
# 20230601_BHZ_lanches_piloto_NB_aucaradoantesedoces_W22           484
# 20230601_BHZ_lanches_piloto_NB_arroz_W22                         565
# 20230601_BHZ_lanches_piloto_NB_azeitesoleosevinagres_W22         310
# 20230601_BHZ_lanches_piloto_NB_cafechocolateseinfusoes_W22       552
# 20230601_BHZ_lanches_piloto_NB_condimentos_W22                   547
# 20230601_BHZ_lanches_piloto_NB_conservaseenlatados_W22           631
# 20230601_BHZ_lanches_piloto_NB_docesesobremesas_W22              648
# 20230601_BHZ_lanches_piloto_NB_farinhasemisturas_W22             592
# 20230601_BHZ_lanches_piloto_NB_feijao_W22                        562
# 20230601_BHZ_lanches_piloto_NB_massasemolhos_W22                 540
# 20230601_BHZ_lanches_piloto_NB_temperos_W22                      545
# 20230601_BHZ_lanches_piloto_NB_carnevermelha_W22                 635
# 20230601_BHZ_lanches_piloto_NB_embutidos_W22                     595
# 20230601_BHZ_lanches_piloto_NB_frango_W22                        515
# 20230601_BHZ_lanches_piloto_NB_peixesefrutosdomar_W22            643
# 20230601_BHZ_lanches_piloto_NB_suinos_W22                        635
# dtype: int64
# Done BHZ lanches_PILOTO
# //-------------------------------------------------------------------------------
# Lanches Experimento50%
# 166
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)
# Uso de data externa
# 20230601_BHZ_lanches_control_NB_aguaseisotonicos_W22              140
# 20230601_BHZ_lanches_control_NB_cervejas_W22                      126
# 20230601_BHZ_lanches_control_NB_refrigeranteseenergeticos_W22     105
# 20230601_BHZ_lanches_control_NB_sucosechas_W22                    135
# 20230601_BHZ_lanches_control_NB_destilados_W22                    165
# 20230601_BHZ_lanches_control_NB_alimentoscongelados_W22           159
# 20230601_BHZ_lanches_control_NB_batataspre-fritas_W22             135
# 20230601_BHZ_lanches_control_NB_polpaseaai_W22                    160
# 20230601_BHZ_lanches_control_NB_coposrecipientesepratos_W22       163
# 20230601_BHZ_lanches_control_NB_embalagens_W22                    166
# 20230601_BHZ_lanches_control_NB_papeis_W22                        141
# 20230601_BHZ_lanches_control_NB_sacos_W22                         160
# 20230601_BHZ_lanches_control_NB_utensilios_W22                    164
# 20230601_BHZ_lanches_control_NB_frutas_W22                         83
# 20230601_BHZ_lanches_control_NB_legumes_W22                        86
# 20230601_BHZ_lanches_control_NB_tuberculos_W22                    101
# 20230601_BHZ_lanches_control_NB_verduras_W22                      119
# 20230601_BHZ_lanches_control_NB_laticinios_W22                    142
# 20230601_BHZ_lanches_control_NB_leite_W22                         111
# 20230601_BHZ_lanches_control_NB_manteigasemargarinas_W22          152
# 20230601_BHZ_lanches_control_NB_ovos_W22                          147
# 20230601_BHZ_lanches_control_NB_queijos_W22                       137
# 20230601_BHZ_lanches_control_NB_desengordurantes_W22              162
# 20230601_BHZ_lanches_control_NB_desinfetantesesanitizantes_W22    144
# 20230601_BHZ_lanches_control_NB_detergentesabaoelava-louas_W22    132
# 20230601_BHZ_lanches_control_NB_outroslimpadores_W22              149
# 20230601_BHZ_lanches_control_NB_utensiliosdelimpeza_W22           153
# 20230601_BHZ_lanches_control_NB_aucaradoantesedoces_W22           132
# 20230601_BHZ_lanches_control_NB_arroz_W22                         146
# 20230601_BHZ_lanches_control_NB_azeitesoleosevinagres_W22          81
# 20230601_BHZ_lanches_control_NB_cafechocolateseinfusoes_W22       138
# 20230601_BHZ_lanches_control_NB_condimentos_W22                   143
# 20230601_BHZ_lanches_control_NB_conservaseenlatados_W22           158
# 20230601_BHZ_lanches_control_NB_docesesobremesas_W22              161
# 20230601_BHZ_lanches_control_NB_farinhasemisturas_W22             147
# 20230601_BHZ_lanches_control_NB_feijao_W22                        146
# 20230601_BHZ_lanches_control_NB_massasemolhos_W22                 139
# 20230601_BHZ_lanches_control_NB_temperos_W22                      148
# 20230601_BHZ_lanches_control_NB_carnevermelha_W22                 158
# 20230601_BHZ_lanches_control_NB_embutidos_W22                     148
# 20230601_BHZ_lanches_control_NB_frango_W22                        118
# 20230601_BHZ_lanches_control_NB_peixesefrutosdomar_W22            161
# 20230601_BHZ_lanches_control_NB_suinos_W22                        160
# dtype: int64
# Done BHZ lanches_CONTROL
# //-------------------------------------------------------------------------------
# Other
# 681
# Uso de data externa
# 20230601_BHZ_other_piloto_NB_aguaseisotonicos_W22              562
# 20230601_BHZ_other_piloto_NB_cervejas_W22                      484
# 20230601_BHZ_other_piloto_NB_refrigeranteseenergeticos_W22     478
# 20230601_BHZ_other_piloto_NB_sucosechas_W22                    574
# 20230601_BHZ_other_piloto_NB_destilados_W22                    674
# 20230601_BHZ_other_piloto_NB_alimentoscongelados_W22           638
# 20230601_BHZ_other_piloto_NB_batataspre-fritas_W22             543
# 20230601_BHZ_other_piloto_NB_polpaseaai_W22                    651
# 20230601_BHZ_other_piloto_NB_coposrecipientesepratos_W22       664
# 20230601_BHZ_other_piloto_NB_embalagens_W22                    674
# 20230601_BHZ_other_piloto_NB_papeis_W22                        578
# 20230601_BHZ_other_piloto_NB_sacos_W22                         668
# 20230601_BHZ_other_piloto_NB_utensilios_W22                    649
# 20230601_BHZ_other_piloto_NB_frutas_W22                        298
# 20230601_BHZ_other_piloto_NB_legumes_W22                       297
# 20230601_BHZ_other_piloto_NB_tuberculos_W22                    381
# 20230601_BHZ_other_piloto_NB_verduras_W22                      447
# 20230601_BHZ_other_piloto_NB_laticinios_W22                    571
# 20230601_BHZ_other_piloto_NB_leite_W22                         494
# 20230601_BHZ_other_piloto_NB_manteigasemargarinas_W22          614
# 20230601_BHZ_other_piloto_NB_ovos_W22                          571
# 20230601_BHZ_other_piloto_NB_queijos_W22                       550
# 20230601_BHZ_other_piloto_NB_desengordurantes_W22              660
# 20230601_BHZ_other_piloto_NB_desinfetantesesanitizantes_W22    550
# 20230601_BHZ_other_piloto_NB_detergentesabaoelava-louas_W22    488
# 20230601_BHZ_other_piloto_NB_outroslimpadores_W22              590
# 20230601_BHZ_other_piloto_NB_utensiliosdelimpeza_W22           601
# 20230601_BHZ_other_piloto_NB_aucaradoantesedoces_W22           513
# 20230601_BHZ_other_piloto_NB_arroz_W22                         529
# 20230601_BHZ_other_piloto_NB_azeitesoleosevinagres_W22         295
# 20230601_BHZ_other_piloto_NB_cafechocolateseinfusoes_W22       574
# 20230601_BHZ_other_piloto_NB_condimentos_W22                   553
# 20230601_BHZ_other_piloto_NB_conservaseenlatados_W22           632
# 20230601_BHZ_other_piloto_NB_docesesobremesas_W22              663
# 20230601_BHZ_other_piloto_NB_farinhasemisturas_W22             572
# 20230601_BHZ_other_piloto_NB_feijao_W22                        534
# 20230601_BHZ_other_piloto_NB_massasemolhos_W22                 511
# 20230601_BHZ_other_piloto_NB_temperos_W22                      506
# 20230601_BHZ_other_piloto_NB_carnevermelha_W22                 651
# 20230601_BHZ_other_piloto_NB_embutidos_W22                     603
# 20230601_BHZ_other_piloto_NB_frango_W22                        543
# 20230601_BHZ_other_piloto_NB_peixesefrutosdomar_W22            660
# 20230601_BHZ_other_piloto_NB_suinos_W22                        644
# dtype: int64
# Done BHZ other_PILOTO
# //-------------------------------------------------------------------------------
# Other Experimento50%
# 170
# Uso de data externa
# 20230601_BHZ_other_control_NB_aguaseisotonicos_W22              141
# 20230601_BHZ_other_control_NB_cervejas_W22                      122
# 20230601_BHZ_other_control_NB_refrigeranteseenergeticos_W22     111
# 20230601_BHZ_other_control_NB_sucosechas_W22                    145
# 20230601_BHZ_other_control_NB_destilados_W22                    168
# 20230601_BHZ_other_control_NB_alimentoscongelados_W22           160
# 20230601_BHZ_other_control_NB_batataspre-fritas_W22             130
# 20230601_BHZ_other_control_NB_polpaseaai_W22                    165
# 20230601_BHZ_other_control_NB_coposrecipientesepratos_W22       165
# 20230601_BHZ_other_control_NB_embalagens_W22                    169
# 20230601_BHZ_other_control_NB_papeis_W22                        146
# 20230601_BHZ_other_control_NB_sacos_W22                         164
# 20230601_BHZ_other_control_NB_utensilios_W22                    167
# 20230601_BHZ_other_control_NB_frutas_W22                         74
# 20230601_BHZ_other_control_NB_legumes_W22                        66
# 20230601_BHZ_other_control_NB_tuberculos_W22                     95
# 20230601_BHZ_other_control_NB_verduras_W22                      105
# 20230601_BHZ_other_control_NB_laticinios_W22                    142
# 20230601_BHZ_other_control_NB_leite_W22                         125
# 20230601_BHZ_other_control_NB_manteigasemargarinas_W22          156
# 20230601_BHZ_other_control_NB_ovos_W22                          135
# 20230601_BHZ_other_control_NB_queijos_W22                       138
# 20230601_BHZ_other_control_NB_desengordurantes_W22              166
# 20230601_BHZ_other_control_NB_desinfetantesesanitizantes_W22    147
# 20230601_BHZ_other_control_NB_detergentesabaoelava-louas_W22    125
# 20230601_BHZ_other_control_NB_outroslimpadores_W22              152
# 20230601_BHZ_other_control_NB_utensiliosdelimpeza_W22           151
# 20230601_BHZ_other_control_NB_aucaradoantesedoces_W22           134
# 20230601_BHZ_other_control_NB_arroz_W22                         133
# 20230601_BHZ_other_control_NB_azeitesoleosevinagres_W22          73
# 20230601_BHZ_other_control_NB_cafechocolateseinfusoes_W22       137
# 20230601_BHZ_other_control_NB_condimentos_W22                   138
# 20230601_BHZ_other_control_NB_conservaseenlatados_W22           152
# 20230601_BHZ_other_control_NB_docesesobremesas_W22              168
# 20230601_BHZ_other_control_NB_farinhasemisturas_W22             149
# 20230601_BHZ_other_control_NB_feijao_W22                        119
# 20230601_BHZ_other_control_NB_massasemolhos_W22                 131
# 20230601_BHZ_other_control_NB_temperos_W22                      129
# 20230601_BHZ_other_control_NB_carnevermelha_W22                 163
# 20230601_BHZ_other_control_NB_embutidos_W22                     145
# 20230601_BHZ_other_control_NB_frango_W22                        131
# 20230601_BHZ_other_control_NB_peixesefrutosdomar_W22            165
# 20230601_BHZ_other_control_NB_suinos_W22                        159
# dtype: int64
# Done BHZ other_CONTROL
# //-------------------------------------------------------------------------------
# Pratos/Refeições
# 792
# Uso de data externa
# 20230601_BHZ_pratosrefeicoes_piloto_NB_aguaseisotonicos_W22              667
# 20230601_BHZ_pratosrefeicoes_piloto_NB_cervejas_W22                      654
# 20230601_BHZ_pratosrefeicoes_piloto_NB_refrigeranteseenergeticos_W22     539
# 20230601_BHZ_pratosrefeicoes_piloto_NB_sucosechas_W22                    681
# 20230601_BHZ_pratosrefeicoes_piloto_NB_destilados_W22                    791
# 20230601_BHZ_pratosrefeicoes_piloto_NB_alimentoscongelados_W22           741
# 20230601_BHZ_pratosrefeicoes_piloto_NB_batataspre-fritas_W22             613
# 20230601_BHZ_pratosrefeicoes_piloto_NB_polpaseaai_W22                    735
# 20230601_BHZ_pratosrefeicoes_piloto_NB_coposrecipientesepratos_W22       773
# 20230601_BHZ_pratosrefeicoes_piloto_NB_embalagens_W22                    779
# 20230601_BHZ_pratosrefeicoes_piloto_NB_papeis_W22                        668
# 20230601_BHZ_pratosrefeicoes_piloto_NB_sacos_W22                         774
# 20230601_BHZ_pratosrefeicoes_piloto_NB_utensilios_W22                    769
# 20230601_BHZ_pratosrefeicoes_piloto_NB_frutas_W22                        257
# 20230601_BHZ_pratosrefeicoes_piloto_NB_legumes_W22                       207
# 20230601_BHZ_pratosrefeicoes_piloto_NB_tuberculos_W22                    268
# 20230601_BHZ_pratosrefeicoes_piloto_NB_verduras_W22                      416
# 20230601_BHZ_pratosrefeicoes_piloto_NB_laticinios_W22                    614
# 20230601_BHZ_pratosrefeicoes_piloto_NB_leite_W22                         585
# 20230601_BHZ_pratosrefeicoes_piloto_NB_manteigasemargarinas_W22          680
# 20230601_BHZ_pratosrefeicoes_piloto_NB_ovos_W22                          611
# 20230601_BHZ_pratosrefeicoes_piloto_NB_queijos_W22                       671
# 20230601_BHZ_pratosrefeicoes_piloto_NB_desengordurantes_W22              763
# 20230601_BHZ_pratosrefeicoes_piloto_NB_desinfetantesesanitizantes_W22    658
# 20230601_BHZ_pratosrefeicoes_piloto_NB_detergentesabaoelava-louas_W22    557
# 20230601_BHZ_pratosrefeicoes_piloto_NB_outroslimpadores_W22              704
# 20230601_BHZ_pratosrefeicoes_piloto_NB_utensiliosdelimpeza_W22           685
# 20230601_BHZ_pratosrefeicoes_piloto_NB_aucaradoantesedoces_W22           623
# 20230601_BHZ_pratosrefeicoes_piloto_NB_arroz_W22                         513
# 20230601_BHZ_pratosrefeicoes_piloto_NB_azeitesoleosevinagres_W22         272
# 20230601_BHZ_pratosrefeicoes_piloto_NB_cafechocolateseinfusoes_W22       663
# 20230601_BHZ_pratosrefeicoes_piloto_NB_condimentos_W22                   588
# 20230601_BHZ_pratosrefeicoes_piloto_NB_conservaseenlatados_W22           702
# 20230601_BHZ_pratosrefeicoes_piloto_NB_docesesobremesas_W22              784
# 20230601_BHZ_pratosrefeicoes_piloto_NB_farinhasemisturas_W22             661
# 20230601_BHZ_pratosrefeicoes_piloto_NB_feijao_W22                        521
# 20230601_BHZ_pratosrefeicoes_piloto_NB_massasemolhos_W22                 527
# 20230601_BHZ_pratosrefeicoes_piloto_NB_temperos_W22                      543
# 20230601_BHZ_pratosrefeicoes_piloto_NB_carnevermelha_W22                 746
# 20230601_BHZ_pratosrefeicoes_piloto_NB_embutidos_W22                     707
# 20230601_BHZ_pratosrefeicoes_piloto_NB_frango_W22                        604
# 20230601_BHZ_pratosrefeicoes_piloto_NB_peixesefrutosdomar_W22            756
# 20230601_BHZ_pratosrefeicoes_piloto_NB_suinos_W22                        748
# dtype: int64
# Done BHZ pratosrefeicoes_PILOTO
# //-------------------------------------------------------------------------------
# Pratos/Refeições Experimento50%
# 198
# Uso de data externa
# 20230601_BHZ_pratosrefeicoes_control_NB_aguaseisotonicos_W22              159
# 20230601_BHZ_pratosrefeicoes_control_NB_cervejas_W22                      166
# 20230601_BHZ_pratosrefeicoes_control_NB_refrigeranteseenergeticos_W22     142
# 20230601_BHZ_pratosrefeicoes_control_NB_sucosechas_W22                    174
# 20230601_BHZ_pratosrefeicoes_control_NB_destilados_W22                    198
# 20230601_BHZ_pratosrefeicoes_control_NB_alimentoscongelados_W22           193
# 20230601_BHZ_pratosrefeicoes_control_NB_batataspre-fritas_W22             158
# 20230601_BHZ_pratosrefeicoes_control_NB_polpaseaai_W22                    184
# 20230601_BHZ_pratosrefeicoes_control_NB_coposrecipientesepratos_W22       192
# 20230601_BHZ_pratosrefeicoes_control_NB_embalagens_W22                    197
# 20230601_BHZ_pratosrefeicoes_control_NB_papeis_W22                        166
# 20230601_BHZ_pratosrefeicoes_control_NB_sacos_W22                         192
# 20230601_BHZ_pratosrefeicoes_control_NB_utensilios_W22                    190
# 20230601_BHZ_pratosrefeicoes_control_NB_frutas_W22                         73
# 20230601_BHZ_pratosrefeicoes_control_NB_legumes_W22                        58
# 20230601_BHZ_pratosrefeicoes_control_NB_tuberculos_W22                     86
# 20230601_BHZ_pratosrefeicoes_control_NB_verduras_W22                      118
# 20230601_BHZ_pratosrefeicoes_control_NB_laticinios_W22                    155
# 20230601_BHZ_pratosrefeicoes_control_NB_leite_W22                         143
# 20230601_BHZ_pratosrefeicoes_control_NB_manteigasemargarinas_W22          170
# 20230601_BHZ_pratosrefeicoes_control_NB_ovos_W22                          159
# 20230601_BHZ_pratosrefeicoes_control_NB_queijos_W22                       158
# 20230601_BHZ_pratosrefeicoes_control_NB_desengordurantes_W22              192
# 20230601_BHZ_pratosrefeicoes_control_NB_desinfetantesesanitizantes_W22    160
# 20230601_BHZ_pratosrefeicoes_control_NB_detergentesabaoelava-louas_W22    132
# 20230601_BHZ_pratosrefeicoes_control_NB_outroslimpadores_W22              171
# 20230601_BHZ_pratosrefeicoes_control_NB_utensiliosdelimpeza_W22           165
# 20230601_BHZ_pratosrefeicoes_control_NB_aucaradoantesedoces_W22           151
# 20230601_BHZ_pratosrefeicoes_control_NB_arroz_W22                         120
# 20230601_BHZ_pratosrefeicoes_control_NB_azeitesoleosevinagres_W22          63
# 20230601_BHZ_pratosrefeicoes_control_NB_cafechocolateseinfusoes_W22       156
# 20230601_BHZ_pratosrefeicoes_control_NB_condimentos_W22                   137
# 20230601_BHZ_pratosrefeicoes_control_NB_conservaseenlatados_W22           177
# 20230601_BHZ_pratosrefeicoes_control_NB_docesesobremesas_W22              195
# 20230601_BHZ_pratosrefeicoes_control_NB_farinhasemisturas_W22             165
# 20230601_BHZ_pratosrefeicoes_control_NB_feijao_W22                        122
# 20230601_BHZ_pratosrefeicoes_control_NB_massasemolhos_W22                 118
# 20230601_BHZ_pratosrefeicoes_control_NB_temperos_W22                      138
# 20230601_BHZ_pratosrefeicoes_control_NB_carnevermelha_W22                 183
# 20230601_BHZ_pratosrefeicoes_control_NB_embutidos_W22                     171
# 20230601_BHZ_pratosrefeicoes_control_NB_frango_W22                        149
# 20230601_BHZ_pratosrefeicoes_control_NB_peixesefrutosdomar_W22            191
# 20230601_BHZ_pratosrefeicoes_control_NB_suinos_W22                        190
# dtype: int64
# Done BHZ pratosrefeicoes_CONTROL
# //-------------------------------------------------------------------------------
# Sucos/Açaí
# 157
# Uso de data externa
# 20230601_BHZ_sucosacai_piloto_NB_aguaseisotonicos_W22              119
# 20230601_BHZ_sucosacai_piloto_NB_refrigeranteseenergeticos_W22     109
# 20230601_BHZ_sucosacai_piloto_NB_sucosechas_W22                    124
# 20230601_BHZ_sucosacai_piloto_NB_alimentoscongelados_W22           151
# 20230601_BHZ_sucosacai_piloto_NB_polpaseaai_W22                    149
# 20230601_BHZ_sucosacai_piloto_NB_coposrecipientesepratos_W22       155
# 20230601_BHZ_sucosacai_piloto_NB_embalagens_W22                    156
# 20230601_BHZ_sucosacai_piloto_NB_papeis_W22                        131
# 20230601_BHZ_sucosacai_piloto_NB_sacos_W22                         154
# 20230601_BHZ_sucosacai_piloto_NB_utensilios_W22                    155
# 20230601_BHZ_sucosacai_piloto_NB_frutas_W22                         53
# 20230601_BHZ_sucosacai_piloto_NB_legumes_W22                       101
# 20230601_BHZ_sucosacai_piloto_NB_tuberculos_W22                    101
# 20230601_BHZ_sucosacai_piloto_NB_verduras_W22                      116
# 20230601_BHZ_sucosacai_piloto_NB_laticinios_W22                    142
# 20230601_BHZ_sucosacai_piloto_NB_leite_W22                          98
# 20230601_BHZ_sucosacai_piloto_NB_manteigasemargarinas_W22          146
# 20230601_BHZ_sucosacai_piloto_NB_desengordurantes_W22              155
# 20230601_BHZ_sucosacai_piloto_NB_desinfetantesesanitizantes_W22    128
# 20230601_BHZ_sucosacai_piloto_NB_detergentesabaoelava-louas_W22    130
# 20230601_BHZ_sucosacai_piloto_NB_outroslimpadores_W22              145
# 20230601_BHZ_sucosacai_piloto_NB_utensiliosdelimpeza_W22           144
# 20230601_BHZ_sucosacai_piloto_NB_aucaradoantesedoces_W22           102
# 20230601_BHZ_sucosacai_piloto_NB_azeitesoleosevinagres_W22          96
# 20230601_BHZ_sucosacai_piloto_NB_cafechocolateseinfusoes_W22       129
# 20230601_BHZ_sucosacai_piloto_NB_docesesobremesas_W22              152
# dtype: int64
# Done BHZ sucosacai_PILOTO
# //-------------------------------------------------------------------------------
# Sucos/Açaí Experimento50%
# 39
# Uso de data externa
# 20230601_BHZ_sucosacai_control_NB_aguaseisotonicos_W22              31
# 20230601_BHZ_sucosacai_control_NB_refrigeranteseenergeticos_W22     30
# 20230601_BHZ_sucosacai_control_NB_sucosechas_W22                    31
# 20230601_BHZ_sucosacai_control_NB_alimentoscongelados_W22           37
# 20230601_BHZ_sucosacai_control_NB_polpaseaai_W22                    34
# 20230601_BHZ_sucosacai_control_NB_coposrecipientesepratos_W22       39
# 20230601_BHZ_sucosacai_control_NB_embalagens_W22                    39
# 20230601_BHZ_sucosacai_control_NB_papeis_W22                        35
# 20230601_BHZ_sucosacai_control_NB_sacos_W22                         39
# 20230601_BHZ_sucosacai_control_NB_utensilios_W22                    39
# 20230601_BHZ_sucosacai_control_NB_frutas_W22                        17
# 20230601_BHZ_sucosacai_control_NB_legumes_W22                       25
# 20230601_BHZ_sucosacai_control_NB_tuberculos_W22                    25
# 20230601_BHZ_sucosacai_control_NB_verduras_W22                      31
# 20230601_BHZ_sucosacai_control_NB_laticinios_W22                    29
# 20230601_BHZ_sucosacai_control_NB_leite_W22                         25
# 20230601_BHZ_sucosacai_control_NB_manteigasemargarinas_W22          34
# 20230601_BHZ_sucosacai_control_NB_desengordurantes_W22              39
# 20230601_BHZ_sucosacai_control_NB_desinfetantesesanitizantes_W22    31
# 20230601_BHZ_sucosacai_control_NB_detergentesabaoelava-louas_W22    28
# 20230601_BHZ_sucosacai_control_NB_outroslimpadores_W22              37
# 20230601_BHZ_sucosacai_control_NB_utensiliosdelimpeza_W22           38
# 20230601_BHZ_sucosacai_control_NB_aucaradoantesedoces_W22           21
# 20230601_BHZ_sucosacai_control_NB_azeitesoleosevinagres_W22         23
# 20230601_BHZ_sucosacai_control_NB_cafechocolateseinfusoes_W22       31
# 20230601_BHZ_sucosacai_control_NB_docesesobremesas_W22              37
# dtype: int64
# Done BHZ sucosacai_CONTROL
# //-------------------------------------------------------------------------------
# Boteco
# 255
# Uso de data externa
# 20230601_BHZ_boteco_piloto_NB_aguaseisotonicos_W22              226
# 20230601_BHZ_boteco_piloto_NB_cervejas_W22                      148
# 20230601_BHZ_boteco_piloto_NB_refrigeranteseenergeticos_W22     193
# 20230601_BHZ_boteco_piloto_NB_sucosechas_W22                    222
# 20230601_BHZ_boteco_piloto_NB_destilados_W22                    250
# 20230601_BHZ_boteco_piloto_NB_alimentoscongelados_W22           249
# 20230601_BHZ_boteco_piloto_NB_batataspre-fritas_W22             222
# 20230601_BHZ_boteco_piloto_NB_polpaseaai_W22                    249
# 20230601_BHZ_boteco_piloto_NB_coposrecipientesepratos_W22       250
# 20230601_BHZ_boteco_piloto_NB_embalagens_W22                    254
# 20230601_BHZ_boteco_piloto_NB_papeis_W22                        220
# 20230601_BHZ_boteco_piloto_NB_sacos_W22                         253
# 20230601_BHZ_boteco_piloto_NB_utensilios_W22                    252
# 20230601_BHZ_boteco_piloto_NB_frutas_W22                        131
# 20230601_BHZ_boteco_piloto_NB_legumes_W22                       153
# 20230601_BHZ_boteco_piloto_NB_tuberculos_W22                    168
# 20230601_BHZ_boteco_piloto_NB_verduras_W22                      191
# 20230601_BHZ_boteco_piloto_NB_laticinios_W22                    228
# 20230601_BHZ_boteco_piloto_NB_leite_W22                         188
# 20230601_BHZ_boteco_piloto_NB_manteigasemargarinas_W22          242
# 20230601_BHZ_boteco_piloto_NB_ovos_W22                          230
# 20230601_BHZ_boteco_piloto_NB_queijos_W22                       218
# 20230601_BHZ_boteco_piloto_NB_desengordurantes_W22              250
# 20230601_BHZ_boteco_piloto_NB_desinfetantesesanitizantes_W22    218
# 20230601_BHZ_boteco_piloto_NB_detergentesabaoelava-louas_W22    205
# 20230601_BHZ_boteco_piloto_NB_outroslimpadores_W22              232
# 20230601_BHZ_boteco_piloto_NB_utensiliosdelimpeza_W22           232
# 20230601_BHZ_boteco_piloto_NB_aucaradoantesedoces_W22           209
# 20230601_BHZ_boteco_piloto_NB_arroz_W22                         218
# 20230601_BHZ_boteco_piloto_NB_azeitesoleosevinagres_W22         141
# 20230601_BHZ_boteco_piloto_NB_cafechocolateseinfusoes_W22       223
# 20230601_BHZ_boteco_piloto_NB_condimentos_W22                   226
# 20230601_BHZ_boteco_piloto_NB_conservaseenlatados_W22           246
# 20230601_BHZ_boteco_piloto_NB_docesesobremesas_W22              253
# 20230601_BHZ_boteco_piloto_NB_farinhasemisturas_W22             231
# 20230601_BHZ_boteco_piloto_NB_feijao_W22                        217
# 20230601_BHZ_boteco_piloto_NB_massasemolhos_W22                 222
# 20230601_BHZ_boteco_piloto_NB_temperos_W22                      221
# 20230601_BHZ_boteco_piloto_NB_carnevermelha_W22                 247
# 20230601_BHZ_boteco_piloto_NB_embutidos_W22                     235
# 20230601_BHZ_boteco_piloto_NB_frango_W22                        217
# 20230601_BHZ_boteco_piloto_NB_peixesefrutosdomar_W22            242
# 20230601_BHZ_boteco_piloto_NB_suinos_W22                        243
# dtype: int64
# Done BHZ boteco_PILOTO
# //-------------------------------------------------------------------------------
# Boteco Experimento50%
# 63
# Uso de data externa
# 20230601_BHZ_boteco_control_NB_aguaseisotonicos_W22              53
# 20230601_BHZ_boteco_control_NB_cervejas_W22                      36
# 20230601_BHZ_boteco_control_NB_refrigeranteseenergeticos_W22     50
# 20230601_BHZ_boteco_control_NB_sucosechas_W22                    58
# 20230601_BHZ_boteco_control_NB_destilados_W22                    62
# 20230601_BHZ_boteco_control_NB_alimentoscongelados_W22           58
# 20230601_BHZ_boteco_control_NB_batataspre-fritas_W22             54
# 20230601_BHZ_boteco_control_NB_polpaseaai_W22                    61
# 20230601_BHZ_boteco_control_NB_coposrecipientesepratos_W22       60
# 20230601_BHZ_boteco_control_NB_embalagens_W22                    63
# 20230601_BHZ_boteco_control_NB_papeis_W22                        52
# 20230601_BHZ_boteco_control_NB_sacos_W22                         60
# 20230601_BHZ_boteco_control_NB_utensilios_W22                    61
# 20230601_BHZ_boteco_control_NB_frutas_W22                        31
# 20230601_BHZ_boteco_control_NB_legumes_W22                       36
# 20230601_BHZ_boteco_control_NB_tuberculos_W22                    36
# 20230601_BHZ_boteco_control_NB_verduras_W22                      44
# 20230601_BHZ_boteco_control_NB_laticinios_W22                    55
# 20230601_BHZ_boteco_control_NB_leite_W22                         42
# 20230601_BHZ_boteco_control_NB_manteigasemargarinas_W22          61
# 20230601_BHZ_boteco_control_NB_ovos_W22                          55
# 20230601_BHZ_boteco_control_NB_queijos_W22                       56
# 20230601_BHZ_boteco_control_NB_desengordurantes_W22              60
# 20230601_BHZ_boteco_control_NB_desinfetantesesanitizantes_W22    51
# 20230601_BHZ_boteco_control_NB_detergentesabaoelava-louas_W22    41
# 20230601_BHZ_boteco_control_NB_outroslimpadores_W22              57
# 20230601_BHZ_boteco_control_NB_utensiliosdelimpeza_W22           55
# 20230601_BHZ_boteco_control_NB_aucaradoantesedoces_W22           53
# 20230601_BHZ_boteco_control_NB_arroz_W22                         53
# 20230601_BHZ_boteco_control_NB_azeitesoleosevinagres_W22         26
# 20230601_BHZ_boteco_control_NB_cafechocolateseinfusoes_W22       55
# 20230601_BHZ_boteco_control_NB_condimentos_W22                   60
# 20230601_BHZ_boteco_control_NB_conservaseenlatados_W22           60
# 20230601_BHZ_boteco_control_NB_docesesobremesas_W22              63
# 20230601_BHZ_boteco_control_NB_farinhasemisturas_W22             56
# 20230601_BHZ_boteco_control_NB_feijao_W22                        52
# 20230601_BHZ_boteco_control_NB_massasemolhos_W22                 55
# 20230601_BHZ_boteco_control_NB_temperos_W22                      53
# 20230601_BHZ_boteco_control_NB_carnevermelha_W22                 62
# 20230601_BHZ_boteco_control_NB_embutidos_W22                     60
# 20230601_BHZ_boteco_control_NB_frango_W22                        51
# 20230601_BHZ_boteco_control_NB_peixesefrutosdomar_W22            60
# 20230601_BHZ_boteco_control_NB_suinos_W22                        60
# dtype: int64
# Done BHZ boteco_CONTROL

# %% [markdown]
# ## Aca creo el archivo para R&D

# %%
# customers =  pd.DataFrame()
# for column,i in enumerate(aux_df.columns):
#     #if ('verduras' in i or 'frutas' in i or 'arroz' in i or 'aceitesygrasas' in i or 'harinasymezclas' in i or 'azucaryendulzantes' in i or 'pollo' in i or 'huevos' in i) and not 'frutasjugo' in i:
#     #if ('verduras' in i or 'frutas' in i) and not 'frutasjugo' in i:
#     customers[i] = aux_df[i]

# %%
# customers.iloc[:6000].to_csv(f'SD/export_data/MS/csv_{city_code}_CLIENTS_PRUEBA_R&D.csv', index = False)

# with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
#        json.dump(global_segment_list, outfile)

# %%
# aux_seg = pd.read_csv(f"prueba_tuberculos_BAQ.csv")
# aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

# aux_seg["final_group2"] = ["piloto" if x == "Super Descuentos" else "control" for x in aux_seg.grupos]
# aux_seg['offer_name'] = f"20230301_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W9"

# aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()

# %%
# lst = []
# for x in aux_seg2.values:
#     h = {'name':x[0], 'customersIds': list(x[1])}
#     lst.append(h)
    
# for x in lst:
#     print(x['name'])
#     #break
#     for i,value in enumerate(global_segment_list):
#         if value['name'] == x['name']:
#             global_segment_list[i]['customersIds'] = x['customersIds']
#             print(i)

# %%
aux_seg = pd.read_csv(f"csv_{city_code}_CLIENTS_FINAL_JUNIO_R&D.csv")
aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

aux_seg["final_group2"] = ["piloto" if x == "Treatment" else "control" for x in aux_seg.final_group]
aux_seg['offer_name'] = f"20230601_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W22"

aux_seg["quartile"] = ["Q0" if x == "-" else x for x in aux_seg.quartile.values]
aux_seg["quartile_name"] = f"20230601_{city_code}_" + aux_seg.subcategory + "_" + aux_seg.quartile + "_" + aux_seg.case

aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()
aux_seg3 = aux_seg.groupby(by = ["quartile_name"])["customer_source_id"].apply(list).reset_index()

# %%
aux_seg.head()
# Out:
#         subcategory  customer_source_id               ms previous_group  \
# 0  aguaseisotonicos           209454980          lanches      Treatment
# 1  aguaseisotonicos            63964025            other      Treatment
# 2  aguaseisotonicos            70331952            other      Treatment
# 3  aguaseisotonicos           103911556  pratosrefeicoes      Treatment
# 4  aguaseisotonicos           124226609  pratosrefeicoes        Control
#
#          case quartile  random final_group final_group2  \
# 0  positivity       Q4       0   Treatment       piloto
# 1  positivity       Q4       0   Treatment       piloto
# 2  positivity       Q4       0   Treatment       piloto
# 3  positivity       Q4       0   Treatment       piloto
# 4  positivity       Q4       0   Treatment       piloto
#
#                                           offer_name  \
# 0  20230601_BHZ_lanches_piloto_NB_aguaseisotonico...
# 1  20230601_BHZ_other_piloto_NB_aguaseisotonicos_W22
# 2  20230601_BHZ_other_piloto_NB_aguaseisotonicos_W22
# 3  20230601_BHZ_pratosrefeicoes_piloto_NB_aguasei...
# 4  20230601_BHZ_pratosrefeicoes_piloto_NB_aguasei...
#
#                                  quartile_name
# 0  20230601_BHZ_aguaseisotonicos_Q4_positivity
# 1  20230601_BHZ_aguaseisotonicos_Q4_positivity
# 2  20230601_BHZ_aguaseisotonicos_Q4_positivity
# 3  20230601_BHZ_aguaseisotonicos_Q4_positivity
# 4  20230601_BHZ_aguaseisotonicos_Q4_positivity

# %%
lst = []
for x in aux_seg2.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst.append(h)

global_segment_list = lst

# %%
lst2 = []
for x in aux_seg3.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst2.append(h)

# %% [markdown]
# # Aca tengo que volver a cargar el archivo de arriba y dejarlo como lista para traer lo otro

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230601_BHZ_padariacafebolos_piloto_NB_aguase...
# 1  20230601_BHZ_padariacafebolos_piloto_NB_cervej...
# 2  20230601_BHZ_padariacafebolos_piloto_NB_refrig...
# 3  20230601_BHZ_padariacafebolos_piloto_NB_sucose...
# 4  20230601_BHZ_padariacafebolos_piloto_NB_destil...
#
#                                    offer_description  discount  \
# 0        padariacafebolos_piloto_NB_aguaseisotonicos         7
# 1                padariacafebolos_piloto_NB_cervejas         5
# 2  padariacafebolos_piloto_NB_refrigeranteseenerg...         5
# 3              padariacafebolos_piloto_NB_sucosechas         6
# 4              padariacafebolos_piloto_NB_destilados         4
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                   9
# 1                         true  01-06-2023  30-06-2023                   9
# 2                         true  01-06-2023  30-06-2023                   9
# 3                         true  01-06-2023  30-06-2023                   9
# 4                         true  01-06-2023  30-06-2023                   9
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1                None
# 1                      1                None
# 2                      1                None
# 3                      1                None
# 4                      1                None
#
#                                               sku_id
# 0                                      616555#616553
# 1  363897#363896#460765#460763#460764#324003#3240...
# 2  453798#453799#453800#453390#453392#453391#2581...
# 3  258191#258190#258179#258178#258185#258184#3974...
# 4                                             589447

# %%
#len_seg =int(len(global_segment_list)/10)
#len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %% [markdown]
# ## Crear segments offers y segments types

# %%
import requests
import json

def create_segments(segment_list):
    
    url = f"https://{city_code}.frubana.com/api/v1/segments/create?api-key=00_growth-team-zzz-qqq_001"

    payload = json.dumps(segment_list)


    headers = {
    'Cookie': 'AWSALB=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALBCORS=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALB=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI; AWSALBCORS=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI',
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.status_code)
    sgt = [(int(x[:6]),x[7:]) for x in list(map(str.strip, response.text[32:].strip('][').replace('"', '').split(',')))]
    time.sleep(40)
    return sgt

# %%
len_seg =int(len(global_segment_list)/10)
len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %%
#offers
sgt=[]

for i in len_seg_list:
    sgt.append(create_segments(i))
    
sgt_end =[item for lista in sgt for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len_seg2 =int(len(lst2)/10)
len_seg_list2 = [lst2[:len_seg2],lst2[len_seg2:len_seg2*2],lst2[len_seg2*2:len_seg2*3],lst2[len_seg2*3:len_seg2*4],lst2[len_seg2*4:len_seg2*5],lst2[len_seg2*5:len_seg2*6],lst2[len_seg2*6:len_seg2*7],lst2[len_seg2*7:len_seg2*8],lst2[len_seg2*8:len_seg2*9],lst2[len_seg2*9:]]

# %%
#types
sgt2=[]

for i in len_seg_list2:
    sgt2.append(create_segments(i))
    
sgt_end2 =[item for lista in sgt2 for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#unir offers con segments
for i in global_offer_csv.offer_name:
    for j,z in sgt_end:
        if z==i:
            global_offer_csv.loc[global_offer_csv.offer_name == i, ('customer_segment_id')] = j

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230601_BHZ_padariacafebolos_piloto_NB_aguase...
# 1  20230601_BHZ_padariacafebolos_piloto_NB_cervej...
# 2  20230601_BHZ_padariacafebolos_piloto_NB_refrig...
# 3  20230601_BHZ_padariacafebolos_piloto_NB_sucose...
# 4  20230601_BHZ_padariacafebolos_piloto_NB_destil...
#
#                                    offer_description  discount  \
# 0        padariacafebolos_piloto_NB_aguaseisotonicos         7
# 1                padariacafebolos_piloto_NB_cervejas         5
# 2  padariacafebolos_piloto_NB_refrigeranteseenerg...         5
# 3              padariacafebolos_piloto_NB_sucosechas         6
# 4              padariacafebolos_piloto_NB_destilados         4
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                   9
# 1                         true  01-06-2023  30-06-2023                   9
# 2                         true  01-06-2023  30-06-2023                   9
# 3                         true  01-06-2023  30-06-2023                   9
# 4                         true  01-06-2023  30-06-2023                   9
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              166919
# 1                      1              166928
# 2                      1              168202
# 3                      1              167877
# 4                      1                None
#
#                                               sku_id
# 0                                      616555#616553
# 1  363897#363896#460765#460763#460764#324003#3240...
# 2  453798#453799#453800#453390#453392#453391#2581...
# 3  258191#258190#258179#258178#258185#258184#3974...
# 4                                             589447

# %%
global_offer_csv = global_offer_csv.loc[~global_offer_csv.customer_segment_id.isnull()].reset_index(drop=True)
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('discount','max_uses_per_order')]=1
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('start_date','end_date')]='01-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('end_date')]='02-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('sku_id')]= global_offer_csv.loc[~global_offer_csv['offer_name'].str.contains("piloto", case=False), ('sku_id')].tolist()

# %%
len_offer =int(len(global_offer_csv)/4)
len_offer = [global_offer_csv[:len_seg],global_offer_csv[len_seg:len_seg*2],global_offer_csv[len_seg*2:len_seg*3],global_offer_csv[len_seg*3:]]

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230601_BHZ_padariacafebolos_piloto_NB_aguase...
# 1  20230601_BHZ_padariacafebolos_piloto_NB_cervej...
# 2  20230601_BHZ_padariacafebolos_piloto_NB_refrig...
# 3  20230601_BHZ_padariacafebolos_piloto_NB_sucose...
# 4  20230601_BHZ_padariacafebolos_piloto_NB_alimen...
#
#                                    offer_description  discount  \
# 0        padariacafebolos_piloto_NB_aguaseisotonicos         7
# 1                padariacafebolos_piloto_NB_cervejas         5
# 2  padariacafebolos_piloto_NB_refrigeranteseenerg...         5
# 3              padariacafebolos_piloto_NB_sucosechas         6
# 4     padariacafebolos_piloto_NB_alimentoscongelados        11
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                   9
# 1                         true  01-06-2023  30-06-2023                   9
# 2                         true  01-06-2023  30-06-2023                   9
# 3                         true  01-06-2023  30-06-2023                   9
# 4                         true  01-06-2023  30-06-2023                  15
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              166919
# 1                      1              166928
# 2                      1              168202
# 3                      1              167877
# 4                      1              166920
#
#                                               sku_id
# 0                                      616555#616553
# 1  363897#363896#460765#460763#460764#324003#3240...
# 2  453798#453799#453800#453390#453392#453391#2581...
# 3  258191#258190#258179#258178#258185#258184#3974...
# 4                               428509#527270#356875

# %%
#//--------------------------------------------
#//Exporting single file data
global_offer_csv.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS.csv', index = False)

for i,offer in enumerate(len_offer):
    offer.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS_{i}.csv', index = False)

with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
        json.dump(global_segment_list, outfile)    
with open(f'SD/export_data/MS/nb_{city_code}_All_MS.json', 'w') as outfile:
        json.dump(global_segment_list, outfile)
print(f'Done {city_code}')
# Out:
# Done BHZ
