# %%
#//----------------------------
#//LIBRARIES
    #Math
import math
    #Numeric Python
import numpy as np
    #Pandas (dataframes)
import pandas as pd
    #datetime for fate manipulation
from datetime import date, datetime, timedelta  
    #Regex for advanced string matching
import re
    #for time related stuff
import time
    #json library
import json
    #Analyst tools
import sys
sys.path.append('../')
from analysts_tools.growth import *
    #Procurement tools
from analysts_tools.redash_methods import *
    #Frubana libraries
from procurement_lib import redash, dw, send_message, send_slack_notification, GoogleSheet, logging

# %%
#//---------------------------------------------------------------------------------------------------------------------------
#// Parametros
"""Todays date should be the first day of the next month which is going to begin with SD"""

city_code = 'SPO'

# Set today's date to the first day of the next month
today = datetime.today()
first_day_next_month = (today.replace(day=1) + timedelta(days=32)).replace(day=1)

# Calculate non_buyers_date (todays date - 1 month)
non_buyers_date = (first_day_next_month - timedelta(days=1)).replace(day=1)
customer_date_desde = (first_day_next_month - timedelta(days=1)).replace(day=1)

# Calculate sku_date_desde (todays date - 2 months)
sku_date_desde = (first_day_next_month - timedelta(days=60)).replace(day=1)

# Convert the dates to strings in the desired format
todays_date = first_day_next_month.strftime('%Y-%m-%d')
non_buyers_date = non_buyers_date.strftime('%Y-%m-%d')
customer_date_desde = customer_date_desde.strftime('%Y-%m-%d')
sku_date_desde = sku_date_desde.strftime('%Y-%m-%d')

print(todays_date) # Output: e.g. 2023-04-01
print(non_buyers_date) # Output: e.g. 2023-03-01
print(sku_date_desde) # Output: e.g. 2023-02-01

tasas = {'BOG': 3776,
         'BAQ': 3776,
         'MDE': 3776,
         'CMX': 19.65,
         'GDL': 19.65,
         'PBC': 19.65,
         'SPO': 4.75,
         'BHZ': 4.75,
         'CWB': 4.75,
         'VCP': 4.75}

t_cambio = tasas[city_code]
# Out:
# 2023-07-01
# 2023-06-01
# 2023-05-01

# %%
query="""
With microsegment as (

SELECT DISTINCT c.customer_id AS user_id,
                c.site_type AS region_code_ms,
                
                (case 
                    -- Colombia
                    when m.microsegment_id not in (1,3,4,28,5,6,7,8,2) and c.site_type = 'BOG' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1,3,4,28,5,11,10,9,2,12) and c.site_type = 'BAQ' then 'Sin Microsegmento'
                    when m.microsegment_id not in (3,4,28,1,24,11,5,2,27) and c.site_type = 'MDE' then 'Sin Microsegmento'
    
                    -- Mexico
                    when m.microsegment_id not in (1,13,14,30,15,16,29,17,6,7,2) and c.site_type = 'CMX' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1, 13,14,30, 15,16,29, 6, 33, 2, 31) and c.site_type = 'GDL' then 'Sin Microsegmento'
                    when m.microsegment_id not in (13,14,30, 15,16,29, 32,2,6,33) and c.site_type = 'PBC' then 'Sin Microsegmento'
                    
                    -- Brasil
                    when m.microsegment_id not in (21,34,38,37,35,36,39,26) and c.site_type in ('SPO','BHZ','CWB','VCP') then 'Sin Microsegmento'
                        
                else m.description end) as microsegment_ok,
                
                m.microsegment_id,
                mo.name as ms_method
                
                
FROM postgres_main_federate."growth_microsegmentation.customer_microsegment" AS cm
INNER JOIN postgres_main_federate."growth_microsegmentation.microsegment" m ON cm.microsegment_id = m.id
INNER JOIN postgres_main_federate."growth_microsegmentation.customer" c ON cm.customer_id = c.id
INNER JOIN postgres_main_federate."growth_microsegmentation.models" mo ON mo.id = cm.model_type_id


)

select m.user_id,
m.region_code_ms,
--m.microsegment_id,

(case 
        when m.microsegment_ok in ('Corrientazo c/desayuno','Corrientazo s/desayuno','Tienda/Restaurante') then 'Corrientazo' 
        when m.microsegment_ok in ('Fonda c/desayuno','Fonda s/desayuno') then 'Fonda'
        when m.microsegment_ok in ('Taquería en calle','Taquería en local') then 'Taquería'

else m.microsegment_ok end) as microsegment,

m.ms_method

from microsegment m
where m.microsegment_ok != 'Sin Microsegmento'
"""

segmentos_fulll = read_connection_data_warehouse.runQuery(query)

segmentos_fulll.columns = ['customer_id', 'city', 'microsegment','NA']
segmentos_fulll = segmentos_fulll[['customer_id', 'city', 'microsegment']]

# %% [markdown]
# ### Loading COSTUMERS INFO

# %%
users_eliminar_kam = get_fresh_query_result("https://internal-redash.federate.frubana.com/",150812,'SeoGHWmDUaaBi7VXje1s9zYNiMD1VHQ1K1DYOxiF',{},20)
users_eliminar = users_eliminar_kam.loc[users_eliminar_kam.registered_city == city_code]['customer_id'].unique().tolist()
# Out:
# 200

# %% [markdown]
# ### Loading FORCED_SKUS // Cleaning SEGMENT_NAMES

# %% [markdown]
# ### Loading DATA_VENTAS // Removing SKUs /\ CUSTOMERS_ID

# %%
#//Remove skus 
#It is used because some SKUs can get in trouble with supplier for the SD or to exclude them for another activity   
skus_remove = GoogleSheet("1Z0T_c36oRHmOHIgEG8_ANcwFykaHgXGAizYAYCKCqtY")
skus_remove = skus_remove.get_as_dataframe('SKUS')

skus_remove = skus_remove['sku_id'].unique().astype(int).tolist()

# %%
query = """
SELECT DISTINCT
    split_part(bs.upc, '-', 1) as region,
    bs.sku_id

FROM postgres_broadleaf_federate."broadleaf.blc_sku"            bs 
LEFT JOIN postgres_broadleaf_federate."broadleaf.blc_product"   bp ON bp.product_id = bs.addl_product_id

WHERE bs.archived = 'N'
    AND bs.sndbx_id is NULL
    AND bp.archived = 'N'
    AND bs.catalog_disc < 0
    AND ((bp.archived = 'N' AND bp.sndbx_id is NULL) OR (bp.archived is NULL))
"""
frida_products = read_connection_data_warehouse.runQuery(query)

# %%
good_skus = frida_products.sku_id.unique()

# %%
#Loading SELL'S DATA from a function
data_ventas = data_ventas_query(ciudad=city_code, tipo_cambio=t_cambio, desde=customer_date_desde, hasta = todays_date, tipo_negocio=1)

# %%
data_ventas = data_ventas[(~data_ventas['sku_id'].isin(skus_remove)) & (data_ventas['sku_id'].isin(good_skus))]

# %%
segmentos_full = segmentos_fulll[segmentos_fulll.city == city_code].copy()

# %%
#//customers for offers */(has further uses)*/
microsegmentacion_df = segmentos_full[(~segmentos_full['customer_id'].isin(users_eliminar))]
data_ventas = data_ventas[(~data_ventas['customer_id'].isin(users_eliminar))]

# %% [markdown]
# ### Create the MS "Other" for BAU

# %%
data_full = data_ventas.merge(microsegmentacion_df[['customer_id','microsegment']], how = 'left', on = 'customer_id')

# %%
data_full['microsegment'] = data_full['microsegment'].fillna('Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                    microsegment  customer_id
# 0                        Boteco         1011
# 1  Grill/Churrascaria/Espetinho          484
# 2        Japonesa/Internacional          387
# 3                       Lanches         4149
# 4                         Other         1577
# 5            Padaria/Cafe/Bolos         2758
# 6  Pizzaria/Pastelaria/Italiano          775
# 7              Pratos/Refeições         5014
# 8                    Sucos/Açaí          580

# %%
segments_validation = data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()

# %%
for ms in segments_validation[segments_validation.customer_id < 180]['microsegment'].unique():
    data_full['microsegment'] = data_full['microsegment'].str.replace(ms,'Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                    microsegment  customer_id
# 0                        Boteco         1011
# 1  Grill/Churrascaria/Espetinho          484
# 2        Japonesa/Internacional          387
# 3                       Lanches         4149
# 4                         Other         1577
# 5            Padaria/Cafe/Bolos         2758
# 6  Pizzaria/Pastelaria/Italiano          775
# 7              Pratos/Refeições         5014
# 8                    Sucos/Açaí          580

# %%
#Get the same variable to do the process job
data_ventas = data_full

# %% [markdown]
# ### PARAMETERS // SOME FUNCTIONS - GET READY TO PROCESSING

# %%
def ms_data(city_code):
  
    paramss_csv=GoogleSheet("1k0ckgkLddxc5lY8NUVGCkvDLTuulLaJm-N535oMNZNw")
    city_paramss = paramss_csv.get_as_dataframe(city_code)
    
    parametros = {}
    parametros[city_code] = {}
    
    for i,ms in enumerate(city_paramss.iloc[:,4:].columns):
        parametros[city_code][ms] = [(value[1],value[2],value[3],value[4+i]) for value in city_paramss.values if value[4+i]>0]
        
    return parametros

# %%
parametros = ms_data(city_code)

# %%
def normalize_text(raw_text):
    """
    Removes common accent characters and normalize text.
    """
    raw_text = raw_text.replace(" ", "")
    raw_text = raw_text.replace("�", "")
    raw_text = raw_text.replace("/", "")
    raw_text = re.sub(r'\s*', '', raw_text)
    raw_text = re.sub(r"[àáâãäå]", 'a', raw_text)
    raw_text = re.sub(r"[èéêë]", 'e', raw_text)
    raw_text = re.sub(r"[ìíîï]", 'i', raw_text) 
    raw_text = re.sub(r"[òóôõö]", 'o', raw_text)
    raw_text = re.sub(r"[ùúûü]", 'u', raw_text)
    raw_text = re.sub(r"[ýÿ]", 'y', raw_text)
    raw_text = re.sub(r"[ß]", 'ss', raw_text)
    raw_text = re.sub(r"[ñ]", 'n', raw_text)
    raw_text = re.sub(r"[ç]", 'c', raw_text)
    raw_text = raw_text.lower()
    return raw_text

# %%
#Sacar de aca los microsegmentos
msg = data_full.microsegment.unique()
msg
# Out:
# array(['Sucos/Açaí', 'Lanches', 'Pratos/Refeições',
#        'Grill/Churrascaria/Espetinho', 'Padaria/Cafe/Bolos', 'Boteco',
#        'Other', 'Pizzaria/Pastelaria/Italiano', 'Japonesa/Internacional'],
#       dtype=object)

# %% [markdown]
# ### END

# %% [markdown]
# # Aca Empieza la Experimentacion

# %%
from sklearn.model_selection import train_test_split

# %%
#//Variables to store all the segments and offers of the city
global_offer_csv = pd.DataFrame()
global_segment_list = [] #//for procesing

# %%
#//----------------------------------------------------------------------------
#//Big loop for creating each city segments/offers files
aux_df = pd.DataFrame()
aux_df['aux']=6000*[0]

for microsegment in msg:
    print('//-------------------------------------------------------------------------------')
    print(microsegment)

    #//Customers per microsegment
    customers_ms = data_ventas[(data_ventas['microsegment'] == microsegment)]['customer_id'].unique()
    #//Customers to give them the skus
    customers_for_skus_ms =  data_ventas[['microsegment','customer_id']][(data_ventas.microsegment == microsegment) & (~data_ventas.customer_id.isin(users_eliminar))]['customer_id'].unique()
    
    #----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_PILOTO" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    rand=1
    customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state=rand)
    
    while abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())) > 0.05:
        #print(data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean(),data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean(),abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())))
        rand+=1
        customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state = rand)
        
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_1)].copy() #le quite la s!!
    
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()
    
    subcats = list(map(lambda x: x[0], parametros[city_code][microsegment]))
    max_uses = list(map(lambda x: int(x[1]), parametros[city_code][microsegment]))
    max_order = list(map(lambda x: int(x[2]), parametros[city_code][microsegment]))
    discount = list(map(lambda x: int(x[3]), parametros[city_code][microsegment]))

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    a, b, c = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
            non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                        limite=0.75, data_ventas_skus = data_skus)

    print(b.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(a)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in b.columns:
        id_list = b[seg].dropna().astype(int)
        d = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)

        lst.append(d)
        
    #//appending to global list    
        global_segment_list.append(d)
    
    print(f'Done {city_code} {ms_name}')

#----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------


#----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_CONTROL" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_2)].copy() #le quite la s!!
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    print('//-------------------------------------------------------------------------------')
    print(f'{microsegment} Experimento50%')
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    e, f, g = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
                non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                          limite=0.75, data_ventas_skus = data_skus)
      
    print(f.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(e)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in f.columns:
        id_list = f[seg].dropna().astype(int)
        h = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)
        
        lst.append(h)
        
        
    #//appending to global list    
        global_segment_list.append(h)
    
    print(f'Done {city_code} {ms_name}')
    #----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#//End of big loop and start of data bundle
# Out:
# //-------------------------------------------------------------------------------
# Sucos/Açaí
# 464
# Uso de data externa
# 20230701_SPO_sucosacai_piloto_NB_aguaseisotonicos_W26              336
# 20230701_SPO_sucosacai_piloto_NB_refrigeranteseenergeticos_W26     308
# 20230701_SPO_sucosacai_piloto_NB_sucosechas_W26                    412
# 20230701_SPO_sucosacai_piloto_NB_alimentoscongelados_W26           443
# 20230701_SPO_sucosacai_piloto_NB_polpaseaai_W26                    445
# 20230701_SPO_sucosacai_piloto_NB_coposrecipientesepratos_W26       460
# 20230701_SPO_sucosacai_piloto_NB_embalagens_W26                    458
# 20230701_SPO_sucosacai_piloto_NB_papeis_W26                        396
# 20230701_SPO_sucosacai_piloto_NB_sacos_W26                         458
# 20230701_SPO_sucosacai_piloto_NB_utensilios_W26                    457
# 20230701_SPO_sucosacai_piloto_NB_frutas_W26                        242
# 20230701_SPO_sucosacai_piloto_NB_legumes_W26                       230
# 20230701_SPO_sucosacai_piloto_NB_tuberculos_W26                    310
# 20230701_SPO_sucosacai_piloto_NB_verduras_W26                      328
# 20230701_SPO_sucosacai_piloto_NB_laticinios_W26                    375
# 20230701_SPO_sucosacai_piloto_NB_leite_W26                         264
# 20230701_SPO_sucosacai_piloto_NB_desengordurantes_W26              452
# 20230701_SPO_sucosacai_piloto_NB_desinfetantesesanitizantes_W26    370
# 20230701_SPO_sucosacai_piloto_NB_detergentesabaoelava-louas_W26    355
# 20230701_SPO_sucosacai_piloto_NB_outroslimpadores_W26              434
# 20230701_SPO_sucosacai_piloto_NB_utensiliosdelimpeza_W26           418
# 20230701_SPO_sucosacai_piloto_NB_aucaradoantesedoces_W26           273
# 20230701_SPO_sucosacai_piloto_NB_cafechocolateseinfusoes_W26       384
# dtype: int64
# Done SPO sucosacai_PILOTO
# //-------------------------------------------------------------------------------
# Sucos/Açaí Experimento50%
# 116
# Uso de data externa
# 20230701_SPO_sucosacai_control_NB_aguaseisotonicos_W26               78
# 20230701_SPO_sucosacai_control_NB_refrigeranteseenergeticos_W26      73
# 20230701_SPO_sucosacai_control_NB_sucosechas_W26                     94
# 20230701_SPO_sucosacai_control_NB_alimentoscongelados_W26           108
# 20230701_SPO_sucosacai_control_NB_polpaseaai_W26                    105
# 20230701_SPO_sucosacai_control_NB_coposrecipientesepratos_W26       116
# 20230701_SPO_sucosacai_control_NB_embalagens_W26                    115
# 20230701_SPO_sucosacai_control_NB_papeis_W26                        100
# 20230701_SPO_sucosacai_control_NB_sacos_W26                         116
# 20230701_SPO_sucosacai_control_NB_utensilios_W26                    115
# 20230701_SPO_sucosacai_control_NB_frutas_W26                         57
# 20230701_SPO_sucosacai_control_NB_legumes_W26                        58
# 20230701_SPO_sucosacai_control_NB_tuberculos_W26                     78
# 20230701_SPO_sucosacai_control_NB_verduras_W26                       77
# 20230701_SPO_sucosacai_control_NB_laticinios_W26                     91
# 20230701_SPO_sucosacai_control_NB_leite_W26                          61
# 20230701_SPO_sucosacai_control_NB_desengordurantes_W26              108
# 20230701_SPO_sucosacai_control_NB_desinfetantesesanitizantes_W26     85
# 20230701_SPO_sucosacai_control_NB_detergentesabaoelava-louas_W26     88
# 20230701_SPO_sucosacai_control_NB_outroslimpadores_W26              108
# 20230701_SPO_sucosacai_control_NB_utensiliosdelimpeza_W26            95
# 20230701_SPO_sucosacai_control_NB_aucaradoantesedoces_W26            68
# 20230701_SPO_sucosacai_control_NB_cafechocolateseinfusoes_W26        83
# dtype: int64
# Done SPO sucosacai_CONTROL
# //-------------------------------------------------------------------------------
# Lanches
# 3320
# Uso de data externa
# 20230701_SPO_lanches_piloto_NB_aguaseisotonicos_W26              2581
# 20230701_SPO_lanches_piloto_NB_cervejas_W26                      2517
# 20230701_SPO_lanches_piloto_NB_refrigeranteseenergeticos_W26     2159
# 20230701_SPO_lanches_piloto_NB_sucosechas_W26                    2812
# 20230701_SPO_lanches_piloto_NB_destilados_W26                    3098
# 20230701_SPO_lanches_piloto_NB_alimentoscongelados_W26           3082
# 20230701_SPO_lanches_piloto_NB_batataspre-fritas_W26             2752
# 20230701_SPO_lanches_piloto_NB_polpaseaai_W26                    3095
# 20230701_SPO_lanches_piloto_NB_coposrecipientesepratos_W26       3304
# 20230701_SPO_lanches_piloto_NB_embalagens_W26                    3272
# 20230701_SPO_lanches_piloto_NB_papeis_W26                        2905
# 20230701_SPO_lanches_piloto_NB_sacos_W26                         3306
# 20230701_SPO_lanches_piloto_NB_utensilios_W26                    3262
# 20230701_SPO_lanches_piloto_NB_frutas_W26                        1713
# 20230701_SPO_lanches_piloto_NB_legumes_W26                       1320
# 20230701_SPO_lanches_piloto_NB_tuberculos_W26                    2165
# 20230701_SPO_lanches_piloto_NB_verduras_W26                      2132
# 20230701_SPO_lanches_piloto_NB_laticinios_W26                    2963
# 20230701_SPO_lanches_piloto_NB_leite_W26                         1962
# 20230701_SPO_lanches_piloto_NB_manteigasemargarinas_W26          2846
# 20230701_SPO_lanches_piloto_NB_ovos_W26                          2884
# 20230701_SPO_lanches_piloto_NB_queijos_W26                       2405
# 20230701_SPO_lanches_piloto_NB_desengordurantes_W26              3236
# 20230701_SPO_lanches_piloto_NB_desinfetantesesanitizantes_W26    2719
# 20230701_SPO_lanches_piloto_NB_detergentesabaoelava-louas_W26    2487
# 20230701_SPO_lanches_piloto_NB_outroslimpadores_W26              3148
# 20230701_SPO_lanches_piloto_NB_utensiliosdelimpeza_W26           2981
# 20230701_SPO_lanches_piloto_NB_aucaradoantesedoces_W26           2032
# 20230701_SPO_lanches_piloto_NB_arroz_W26                         2507
# 20230701_SPO_lanches_piloto_NB_azeitesoleosevinagres_W26         1619
# 20230701_SPO_lanches_piloto_NB_cafechocolateseinfusoes_W26       2612
# 20230701_SPO_lanches_piloto_NB_condimentos_W26                   2601
# 20230701_SPO_lanches_piloto_NB_conservaseenlatados_W26           2979
# 20230701_SPO_lanches_piloto_NB_farinhasemisturas_W26             2630
# 20230701_SPO_lanches_piloto_NB_feijao_W26                        2552
# 20230701_SPO_lanches_piloto_NB_graos_W26                         3191
# 20230701_SPO_lanches_piloto_NB_massasemolhos_W26                 2746
# 20230701_SPO_lanches_piloto_NB_temperos_W26                      2669
# 20230701_SPO_lanches_piloto_NB_carnevermelha_W26                 3054
# 20230701_SPO_lanches_piloto_NB_embutidos_W26                     2691
# 20230701_SPO_lanches_piloto_NB_frango_W26                        2497
# 20230701_SPO_lanches_piloto_NB_peixesefrutosdomar_W26            3236
# 20230701_SPO_lanches_piloto_NB_suinos_W26                        2979
# dtype: int64
# Done SPO lanches_PILOTO
# //-------------------------------------------------------------------------------
# Lanches Experimento50%
# 829
# Uso de data externa
# 20230701_SPO_lanches_control_NB_aguaseisotonicos_W26              638
# 20230701_SPO_lanches_control_NB_cervejas_W26                      635
# 20230701_SPO_lanches_control_NB_refrigeranteseenergeticos_W26     528
# 20230701_SPO_lanches_control_NB_sucosechas_W26                    693
# 20230701_SPO_lanches_control_NB_destilados_W26                    778
# 20230701_SPO_lanches_control_NB_alimentoscongelados_W26           763
# 20230701_SPO_lanches_control_NB_batataspre-fritas_W26             669
# 20230701_SPO_lanches_control_NB_polpaseaai_W26                    770
# 20230701_SPO_lanches_control_NB_coposrecipientesepratos_W26       824
# 20230701_SPO_lanches_control_NB_embalagens_W26                    814
# 20230701_SPO_lanches_control_NB_papeis_W26                        737
# 20230701_SPO_lanches_control_NB_sacos_W26                         823
# 20230701_SPO_lanches_control_NB_utensilios_W26                    813
# 20230701_SPO_lanches_control_NB_frutas_W26                        415
# 20230701_SPO_lanches_control_NB_legumes_W26                       330
# 20230701_SPO_lanches_control_NB_tuberculos_W26                    519
# 20230701_SPO_lanches_control_NB_verduras_W26                      512
# 20230701_SPO_lanches_control_NB_laticinios_W26                    723
# 20230701_SPO_lanches_control_NB_leite_W26                         487
# 20230701_SPO_lanches_control_NB_manteigasemargarinas_W26          716
# 20230701_SPO_lanches_control_NB_ovos_W26                          700
# 20230701_SPO_lanches_control_NB_queijos_W26                       610
# 20230701_SPO_lanches_control_NB_desengordurantes_W26              801
# 20230701_SPO_lanches_control_NB_desinfetantesesanitizantes_W26    675
# 20230701_SPO_lanches_control_NB_detergentesabaoelava-louas_W26    612
# 20230701_SPO_lanches_control_NB_outroslimpadores_W26              778
# 20230701_SPO_lanches_control_NB_utensiliosdelimpeza_W26           739
# 20230701_SPO_lanches_control_NB_aucaradoantesedoces_W26           522
# 20230701_SPO_lanches_control_NB_arroz_W26                         607
# 20230701_SPO_lanches_control_NB_azeitesoleosevinagres_W26         413
# 20230701_SPO_lanches_control_NB_cafechocolateseinfusoes_W26       619
# 20230701_SPO_lanches_control_NB_condimentos_W26                   647
# 20230701_SPO_lanches_control_NB_conservaseenlatados_W26           751
# 20230701_SPO_lanches_control_NB_farinhasemisturas_W26             638
# 20230701_SPO_lanches_control_NB_feijao_W26                        634
# 20230701_SPO_lanches_control_NB_graos_W26                         797
# 20230701_SPO_lanches_control_NB_massasemolhos_W26                 680
# 20230701_SPO_lanches_control_NB_temperos_W26                      649
# 20230701_SPO_lanches_control_NB_carnevermelha_W26                 772
# 20230701_SPO_lanches_control_NB_embutidos_W26                     680
# 20230701_SPO_lanches_control_NB_frango_W26                        629
# 20230701_SPO_lanches_control_NB_peixesefrutosdomar_W26            804
# 20230701_SPO_lanches_control_NB_suinos_W26                        758
# dtype: int64
# Done SPO lanches_CONTROL
# //-------------------------------------------------------------------------------
# Pratos/Refeições
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)
# 4012
# Uso de data externa
# 20230701_SPO_pratosrefeicoes_piloto_NB_aguaseisotonicos_W26              3156
# 20230701_SPO_pratosrefeicoes_piloto_NB_cervejas_W26                      3294
# 20230701_SPO_pratosrefeicoes_piloto_NB_refrigeranteseenergeticos_W26     2643
# 20230701_SPO_pratosrefeicoes_piloto_NB_sucosechas_W26                    3597
# 20230701_SPO_pratosrefeicoes_piloto_NB_destilados_W26                    3831
# 20230701_SPO_pratosrefeicoes_piloto_NB_alimentoscongelados_W26           3630
# 20230701_SPO_pratosrefeicoes_piloto_NB_batataspre-fritas_W26             3088
# 20230701_SPO_pratosrefeicoes_piloto_NB_polpaseaai_W26                    3691
# 20230701_SPO_pratosrefeicoes_piloto_NB_coposrecipientesepratos_W26       4001
# 20230701_SPO_pratosrefeicoes_piloto_NB_embalagens_W26                    3947
# 20230701_SPO_pratosrefeicoes_piloto_NB_papeis_W26                        3511
# 20230701_SPO_pratosrefeicoes_piloto_NB_sacos_W26                         3978
# 20230701_SPO_pratosrefeicoes_piloto_NB_utensilios_W26                    3899
# 20230701_SPO_pratosrefeicoes_piloto_NB_frutas_W26                        1750
# 20230701_SPO_pratosrefeicoes_piloto_NB_legumes_W26                       1082
# 20230701_SPO_pratosrefeicoes_piloto_NB_tuberculos_W26                    1956
# 20230701_SPO_pratosrefeicoes_piloto_NB_verduras_W26                      2103
# 20230701_SPO_pratosrefeicoes_piloto_NB_laticinios_W26                    3353
# 20230701_SPO_pratosrefeicoes_piloto_NB_leite_W26                         2401
# 20230701_SPO_pratosrefeicoes_piloto_NB_manteigasemargarinas_W26          3315
# 20230701_SPO_pratosrefeicoes_piloto_NB_ovos_W26                          3303
# 20230701_SPO_pratosrefeicoes_piloto_NB_queijos_W26                       3043
# 20230701_SPO_pratosrefeicoes_piloto_NB_desengordurantes_W26              3871
# 20230701_SPO_pratosrefeicoes_piloto_NB_desinfetantesesanitizantes_W26    3104
# 20230701_SPO_pratosrefeicoes_piloto_NB_detergentesabaoelava-louas_W26    2740
# 20230701_SPO_pratosrefeicoes_piloto_NB_outroslimpadores_W26              3753
# 20230701_SPO_pratosrefeicoes_piloto_NB_utensiliosdelimpeza_W26           3379
# 20230701_SPO_pratosrefeicoes_piloto_NB_aucaradoantesedoces_W26           2417
# 20230701_SPO_pratosrefeicoes_piloto_NB_arroz_W26                         2108
# 20230701_SPO_pratosrefeicoes_piloto_NB_azeitesoleosevinagres_W26         1437
# 20230701_SPO_pratosrefeicoes_piloto_NB_cafechocolateseinfusoes_W26       2953
# 20230701_SPO_pratosrefeicoes_piloto_NB_condimentos_W26                   3109
# 20230701_SPO_pratosrefeicoes_piloto_NB_conservaseenlatados_W26           3480
# 20230701_SPO_pratosrefeicoes_piloto_NB_farinhasemisturas_W26             2742
# 20230701_SPO_pratosrefeicoes_piloto_NB_feijao_W26                        2240
# 20230701_SPO_pratosrefeicoes_piloto_NB_graos_W26                         3800
# 20230701_SPO_pratosrefeicoes_piloto_NB_massasemolhos_W26                 2783
# 20230701_SPO_pratosrefeicoes_piloto_NB_temperos_W26                      2676
# 20230701_SPO_pratosrefeicoes_piloto_NB_carnevermelha_W26                 3585
# 20230701_SPO_pratosrefeicoes_piloto_NB_embutidos_W26                     3221
# 20230701_SPO_pratosrefeicoes_piloto_NB_frango_W26                        3166
# 20230701_SPO_pratosrefeicoes_piloto_NB_peixesefrutosdomar_W26            3825
# 20230701_SPO_pratosrefeicoes_piloto_NB_suinos_W26                        3600
# dtype: int64
# Done SPO pratosrefeicoes_PILOTO
# //-------------------------------------------------------------------------------
# Pratos/Refeições Experimento50%
# 1002
# Uso de data externa
# 20230701_SPO_pratosrefeicoes_control_NB_aguaseisotonicos_W26              799
# 20230701_SPO_pratosrefeicoes_control_NB_cervejas_W26                      818
# 20230701_SPO_pratosrefeicoes_control_NB_refrigeranteseenergeticos_W26     693
# 20230701_SPO_pratosrefeicoes_control_NB_sucosechas_W26                    916
# 20230701_SPO_pratosrefeicoes_control_NB_destilados_W26                    960
# 20230701_SPO_pratosrefeicoes_control_NB_alimentoscongelados_W26           908
# 20230701_SPO_pratosrefeicoes_control_NB_batataspre-fritas_W26             765
# 20230701_SPO_pratosrefeicoes_control_NB_polpaseaai_W26                    916
# 20230701_SPO_pratosrefeicoes_control_NB_coposrecipientesepratos_W26       999
# 20230701_SPO_pratosrefeicoes_control_NB_embalagens_W26                    976
# 20230701_SPO_pratosrefeicoes_control_NB_papeis_W26                        851
# 20230701_SPO_pratosrefeicoes_control_NB_sacos_W26                         992
# 20230701_SPO_pratosrefeicoes_control_NB_utensilios_W26                    967
# 20230701_SPO_pratosrefeicoes_control_NB_frutas_W26                        429
# 20230701_SPO_pratosrefeicoes_control_NB_legumes_W26                       274
# 20230701_SPO_pratosrefeicoes_control_NB_tuberculos_W26                    490
# 20230701_SPO_pratosrefeicoes_control_NB_verduras_W26                      522
# 20230701_SPO_pratosrefeicoes_control_NB_laticinios_W26                    820
# 20230701_SPO_pratosrefeicoes_control_NB_leite_W26                         599
# 20230701_SPO_pratosrefeicoes_control_NB_manteigasemargarinas_W26          831
# 20230701_SPO_pratosrefeicoes_control_NB_ovos_W26                          812
# 20230701_SPO_pratosrefeicoes_control_NB_queijos_W26                       766
# 20230701_SPO_pratosrefeicoes_control_NB_desengordurantes_W26              961
# 20230701_SPO_pratosrefeicoes_control_NB_desinfetantesesanitizantes_W26    787
# 20230701_SPO_pratosrefeicoes_control_NB_detergentesabaoelava-louas_W26    670
# 20230701_SPO_pratosrefeicoes_control_NB_outroslimpadores_W26              924
# 20230701_SPO_pratosrefeicoes_control_NB_utensiliosdelimpeza_W26           845
# 20230701_SPO_pratosrefeicoes_control_NB_aucaradoantesedoces_W26           592
# 20230701_SPO_pratosrefeicoes_control_NB_arroz_W26                         518
# 20230701_SPO_pratosrefeicoes_control_NB_azeitesoleosevinagres_W26         356
# 20230701_SPO_pratosrefeicoes_control_NB_cafechocolateseinfusoes_W26       751
# 20230701_SPO_pratosrefeicoes_control_NB_condimentos_W26                   790
# 20230701_SPO_pratosrefeicoes_control_NB_conservaseenlatados_W26           861
# 20230701_SPO_pratosrefeicoes_control_NB_farinhasemisturas_W26             676
# 20230701_SPO_pratosrefeicoes_control_NB_feijao_W26                        577
# 20230701_SPO_pratosrefeicoes_control_NB_graos_W26                         957
# 20230701_SPO_pratosrefeicoes_control_NB_massasemolhos_W26                 699
# 20230701_SPO_pratosrefeicoes_control_NB_temperos_W26                      641
# 20230701_SPO_pratosrefeicoes_control_NB_carnevermelha_W26                 899
# 20230701_SPO_pratosrefeicoes_control_NB_embutidos_W26                     798
# 20230701_SPO_pratosrefeicoes_control_NB_frango_W26                        779
# 20230701_SPO_pratosrefeicoes_control_NB_peixesefrutosdomar_W26            956
# 20230701_SPO_pratosrefeicoes_control_NB_suinos_W26                        904
# dtype: int64
# Done SPO pratosrefeicoes_CONTROL
# //-------------------------------------------------------------------------------
# Grill/Churrascaria/Espetinho
# 388
# Uso de data externa
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_aguaseisotonicos_W26              295
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_cervejas_W26                      260
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_refrigeranteseenergeticos_W26     231
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_sucosechas_W26                    334
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_destilados_W26                    366
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_alimentoscongelados_W26           357
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_batataspre-fritas_W26             311
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_polpaseaai_W26                    371
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_coposrecipientesepratos_W26       387
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_embalagens_W26                    385
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_papeis_W26                        330
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_sacos_W26                         385
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_utensilios_W26                    385
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_frutas_W26                        196
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_legumes_W26                       156
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_tuberculos_W26                    255
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_verduras_W26                      264
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_laticinios_W26                    338
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_leite_W26                         259
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_manteigasemargarinas_W26          339
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_ovos_W26                          344
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_queijos_W26                       314
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_desengordurantes_W26              375
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_desinfetantesesanitizantes_W26    305
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_detergentesabaoelava-louas_W26    266
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_outroslimpadores_W26              365
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_utensiliosdelimpeza_W26           338
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_aucaradoantesedoces_W26           244
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_arroz_W26                         256
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_azeitesoleosevinagres_W26         173
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_cafechocolateseinfusoes_W26       303
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_condimentos_W26                   305
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_conservaseenlatados_W26           345
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_farinhasemisturas_W26             302
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_feijao_W26                        262
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_graos_W26                         377
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_massasemolhos_W26                 305
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_temperos_W26                      270
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_carnevermelha_W26                 363
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_embutidos_W26                     329
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_frango_W26                        307
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_peixesefrutosdomar_W26            384
# 20230701_SPO_grillchurrascariaespetinho_piloto_NB_suinos_W26                        342
# dtype: int64
# Done SPO grillchurrascariaespetinho_PILOTO
# //-------------------------------------------------------------------------------
# Grill/Churrascaria/Espetinho Experimento50%
# 96
# Uso de data externa
# 20230701_SPO_grillchurrascariaespetinho_control_NB_aguaseisotonicos_W26              67
# 20230701_SPO_grillchurrascariaespetinho_control_NB_cervejas_W26                      66
# 20230701_SPO_grillchurrascariaespetinho_control_NB_refrigeranteseenergeticos_W26     59
# 20230701_SPO_grillchurrascariaespetinho_control_NB_sucosechas_W26                    83
# 20230701_SPO_grillchurrascariaespetinho_control_NB_destilados_W26                    90
# 20230701_SPO_grillchurrascariaespetinho_control_NB_alimentoscongelados_W26           90
# 20230701_SPO_grillchurrascariaespetinho_control_NB_batataspre-fritas_W26             79
# 20230701_SPO_grillchurrascariaespetinho_control_NB_polpaseaai_W26                    90
# 20230701_SPO_grillchurrascariaespetinho_control_NB_coposrecipientesepratos_W26       96
# 20230701_SPO_grillchurrascariaespetinho_control_NB_embalagens_W26                    92
# 20230701_SPO_grillchurrascariaespetinho_control_NB_papeis_W26                        83
# 20230701_SPO_grillchurrascariaespetinho_control_NB_sacos_W26                         95
# 20230701_SPO_grillchurrascariaespetinho_control_NB_utensilios_W26                    90
# 20230701_SPO_grillchurrascariaespetinho_control_NB_frutas_W26                        55
# 20230701_SPO_grillchurrascariaespetinho_control_NB_legumes_W26                       47
# 20230701_SPO_grillchurrascariaespetinho_control_NB_tuberculos_W26                    63
# 20230701_SPO_grillchurrascariaespetinho_control_NB_verduras_W26                      66
# 20230701_SPO_grillchurrascariaespetinho_control_NB_laticinios_W26                    84
# 20230701_SPO_grillchurrascariaespetinho_control_NB_leite_W26                         67
# 20230701_SPO_grillchurrascariaespetinho_control_NB_manteigasemargarinas_W26          86
# 20230701_SPO_grillchurrascariaespetinho_control_NB_ovos_W26                          84
# 20230701_SPO_grillchurrascariaespetinho_control_NB_queijos_W26                       79
# 20230701_SPO_grillchurrascariaespetinho_control_NB_desengordurantes_W26              93
# 20230701_SPO_grillchurrascariaespetinho_control_NB_desinfetantesesanitizantes_W26    80
# 20230701_SPO_grillchurrascariaespetinho_control_NB_detergentesabaoelava-louas_W26    66
# 20230701_SPO_grillchurrascariaespetinho_control_NB_outroslimpadores_W26              90
# 20230701_SPO_grillchurrascariaespetinho_control_NB_utensiliosdelimpeza_W26           83
# 20230701_SPO_grillchurrascariaespetinho_control_NB_aucaradoantesedoces_W26           68
# 20230701_SPO_grillchurrascariaespetinho_control_NB_arroz_W26                         66
# 20230701_SPO_grillchurrascariaespetinho_control_NB_azeitesoleosevinagres_W26         40
# 20230701_SPO_grillchurrascariaespetinho_control_NB_cafechocolateseinfusoes_W26       79
# 20230701_SPO_grillchurrascariaespetinho_control_NB_condimentos_W26                   72
# 20230701_SPO_grillchurrascariaespetinho_control_NB_conservaseenlatados_W26           86
# 20230701_SPO_grillchurrascariaespetinho_control_NB_farinhasemisturas_W26             75
# 20230701_SPO_grillchurrascariaespetinho_control_NB_feijao_W26                        72
# 20230701_SPO_grillchurrascariaespetinho_control_NB_graos_W26                         91
# 20230701_SPO_grillchurrascariaespetinho_control_NB_massasemolhos_W26                 75
# 20230701_SPO_grillchurrascariaespetinho_control_NB_temperos_W26                      72
# 20230701_SPO_grillchurrascariaespetinho_control_NB_carnevermelha_W26                 89
# 20230701_SPO_grillchurrascariaespetinho_control_NB_embutidos_W26                     78
# 20230701_SPO_grillchurrascariaespetinho_control_NB_frango_W26                        70
# 20230701_SPO_grillchurrascariaespetinho_control_NB_peixesefrutosdomar_W26            95
# 20230701_SPO_grillchurrascariaespetinho_control_NB_suinos_W26                        79
# dtype: int64
# Done SPO grillchurrascariaespetinho_CONTROL
# //-------------------------------------------------------------------------------
# Padaria/Cafe/Bolos
# 2207
# Uso de data externa
# 20230701_SPO_padariacafebolos_piloto_NB_aguaseisotonicos_W26              1735
# 20230701_SPO_padariacafebolos_piloto_NB_cervejas_W26                      1781
# 20230701_SPO_padariacafebolos_piloto_NB_refrigeranteseenergeticos_W26     1577
# 20230701_SPO_padariacafebolos_piloto_NB_sucosechas_W26                    1918
# 20230701_SPO_padariacafebolos_piloto_NB_destilados_W26                    2028
# 20230701_SPO_padariacafebolos_piloto_NB_alimentoscongelados_W26           2084
# 20230701_SPO_padariacafebolos_piloto_NB_batataspre-fritas_W26             1998
# 20230701_SPO_padariacafebolos_piloto_NB_polpaseaai_W26                    2096
# 20230701_SPO_padariacafebolos_piloto_NB_coposrecipientesepratos_W26       2193
# 20230701_SPO_padariacafebolos_piloto_NB_embalagens_W26                    2178
# 20230701_SPO_padariacafebolos_piloto_NB_papeis_W26                        1938
# 20230701_SPO_padariacafebolos_piloto_NB_sacos_W26                         2194
# 20230701_SPO_padariacafebolos_piloto_NB_utensilios_W26                    2125
# 20230701_SPO_padariacafebolos_piloto_NB_frutas_W26                        1135
# 20230701_SPO_padariacafebolos_piloto_NB_legumes_W26                       1023
# 20230701_SPO_padariacafebolos_piloto_NB_tuberculos_W26                    1450
# 20230701_SPO_padariacafebolos_piloto_NB_verduras_W26                      1543
# 20230701_SPO_padariacafebolos_piloto_NB_laticinios_W26                    1825
# 20230701_SPO_padariacafebolos_piloto_NB_leite_W26                         1031
# 20230701_SPO_padariacafebolos_piloto_NB_manteigasemargarinas_W26          1768
# 20230701_SPO_padariacafebolos_piloto_NB_ovos_W26                          2000
# 20230701_SPO_padariacafebolos_piloto_NB_queijos_W26                       1595
# 20230701_SPO_padariacafebolos_piloto_NB_desengordurantes_W26              2147
# 20230701_SPO_padariacafebolos_piloto_NB_desinfetantesesanitizantes_W26    1711
# 20230701_SPO_padariacafebolos_piloto_NB_detergentesabaoelava-louas_W26    1529
# 20230701_SPO_padariacafebolos_piloto_NB_outroslimpadores_W26              2070
# 20230701_SPO_padariacafebolos_piloto_NB_utensiliosdelimpeza_W26           1946
# 20230701_SPO_padariacafebolos_piloto_NB_aucaradoantesedoces_W26            806
# 20230701_SPO_padariacafebolos_piloto_NB_arroz_W26                         1735
# 20230701_SPO_padariacafebolos_piloto_NB_azeitesoleosevinagres_W26         1177
# 20230701_SPO_padariacafebolos_piloto_NB_cafechocolateseinfusoes_W26       1675
# 20230701_SPO_padariacafebolos_piloto_NB_condimentos_W26                   1876
# 20230701_SPO_padariacafebolos_piloto_NB_conservaseenlatados_W26           1901
# 20230701_SPO_padariacafebolos_piloto_NB_farinhasemisturas_W26             1682
# 20230701_SPO_padariacafebolos_piloto_NB_feijao_W26                        1762
# 20230701_SPO_padariacafebolos_piloto_NB_graos_W26                         2038
# 20230701_SPO_padariacafebolos_piloto_NB_massasemolhos_W26                 1836
# 20230701_SPO_padariacafebolos_piloto_NB_temperos_W26                      1761
# 20230701_SPO_padariacafebolos_piloto_NB_carnevermelha_W26                 2072
# 20230701_SPO_padariacafebolos_piloto_NB_embutidos_W26                     1830
# 20230701_SPO_padariacafebolos_piloto_NB_frango_W26                        1783
# 20230701_SPO_padariacafebolos_piloto_NB_peixesefrutosdomar_W26            2153
# 20230701_SPO_padariacafebolos_piloto_NB_suinos_W26                        2079
# dtype: int64
# Done SPO padariacafebolos_PILOTO
# //-------------------------------------------------------------------------------
# Padaria/Cafe/Bolos Experimento50%
# 551
# Uso de data externa
# 20230701_SPO_padariacafebolos_control_NB_aguaseisotonicos_W26              445
# 20230701_SPO_padariacafebolos_control_NB_cervejas_W26                      451
# 20230701_SPO_padariacafebolos_control_NB_refrigeranteseenergeticos_W26     379
# 20230701_SPO_padariacafebolos_control_NB_sucosechas_W26                    475
# 20230701_SPO_padariacafebolos_control_NB_destilados_W26                    505
# 20230701_SPO_padariacafebolos_control_NB_alimentoscongelados_W26           525
# 20230701_SPO_padariacafebolos_control_NB_batataspre-fritas_W26             512
# 20230701_SPO_padariacafebolos_control_NB_polpaseaai_W26                    528
# 20230701_SPO_padariacafebolos_control_NB_coposrecipientesepratos_W26       547
# 20230701_SPO_padariacafebolos_control_NB_embalagens_W26                    546
# 20230701_SPO_padariacafebolos_control_NB_papeis_W26                        488
# 20230701_SPO_padariacafebolos_control_NB_sacos_W26                         545
# 20230701_SPO_padariacafebolos_control_NB_utensilios_W26                    532
# 20230701_SPO_padariacafebolos_control_NB_frutas_W26                        282
# 20230701_SPO_padariacafebolos_control_NB_legumes_W26                       250
# 20230701_SPO_padariacafebolos_control_NB_tuberculos_W26                    364
# 20230701_SPO_padariacafebolos_control_NB_verduras_W26                      385
# 20230701_SPO_padariacafebolos_control_NB_laticinios_W26                    459
# 20230701_SPO_padariacafebolos_control_NB_leite_W26                         256
# 20230701_SPO_padariacafebolos_control_NB_manteigasemargarinas_W26          428
# 20230701_SPO_padariacafebolos_control_NB_ovos_W26                          512
# 20230701_SPO_padariacafebolos_control_NB_queijos_W26                       402
# 20230701_SPO_padariacafebolos_control_NB_desengordurantes_W26              537
# 20230701_SPO_padariacafebolos_control_NB_desinfetantesesanitizantes_W26    439
# 20230701_SPO_padariacafebolos_control_NB_detergentesabaoelava-louas_W26    377
# 20230701_SPO_padariacafebolos_control_NB_outroslimpadores_W26              524
# 20230701_SPO_padariacafebolos_control_NB_utensiliosdelimpeza_W26           495
# 20230701_SPO_padariacafebolos_control_NB_aucaradoantesedoces_W26           205
# 20230701_SPO_padariacafebolos_control_NB_arroz_W26                         442
# 20230701_SPO_padariacafebolos_control_NB_azeitesoleosevinagres_W26         289
# 20230701_SPO_padariacafebolos_control_NB_cafechocolateseinfusoes_W26       422
# 20230701_SPO_padariacafebolos_control_NB_condimentos_W26                   483
# 20230701_SPO_padariacafebolos_control_NB_conservaseenlatados_W26           480
# 20230701_SPO_padariacafebolos_control_NB_farinhasemisturas_W26             427
# 20230701_SPO_padariacafebolos_control_NB_feijao_W26                        445
# 20230701_SPO_padariacafebolos_control_NB_graos_W26                         514
# 20230701_SPO_padariacafebolos_control_NB_massasemolhos_W26                 466
# 20230701_SPO_padariacafebolos_control_NB_temperos_W26                      433
# 20230701_SPO_padariacafebolos_control_NB_carnevermelha_W26                 521
# 20230701_SPO_padariacafebolos_control_NB_embutidos_W26                     442
# 20230701_SPO_padariacafebolos_control_NB_frango_W26                        446
# 20230701_SPO_padariacafebolos_control_NB_peixesefrutosdomar_W26            535
# 20230701_SPO_padariacafebolos_control_NB_suinos_W26                        518
# dtype: int64
# Done SPO padariacafebolos_CONTROL
# //-------------------------------------------------------------------------------
# Boteco
# 809
# Uso de data externa
# 20230701_SPO_boteco_piloto_NB_aguaseisotonicos_W26              655
# 20230701_SPO_boteco_piloto_NB_cervejas_W26                      420
# 20230701_SPO_boteco_piloto_NB_refrigeranteseenergeticos_W26     541
# 20230701_SPO_boteco_piloto_NB_sucosechas_W26                    750
# 20230701_SPO_boteco_piloto_NB_destilados_W26                    655
# 20230701_SPO_boteco_piloto_NB_alimentoscongelados_W26           764
# 20230701_SPO_boteco_piloto_NB_batataspre-fritas_W26             699
# 20230701_SPO_boteco_piloto_NB_polpaseaai_W26                    792
# 20230701_SPO_boteco_piloto_NB_coposrecipientesepratos_W26       806
# 20230701_SPO_boteco_piloto_NB_embalagens_W26                    807
# 20230701_SPO_boteco_piloto_NB_papeis_W26                        726
# 20230701_SPO_boteco_piloto_NB_sacos_W26                         807
# 20230701_SPO_boteco_piloto_NB_utensilios_W26                    801
# 20230701_SPO_boteco_piloto_NB_frutas_W26                        483
# 20230701_SPO_boteco_piloto_NB_legumes_W26                       479
# 20230701_SPO_boteco_piloto_NB_tuberculos_W26                    584
# 20230701_SPO_boteco_piloto_NB_verduras_W26                      654
# 20230701_SPO_boteco_piloto_NB_laticinios_W26                    736
# 20230701_SPO_boteco_piloto_NB_leite_W26                         566
# 20230701_SPO_boteco_piloto_NB_manteigasemargarinas_W26          749
# 20230701_SPO_boteco_piloto_NB_ovos_W26                          748
# 20230701_SPO_boteco_piloto_NB_queijos_W26                       726
# 20230701_SPO_boteco_piloto_NB_desengordurantes_W26              797
# 20230701_SPO_boteco_piloto_NB_desinfetantesesanitizantes_W26    707
# 20230701_SPO_boteco_piloto_NB_detergentesabaoelava-louas_W26    660
# 20230701_SPO_boteco_piloto_NB_outroslimpadores_W26              784
# 20230701_SPO_boteco_piloto_NB_utensiliosdelimpeza_W26           760
# 20230701_SPO_boteco_piloto_NB_aucaradoantesedoces_W26           609
# 20230701_SPO_boteco_piloto_NB_arroz_W26                         665
# 20230701_SPO_boteco_piloto_NB_azeitesoleosevinagres_W26         567
# 20230701_SPO_boteco_piloto_NB_cafechocolateseinfusoes_W26       687
# 20230701_SPO_boteco_piloto_NB_condimentos_W26                   733
# 20230701_SPO_boteco_piloto_NB_conservaseenlatados_W26           759
# 20230701_SPO_boteco_piloto_NB_farinhasemisturas_W26             701
# 20230701_SPO_boteco_piloto_NB_feijao_W26                        655
# 20230701_SPO_boteco_piloto_NB_graos_W26                         785
# 20230701_SPO_boteco_piloto_NB_massasemolhos_W26                 714
# 20230701_SPO_boteco_piloto_NB_temperos_W26                      705
# 20230701_SPO_boteco_piloto_NB_carnevermelha_W26                 742
# 20230701_SPO_boteco_piloto_NB_embutidos_W26                     670
# 20230701_SPO_boteco_piloto_NB_frango_W26                        657
# 20230701_SPO_boteco_piloto_NB_peixesefrutosdomar_W26            777
# 20230701_SPO_boteco_piloto_NB_suinos_W26                        754
# dtype: int64
# Done SPO boteco_PILOTO
# //-------------------------------------------------------------------------------
# Boteco Experimento50%
# 202
# Uso de data externa
# 20230701_SPO_boteco_control_NB_aguaseisotonicos_W26              149
# 20230701_SPO_boteco_control_NB_cervejas_W26                       89
# 20230701_SPO_boteco_control_NB_refrigeranteseenergeticos_W26     121
# 20230701_SPO_boteco_control_NB_sucosechas_W26                    185
# 20230701_SPO_boteco_control_NB_destilados_W26                    147
# 20230701_SPO_boteco_control_NB_alimentoscongelados_W26           194
# 20230701_SPO_boteco_control_NB_batataspre-fritas_W26             182
# 20230701_SPO_boteco_control_NB_polpaseaai_W26                    199
# 20230701_SPO_boteco_control_NB_coposrecipientesepratos_W26       200
# 20230701_SPO_boteco_control_NB_embalagens_W26                    201
# 20230701_SPO_boteco_control_NB_papeis_W26                        179
# 20230701_SPO_boteco_control_NB_sacos_W26                         201
# 20230701_SPO_boteco_control_NB_utensilios_W26                    200
# 20230701_SPO_boteco_control_NB_frutas_W26                        122
# 20230701_SPO_boteco_control_NB_legumes_W26                       124
# 20230701_SPO_boteco_control_NB_tuberculos_W26                    157
# 20230701_SPO_boteco_control_NB_verduras_W26                      161
# 20230701_SPO_boteco_control_NB_laticinios_W26                    188
# 20230701_SPO_boteco_control_NB_leite_W26                         133
# 20230701_SPO_boteco_control_NB_manteigasemargarinas_W26          180
# 20230701_SPO_boteco_control_NB_ovos_W26                          190
# 20230701_SPO_boteco_control_NB_queijos_W26                       177
# 20230701_SPO_boteco_control_NB_desengordurantes_W26              200
# 20230701_SPO_boteco_control_NB_desinfetantesesanitizantes_W26    169
# 20230701_SPO_boteco_control_NB_detergentesabaoelava-louas_W26    162
# 20230701_SPO_boteco_control_NB_outroslimpadores_W26              193
# 20230701_SPO_boteco_control_NB_utensiliosdelimpeza_W26           187
# 20230701_SPO_boteco_control_NB_aucaradoantesedoces_W26           142
# 20230701_SPO_boteco_control_NB_arroz_W26                         166
# 20230701_SPO_boteco_control_NB_azeitesoleosevinagres_W26         143
# 20230701_SPO_boteco_control_NB_cafechocolateseinfusoes_W26       161
# 20230701_SPO_boteco_control_NB_condimentos_W26                   189
# 20230701_SPO_boteco_control_NB_conservaseenlatados_W26           183
# 20230701_SPO_boteco_control_NB_farinhasemisturas_W26             167
# 20230701_SPO_boteco_control_NB_feijao_W26                        170
# 20230701_SPO_boteco_control_NB_graos_W26                         190
# 20230701_SPO_boteco_control_NB_massasemolhos_W26                 170
# 20230701_SPO_boteco_control_NB_temperos_W26                      176
# 20230701_SPO_boteco_control_NB_carnevermelha_W26                 189
# 20230701_SPO_boteco_control_NB_embutidos_W26                     168
# 20230701_SPO_boteco_control_NB_frango_W26                        174
# 20230701_SPO_boteco_control_NB_peixesefrutosdomar_W26            198
# 20230701_SPO_boteco_control_NB_suinos_W26                        187
# dtype: int64
# Done SPO boteco_CONTROL
# //-------------------------------------------------------------------------------
# Other
# 1262
# Uso de data externa
# 20230701_SPO_other_piloto_NB_aguaseisotonicos_W26               961
# 20230701_SPO_other_piloto_NB_cervejas_W26                      1029
# 20230701_SPO_other_piloto_NB_refrigeranteseenergeticos_W26      866
# 20230701_SPO_other_piloto_NB_sucosechas_W26                    1133
# 20230701_SPO_other_piloto_NB_destilados_W26                    1219
# 20230701_SPO_other_piloto_NB_alimentoscongelados_W26           1110
# 20230701_SPO_other_piloto_NB_batataspre-fritas_W26             1032
# 20230701_SPO_other_piloto_NB_polpaseaai_W26                    1170
# 20230701_SPO_other_piloto_NB_coposrecipientesepratos_W26       1255
# 20230701_SPO_other_piloto_NB_embalagens_W26                    1241
# 20230701_SPO_other_piloto_NB_papeis_W26                        1072
# 20230701_SPO_other_piloto_NB_sacos_W26                         1245
# 20230701_SPO_other_piloto_NB_utensilios_W26                    1211
# 20230701_SPO_other_piloto_NB_frutas_W26                         550
# 20230701_SPO_other_piloto_NB_legumes_W26                        417
# 20230701_SPO_other_piloto_NB_tuberculos_W26                     662
# 20230701_SPO_other_piloto_NB_verduras_W26                       664
# 20230701_SPO_other_piloto_NB_laticinios_W26                    1009
# 20230701_SPO_other_piloto_NB_leite_W26                          751
# 20230701_SPO_other_piloto_NB_manteigasemargarinas_W26          1029
# 20230701_SPO_other_piloto_NB_ovos_W26                           989
# 20230701_SPO_other_piloto_NB_queijos_W26                        925
# 20230701_SPO_other_piloto_NB_desengordurantes_W26              1193
# 20230701_SPO_other_piloto_NB_desinfetantesesanitizantes_W26     967
# 20230701_SPO_other_piloto_NB_detergentesabaoelava-louas_W26     852
# 20230701_SPO_other_piloto_NB_outroslimpadores_W26              1161
# 20230701_SPO_other_piloto_NB_utensiliosdelimpeza_W26           1062
# 20230701_SPO_other_piloto_NB_aucaradoantesedoces_W26            732
# 20230701_SPO_other_piloto_NB_arroz_W26                          819
# 20230701_SPO_other_piloto_NB_azeitesoleosevinagres_W26          614
# 20230701_SPO_other_piloto_NB_cafechocolateseinfusoes_W26        970
# 20230701_SPO_other_piloto_NB_condimentos_W26                    998
# 20230701_SPO_other_piloto_NB_conservaseenlatados_W26           1073
# 20230701_SPO_other_piloto_NB_farinhasemisturas_W26              886
# 20230701_SPO_other_piloto_NB_feijao_W26                         836
# 20230701_SPO_other_piloto_NB_graos_W26                         1174
# 20230701_SPO_other_piloto_NB_massasemolhos_W26                  927
# 20230701_SPO_other_piloto_NB_temperos_W26                       904
# 20230701_SPO_other_piloto_NB_carnevermelha_W26                 1131
# 20230701_SPO_other_piloto_NB_embutidos_W26                      996
# 20230701_SPO_other_piloto_NB_frango_W26                         927
# 20230701_SPO_other_piloto_NB_peixesefrutosdomar_W26            1198
# 20230701_SPO_other_piloto_NB_suinos_W26                        1110
# dtype: int64
# Done SPO other_PILOTO
# //-------------------------------------------------------------------------------
# Other Experimento50%
# 315
# Uso de data externa
# 20230701_SPO_other_control_NB_aguaseisotonicos_W26              245
# 20230701_SPO_other_control_NB_cervejas_W26                      260
# 20230701_SPO_other_control_NB_refrigeranteseenergeticos_W26     227
# 20230701_SPO_other_control_NB_sucosechas_W26                    287
# 20230701_SPO_other_control_NB_destilados_W26                    303
# 20230701_SPO_other_control_NB_alimentoscongelados_W26           270
# 20230701_SPO_other_control_NB_batataspre-fritas_W26             264
# 20230701_SPO_other_control_NB_polpaseaai_W26                    292
# 20230701_SPO_other_control_NB_coposrecipientesepratos_W26       311
# 20230701_SPO_other_control_NB_embalagens_W26                    309
# 20230701_SPO_other_control_NB_papeis_W26                        262
# 20230701_SPO_other_control_NB_sacos_W26                         309
# 20230701_SPO_other_control_NB_utensilios_W26                    306
# 20230701_SPO_other_control_NB_frutas_W26                        138
# 20230701_SPO_other_control_NB_legumes_W26                        93
# 20230701_SPO_other_control_NB_tuberculos_W26                    161
# 20230701_SPO_other_control_NB_verduras_W26                      165
# 20230701_SPO_other_control_NB_laticinios_W26                    253
# 20230701_SPO_other_control_NB_leite_W26                         196
# 20230701_SPO_other_control_NB_manteigasemargarinas_W26          260
# 20230701_SPO_other_control_NB_ovos_W26                          246
# 20230701_SPO_other_control_NB_queijos_W26                       230
# 20230701_SPO_other_control_NB_desengordurantes_W26              297
# 20230701_SPO_other_control_NB_desinfetantesesanitizantes_W26    231
# 20230701_SPO_other_control_NB_detergentesabaoelava-louas_W26    203
# 20230701_SPO_other_control_NB_outroslimpadores_W26              295
# 20230701_SPO_other_control_NB_utensiliosdelimpeza_W26           261
# 20230701_SPO_other_control_NB_aucaradoantesedoces_W26           184
# 20230701_SPO_other_control_NB_arroz_W26                         189
# 20230701_SPO_other_control_NB_azeitesoleosevinagres_W26         137
# 20230701_SPO_other_control_NB_cafechocolateseinfusoes_W26       237
# 20230701_SPO_other_control_NB_condimentos_W26                   236
# 20230701_SPO_other_control_NB_conservaseenlatados_W26           260
# 20230701_SPO_other_control_NB_farinhasemisturas_W26             212
# 20230701_SPO_other_control_NB_feijao_W26                        210
# 20230701_SPO_other_control_NB_graos_W26                         292
# 20230701_SPO_other_control_NB_massasemolhos_W26                 224
# 20230701_SPO_other_control_NB_temperos_W26                      223
# 20230701_SPO_other_control_NB_carnevermelha_W26                 275
# 20230701_SPO_other_control_NB_embutidos_W26                     255
# 20230701_SPO_other_control_NB_frango_W26                        236
# 20230701_SPO_other_control_NB_peixesefrutosdomar_W26            297
# 20230701_SPO_other_control_NB_suinos_W26                        278
# dtype: int64
# Done SPO other_CONTROL
# //-------------------------------------------------------------------------------
# Pizzaria/Pastelaria/Italiano
# 620
# Uso de data externa
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_aguaseisotonicos_W26              506
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_cervejas_W26                      511
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_refrigeranteseenergeticos_W26     394
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_sucosechas_W26                    551
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_destilados_W26                    605
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_alimentoscongelados_W26           563
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_batataspre-fritas_W26             541
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_polpaseaai_W26                    589
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_coposrecipientesepratos_W26       618
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_embalagens_W26                    606
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_papeis_W26                        535
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_sacos_W26                         618
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_utensilios_W26                    608
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_frutas_W26                        334
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_legumes_W26                       228
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_tuberculos_W26                    449
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_verduras_W26                      399
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_laticinios_W26                    553
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_leite_W26                         437
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_manteigasemargarinas_W26          552
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_ovos_W26                          541
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_queijos_W26                       424
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_desengordurantes_W26              603
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_desinfetantesesanitizantes_W26    509
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_detergentesabaoelava-louas_W26    446
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_outroslimpadores_W26              566
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_utensiliosdelimpeza_W26           563
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_aucaradoantesedoces_W26           381
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_arroz_W26                         522
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_azeitesoleosevinagres_W26         305
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_cafechocolateseinfusoes_W26       526
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_condimentos_W26                   488
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_conservaseenlatados_W26           534
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_farinhasemisturas_W26             517
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_feijao_W26                        530
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_graos_W26                         606
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_massasemolhos_W26                 540
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_temperos_W26                      478
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_carnevermelha_W26                 571
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_embutidos_W26                     534
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_frango_W26                        456
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_peixesefrutosdomar_W26            608
# 20230701_SPO_pizzariapastelariaitaliano_piloto_NB_suinos_W26                        567
# dtype: int64
# Done SPO pizzariapastelariaitaliano_PILOTO
# //-------------------------------------------------------------------------------
# Pizzaria/Pastelaria/Italiano Experimento50%
# 155
# Uso de data externa
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_aguaseisotonicos_W26              132
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_cervejas_W26                      127
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_refrigeranteseenergeticos_W26      97
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_sucosechas_W26                    131
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_destilados_W26                    152
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_alimentoscongelados_W26           143
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_batataspre-fritas_W26             141
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_polpaseaai_W26                    145
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_coposrecipientesepratos_W26       154
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_embalagens_W26                    153
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_papeis_W26                        138
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_sacos_W26                         153
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_utensilios_W26                    149
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_frutas_W26                         94
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_legumes_W26                        58
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_tuberculos_W26                    114
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_verduras_W26                       98
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_laticinios_W26                    139
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_leite_W26                         114
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_manteigasemargarinas_W26          134
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_ovos_W26                          128
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_queijos_W26                       109
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_desengordurantes_W26              150
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_desinfetantesesanitizantes_W26    121
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_detergentesabaoelava-louas_W26    114
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_outroslimpadores_W26              149
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_utensiliosdelimpeza_W26           147
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_aucaradoantesedoces_W26           107
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_arroz_W26                         130
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_azeitesoleosevinagres_W26          80
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_cafechocolateseinfusoes_W26       133
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_condimentos_W26                   124
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_conservaseenlatados_W26           136
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_farinhasemisturas_W26             131
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_feijao_W26                        136
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_graos_W26                         151
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_massasemolhos_W26                 128
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_temperos_W26                      130
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_carnevermelha_W26                 142
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_embutidos_W26                     132
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_frango_W26                        119
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_peixesefrutosdomar_W26            153
# 20230701_SPO_pizzariapastelariaitaliano_control_NB_suinos_W26                        145
# dtype: int64
# Done SPO pizzariapastelariaitaliano_CONTROL
# //-------------------------------------------------------------------------------
# Japonesa/Internacional
# 310
# Uso de data externa
# 20230701_SPO_japonesainternacional_piloto_NB_aguaseisotonicos_W26              243
# 20230701_SPO_japonesainternacional_piloto_NB_cervejas_W26                      251
# 20230701_SPO_japonesainternacional_piloto_NB_refrigeranteseenergeticos_W26     191
# 20230701_SPO_japonesainternacional_piloto_NB_sucosechas_W26                    285
# 20230701_SPO_japonesainternacional_piloto_NB_destilados_W26                    304
# 20230701_SPO_japonesainternacional_piloto_NB_alimentoscongelados_W26           282
# 20230701_SPO_japonesainternacional_piloto_NB_batataspre-fritas_W26             270
# 20230701_SPO_japonesainternacional_piloto_NB_polpaseaai_W26                    298
# 20230701_SPO_japonesainternacional_piloto_NB_coposrecipientesepratos_W26       308
# 20230701_SPO_japonesainternacional_piloto_NB_embalagens_W26                    305
# 20230701_SPO_japonesainternacional_piloto_NB_papeis_W26                        263
# 20230701_SPO_japonesainternacional_piloto_NB_sacos_W26                         307
# 20230701_SPO_japonesainternacional_piloto_NB_utensilios_W26                    305
# 20230701_SPO_japonesainternacional_piloto_NB_frutas_W26                        154
# 20230701_SPO_japonesainternacional_piloto_NB_legumes_W26                       140
# 20230701_SPO_japonesainternacional_piloto_NB_tuberculos_W26                    195
# 20230701_SPO_japonesainternacional_piloto_NB_verduras_W26                      163
# 20230701_SPO_japonesainternacional_piloto_NB_laticinios_W26                    271
# 20230701_SPO_japonesainternacional_piloto_NB_leite_W26                         230
# 20230701_SPO_japonesainternacional_piloto_NB_manteigasemargarinas_W26          262
# 20230701_SPO_japonesainternacional_piloto_NB_ovos_W26                          257
# 20230701_SPO_japonesainternacional_piloto_NB_queijos_W26                       252
# 20230701_SPO_japonesainternacional_piloto_NB_desengordurantes_W26              299
# 20230701_SPO_japonesainternacional_piloto_NB_desinfetantesesanitizantes_W26    226
# 20230701_SPO_japonesainternacional_piloto_NB_detergentesabaoelava-louas_W26    191
# 20230701_SPO_japonesainternacional_piloto_NB_outroslimpadores_W26              286
# 20230701_SPO_japonesainternacional_piloto_NB_utensiliosdelimpeza_W26           271
# 20230701_SPO_japonesainternacional_piloto_NB_aucaradoantesedoces_W26           147
# 20230701_SPO_japonesainternacional_piloto_NB_arroz_W26                         174
# 20230701_SPO_japonesainternacional_piloto_NB_azeitesoleosevinagres_W26         106
# 20230701_SPO_japonesainternacional_piloto_NB_cafechocolateseinfusoes_W26       230
# 20230701_SPO_japonesainternacional_piloto_NB_condimentos_W26                   250
# 20230701_SPO_japonesainternacional_piloto_NB_conservaseenlatados_W26           277
# 20230701_SPO_japonesainternacional_piloto_NB_farinhasemisturas_W26             205
# 20230701_SPO_japonesainternacional_piloto_NB_feijao_W26                        228
# 20230701_SPO_japonesainternacional_piloto_NB_graos_W26                         307
# 20230701_SPO_japonesainternacional_piloto_NB_massasemolhos_W26                 240
# 20230701_SPO_japonesainternacional_piloto_NB_temperos_W26                      222
# 20230701_SPO_japonesainternacional_piloto_NB_carnevermelha_W26                 291
# 20230701_SPO_japonesainternacional_piloto_NB_embutidos_W26                     272
# 20230701_SPO_japonesainternacional_piloto_NB_frango_W26                        243
# 20230701_SPO_japonesainternacional_piloto_NB_peixesefrutosdomar_W26            297
# 20230701_SPO_japonesainternacional_piloto_NB_suinos_W26                        289
# dtype: int64
# Done SPO japonesainternacional_PILOTO
# //-------------------------------------------------------------------------------
# Japonesa/Internacional Experimento50%
# 77
# Uso de data externa
# 20230701_SPO_japonesainternacional_control_NB_aguaseisotonicos_W26              56
# 20230701_SPO_japonesainternacional_control_NB_cervejas_W26                      57
# 20230701_SPO_japonesainternacional_control_NB_refrigeranteseenergeticos_W26     40
# 20230701_SPO_japonesainternacional_control_NB_sucosechas_W26                    71
# 20230701_SPO_japonesainternacional_control_NB_destilados_W26                    76
# 20230701_SPO_japonesainternacional_control_NB_alimentoscongelados_W26           71
# 20230701_SPO_japonesainternacional_control_NB_batataspre-fritas_W26             66
# 20230701_SPO_japonesainternacional_control_NB_polpaseaai_W26                    74
# 20230701_SPO_japonesainternacional_control_NB_coposrecipientesepratos_W26       77
# 20230701_SPO_japonesainternacional_control_NB_embalagens_W26                    76
# 20230701_SPO_japonesainternacional_control_NB_papeis_W26                        61
# 20230701_SPO_japonesainternacional_control_NB_sacos_W26                         76
# 20230701_SPO_japonesainternacional_control_NB_utensilios_W26                    77
# 20230701_SPO_japonesainternacional_control_NB_frutas_W26                        38
# 20230701_SPO_japonesainternacional_control_NB_legumes_W26                       32
# 20230701_SPO_japonesainternacional_control_NB_tuberculos_W26                    46
# 20230701_SPO_japonesainternacional_control_NB_verduras_W26                      41
# 20230701_SPO_japonesainternacional_control_NB_laticinios_W26                    63
# 20230701_SPO_japonesainternacional_control_NB_leite_W26                         51
# 20230701_SPO_japonesainternacional_control_NB_manteigasemargarinas_W26          63
# 20230701_SPO_japonesainternacional_control_NB_ovos_W26                          66
# 20230701_SPO_japonesainternacional_control_NB_queijos_W26                       57
# 20230701_SPO_japonesainternacional_control_NB_desengordurantes_W26              75
# 20230701_SPO_japonesainternacional_control_NB_desinfetantesesanitizantes_W26    51
# 20230701_SPO_japonesainternacional_control_NB_detergentesabaoelava-louas_W26    42
# 20230701_SPO_japonesainternacional_control_NB_outroslimpadores_W26              71
# 20230701_SPO_japonesainternacional_control_NB_utensiliosdelimpeza_W26           68
# 20230701_SPO_japonesainternacional_control_NB_aucaradoantesedoces_W26           30
# 20230701_SPO_japonesainternacional_control_NB_arroz_W26                         48
# 20230701_SPO_japonesainternacional_control_NB_azeitesoleosevinagres_W26         27
# 20230701_SPO_japonesainternacional_control_NB_cafechocolateseinfusoes_W26       61
# 20230701_SPO_japonesainternacional_control_NB_condimentos_W26                   59
# 20230701_SPO_japonesainternacional_control_NB_conservaseenlatados_W26           68
# 20230701_SPO_japonesainternacional_control_NB_farinhasemisturas_W26             51
# 20230701_SPO_japonesainternacional_control_NB_feijao_W26                        54
# 20230701_SPO_japonesainternacional_control_NB_graos_W26                         73
# 20230701_SPO_japonesainternacional_control_NB_massasemolhos_W26                 57
# 20230701_SPO_japonesainternacional_control_NB_temperos_W26                      50
# 20230701_SPO_japonesainternacional_control_NB_carnevermelha_W26                 74
# 20230701_SPO_japonesainternacional_control_NB_embutidos_W26                     65
# 20230701_SPO_japonesainternacional_control_NB_frango_W26                        62
# 20230701_SPO_japonesainternacional_control_NB_peixesefrutosdomar_W26            76
# 20230701_SPO_japonesainternacional_control_NB_suinos_W26                        67
# dtype: int64
# Done SPO japonesainternacional_CONTROL

# %% [markdown]
# ## Aca creo el archivo para R&D

# %%
# customers =  pd.DataFrame()
# for column,i in enumerate(aux_df.columns):
#     #if ('verduras' in i or 'frutas' in i or 'arroz' in i or 'aceitesygrasas' in i or 'harinasymezclas' in i or 'azucaryendulzantes' in i or 'pollo' in i or 'huevos' in i) and not 'frutasjugo' in i:
#     #if ('verduras' in i or 'frutas' in i) and not 'frutasjugo' in i:
#     customers[i] = aux_df[i]

# %%
# customers.iloc[:6000].to_csv(f'SD/export_data/MS/csv_{city_code}_CLIENTS_PRUEBA_R&D.csv', index = False)

# with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
#        json.dump(global_segment_list, outfile)

# %%
# aux_seg = pd.read_csv(f"prueba_tuberculos_BAQ.csv")
# aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

# aux_seg["final_group2"] = ["piloto" if x == "Super Descuentos" else "control" for x in aux_seg.grupos]
# aux_seg['offer_name'] = f"20230301_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W9"

# aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()

# %%
# lst = []
# for x in aux_seg2.values:
#     h = {'name':x[0], 'customersIds': list(x[1])}
#     lst.append(h)
    
# for x in lst:
#     print(x['name'])
#     #break
#     for i,value in enumerate(global_segment_list):
#         if value['name'] == x['name']:
#             global_segment_list[i]['customersIds'] = x['customersIds']
#             print(i)

# %%
aux_seg = pd.read_csv(f"csv_{city_code}_CLIENTS_FINAL_JULIO_R&D.csv")
aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

aux_seg["final_group2"] = ["piloto" if x == "Treatment" else "control" for x in aux_seg.final_group]
aux_seg['offer_name'] = f"20230701_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W26"

aux_seg["quartile"] = ["Q0" if x == "-" else x for x in aux_seg.quartile.values]
aux_seg["quartile_name"] = f"20230701_{city_code}_" + aux_seg.subcategory + "_" + aux_seg.quartile + "_" + aux_seg.case

aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()
aux_seg3 = aux_seg.groupby(by = ["quartile_name"])["customer_source_id"].apply(list).reset_index()

# %%
aux_seg.head()
# Out:
#         subcategory  customer_source_id               ms previous_group  \
# 0  aguaseisotonicos           187220351            other        Control
# 1  aguaseisotonicos           254507038  pratosrefeicoes      Treatment
# 2  aguaseisotonicos           267388376  pratosrefeicoes      Treatment
# 3  aguaseisotonicos            19666340            other      Treatment
# 4  aguaseisotonicos            40749052          lanches      Treatment
#
#          case quartile  random final_group final_group2  \
# 0  positivity       Q4       0   Treatment       piloto
# 1  positivity       Q4       0   Treatment       piloto
# 2  positivity       Q4       0   Treatment       piloto
# 3  positivity       Q4       0   Treatment       piloto
# 4  positivity       Q4       0   Treatment       piloto
#
#                                           offer_name  \
# 0  20230701_SPO_other_piloto_NB_aguaseisotonicos_W26
# 1  20230701_SPO_pratosrefeicoes_piloto_NB_aguasei...
# 2  20230701_SPO_pratosrefeicoes_piloto_NB_aguasei...
# 3  20230701_SPO_other_piloto_NB_aguaseisotonicos_W26
# 4  20230701_SPO_lanches_piloto_NB_aguaseisotonico...
#
#                                  quartile_name
# 0  20230701_SPO_aguaseisotonicos_Q4_positivity
# 1  20230701_SPO_aguaseisotonicos_Q4_positivity
# 2  20230701_SPO_aguaseisotonicos_Q4_positivity
# 3  20230701_SPO_aguaseisotonicos_Q4_positivity
# 4  20230701_SPO_aguaseisotonicos_Q4_positivity

# %%
lst = []
for x in aux_seg2.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst.append(h)

global_segment_list = lst

# %%
lst2 = []
for x in aux_seg3.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst2.append(h)

# %% [markdown]
# # Aca tengo que volver a cargar el archivo de arriba y dejarlo como lista para traer lo otro

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_SPO_sucosacai_piloto_NB_aguaseisotoni...
# 1  20230701_SPO_sucosacai_piloto_NB_refrigerantes...
# 2    20230701_SPO_sucosacai_piloto_NB_sucosechas_W26
# 3  20230701_SPO_sucosacai_piloto_NB_alimentoscong...
# 4    20230701_SPO_sucosacai_piloto_NB_polpaseaai_W26
#
#                                offer_description  discount  \
# 0           sucosacai_piloto_NB_aguaseisotonicos         5
# 1  sucosacai_piloto_NB_refrigeranteseenergeticos         5
# 2                 sucosacai_piloto_NB_sucosechas         9
# 3        sucosacai_piloto_NB_alimentoscongelados         5
# 4                 sucosacai_piloto_NB_polpaseaai        12
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                   7
# 1                         true  01-07-2023  31-07-2023                   7
# 2                         true  01-07-2023  31-07-2023                   7
# 3                         true  01-07-2023  31-07-2023                  15
# 4                         true  01-07-2023  31-07-2023                  50
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1                None
# 1                      1                None
# 2                      1                None
# 3                      1                None
# 4                      1                None
#
#                                               sku_id
# 0   244568#244567#246590#597183#244570#244569#246591
# 1  244764#246588#244765#363755#363756#363757#4520...
# 2  397324#397325#244789#244790#248558#244785#2447...
# 3  531043#582043#531039#243671#356913#581687#5820...
# 4  512679#512666#504854#512660#504848#512674#5048...

# %%
#len_seg =int(len(global_segment_list)/10)
#len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %% [markdown]
# ## Crear segments offers y segments types

# %%
import requests
import json

def create_segments(segment_list):
    
    url = f"https://{city_code}.frubana.com/api/v1/segments/create?api-key=00_growth-team-zzz-qqq_001"

    payload = json.dumps(segment_list)


    headers = {
    'Cookie': 'AWSALB=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALBCORS=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALB=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI; AWSALBCORS=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI',
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.status_code)
    sgt = [(int(x[:6]),x[7:]) for x in list(map(str.strip, response.text[32:].strip('][').replace('"', '').split(',')))]
    time.sleep(40)
    return sgt

# %%
len_seg =int(len(global_segment_list)/10)
len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %%
#offers
sgt=[]

for i in len_seg_list:
    sgt.append(create_segments(i))
    
sgt_end =[item for lista in sgt for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len_seg2 =int(len(lst2)/10)
len_seg_list2 = [lst2[:len_seg2],lst2[len_seg2:len_seg2*2],lst2[len_seg2*2:len_seg2*3],lst2[len_seg2*3:len_seg2*4],lst2[len_seg2*4:len_seg2*5],lst2[len_seg2*5:len_seg2*6],lst2[len_seg2*6:len_seg2*7],lst2[len_seg2*7:len_seg2*8],lst2[len_seg2*8:len_seg2*9],lst2[len_seg2*9:]]

# %%
#types
sgt2=[]

for i in len_seg_list2:
    sgt2.append(create_segments(i))
    
sgt_end2 =[item for lista in sgt2 for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#unir offers con segments
for i in global_offer_csv.offer_name:
    for j,z in sgt_end:
        if z==i:
            global_offer_csv.loc[global_offer_csv.offer_name == i, ('customer_segment_id')] = j

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_SPO_sucosacai_piloto_NB_aguaseisotoni...
# 1  20230701_SPO_sucosacai_piloto_NB_refrigerantes...
# 2    20230701_SPO_sucosacai_piloto_NB_sucosechas_W26
# 3  20230701_SPO_sucosacai_piloto_NB_alimentoscong...
# 4    20230701_SPO_sucosacai_piloto_NB_polpaseaai_W26
#
#                                offer_description  discount  \
# 0           sucosacai_piloto_NB_aguaseisotonicos         5
# 1  sucosacai_piloto_NB_refrigeranteseenergeticos         5
# 2                 sucosacai_piloto_NB_sucosechas         9
# 3        sucosacai_piloto_NB_alimentoscongelados         5
# 4                 sucosacai_piloto_NB_polpaseaai        12
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                   7
# 1                         true  01-07-2023  31-07-2023                   7
# 2                         true  01-07-2023  31-07-2023                   7
# 3                         true  01-07-2023  31-07-2023                  15
# 4                         true  01-07-2023  31-07-2023                  50
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              184988
# 1                      1              185004
# 2                      1              185006
# 3                      1              184989
# 4                      1              185003
#
#                                               sku_id
# 0   244568#244567#246590#597183#244570#244569#246591
# 1  244764#246588#244765#363755#363756#363757#4520...
# 2  397324#397325#244789#244790#248558#244785#2447...
# 3  531043#582043#531039#243671#356913#581687#5820...
# 4  512679#512666#504854#512660#504848#512674#5048...

# %%
global_offer_csv = global_offer_csv.loc[~global_offer_csv.customer_segment_id.isnull()].reset_index(drop=True)
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('discount','max_uses_per_order')]=1
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('start_date','end_date')]='01-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('end_date')]='02-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('sku_id')]= global_offer_csv.loc[~global_offer_csv['offer_name'].str.contains("piloto", case=False), ('sku_id')].tolist()

# %%
len_offer =int(len(global_offer_csv)/4)
len_offer = [global_offer_csv[:len_seg],global_offer_csv[len_seg:len_seg*2],global_offer_csv[len_seg*2:len_seg*3],global_offer_csv[len_seg*3:]]

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_SPO_sucosacai_piloto_NB_aguaseisotoni...
# 1  20230701_SPO_sucosacai_piloto_NB_refrigerantes...
# 2    20230701_SPO_sucosacai_piloto_NB_sucosechas_W26
# 3  20230701_SPO_sucosacai_piloto_NB_alimentoscong...
# 4    20230701_SPO_sucosacai_piloto_NB_polpaseaai_W26
#
#                                offer_description  discount  \
# 0           sucosacai_piloto_NB_aguaseisotonicos         5
# 1  sucosacai_piloto_NB_refrigeranteseenergeticos         5
# 2                 sucosacai_piloto_NB_sucosechas         9
# 3        sucosacai_piloto_NB_alimentoscongelados         5
# 4                 sucosacai_piloto_NB_polpaseaai        12
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                   7
# 1                         true  01-07-2023  31-07-2023                   7
# 2                         true  01-07-2023  31-07-2023                   7
# 3                         true  01-07-2023  31-07-2023                  15
# 4                         true  01-07-2023  31-07-2023                  50
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              184988
# 1                      1              185004
# 2                      1              185006
# 3                      1              184989
# 4                      1              185003
#
#                                               sku_id
# 0   244568#244567#246590#597183#244570#244569#246591
# 1  244764#246588#244765#363755#363756#363757#4520...
# 2  397324#397325#244789#244790#248558#244785#2447...
# 3  531043#582043#531039#243671#356913#581687#5820...
# 4  512679#512666#504854#512660#504848#512674#5048...

# %%
#//--------------------------------------------
#//Exporting single file data
global_offer_csv.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS.csv', index = False)

for i,offer in enumerate(len_offer):
    offer.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS_{i}.csv', index = False)

with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
        json.dump(global_segment_list, outfile)    
with open(f'SD/export_data/MS/nb_{city_code}_All_MS.json', 'w') as outfile:
        json.dump(global_segment_list, outfile)
print(f'Done {city_code}')
# Out:
# Done SPO
