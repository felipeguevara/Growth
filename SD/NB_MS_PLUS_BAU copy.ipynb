# %%
#//----------------------------
#//LIBRARIES
    #Math
import math
    #Numeric Python
import numpy as np
    #Pandas (dataframes)
import pandas as pd
    #datetime for fate manipulation
from datetime import date, datetime, timedelta  
    #Regex for advanced string matching
import re
    #for time related stuff
import time
    #json library
import json
    #Analyst tools
import sys
sys.path.append('../')
from analysts_tools.growth import *
    #Procurement tools
from analysts_tools.redash_methods import *
    #Frubana libraries
from procurement_lib import redash, dw, send_message, send_slack_notification, GoogleSheet, logging

# %%
#//---------------------------------------------------------------------------------------------------------------------------
#// Parametros
"""Todays date should be the first day of the next month which is going to begin with SD"""

city_code = 'SPO'

# Set today's date to the first day of the next month
today = datetime.today()
first_day_next_month = (today.replace(day=1) + timedelta(days=32)).replace(day=1)

# Calculate non_buyers_date (todays date - 1 month)
non_buyers_date = (first_day_next_month - timedelta(days=1)).replace(day=1)
customer_date_desde = (first_day_next_month - timedelta(days=1)).replace(day=1)

# Calculate sku_date_desde (todays date - 2 months)
sku_date_desde = (first_day_next_month - timedelta(days=60)).replace(day=1)

# Convert the dates to strings in the desired format
todays_date = first_day_next_month.strftime('%Y-%m-%d')
non_buyers_date = non_buyers_date.strftime('%Y-%m-%d')
customer_date_desde = customer_date_desde.strftime('%Y-%m-%d')
sku_date_desde = sku_date_desde.strftime('%Y-%m-%d')

print(todays_date) # Output: e.g. 2023-04-01
print(non_buyers_date) # Output: e.g. 2023-03-01
print(sku_date_desde) # Output: e.g. 2023-02-01

tasas = {'BOG': 3776,
         'BAQ': 3776,
         'MDE': 3776,
         'CMX': 19.65,
         'GDL': 19.65,
         'PBC': 19.65,
         'SPO': 4.75,
         'BHZ': 4.75,
         'CWB': 4.75,
         'VCP': 4.75}

t_cambio = tasas[city_code]
# Out:
# 2023-06-01
# 2023-05-01
# 2023-04-01

# %%
query="""
With microsegment as (

SELECT DISTINCT c.customer_id AS user_id,
                c.site_type AS region_code_ms,
                
                (case 
                    -- Colombia
                    when m.microsegment_id not in (1,3,4,28,5,6,7,8,2) and c.site_type = 'BOG' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1,3,4,28,5,11,10,9,2,12) and c.site_type = 'BAQ' then 'Sin Microsegmento'
                    when m.microsegment_id not in (3,4,28,1,24,11,5,2,27) and c.site_type = 'MDE' then 'Sin Microsegmento'
    
                    -- Mexico
                    when m.microsegment_id not in (1,13,14,30,15,16,29,17,6,7,2) and c.site_type = 'CMX' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1, 13,14,30, 15,16,29, 6, 33, 2, 31) and c.site_type = 'GDL' then 'Sin Microsegmento'
                    when m.microsegment_id not in (13,14,30, 15,16,29, 32,2,6,33) and c.site_type = 'PBC' then 'Sin Microsegmento'
                    
                    -- Brasil
                    when m.microsegment_id not in (21,34,38,37,35,36,39,26) and c.site_type in ('SPO','BHZ','CWB','VCP') then 'Sin Microsegmento'
                        
                else m.description end) as microsegment_ok,
                
                m.microsegment_id,
                mo.name as ms_method
                
                
FROM postgres_main_federate."growth_microsegmentation.customer_microsegment" AS cm
INNER JOIN postgres_main_federate."growth_microsegmentation.microsegment" m ON cm.microsegment_id = m.id
INNER JOIN postgres_main_federate."growth_microsegmentation.customer" c ON cm.customer_id = c.id
INNER JOIN postgres_main_federate."growth_microsegmentation.models" mo ON mo.id = cm.model_type_id


)

select m.user_id,
m.region_code_ms,
--m.microsegment_id,

(case 
        when m.microsegment_ok in ('Corrientazo c/desayuno','Corrientazo s/desayuno','Tienda/Restaurante') then 'Corrientazo' 
        when m.microsegment_ok in ('Fonda c/desayuno','Fonda s/desayuno') then 'Fonda'
        when m.microsegment_ok in ('Taquería en calle','Taquería en local') then 'Taquería'

else m.microsegment_ok end) as microsegment,

m.ms_method

from microsegment m
where m.microsegment_ok != 'Sin Microsegmento'
"""

segmentos_fulll = read_connection_data_warehouse.runQuery(query)

segmentos_fulll.columns = ['customer_id', 'city', 'microsegment','NA']
segmentos_fulll = segmentos_fulll[['customer_id', 'city', 'microsegment']]

# %% [markdown]
# ### Loading COSTUMERS INFO

# %%
users_eliminar_kam = get_fresh_query_result("https://internal-redash.federate.frubana.com/",150812,'SeoGHWmDUaaBi7VXje1s9zYNiMD1VHQ1K1DYOxiF',{},20)
users_eliminar = users_eliminar_kam.loc[users_eliminar_kam.registered_city == city_code]['customer_id'].unique().tolist()
# Out:
# 200

# %% [markdown]
# ### Loading FORCED_SKUS // Cleaning SEGMENT_NAMES

# %% [markdown]
# ### Loading DATA_VENTAS // Removing SKUs /\ CUSTOMERS_ID

# %%
#//Remove skus 
#It is used because some SKUs can get in trouble with supplier for the SD or to exclude them for another activity   
skus_remove = GoogleSheet("1Z0T_c36oRHmOHIgEG8_ANcwFykaHgXGAizYAYCKCqtY")
skus_remove = skus_remove.get_as_dataframe('SKUS')

skus_remove = skus_remove['sku_id'].unique().astype(int).tolist()

# %%
query = """
SELECT DISTINCT
    split_part(bs.upc, '-', 1) as region,
    bs.sku_id

FROM postgres_broadleaf_federate."broadleaf.blc_sku"            bs 
LEFT JOIN postgres_broadleaf_federate."broadleaf.blc_product"   bp ON bp.product_id = bs.addl_product_id

WHERE bs.archived = 'N'
    AND bs.sndbx_id is NULL
    AND bp.archived = 'N'
    AND bs.catalog_disc < 0
    AND ((bp.archived = 'N' AND bp.sndbx_id is NULL) OR (bp.archived is NULL))
"""
frida_products = read_connection_data_warehouse.runQuery(query)

# %%
good_skus = frida_products.sku_id.unique()

# %%
#Loading SELL'S DATA from a function
data_ventas = data_ventas_query(ciudad=city_code, tipo_cambio=t_cambio, desde=customer_date_desde, hasta = todays_date, tipo_negocio=1)

# %%
data_ventas = data_ventas[(~data_ventas['sku_id'].isin(skus_remove)) & (data_ventas['sku_id'].isin(good_skus))]

# %%
segmentos_full = segmentos_fulll[segmentos_fulll.city == city_code].copy()

# %%
#//customers for offers */(has further uses)*/
microsegmentacion_df = segmentos_full[(~segmentos_full['customer_id'].isin(users_eliminar))]
data_ventas = data_ventas[(~data_ventas['customer_id'].isin(users_eliminar))]

# %% [markdown]
# ### Create the MS "Other" for BAU

# %%
data_full = data_ventas.merge(microsegmentacion_df[['customer_id','microsegment']], how = 'left', on = 'customer_id')

# %%
data_full['microsegment'] = data_full['microsegment'].fillna('Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                    microsegment  customer_id
# 0                        Boteco          962
# 1  Grill/Churrascaria/Espetinho          485
# 2        Japonesa/Internacional          353
# 3                       Lanches         4028
# 4                         Other         1550
# 5            Padaria/Cafe/Bolos         2706
# 6  Pizzaria/Pastelaria/Italiano          739
# 7              Pratos/Refeições         4871
# 8                    Sucos/Açaí          567

# %%
segments_validation = data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()

# %%
for ms in segments_validation[segments_validation.customer_id < 180]['microsegment'].unique():
    data_full['microsegment'] = data_full['microsegment'].str.replace(ms,'Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                    microsegment  customer_id
# 0                        Boteco          962
# 1  Grill/Churrascaria/Espetinho          485
# 2        Japonesa/Internacional          353
# 3                       Lanches         4028
# 4                         Other         1550
# 5            Padaria/Cafe/Bolos         2706
# 6  Pizzaria/Pastelaria/Italiano          739
# 7              Pratos/Refeições         4871
# 8                    Sucos/Açaí          567

# %%
#Get the same variable to do the process job
data_ventas = data_full

# %% [markdown]
# ### PARAMETERS // SOME FUNCTIONS - GET READY TO PROCESSING

# %%
def ms_data(city_code):
  
    paramss_csv=GoogleSheet("1k0ckgkLddxc5lY8NUVGCkvDLTuulLaJm-N535oMNZNw")
    city_paramss = paramss_csv.get_as_dataframe(city_code)
    
    parametros = {}
    parametros[city_code] = {}
    
    for i,ms in enumerate(city_paramss.iloc[:,4:].columns):
        parametros[city_code][ms] = [(value[1],value[2],value[3],value[4+i]) for value in city_paramss.values if value[4+i]>0]
        
    return parametros

# %%
parametros = ms_data(city_code)

# %%
def normalize_text(raw_text):
    """
    Removes common accent characters and normalize text.
    """
    raw_text = raw_text.replace(" ", "")
    raw_text = raw_text.replace("�", "")
    raw_text = raw_text.replace("/", "")
    raw_text = re.sub(r'\s*', '', raw_text)
    raw_text = re.sub(r"[àáâãäå]", 'a', raw_text)
    raw_text = re.sub(r"[èéêë]", 'e', raw_text)
    raw_text = re.sub(r"[ìíîï]", 'i', raw_text) 
    raw_text = re.sub(r"[òóôõö]", 'o', raw_text)
    raw_text = re.sub(r"[ùúûü]", 'u', raw_text)
    raw_text = re.sub(r"[ýÿ]", 'y', raw_text)
    raw_text = re.sub(r"[ß]", 'ss', raw_text)
    raw_text = re.sub(r"[ñ]", 'n', raw_text)
    raw_text = re.sub(r"[ç]", 'c', raw_text)
    raw_text = raw_text.lower()
    return raw_text

# %%
#Sacar de aca los microsegmentos
msg = data_full.microsegment.unique()
msg
# Out:
# array(['Lanches', 'Padaria/Cafe/Bolos', 'Pratos/Refeições', 'Other',
#        'Grill/Churrascaria/Espetinho', 'Boteco',
#        'Pizzaria/Pastelaria/Italiano', 'Sucos/Açaí',
#        'Japonesa/Internacional'], dtype=object)

# %% [markdown]
# ### END

# %% [markdown]
# # Aca Empieza la Experimentacion

# %%
from sklearn.model_selection import train_test_split

# %%
#//Variables to store all the segments and offers of the city
global_offer_csv = pd.DataFrame()
global_segment_list = [] #//for procesing

# %%
#//----------------------------------------------------------------------------
#//Big loop for creating each city segments/offers files
aux_df = pd.DataFrame()
aux_df['aux']=6000*[0]

for microsegment in msg:
    print('//-------------------------------------------------------------------------------')
    print(microsegment)

    #//Customers per microsegment
    customers_ms = data_ventas[(data_ventas['microsegment'] == microsegment)]['customer_id'].unique()
    #//Customers to give them the skus
    customers_for_skus_ms =  data_ventas[['microsegment','customer_id']][(data_ventas.microsegment == microsegment) & (~data_ventas.customer_id.isin(users_eliminar))]['customer_id'].unique()
    
    #----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_PILOTO" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    rand=1
    customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state=rand)
    
    while abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())) > 0.05:
        #print(data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean(),data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean(),abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())))
        rand+=1
        customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state = rand)
        
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_1)].copy() #le quite la s!!
    
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()
    
    subcats = list(map(lambda x: x[0], parametros[city_code][microsegment]))
    max_uses = list(map(lambda x: int(x[1]), parametros[city_code][microsegment]))
    max_order = list(map(lambda x: int(x[2]), parametros[city_code][microsegment]))
    discount = list(map(lambda x: int(x[3]), parametros[city_code][microsegment]))

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    a, b, c = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
            non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                        limite=0.75, data_ventas_skus = data_skus)

    print(b.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(a)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in b.columns:
        id_list = b[seg].dropna().astype(int)
        d = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)

        lst.append(d)
        
    #//appending to global list    
        global_segment_list.append(d)
    
    print(f'Done {city_code} {ms_name}')

#----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------


#----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_CONTROL" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_2)].copy() #le quite la s!!
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    print('//-------------------------------------------------------------------------------')
    print(f'{microsegment} Experimento50%')
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    e, f, g = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
                non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                          limite=0.75, data_ventas_skus = data_skus)
      
    print(f.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(e)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in f.columns:
        id_list = f[seg].dropna().astype(int)
        h = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)
        
        lst.append(h)
        
        
    #//appending to global list    
        global_segment_list.append(h)
    
    print(f'Done {city_code} {ms_name}')
    #----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#//End of big loop and start of data bundle
# Out:
# //-------------------------------------------------------------------------------
# Lanches
# 3223
# Uso de data externa
# 20230601_SPO_lanches_piloto_NB_aguaseisotonicos_W22              2405
# 20230601_SPO_lanches_piloto_NB_cervejas_W22                      2449
# 20230601_SPO_lanches_piloto_NB_refrigeranteseenergeticos_W22     1960
# 20230601_SPO_lanches_piloto_NB_sucosechas_W22                    2707
# 20230601_SPO_lanches_piloto_NB_destilados_W22                    3040
# 20230601_SPO_lanches_piloto_NB_alimentoscongelados_W22           2960
# 20230601_SPO_lanches_piloto_NB_batataspre-fritas_W22             2692
# 20230601_SPO_lanches_piloto_NB_polpaseaai_W22                    2959
# 20230601_SPO_lanches_piloto_NB_coposrecipientesepratos_W22       3192
# 20230601_SPO_lanches_piloto_NB_embalagens_W22                    3166
# 20230601_SPO_lanches_piloto_NB_papeis_W22                        2788
# 20230601_SPO_lanches_piloto_NB_sacos_W22                         3198
# 20230601_SPO_lanches_piloto_NB_utensilios_W22                    3130
# 20230601_SPO_lanches_piloto_NB_frutas_W22                        1675
# 20230601_SPO_lanches_piloto_NB_legumes_W22                       1284
# 20230601_SPO_lanches_piloto_NB_tuberculos_W22                    2074
# 20230601_SPO_lanches_piloto_NB_verduras_W22                      2042
# 20230601_SPO_lanches_piloto_NB_laticinios_W22                    2840
# 20230601_SPO_lanches_piloto_NB_leite_W22                         1937
# 20230601_SPO_lanches_piloto_NB_manteigasemargarinas_W22          2780
# 20230601_SPO_lanches_piloto_NB_ovos_W22                          2734
# 20230601_SPO_lanches_piloto_NB_queijos_W22                       2316
# 20230601_SPO_lanches_piloto_NB_desengordurantes_W22              3127
# 20230601_SPO_lanches_piloto_NB_desinfetantesesanitizantes_W22    2564
# 20230601_SPO_lanches_piloto_NB_detergentesabaoelava-louas_W22    2364
# 20230601_SPO_lanches_piloto_NB_outroslimpadores_W22              3030
# 20230601_SPO_lanches_piloto_NB_utensiliosdelimpeza_W22           2887
# 20230601_SPO_lanches_piloto_NB_aucaradoantesedoces_W22           2071
# 20230601_SPO_lanches_piloto_NB_arroz_W22                         2379
# 20230601_SPO_lanches_piloto_NB_azeitesoleosevinagres_W22         1517
# 20230601_SPO_lanches_piloto_NB_cafechocolateseinfusoes_W22       2490
# 20230601_SPO_lanches_piloto_NB_condimentos_W22                   2511
# 20230601_SPO_lanches_piloto_NB_conservaseenlatados_W22           2991
# 20230601_SPO_lanches_piloto_NB_docesesobremesas_W22              3184
# 20230601_SPO_lanches_piloto_NB_farinhasemisturas_W22             2570
# 20230601_SPO_lanches_piloto_NB_feijao_W22                        2479
# 20230601_SPO_lanches_piloto_NB_graos_W22                         3127
# 20230601_SPO_lanches_piloto_NB_massasemolhos_W22                 2703
# 20230601_SPO_lanches_piloto_NB_temperos_W22                      2634
# 20230601_SPO_lanches_piloto_NB_carnevermelha_W22                 2919
# 20230601_SPO_lanches_piloto_NB_embutidos_W22                     2586
# 20230601_SPO_lanches_piloto_NB_frango_W22                        2439
# 20230601_SPO_lanches_piloto_NB_peixesefrutosdomar_W22            3154
# 20230601_SPO_lanches_piloto_NB_suinos_W22                        2921
# dtype: int64
# Done SPO lanches_PILOTO
# //-------------------------------------------------------------------------------
# Lanches Experimento50%
# 805
# Uso de data externa
# 20230601_SPO_lanches_control_NB_aguaseisotonicos_W22              617
# 20230601_SPO_lanches_control_NB_cervejas_W22                      624
# 20230601_SPO_lanches_control_NB_refrigeranteseenergeticos_W22     502
# 20230601_SPO_lanches_control_NB_sucosechas_W22                    670
# 20230601_SPO_lanches_control_NB_destilados_W22                    761
# 20230601_SPO_lanches_control_NB_alimentoscongelados_W22           740
# 20230601_SPO_lanches_control_NB_batataspre-fritas_W22             661
# 20230601_SPO_lanches_control_NB_polpaseaai_W22                    740
# 20230601_SPO_lanches_control_NB_coposrecipientesepratos_W22       798
# 20230601_SPO_lanches_control_NB_embalagens_W22                    800
# 20230601_SPO_lanches_control_NB_papeis_W22                        709
# 20230601_SPO_lanches_control_NB_sacos_W22                         802
# 20230601_SPO_lanches_control_NB_utensilios_W22                    789
# 20230601_SPO_lanches_control_NB_frutas_W22                        411
# 20230601_SPO_lanches_control_NB_legumes_W22                       328
# 20230601_SPO_lanches_control_NB_tuberculos_W22                    507
# 20230601_SPO_lanches_control_NB_verduras_W22                      500
# 20230601_SPO_lanches_control_NB_laticinios_W22                    706
# 20230601_SPO_lanches_control_NB_leite_W22                         485
# 20230601_SPO_lanches_control_NB_manteigasemargarinas_W22          697
# 20230601_SPO_lanches_control_NB_ovos_W22                          684
# 20230601_SPO_lanches_control_NB_queijos_W22                       580
# 20230601_SPO_lanches_control_NB_desengordurantes_W22              780
# 20230601_SPO_lanches_control_NB_desinfetantesesanitizantes_W22    647
# 20230601_SPO_lanches_control_NB_detergentesabaoelava-louas_W22    585
# 20230601_SPO_lanches_control_NB_outroslimpadores_W22              761
# 20230601_SPO_lanches_control_NB_utensiliosdelimpeza_W22           717
# 20230601_SPO_lanches_control_NB_aucaradoantesedoces_W22           514
# 20230601_SPO_lanches_control_NB_arroz_W22                         589
# 20230601_SPO_lanches_control_NB_azeitesoleosevinagres_W22         376
# 20230601_SPO_lanches_control_NB_cafechocolateseinfusoes_W22       633
# 20230601_SPO_lanches_control_NB_condimentos_W22                   620
# 20230601_SPO_lanches_control_NB_conservaseenlatados_W22           734
# 20230601_SPO_lanches_control_NB_docesesobremesas_W22              793
# 20230601_SPO_lanches_control_NB_farinhasemisturas_W22             637
# 20230601_SPO_lanches_control_NB_feijao_W22                        621
# 20230601_SPO_lanches_control_NB_graos_W22                         779
# 20230601_SPO_lanches_control_NB_massasemolhos_W22                 665
# 20230601_SPO_lanches_control_NB_temperos_W22                      648
# 20230601_SPO_lanches_control_NB_carnevermelha_W22                 741
# 20230601_SPO_lanches_control_NB_embutidos_W22                     643
# 20230601_SPO_lanches_control_NB_frango_W22                        604
# 20230601_SPO_lanches_control_NB_peixesefrutosdomar_W22            792
# 20230601_SPO_lanches_control_NB_suinos_W22                        727
# dtype: int64
# Done SPO lanches_CONTROL
# //-------------------------------------------------------------------------------
# Padaria/Cafe/Bolos
# 2165
# Uso de data externa
# 20230601_SPO_padariacafebolos_piloto_NB_aguaseisotonicos_W22              1672
# 20230601_SPO_padariacafebolos_piloto_NB_cervejas_W22                      1751
# 20230601_SPO_padariacafebolos_piloto_NB_refrigeranteseenergeticos_W22     1478
# 20230601_SPO_padariacafebolos_piloto_NB_sucosechas_W22                    1876
# 20230601_SPO_padariacafebolos_piloto_NB_destilados_W22                    2015
# 20230601_SPO_padariacafebolos_piloto_NB_alimentoscongelados_W22           2058
# 20230601_SPO_padariacafebolos_piloto_NB_batataspre-fritas_W22             1990
# 20230601_SPO_padariacafebolos_piloto_NB_polpaseaai_W22                    2042
# 20230601_SPO_padariacafebolos_piloto_NB_coposrecipientesepratos_W22       2145
# 20230601_SPO_padariacafebolos_piloto_NB_embalagens_W22                    2143
# 20230601_SPO_padariacafebolos_piloto_NB_papeis_W22                        1875
# 20230601_SPO_padariacafebolos_piloto_NB_sacos_W22                         2145
# 20230601_SPO_padariacafebolos_piloto_NB_utensilios_W22                    2032
# 20230601_SPO_padariacafebolos_piloto_NB_frutas_W22                        1148
# 20230601_SPO_padariacafebolos_piloto_NB_legumes_W22                       1027
# 20230601_SPO_padariacafebolos_piloto_NB_tuberculos_W22                    1437
# 20230601_SPO_padariacafebolos_piloto_NB_verduras_W22                      1554
# 20230601_SPO_padariacafebolos_piloto_NB_laticinios_W22                    1763
# 20230601_SPO_padariacafebolos_piloto_NB_leite_W22                          927
# 20230601_SPO_padariacafebolos_piloto_NB_manteigasemargarinas_W22          1729
# 20230601_SPO_padariacafebolos_piloto_NB_ovos_W22                          1930
# 20230601_SPO_padariacafebolos_piloto_NB_queijos_W22                       1524
# 20230601_SPO_padariacafebolos_piloto_NB_desengordurantes_W22              2082
# 20230601_SPO_padariacafebolos_piloto_NB_desinfetantesesanitizantes_W22    1636
# 20230601_SPO_padariacafebolos_piloto_NB_detergentesabaoelava-louas_W22    1455
# 20230601_SPO_padariacafebolos_piloto_NB_outroslimpadores_W22              2019
# 20230601_SPO_padariacafebolos_piloto_NB_utensiliosdelimpeza_W22           1917
# 20230601_SPO_padariacafebolos_piloto_NB_aucaradoantesedoces_W22            834
# 20230601_SPO_padariacafebolos_piloto_NB_arroz_W22                         1730
# 20230601_SPO_padariacafebolos_piloto_NB_azeitesoleosevinagres_W22         1100
# 20230601_SPO_padariacafebolos_piloto_NB_cafechocolateseinfusoes_W22       1628
# 20230601_SPO_padariacafebolos_piloto_NB_condimentos_W22                   1887
# 20230601_SPO_padariacafebolos_piloto_NB_conservaseenlatados_W22           1968
# 20230601_SPO_padariacafebolos_piloto_NB_docesesobremesas_W22              2082
# 20230601_SPO_padariacafebolos_piloto_NB_farinhasemisturas_W22             1693
# 20230601_SPO_padariacafebolos_piloto_NB_feijao_W22                        1757
# 20230601_SPO_padariacafebolos_piloto_NB_graos_W22                         2047
# 20230601_SPO_padariacafebolos_piloto_NB_massasemolhos_W22                 1863
# 20230601_SPO_padariacafebolos_piloto_NB_temperos_W22                      1761
# 20230601_SPO_padariacafebolos_piloto_NB_carnevermelha_W22                 2024
# 20230601_SPO_padariacafebolos_piloto_NB_embutidos_W22                     1786
# 20230601_SPO_padariacafebolos_piloto_NB_frango_W22                        1736
# 20230601_SPO_padariacafebolos_piloto_NB_peixesefrutosdomar_W22            2129
# 20230601_SPO_padariacafebolos_piloto_NB_suinos_W22                        2064
# dtype: int64
# Done SPO padariacafebolos_PILOTO
# //-------------------------------------------------------------------------------
# Padaria/Cafe/Bolos Experimento50%
# 541
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)
# Uso de data externa
# 20230601_SPO_padariacafebolos_control_NB_aguaseisotonicos_W22              409
# 20230601_SPO_padariacafebolos_control_NB_cervejas_W22                      437
# 20230601_SPO_padariacafebolos_control_NB_refrigeranteseenergeticos_W22     367
# 20230601_SPO_padariacafebolos_control_NB_sucosechas_W22                    465
# 20230601_SPO_padariacafebolos_control_NB_destilados_W22                    510
# 20230601_SPO_padariacafebolos_control_NB_alimentoscongelados_W22           516
# 20230601_SPO_padariacafebolos_control_NB_batataspre-fritas_W22             498
# 20230601_SPO_padariacafebolos_control_NB_polpaseaai_W22                    501
# 20230601_SPO_padariacafebolos_control_NB_coposrecipientesepratos_W22       537
# 20230601_SPO_padariacafebolos_control_NB_embalagens_W22                    528
# 20230601_SPO_padariacafebolos_control_NB_papeis_W22                        458
# 20230601_SPO_padariacafebolos_control_NB_sacos_W22                         535
# 20230601_SPO_padariacafebolos_control_NB_utensilios_W22                    506
# 20230601_SPO_padariacafebolos_control_NB_frutas_W22                        263
# 20230601_SPO_padariacafebolos_control_NB_legumes_W22                       245
# 20230601_SPO_padariacafebolos_control_NB_tuberculos_W22                    344
# 20230601_SPO_padariacafebolos_control_NB_verduras_W22                      373
# 20230601_SPO_padariacafebolos_control_NB_laticinios_W22                    428
# 20230601_SPO_padariacafebolos_control_NB_leite_W22                         235
# 20230601_SPO_padariacafebolos_control_NB_manteigasemargarinas_W22          435
# 20230601_SPO_padariacafebolos_control_NB_ovos_W22                          479
# 20230601_SPO_padariacafebolos_control_NB_queijos_W22                       393
# 20230601_SPO_padariacafebolos_control_NB_desengordurantes_W22              535
# 20230601_SPO_padariacafebolos_control_NB_desinfetantesesanitizantes_W22    408
# 20230601_SPO_padariacafebolos_control_NB_detergentesabaoelava-louas_W22    361
# 20230601_SPO_padariacafebolos_control_NB_outroslimpadores_W22              503
# 20230601_SPO_padariacafebolos_control_NB_utensiliosdelimpeza_W22           482
# 20230601_SPO_padariacafebolos_control_NB_aucaradoantesedoces_W22           211
# 20230601_SPO_padariacafebolos_control_NB_arroz_W22                         406
# 20230601_SPO_padariacafebolos_control_NB_azeitesoleosevinagres_W22         265
# 20230601_SPO_padariacafebolos_control_NB_cafechocolateseinfusoes_W22       406
# 20230601_SPO_padariacafebolos_control_NB_condimentos_W22                   452
# 20230601_SPO_padariacafebolos_control_NB_conservaseenlatados_W22           482
# 20230601_SPO_padariacafebolos_control_NB_docesesobremesas_W22              524
# 20230601_SPO_padariacafebolos_control_NB_farinhasemisturas_W22             419
# 20230601_SPO_padariacafebolos_control_NB_feijao_W22                        418
# 20230601_SPO_padariacafebolos_control_NB_graos_W22                         509
# 20230601_SPO_padariacafebolos_control_NB_massasemolhos_W22                 440
# 20230601_SPO_padariacafebolos_control_NB_temperos_W22                      438
# 20230601_SPO_padariacafebolos_control_NB_carnevermelha_W22                 492
# 20230601_SPO_padariacafebolos_control_NB_embutidos_W22                     441
# 20230601_SPO_padariacafebolos_control_NB_frango_W22                        455
# 20230601_SPO_padariacafebolos_control_NB_peixesefrutosdomar_W22            534
# 20230601_SPO_padariacafebolos_control_NB_suinos_W22                        511
# dtype: int64
# Done SPO padariacafebolos_CONTROL
# //-------------------------------------------------------------------------------
# Pratos/Refeições
# 3897
# Uso de data externa
# 20230601_SPO_pratosrefeicoes_piloto_NB_aguaseisotonicos_W22              2962
# 20230601_SPO_pratosrefeicoes_piloto_NB_cervejas_W22                      3205
# 20230601_SPO_pratosrefeicoes_piloto_NB_refrigeranteseenergeticos_W22     2546
# 20230601_SPO_pratosrefeicoes_piloto_NB_sucosechas_W22                    3489
# 20230601_SPO_pratosrefeicoes_piloto_NB_destilados_W22                    3760
# 20230601_SPO_pratosrefeicoes_piloto_NB_alimentoscongelados_W22           3467
# 20230601_SPO_pratosrefeicoes_piloto_NB_batataspre-fritas_W22             3056
# 20230601_SPO_pratosrefeicoes_piloto_NB_polpaseaai_W22                    3542
# 20230601_SPO_pratosrefeicoes_piloto_NB_coposrecipientesepratos_W22       3880
# 20230601_SPO_pratosrefeicoes_piloto_NB_embalagens_W22                    3820
# 20230601_SPO_pratosrefeicoes_piloto_NB_papeis_W22                        3340
# 20230601_SPO_pratosrefeicoes_piloto_NB_sacos_W22                         3860
# 20230601_SPO_pratosrefeicoes_piloto_NB_utensilios_W22                    3787
# 20230601_SPO_pratosrefeicoes_piloto_NB_frutas_W22                        1712
# 20230601_SPO_pratosrefeicoes_piloto_NB_legumes_W22                       1068
# 20230601_SPO_pratosrefeicoes_piloto_NB_tuberculos_W22                    1869
# 20230601_SPO_pratosrefeicoes_piloto_NB_verduras_W22                      2028
# 20230601_SPO_pratosrefeicoes_piloto_NB_laticinios_W22                    3232
# 20230601_SPO_pratosrefeicoes_piloto_NB_leite_W22                         2363
# 20230601_SPO_pratosrefeicoes_piloto_NB_manteigasemargarinas_W22          3221
# 20230601_SPO_pratosrefeicoes_piloto_NB_ovos_W22                          3145
# 20230601_SPO_pratosrefeicoes_piloto_NB_queijos_W22                       2981
# 20230601_SPO_pratosrefeicoes_piloto_NB_desengordurantes_W22              3746
# 20230601_SPO_pratosrefeicoes_piloto_NB_desinfetantesesanitizantes_W22    2970
# 20230601_SPO_pratosrefeicoes_piloto_NB_detergentesabaoelava-louas_W22    2576
# 20230601_SPO_pratosrefeicoes_piloto_NB_outroslimpadores_W22              3601
# 20230601_SPO_pratosrefeicoes_piloto_NB_utensiliosdelimpeza_W22           3301
# 20230601_SPO_pratosrefeicoes_piloto_NB_aucaradoantesedoces_W22           2446
# 20230601_SPO_pratosrefeicoes_piloto_NB_arroz_W22                         1926
# 20230601_SPO_pratosrefeicoes_piloto_NB_azeitesoleosevinagres_W22         1353
# 20230601_SPO_pratosrefeicoes_piloto_NB_cafechocolateseinfusoes_W22       2912
# 20230601_SPO_pratosrefeicoes_piloto_NB_condimentos_W22                   2996
# 20230601_SPO_pratosrefeicoes_piloto_NB_conservaseenlatados_W22           3486
# 20230601_SPO_pratosrefeicoes_piloto_NB_docesesobremesas_W22              3836
# 20230601_SPO_pratosrefeicoes_piloto_NB_farinhasemisturas_W22             2653
# 20230601_SPO_pratosrefeicoes_piloto_NB_feijao_W22                        2219
# 20230601_SPO_pratosrefeicoes_piloto_NB_graos_W22                         3714
# 20230601_SPO_pratosrefeicoes_piloto_NB_massasemolhos_W22                 2768
# 20230601_SPO_pratosrefeicoes_piloto_NB_temperos_W22                      2623
# 20230601_SPO_pratosrefeicoes_piloto_NB_carnevermelha_W22                 3459
# 20230601_SPO_pratosrefeicoes_piloto_NB_embutidos_W22                     3124
# 20230601_SPO_pratosrefeicoes_piloto_NB_frango_W22                        3076
# 20230601_SPO_pratosrefeicoes_piloto_NB_peixesefrutosdomar_W22            3747
# 20230601_SPO_pratosrefeicoes_piloto_NB_suinos_W22                        3500
# dtype: int64
# Done SPO pratosrefeicoes_PILOTO
# //-------------------------------------------------------------------------------
# Pratos/Refeições Experimento50%
# 974
# Uso de data externa
# 20230601_SPO_pratosrefeicoes_control_NB_aguaseisotonicos_W22              775
# 20230601_SPO_pratosrefeicoes_control_NB_cervejas_W22                      784
# 20230601_SPO_pratosrefeicoes_control_NB_refrigeranteseenergeticos_W22     643
# 20230601_SPO_pratosrefeicoes_control_NB_sucosechas_W22                    873
# 20230601_SPO_pratosrefeicoes_control_NB_destilados_W22                    943
# 20230601_SPO_pratosrefeicoes_control_NB_alimentoscongelados_W22           879
# 20230601_SPO_pratosrefeicoes_control_NB_batataspre-fritas_W22             738
# 20230601_SPO_pratosrefeicoes_control_NB_polpaseaai_W22                    882
# 20230601_SPO_pratosrefeicoes_control_NB_coposrecipientesepratos_W22       969
# 20230601_SPO_pratosrefeicoes_control_NB_embalagens_W22                    956
# 20230601_SPO_pratosrefeicoes_control_NB_papeis_W22                        806
# 20230601_SPO_pratosrefeicoes_control_NB_sacos_W22                         964
# 20230601_SPO_pratosrefeicoes_control_NB_utensilios_W22                    943
# 20230601_SPO_pratosrefeicoes_control_NB_frutas_W22                        421
# 20230601_SPO_pratosrefeicoes_control_NB_legumes_W22                       243
# 20230601_SPO_pratosrefeicoes_control_NB_tuberculos_W22                    450
# 20230601_SPO_pratosrefeicoes_control_NB_verduras_W22                      507
# 20230601_SPO_pratosrefeicoes_control_NB_laticinios_W22                    801
# 20230601_SPO_pratosrefeicoes_control_NB_leite_W22                         567
# 20230601_SPO_pratosrefeicoes_control_NB_manteigasemargarinas_W22          796
# 20230601_SPO_pratosrefeicoes_control_NB_ovos_W22                          774
# 20230601_SPO_pratosrefeicoes_control_NB_queijos_W22                       746
# 20230601_SPO_pratosrefeicoes_control_NB_desengordurantes_W22              926
# 20230601_SPO_pratosrefeicoes_control_NB_desinfetantesesanitizantes_W22    747
# 20230601_SPO_pratosrefeicoes_control_NB_detergentesabaoelava-louas_W22    644
# 20230601_SPO_pratosrefeicoes_control_NB_outroslimpadores_W22              905
# 20230601_SPO_pratosrefeicoes_control_NB_utensiliosdelimpeza_W22           827
# 20230601_SPO_pratosrefeicoes_control_NB_aucaradoantesedoces_W22           589
# 20230601_SPO_pratosrefeicoes_control_NB_arroz_W22                         481
# 20230601_SPO_pratosrefeicoes_control_NB_azeitesoleosevinagres_W22         338
# 20230601_SPO_pratosrefeicoes_control_NB_cafechocolateseinfusoes_W22       710
# 20230601_SPO_pratosrefeicoes_control_NB_condimentos_W22                   747
# 20230601_SPO_pratosrefeicoes_control_NB_conservaseenlatados_W22           870
# 20230601_SPO_pratosrefeicoes_control_NB_docesesobremesas_W22              954
# 20230601_SPO_pratosrefeicoes_control_NB_farinhasemisturas_W22             680
# 20230601_SPO_pratosrefeicoes_control_NB_feijao_W22                        537
# 20230601_SPO_pratosrefeicoes_control_NB_graos_W22                         930
# 20230601_SPO_pratosrefeicoes_control_NB_massasemolhos_W22                 687
# 20230601_SPO_pratosrefeicoes_control_NB_temperos_W22                      662
# 20230601_SPO_pratosrefeicoes_control_NB_carnevermelha_W22                 852
# 20230601_SPO_pratosrefeicoes_control_NB_embutidos_W22                     783
# 20230601_SPO_pratosrefeicoes_control_NB_frango_W22                        761
# 20230601_SPO_pratosrefeicoes_control_NB_peixesefrutosdomar_W22            928
# 20230601_SPO_pratosrefeicoes_control_NB_suinos_W22                        890
# dtype: int64
# Done SPO pratosrefeicoes_CONTROL
# //-------------------------------------------------------------------------------
# Other
# 1240
# Uso de data externa
# 20230601_SPO_other_piloto_NB_aguaseisotonicos_W22               937
# 20230601_SPO_other_piloto_NB_cervejas_W22                       986
# 20230601_SPO_other_piloto_NB_refrigeranteseenergeticos_W22      796
# 20230601_SPO_other_piloto_NB_sucosechas_W22                    1103
# 20230601_SPO_other_piloto_NB_destilados_W22                    1191
# 20230601_SPO_other_piloto_NB_alimentoscongelados_W22           1074
# 20230601_SPO_other_piloto_NB_batataspre-fritas_W22             1007
# 20230601_SPO_other_piloto_NB_polpaseaai_W22                    1137
# 20230601_SPO_other_piloto_NB_coposrecipientesepratos_W22       1235
# 20230601_SPO_other_piloto_NB_embalagens_W22                    1211
# 20230601_SPO_other_piloto_NB_papeis_W22                        1024
# 20230601_SPO_other_piloto_NB_sacos_W22                         1217
# 20230601_SPO_other_piloto_NB_utensilios_W22                    1181
# 20230601_SPO_other_piloto_NB_frutas_W22                         518
# 20230601_SPO_other_piloto_NB_legumes_W22                        406
# 20230601_SPO_other_piloto_NB_tuberculos_W22                     628
# 20230601_SPO_other_piloto_NB_verduras_W22                       627
# 20230601_SPO_other_piloto_NB_laticinios_W22                     983
# 20230601_SPO_other_piloto_NB_leite_W22                          723
# 20230601_SPO_other_piloto_NB_manteigasemargarinas_W22          1013
# 20230601_SPO_other_piloto_NB_ovos_W22                           943
# 20230601_SPO_other_piloto_NB_queijos_W22                        885
# 20230601_SPO_other_piloto_NB_desengordurantes_W22              1187
# 20230601_SPO_other_piloto_NB_desinfetantesesanitizantes_W22     890
# 20230601_SPO_other_piloto_NB_detergentesabaoelava-louas_W22     796
# 20230601_SPO_other_piloto_NB_outroslimpadores_W22              1128
# 20230601_SPO_other_piloto_NB_utensiliosdelimpeza_W22           1033
# 20230601_SPO_other_piloto_NB_aucaradoantesedoces_W22            723
# 20230601_SPO_other_piloto_NB_arroz_W22                          767
# 20230601_SPO_other_piloto_NB_azeitesoleosevinagres_W22          552
# 20230601_SPO_other_piloto_NB_cafechocolateseinfusoes_W22        943
# 20230601_SPO_other_piloto_NB_condimentos_W22                    915
# 20230601_SPO_other_piloto_NB_conservaseenlatados_W22           1091
# 20230601_SPO_other_piloto_NB_docesesobremesas_W22              1206
# 20230601_SPO_other_piloto_NB_farinhasemisturas_W22              878
# 20230601_SPO_other_piloto_NB_feijao_W22                         832
# 20230601_SPO_other_piloto_NB_graos_W22                         1159
# 20230601_SPO_other_piloto_NB_massasemolhos_W22                  909
# 20230601_SPO_other_piloto_NB_temperos_W22                       881
# 20230601_SPO_other_piloto_NB_carnevermelha_W22                 1094
# 20230601_SPO_other_piloto_NB_embutidos_W22                     1003
# 20230601_SPO_other_piloto_NB_frango_W22                         913
# 20230601_SPO_other_piloto_NB_peixesefrutosdomar_W22            1192
# 20230601_SPO_other_piloto_NB_suinos_W22                        1111
# dtype: int64
# Done SPO other_PILOTO
# //-------------------------------------------------------------------------------
# Other Experimento50%
# 310
# Uso de data externa
# 20230601_SPO_other_control_NB_aguaseisotonicos_W22              244
# 20230601_SPO_other_control_NB_cervejas_W22                      239
# 20230601_SPO_other_control_NB_refrigeranteseenergeticos_W22     196
# 20230601_SPO_other_control_NB_sucosechas_W22                    276
# 20230601_SPO_other_control_NB_destilados_W22                    300
# 20230601_SPO_other_control_NB_alimentoscongelados_W22           267
# 20230601_SPO_other_control_NB_batataspre-fritas_W22             255
# 20230601_SPO_other_control_NB_polpaseaai_W22                    289
# 20230601_SPO_other_control_NB_coposrecipientesepratos_W22       309
# 20230601_SPO_other_control_NB_embalagens_W22                    305
# 20230601_SPO_other_control_NB_papeis_W22                        260
# 20230601_SPO_other_control_NB_sacos_W22                         308
# 20230601_SPO_other_control_NB_utensilios_W22                    299
# 20230601_SPO_other_control_NB_frutas_W22                        125
# 20230601_SPO_other_control_NB_legumes_W22                        88
# 20230601_SPO_other_control_NB_tuberculos_W22                    149
# 20230601_SPO_other_control_NB_verduras_W22                      152
# 20230601_SPO_other_control_NB_laticinios_W22                    238
# 20230601_SPO_other_control_NB_leite_W22                         180
# 20230601_SPO_other_control_NB_manteigasemargarinas_W22          243
# 20230601_SPO_other_control_NB_ovos_W22                          233
# 20230601_SPO_other_control_NB_queijos_W22                       227
# 20230601_SPO_other_control_NB_desengordurantes_W22              295
# 20230601_SPO_other_control_NB_desinfetantesesanitizantes_W22    217
# 20230601_SPO_other_control_NB_detergentesabaoelava-louas_W22    200
# 20230601_SPO_other_control_NB_outroslimpadores_W22              283
# 20230601_SPO_other_control_NB_utensiliosdelimpeza_W22           258
# 20230601_SPO_other_control_NB_aucaradoantesedoces_W22           171
# 20230601_SPO_other_control_NB_arroz_W22                         196
# 20230601_SPO_other_control_NB_azeitesoleosevinagres_W22         145
# 20230601_SPO_other_control_NB_cafechocolateseinfusoes_W22       226
# 20230601_SPO_other_control_NB_condimentos_W22                   233
# 20230601_SPO_other_control_NB_conservaseenlatados_W22           264
# 20230601_SPO_other_control_NB_docesesobremesas_W22              304
# 20230601_SPO_other_control_NB_farinhasemisturas_W22             212
# 20230601_SPO_other_control_NB_feijao_W22                        205
# 20230601_SPO_other_control_NB_graos_W22                         293
# 20230601_SPO_other_control_NB_massasemolhos_W22                 231
# 20230601_SPO_other_control_NB_temperos_W22                      227
# 20230601_SPO_other_control_NB_carnevermelha_W22                 261
# 20230601_SPO_other_control_NB_embutidos_W22                     244
# 20230601_SPO_other_control_NB_frango_W22                        223
# 20230601_SPO_other_control_NB_peixesefrutosdomar_W22            296
# 20230601_SPO_other_control_NB_suinos_W22                        264
# dtype: int64
# Done SPO other_CONTROL
# //-------------------------------------------------------------------------------
# Grill/Churrascaria/Espetinho
# 388
# Uso de data externa
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_aguaseisotonicos_W22              294
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_cervejas_W22                      271
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_refrigeranteseenergeticos_W22     246
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_sucosechas_W22                    350
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_destilados_W22                    376
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_alimentoscongelados_W22           352
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_batataspre-fritas_W22             317
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_polpaseaai_W22                    359
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_coposrecipientesepratos_W22       383
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_embalagens_W22                    381
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_papeis_W22                        347
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_sacos_W22                         386
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_utensilios_W22                    382
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_frutas_W22                        211
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_legumes_W22                       160
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_tuberculos_W22                    251
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_verduras_W22                      267
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_laticinios_W22                    338
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_leite_W22                         256
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_manteigasemargarinas_W22          339
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_ovos_W22                          341
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_queijos_W22                       325
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_desengordurantes_W22              373
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_desinfetantesesanitizantes_W22    312
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_detergentesabaoelava-louas_W22    276
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_outroslimpadores_W22              368
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_utensiliosdelimpeza_W22           341
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_aucaradoantesedoces_W22           254
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_arroz_W22                         252
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_azeitesoleosevinagres_W22         163
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_cafechocolateseinfusoes_W22       307
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_condimentos_W22                   314
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_conservaseenlatados_W22           346
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_docesesobremesas_W22              385
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_farinhasemisturas_W22             309
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_feijao_W22                        260
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_graos_W22                         380
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_massasemolhos_W22                 313
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_temperos_W22                      285
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_carnevermelha_W22                 359
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_embutidos_W22                     324
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_frango_W22                        308
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_peixesefrutosdomar_W22            382
# 20230601_SPO_grillchurrascariaespetinho_piloto_NB_suinos_W22                        340
# dtype: int64
# Done SPO grillchurrascariaespetinho_PILOTO
# //-------------------------------------------------------------------------------
# Grill/Churrascaria/Espetinho Experimento50%
# 97
# Uso de data externa
# 20230601_SPO_grillchurrascariaespetinho_control_NB_aguaseisotonicos_W22              69
# 20230601_SPO_grillchurrascariaespetinho_control_NB_cervejas_W22                      66
# 20230601_SPO_grillchurrascariaespetinho_control_NB_refrigeranteseenergeticos_W22     54
# 20230601_SPO_grillchurrascariaespetinho_control_NB_sucosechas_W22                    81
# 20230601_SPO_grillchurrascariaespetinho_control_NB_destilados_W22                    93
# 20230601_SPO_grillchurrascariaespetinho_control_NB_alimentoscongelados_W22           86
# 20230601_SPO_grillchurrascariaespetinho_control_NB_batataspre-fritas_W22             71
# 20230601_SPO_grillchurrascariaespetinho_control_NB_polpaseaai_W22                    91
# 20230601_SPO_grillchurrascariaespetinho_control_NB_coposrecipientesepratos_W22       96
# 20230601_SPO_grillchurrascariaespetinho_control_NB_embalagens_W22                    94
# 20230601_SPO_grillchurrascariaespetinho_control_NB_papeis_W22                        82
# 20230601_SPO_grillchurrascariaespetinho_control_NB_sacos_W22                         95
# 20230601_SPO_grillchurrascariaespetinho_control_NB_utensilios_W22                    92
# 20230601_SPO_grillchurrascariaespetinho_control_NB_frutas_W22                        52
# 20230601_SPO_grillchurrascariaespetinho_control_NB_legumes_W22                       39
# 20230601_SPO_grillchurrascariaespetinho_control_NB_tuberculos_W22                    66
# 20230601_SPO_grillchurrascariaespetinho_control_NB_verduras_W22                      65
# 20230601_SPO_grillchurrascariaespetinho_control_NB_laticinios_W22                    88
# 20230601_SPO_grillchurrascariaespetinho_control_NB_leite_W22                         67
# 20230601_SPO_grillchurrascariaespetinho_control_NB_manteigasemargarinas_W22          87
# 20230601_SPO_grillchurrascariaespetinho_control_NB_ovos_W22                          87
# 20230601_SPO_grillchurrascariaespetinho_control_NB_queijos_W22                       76
# 20230601_SPO_grillchurrascariaespetinho_control_NB_desengordurantes_W22              92
# 20230601_SPO_grillchurrascariaespetinho_control_NB_desinfetantesesanitizantes_W22    81
# 20230601_SPO_grillchurrascariaespetinho_control_NB_detergentesabaoelava-louas_W22    69
# 20230601_SPO_grillchurrascariaespetinho_control_NB_outroslimpadores_W22              92
# 20230601_SPO_grillchurrascariaespetinho_control_NB_utensiliosdelimpeza_W22           87
# 20230601_SPO_grillchurrascariaespetinho_control_NB_aucaradoantesedoces_W22           66
# 20230601_SPO_grillchurrascariaespetinho_control_NB_arroz_W22                         66
# 20230601_SPO_grillchurrascariaespetinho_control_NB_azeitesoleosevinagres_W22         42
# 20230601_SPO_grillchurrascariaespetinho_control_NB_cafechocolateseinfusoes_W22       78
# 20230601_SPO_grillchurrascariaespetinho_control_NB_condimentos_W22                   77
# 20230601_SPO_grillchurrascariaespetinho_control_NB_conservaseenlatados_W22           86
# 20230601_SPO_grillchurrascariaespetinho_control_NB_docesesobremesas_W22              94
# 20230601_SPO_grillchurrascariaespetinho_control_NB_farinhasemisturas_W22             76
# 20230601_SPO_grillchurrascariaespetinho_control_NB_feijao_W22                        74
# 20230601_SPO_grillchurrascariaespetinho_control_NB_graos_W22                         94
# 20230601_SPO_grillchurrascariaespetinho_control_NB_massasemolhos_W22                 80
# 20230601_SPO_grillchurrascariaespetinho_control_NB_temperos_W22                      69
# 20230601_SPO_grillchurrascariaespetinho_control_NB_carnevermelha_W22                 86
# 20230601_SPO_grillchurrascariaespetinho_control_NB_embutidos_W22                     82
# 20230601_SPO_grillchurrascariaespetinho_control_NB_frango_W22                        77
# 20230601_SPO_grillchurrascariaespetinho_control_NB_peixesefrutosdomar_W22            96
# 20230601_SPO_grillchurrascariaespetinho_control_NB_suinos_W22                        91
# dtype: int64
# Done SPO grillchurrascariaespetinho_CONTROL
# //-------------------------------------------------------------------------------
# Boteco
# 770
# Uso de data externa
# 20230601_SPO_boteco_piloto_NB_aguaseisotonicos_W22              618
# 20230601_SPO_boteco_piloto_NB_cervejas_W22                      390
# 20230601_SPO_boteco_piloto_NB_refrigeranteseenergeticos_W22     505
# 20230601_SPO_boteco_piloto_NB_sucosechas_W22                    712
# 20230601_SPO_boteco_piloto_NB_destilados_W22                    644
# 20230601_SPO_boteco_piloto_NB_alimentoscongelados_W22           732
# 20230601_SPO_boteco_piloto_NB_batataspre-fritas_W22             662
# 20230601_SPO_boteco_piloto_NB_polpaseaai_W22                    750
# 20230601_SPO_boteco_piloto_NB_coposrecipientesepratos_W22       758
# 20230601_SPO_boteco_piloto_NB_embalagens_W22                    767
# 20230601_SPO_boteco_piloto_NB_papeis_W22                        672
# 20230601_SPO_boteco_piloto_NB_sacos_W22                         769
# 20230601_SPO_boteco_piloto_NB_utensilios_W22                    746
# 20230601_SPO_boteco_piloto_NB_frutas_W22                        448
# 20230601_SPO_boteco_piloto_NB_legumes_W22                       456
# 20230601_SPO_boteco_piloto_NB_tuberculos_W22                    562
# 20230601_SPO_boteco_piloto_NB_verduras_W22                      609
# 20230601_SPO_boteco_piloto_NB_laticinios_W22                    694
# 20230601_SPO_boteco_piloto_NB_leite_W22                         520
# 20230601_SPO_boteco_piloto_NB_manteigasemargarinas_W22          709
# 20230601_SPO_boteco_piloto_NB_ovos_W22                          699
# 20230601_SPO_boteco_piloto_NB_queijos_W22                       691
# 20230601_SPO_boteco_piloto_NB_desengordurantes_W22              751
# 20230601_SPO_boteco_piloto_NB_desinfetantesesanitizantes_W22    660
# 20230601_SPO_boteco_piloto_NB_detergentesabaoelava-louas_W22    626
# 20230601_SPO_boteco_piloto_NB_outroslimpadores_W22              741
# 20230601_SPO_boteco_piloto_NB_utensiliosdelimpeza_W22           711
# 20230601_SPO_boteco_piloto_NB_aucaradoantesedoces_W22           572
# 20230601_SPO_boteco_piloto_NB_arroz_W22                         610
# 20230601_SPO_boteco_piloto_NB_azeitesoleosevinagres_W22         515
# 20230601_SPO_boteco_piloto_NB_cafechocolateseinfusoes_W22       631
# 20230601_SPO_boteco_piloto_NB_condimentos_W22                   705
# 20230601_SPO_boteco_piloto_NB_conservaseenlatados_W22           732
# 20230601_SPO_boteco_piloto_NB_docesesobremesas_W22              764
# 20230601_SPO_boteco_piloto_NB_farinhasemisturas_W22             672
# 20230601_SPO_boteco_piloto_NB_feijao_W22                        624
# 20230601_SPO_boteco_piloto_NB_graos_W22                         748
# 20230601_SPO_boteco_piloto_NB_massasemolhos_W22                 673
# 20230601_SPO_boteco_piloto_NB_temperos_W22                      662
# 20230601_SPO_boteco_piloto_NB_carnevermelha_W22                 695
# 20230601_SPO_boteco_piloto_NB_embutidos_W22                     632
# 20230601_SPO_boteco_piloto_NB_frango_W22                        623
# 20230601_SPO_boteco_piloto_NB_peixesefrutosdomar_W22            748
# 20230601_SPO_boteco_piloto_NB_suinos_W22                        721
# dtype: int64
# Done SPO boteco_PILOTO
# //-------------------------------------------------------------------------------
# Boteco Experimento50%
# 192
# Uso de data externa
# 20230601_SPO_boteco_control_NB_aguaseisotonicos_W22              154
# 20230601_SPO_boteco_control_NB_cervejas_W22                       90
# 20230601_SPO_boteco_control_NB_refrigeranteseenergeticos_W22     122
# 20230601_SPO_boteco_control_NB_sucosechas_W22                    177
# 20230601_SPO_boteco_control_NB_destilados_W22                    166
# 20230601_SPO_boteco_control_NB_alimentoscongelados_W22           180
# 20230601_SPO_boteco_control_NB_batataspre-fritas_W22             175
# 20230601_SPO_boteco_control_NB_polpaseaai_W22                    185
# 20230601_SPO_boteco_control_NB_coposrecipientesepratos_W22       190
# 20230601_SPO_boteco_control_NB_embalagens_W22                    192
# 20230601_SPO_boteco_control_NB_papeis_W22                        169
# 20230601_SPO_boteco_control_NB_sacos_W22                         192
# 20230601_SPO_boteco_control_NB_utensilios_W22                    185
# 20230601_SPO_boteco_control_NB_frutas_W22                        110
# 20230601_SPO_boteco_control_NB_legumes_W22                       120
# 20230601_SPO_boteco_control_NB_tuberculos_W22                    146
# 20230601_SPO_boteco_control_NB_verduras_W22                      153
# 20230601_SPO_boteco_control_NB_laticinios_W22                    175
# 20230601_SPO_boteco_control_NB_leite_W22                         121
# 20230601_SPO_boteco_control_NB_manteigasemargarinas_W22          180
# 20230601_SPO_boteco_control_NB_ovos_W22                          178
# 20230601_SPO_boteco_control_NB_queijos_W22                       174
# 20230601_SPO_boteco_control_NB_desengordurantes_W22              189
# 20230601_SPO_boteco_control_NB_desinfetantesesanitizantes_W22    165
# 20230601_SPO_boteco_control_NB_detergentesabaoelava-louas_W22    149
# 20230601_SPO_boteco_control_NB_outroslimpadores_W22              183
# 20230601_SPO_boteco_control_NB_utensiliosdelimpeza_W22           177
# 20230601_SPO_boteco_control_NB_aucaradoantesedoces_W22           141
# 20230601_SPO_boteco_control_NB_arroz_W22                         156
# 20230601_SPO_boteco_control_NB_azeitesoleosevinagres_W22         126
# 20230601_SPO_boteco_control_NB_cafechocolateseinfusoes_W22       160
# 20230601_SPO_boteco_control_NB_condimentos_W22                   176
# 20230601_SPO_boteco_control_NB_conservaseenlatados_W22           177
# 20230601_SPO_boteco_control_NB_docesesobremesas_W22              189
# 20230601_SPO_boteco_control_NB_farinhasemisturas_W22             172
# 20230601_SPO_boteco_control_NB_feijao_W22                        161
# 20230601_SPO_boteco_control_NB_graos_W22                         184
# 20230601_SPO_boteco_control_NB_massasemolhos_W22                 166
# 20230601_SPO_boteco_control_NB_temperos_W22                      178
# 20230601_SPO_boteco_control_NB_carnevermelha_W22                 180
# 20230601_SPO_boteco_control_NB_embutidos_W22                     166
# 20230601_SPO_boteco_control_NB_frango_W22                        165
# 20230601_SPO_boteco_control_NB_peixesefrutosdomar_W22            190
# 20230601_SPO_boteco_control_NB_suinos_W22                        185
# dtype: int64
# Done SPO boteco_CONTROL
# //-------------------------------------------------------------------------------
# Pizzaria/Pastelaria/Italiano
# 592
# Uso de data externa
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_aguaseisotonicos_W22              459
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_cervejas_W22                      495
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_refrigeranteseenergeticos_W22     370
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_sucosechas_W22                    509
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_destilados_W22                    581
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_alimentoscongelados_W22           536
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_batataspre-fritas_W22             515
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_polpaseaai_W22                    553
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_coposrecipientesepratos_W22       590
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_embalagens_W22                    581
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_papeis_W22                        521
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_sacos_W22                         586
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_utensilios_W22                    582
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_frutas_W22                        321
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_legumes_W22                       221
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_tuberculos_W22                    422
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_verduras_W22                      381
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_laticinios_W22                    524
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_leite_W22                         412
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_manteigasemargarinas_W22          535
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_ovos_W22                          494
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_queijos_W22                       379
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_desengordurantes_W22              573
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_desinfetantesesanitizantes_W22    474
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_detergentesabaoelava-louas_W22    439
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_outroslimpadores_W22              558
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_utensiliosdelimpeza_W22           536
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_aucaradoantesedoces_W22           364
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_arroz_W22                         491
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_azeitesoleosevinagres_W22         263
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_cafechocolateseinfusoes_W22       498
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_condimentos_W22                   459
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_conservaseenlatados_W22           504
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_docesesobremesas_W22              584
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_farinhasemisturas_W22             500
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_feijao_W22                        503
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_graos_W22                         580
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_massasemolhos_W22                 509
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_temperos_W22                      484
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_carnevermelha_W22                 542
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_embutidos_W22                     508
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_frango_W22                        440
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_peixesefrutosdomar_W22            579
# 20230601_SPO_pizzariapastelariaitaliano_piloto_NB_suinos_W22                        549
# dtype: int64
# Done SPO pizzariapastelariaitaliano_PILOTO
# //-------------------------------------------------------------------------------
# Pizzaria/Pastelaria/Italiano Experimento50%
# 147
# Uso de data externa
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_aguaseisotonicos_W22              114
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_cervejas_W22                      117
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_refrigeranteseenergeticos_W22      92
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_sucosechas_W22                    131
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_destilados_W22                    147
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_alimentoscongelados_W22           122
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_batataspre-fritas_W22             132
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_polpaseaai_W22                    140
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_coposrecipientesepratos_W22       147
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_embalagens_W22                    144
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_papeis_W22                        130
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_sacos_W22                         147
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_utensilios_W22                    145
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_frutas_W22                         84
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_legumes_W22                        51
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_tuberculos_W22                    101
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_verduras_W22                       92
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_laticinios_W22                    127
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_leite_W22                         103
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_manteigasemargarinas_W22          134
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_ovos_W22                          124
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_queijos_W22                       107
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_desengordurantes_W22              144
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_desinfetantesesanitizantes_W22    117
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_detergentesabaoelava-louas_W22    108
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_outroslimpadores_W22              136
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_utensiliosdelimpeza_W22           136
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_aucaradoantesedoces_W22            95
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_arroz_W22                         122
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_azeitesoleosevinagres_W22          66
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_cafechocolateseinfusoes_W22       128
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_condimentos_W22                   127
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_conservaseenlatados_W22           137
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_docesesobremesas_W22              144
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_farinhasemisturas_W22             122
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_feijao_W22                        124
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_graos_W22                         145
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_massasemolhos_W22                 127
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_temperos_W22                      118
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_carnevermelha_W22                 132
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_embutidos_W22                     125
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_frango_W22                        109
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_peixesefrutosdomar_W22            143
# 20230601_SPO_pizzariapastelariaitaliano_control_NB_suinos_W22                        136
# dtype: int64
# Done SPO pizzariapastelariaitaliano_CONTROL
# //-------------------------------------------------------------------------------
# Sucos/Açaí
# 454
# Uso de data externa
# 20230601_SPO_sucosacai_piloto_NB_aguaseisotonicos_W22              321
# 20230601_SPO_sucosacai_piloto_NB_refrigeranteseenergeticos_W22     297
# 20230601_SPO_sucosacai_piloto_NB_sucosechas_W22                    383
# 20230601_SPO_sucosacai_piloto_NB_alimentoscongelados_W22           420
# 20230601_SPO_sucosacai_piloto_NB_polpaseaai_W22                    424
# 20230601_SPO_sucosacai_piloto_NB_coposrecipientesepratos_W22       448
# 20230601_SPO_sucosacai_piloto_NB_embalagens_W22                    452
# 20230601_SPO_sucosacai_piloto_NB_papeis_W22                        397
# 20230601_SPO_sucosacai_piloto_NB_sacos_W22                         452
# 20230601_SPO_sucosacai_piloto_NB_utensilios_W22                    437
# 20230601_SPO_sucosacai_piloto_NB_frutas_W22                        253
# 20230601_SPO_sucosacai_piloto_NB_legumes_W22                       237
# 20230601_SPO_sucosacai_piloto_NB_tuberculos_W22                    297
# 20230601_SPO_sucosacai_piloto_NB_verduras_W22                      331
# 20230601_SPO_sucosacai_piloto_NB_laticinios_W22                    358
# 20230601_SPO_sucosacai_piloto_NB_leite_W22                         239
# 20230601_SPO_sucosacai_piloto_NB_desengordurantes_W22              438
# 20230601_SPO_sucosacai_piloto_NB_desinfetantesesanitizantes_W22    363
# 20230601_SPO_sucosacai_piloto_NB_detergentesabaoelava-louas_W22    336
# 20230601_SPO_sucosacai_piloto_NB_outroslimpadores_W22              421
# 20230601_SPO_sucosacai_piloto_NB_utensiliosdelimpeza_W22           411
# 20230601_SPO_sucosacai_piloto_NB_aucaradoantesedoces_W22           263
# 20230601_SPO_sucosacai_piloto_NB_cafechocolateseinfusoes_W22       368
# 20230601_SPO_sucosacai_piloto_NB_docesesobremesas_W22              448
# dtype: int64
# Done SPO sucosacai_PILOTO
# //-------------------------------------------------------------------------------
# Sucos/Açaí Experimento50%
# 113
# Uso de data externa
# 20230601_SPO_sucosacai_control_NB_aguaseisotonicos_W22               79
# 20230601_SPO_sucosacai_control_NB_refrigeranteseenergeticos_W22      73
# 20230601_SPO_sucosacai_control_NB_sucosechas_W22                     97
# 20230601_SPO_sucosacai_control_NB_alimentoscongelados_W22           102
# 20230601_SPO_sucosacai_control_NB_polpaseaai_W22                    109
# 20230601_SPO_sucosacai_control_NB_coposrecipientesepratos_W22       111
# 20230601_SPO_sucosacai_control_NB_embalagens_W22                    113
# 20230601_SPO_sucosacai_control_NB_papeis_W22                         97
# 20230601_SPO_sucosacai_control_NB_sacos_W22                         113
# 20230601_SPO_sucosacai_control_NB_utensilios_W22                    111
# 20230601_SPO_sucosacai_control_NB_frutas_W22                         62
# 20230601_SPO_sucosacai_control_NB_legumes_W22                        58
# 20230601_SPO_sucosacai_control_NB_tuberculos_W22                     74
# 20230601_SPO_sucosacai_control_NB_verduras_W22                       88
# 20230601_SPO_sucosacai_control_NB_laticinios_W22                     93
# 20230601_SPO_sucosacai_control_NB_leite_W22                          63
# 20230601_SPO_sucosacai_control_NB_desengordurantes_W22              107
# 20230601_SPO_sucosacai_control_NB_desinfetantesesanitizantes_W22     89
# 20230601_SPO_sucosacai_control_NB_detergentesabaoelava-louas_W22     87
# 20230601_SPO_sucosacai_control_NB_outroslimpadores_W22              106
# 20230601_SPO_sucosacai_control_NB_utensiliosdelimpeza_W22            97
# 20230601_SPO_sucosacai_control_NB_aucaradoantesedoces_W22            65
# 20230601_SPO_sucosacai_control_NB_cafechocolateseinfusoes_W22        92
# 20230601_SPO_sucosacai_control_NB_docesesobremesas_W22              112
# dtype: int64
# Done SPO sucosacai_CONTROL
# //-------------------------------------------------------------------------------
# Japonesa/Internacional
# 283
# Uso de data externa
# 20230601_SPO_japonesainternacional_piloto_NB_aguaseisotonicos_W22              218
# 20230601_SPO_japonesainternacional_piloto_NB_cervejas_W22                      224
# 20230601_SPO_japonesainternacional_piloto_NB_refrigeranteseenergeticos_W22     158
# 20230601_SPO_japonesainternacional_piloto_NB_sucosechas_W22                    252
# 20230601_SPO_japonesainternacional_piloto_NB_destilados_W22                    274
# 20230601_SPO_japonesainternacional_piloto_NB_alimentoscongelados_W22           247
# 20230601_SPO_japonesainternacional_piloto_NB_batataspre-fritas_W22             242
# 20230601_SPO_japonesainternacional_piloto_NB_polpaseaai_W22                    273
# 20230601_SPO_japonesainternacional_piloto_NB_coposrecipientesepratos_W22       281
# 20230601_SPO_japonesainternacional_piloto_NB_embalagens_W22                    281
# 20230601_SPO_japonesainternacional_piloto_NB_papeis_W22                        234
# 20230601_SPO_japonesainternacional_piloto_NB_sacos_W22                         278
# 20230601_SPO_japonesainternacional_piloto_NB_utensilios_W22                    275
# 20230601_SPO_japonesainternacional_piloto_NB_frutas_W22                        135
# 20230601_SPO_japonesainternacional_piloto_NB_legumes_W22                       110
# 20230601_SPO_japonesainternacional_piloto_NB_tuberculos_W22                    167
# 20230601_SPO_japonesainternacional_piloto_NB_verduras_W22                      143
# 20230601_SPO_japonesainternacional_piloto_NB_laticinios_W22                    239
# 20230601_SPO_japonesainternacional_piloto_NB_leite_W22                         206
# 20230601_SPO_japonesainternacional_piloto_NB_manteigasemargarinas_W22          244
# 20230601_SPO_japonesainternacional_piloto_NB_ovos_W22                          229
# 20230601_SPO_japonesainternacional_piloto_NB_queijos_W22                       227
# 20230601_SPO_japonesainternacional_piloto_NB_desengordurantes_W22              268
# 20230601_SPO_japonesainternacional_piloto_NB_desinfetantesesanitizantes_W22    196
# 20230601_SPO_japonesainternacional_piloto_NB_detergentesabaoelava-louas_W22    163
# 20230601_SPO_japonesainternacional_piloto_NB_outroslimpadores_W22              269
# 20230601_SPO_japonesainternacional_piloto_NB_utensiliosdelimpeza_W22           243
# 20230601_SPO_japonesainternacional_piloto_NB_aucaradoantesedoces_W22           134
# 20230601_SPO_japonesainternacional_piloto_NB_arroz_W22                         170
# 20230601_SPO_japonesainternacional_piloto_NB_azeitesoleosevinagres_W22          89
# 20230601_SPO_japonesainternacional_piloto_NB_cafechocolateseinfusoes_W22       206
# 20230601_SPO_japonesainternacional_piloto_NB_condimentos_W22                   226
# 20230601_SPO_japonesainternacional_piloto_NB_conservaseenlatados_W22           259
# 20230601_SPO_japonesainternacional_piloto_NB_docesesobremesas_W22              275
# 20230601_SPO_japonesainternacional_piloto_NB_farinhasemisturas_W22             183
# 20230601_SPO_japonesainternacional_piloto_NB_feijao_W22                        203
# 20230601_SPO_japonesainternacional_piloto_NB_graos_W22                         278
# 20230601_SPO_japonesainternacional_piloto_NB_massasemolhos_W22                 220
# 20230601_SPO_japonesainternacional_piloto_NB_temperos_W22                      193
# 20230601_SPO_japonesainternacional_piloto_NB_carnevermelha_W22                 261
# 20230601_SPO_japonesainternacional_piloto_NB_embutidos_W22                     243
# 20230601_SPO_japonesainternacional_piloto_NB_frango_W22                        210
# 20230601_SPO_japonesainternacional_piloto_NB_peixesefrutosdomar_W22            272
# 20230601_SPO_japonesainternacional_piloto_NB_suinos_W22                        261
# dtype: int64
# Done SPO japonesainternacional_PILOTO
# //-------------------------------------------------------------------------------
# Japonesa/Internacional Experimento50%
# 70
# Uso de data externa
# 20230601_SPO_japonesainternacional_control_NB_aguaseisotonicos_W22              53
# 20230601_SPO_japonesainternacional_control_NB_cervejas_W22                      52
# 20230601_SPO_japonesainternacional_control_NB_refrigeranteseenergeticos_W22     46
# 20230601_SPO_japonesainternacional_control_NB_sucosechas_W22                    58
# 20230601_SPO_japonesainternacional_control_NB_destilados_W22                    70
# 20230601_SPO_japonesainternacional_control_NB_alimentoscongelados_W22           58
# 20230601_SPO_japonesainternacional_control_NB_batataspre-fritas_W22             64
# 20230601_SPO_japonesainternacional_control_NB_polpaseaai_W22                    65
# 20230601_SPO_japonesainternacional_control_NB_coposrecipientesepratos_W22       69
# 20230601_SPO_japonesainternacional_control_NB_embalagens_W22                    67
# 20230601_SPO_japonesainternacional_control_NB_papeis_W22                        57
# 20230601_SPO_japonesainternacional_control_NB_sacos_W22                         70
# 20230601_SPO_japonesainternacional_control_NB_utensilios_W22                    65
# 20230601_SPO_japonesainternacional_control_NB_frutas_W22                        37
# 20230601_SPO_japonesainternacional_control_NB_legumes_W22                       29
# 20230601_SPO_japonesainternacional_control_NB_tuberculos_W22                    40
# 20230601_SPO_japonesainternacional_control_NB_verduras_W22                      36
# 20230601_SPO_japonesainternacional_control_NB_laticinios_W22                    58
# 20230601_SPO_japonesainternacional_control_NB_leite_W22                         51
# 20230601_SPO_japonesainternacional_control_NB_manteigasemargarinas_W22          56
# 20230601_SPO_japonesainternacional_control_NB_ovos_W22                          54
# 20230601_SPO_japonesainternacional_control_NB_queijos_W22                       57
# 20230601_SPO_japonesainternacional_control_NB_desengordurantes_W22              69
# 20230601_SPO_japonesainternacional_control_NB_desinfetantesesanitizantes_W22    51
# 20230601_SPO_japonesainternacional_control_NB_detergentesabaoelava-louas_W22    47
# 20230601_SPO_japonesainternacional_control_NB_outroslimpadores_W22              66
# 20230601_SPO_japonesainternacional_control_NB_utensiliosdelimpeza_W22           60
# 20230601_SPO_japonesainternacional_control_NB_aucaradoantesedoces_W22           33
# 20230601_SPO_japonesainternacional_control_NB_arroz_W22                         40
# 20230601_SPO_japonesainternacional_control_NB_azeitesoleosevinagres_W22         19
# 20230601_SPO_japonesainternacional_control_NB_cafechocolateseinfusoes_W22       50
# 20230601_SPO_japonesainternacional_control_NB_condimentos_W22                   57
# 20230601_SPO_japonesainternacional_control_NB_conservaseenlatados_W22           63
# 20230601_SPO_japonesainternacional_control_NB_docesesobremesas_W22              67
# 20230601_SPO_japonesainternacional_control_NB_farinhasemisturas_W22             43
# 20230601_SPO_japonesainternacional_control_NB_feijao_W22                        48
# 20230601_SPO_japonesainternacional_control_NB_graos_W22                         68
# 20230601_SPO_japonesainternacional_control_NB_massasemolhos_W22                 54
# 20230601_SPO_japonesainternacional_control_NB_temperos_W22                      49
# 20230601_SPO_japonesainternacional_control_NB_carnevermelha_W22                 66
# 20230601_SPO_japonesainternacional_control_NB_embutidos_W22                     57
# 20230601_SPO_japonesainternacional_control_NB_frango_W22                        55
# 20230601_SPO_japonesainternacional_control_NB_peixesefrutosdomar_W22            68
# 20230601_SPO_japonesainternacional_control_NB_suinos_W22                        65
# dtype: int64
# Done SPO japonesainternacional_CONTROL

# %% [markdown]
# ## Aca creo el archivo para R&D

# %%
# customers =  pd.DataFrame()
# for column,i in enumerate(aux_df.columns):
#     #if ('verduras' in i or 'frutas' in i or 'arroz' in i or 'aceitesygrasas' in i or 'harinasymezclas' in i or 'azucaryendulzantes' in i or 'pollo' in i or 'huevos' in i) and not 'frutasjugo' in i:
#     #if ('verduras' in i or 'frutas' in i) and not 'frutasjugo' in i:
#     customers[i] = aux_df[i]

# %%
# customers.iloc[:6000].to_csv(f'SD/export_data/MS/csv_{city_code}_CLIENTS_PRUEBA_R&D.csv', index = False)

# with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
#        json.dump(global_segment_list, outfile)

# %%
# aux_seg = pd.read_csv(f"prueba_tuberculos_BAQ.csv")
# aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

# aux_seg["final_group2"] = ["piloto" if x == "Super Descuentos" else "control" for x in aux_seg.grupos]
# aux_seg['offer_name'] = f"20230301_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W9"

# aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()

# %%
# lst = []
# for x in aux_seg2.values:
#     h = {'name':x[0], 'customersIds': list(x[1])}
#     lst.append(h)
    
# for x in lst:
#     print(x['name'])
#     #break
#     for i,value in enumerate(global_segment_list):
#         if value['name'] == x['name']:
#             global_segment_list[i]['customersIds'] = x['customersIds']
#             print(i)

# %%
aux_seg = pd.read_csv(f"csv_{city_code}_CLIENTS_FINAL_JUNIO_R&D.csv")
aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

aux_seg["final_group2"] = ["piloto" if x == "Treatment" else "control" for x in aux_seg.final_group]
aux_seg['offer_name'] = f"20230601_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W22"

aux_seg["quartile"] = ["Q0" if x == "-" else x for x in aux_seg.quartile.values]
aux_seg["quartile_name"] = f"20230601_{city_code}_" + aux_seg.subcategory + "_" + aux_seg.quartile + "_" + aux_seg.case

aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()
aux_seg3 = aux_seg.groupby(by = ["quartile_name"])["customer_source_id"].apply(list).reset_index()

# %%
aux_seg.head()
# Out:
#         subcategory  customer_source_id         ms previous_group        case  \
# 0  aguaseisotonicos            20309798  sucosacai      Treatment  positivity
# 1  aguaseisotonicos            42445861      other      Treatment  positivity
# 2  aguaseisotonicos            61417253      other      Treatment  positivity
# 3  aguaseisotonicos            65956936    lanches        Control  positivity
# 4  aguaseisotonicos            76380245    lanches      Treatment  positivity
#
#   quartile  random final_group final_group2  \
# 0       Q4       0   Treatment       piloto
# 1       Q4       0   Treatment       piloto
# 2       Q4       0   Treatment       piloto
# 3       Q4       0   Treatment       piloto
# 4       Q4       0   Treatment       piloto
#
#                                           offer_name  \
# 0  20230601_SPO_sucosacai_piloto_NB_aguaseisotoni...
# 1  20230601_SPO_other_piloto_NB_aguaseisotonicos_W22
# 2  20230601_SPO_other_piloto_NB_aguaseisotonicos_W22
# 3  20230601_SPO_lanches_piloto_NB_aguaseisotonico...
# 4  20230601_SPO_lanches_piloto_NB_aguaseisotonico...
#
#                                  quartile_name
# 0  20230601_SPO_aguaseisotonicos_Q4_positivity
# 1  20230601_SPO_aguaseisotonicos_Q4_positivity
# 2  20230601_SPO_aguaseisotonicos_Q4_positivity
# 3  20230601_SPO_aguaseisotonicos_Q4_positivity
# 4  20230601_SPO_aguaseisotonicos_Q4_positivity

# %%
lst = []
for x in aux_seg2.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst.append(h)

global_segment_list = lst

# %%
lst2 = []
for x in aux_seg3.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst2.append(h)

# %% [markdown]
# # Aca tengo que volver a cargar el archivo de arriba y dejarlo como lista para traer lo otro

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230601_SPO_lanches_piloto_NB_aguaseisotonico...
# 1        20230601_SPO_lanches_piloto_NB_cervejas_W22
# 2  20230601_SPO_lanches_piloto_NB_refrigerantesee...
# 3      20230601_SPO_lanches_piloto_NB_sucosechas_W22
# 4      20230601_SPO_lanches_piloto_NB_destilados_W22
#
#                              offer_description  discount  \
# 0           lanches_piloto_NB_aguaseisotonicos         5
# 1                   lanches_piloto_NB_cervejas         7
# 2  lanches_piloto_NB_refrigeranteseenergeticos         5
# 3                 lanches_piloto_NB_sucosechas         8
# 4                 lanches_piloto_NB_destilados         6
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                   7
# 1                         true  01-06-2023  30-06-2023                   7
# 2                         true  01-06-2023  30-06-2023                   7
# 3                         true  01-06-2023  30-06-2023                   7
# 4                         true  01-06-2023  30-06-2023                   7
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1                None
# 1                      1                None
# 2                      1                None
# 3                      1                None
# 4                      1                None
#
#                                               sku_id
# 0                 246590#244568#244567#597183#597691
# 1  574156#364852#364853#244749#570654#244750#3637...
# 2  244764#246588#244765#363756#363755#363757#4830...
# 3  397324#397325#244790#244789#244785#248558#2447...
# 4          576210#572844#572845#572852#572853#600091

# %%
#len_seg =int(len(global_segment_list)/10)
#len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %% [markdown]
# ## Crear segments offers y segments types

# %%
import requests
import json

def create_segments(segment_list):
    
    url = f"https://{city_code}.frubana.com/api/v1/segments/create?api-key=00_growth-team-zzz-qqq_001"

    payload = json.dumps(segment_list)


    headers = {
    'Cookie': 'AWSALB=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALBCORS=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALB=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI; AWSALBCORS=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI',
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.status_code)
    sgt = [(int(x[:6]),x[7:]) for x in list(map(str.strip, response.text[32:].strip('][').replace('"', '').split(',')))]
    time.sleep(40)
    return sgt

# %%
len_seg =int(len(global_segment_list)/10)
len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %%
#offers
sgt=[]

for i in len_seg_list:
    sgt.append(create_segments(i))
    
sgt_end =[item for lista in sgt for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len_seg2 =int(len(lst2)/10)
len_seg_list2 = [lst2[:len_seg2],lst2[len_seg2:len_seg2*2],lst2[len_seg2*2:len_seg2*3],lst2[len_seg2*3:len_seg2*4],lst2[len_seg2*4:len_seg2*5],lst2[len_seg2*5:len_seg2*6],lst2[len_seg2*6:len_seg2*7],lst2[len_seg2*7:len_seg2*8],lst2[len_seg2*8:len_seg2*9],lst2[len_seg2*9:]]

# %%
#types
sgt2=[]

for i in len_seg_list2:
    sgt2.append(create_segments(i))
    
sgt_end2 =[item for lista in sgt2 for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#unir offers con segments
for i in global_offer_csv.offer_name:
    for j,z in sgt_end:
        if z==i:
            global_offer_csv.loc[global_offer_csv.offer_name == i, ('customer_segment_id')] = j

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230601_SPO_lanches_piloto_NB_aguaseisotonico...
# 1        20230601_SPO_lanches_piloto_NB_cervejas_W22
# 2  20230601_SPO_lanches_piloto_NB_refrigerantesee...
# 3      20230601_SPO_lanches_piloto_NB_sucosechas_W22
# 4      20230601_SPO_lanches_piloto_NB_destilados_W22
#
#                              offer_description  discount  \
# 0           lanches_piloto_NB_aguaseisotonicos         5
# 1                   lanches_piloto_NB_cervejas         7
# 2  lanches_piloto_NB_refrigeranteseenergeticos         5
# 3                 lanches_piloto_NB_sucosechas         8
# 4                 lanches_piloto_NB_destilados         6
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                   7
# 1                         true  01-06-2023  30-06-2023                   7
# 2                         true  01-06-2023  30-06-2023                   7
# 3                         true  01-06-2023  30-06-2023                   7
# 4                         true  01-06-2023  30-06-2023                   7
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              169562
# 1                      1              169570
# 2                      1              169597
# 3                      1              169599
# 4                      1              169576
#
#                                               sku_id
# 0                 246590#244568#244567#597183#597691
# 1  574156#364852#364853#244749#570654#244750#3637...
# 2  244764#246588#244765#363756#363755#363757#4830...
# 3  397324#397325#244790#244789#244785#248558#2447...
# 4          576210#572844#572845#572852#572853#600091

# %%
global_offer_csv = global_offer_csv.loc[~global_offer_csv.customer_segment_id.isnull()].reset_index(drop=True)
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('discount','max_uses_per_order')]=1
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('start_date','end_date')]='01-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('end_date')]='02-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('sku_id')]= global_offer_csv.loc[~global_offer_csv['offer_name'].str.contains("piloto", case=False), ('sku_id')].tolist()

# %%
len_offer =int(len(global_offer_csv)/4)
len_offer = [global_offer_csv[:len_seg],global_offer_csv[len_seg:len_seg*2],global_offer_csv[len_seg*2:len_seg*3],global_offer_csv[len_seg*3:]]

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230601_SPO_lanches_piloto_NB_aguaseisotonico...
# 1        20230601_SPO_lanches_piloto_NB_cervejas_W22
# 2  20230601_SPO_lanches_piloto_NB_refrigerantesee...
# 3      20230601_SPO_lanches_piloto_NB_sucosechas_W22
# 4      20230601_SPO_lanches_piloto_NB_destilados_W22
#
#                              offer_description  discount  \
# 0           lanches_piloto_NB_aguaseisotonicos         5
# 1                   lanches_piloto_NB_cervejas         7
# 2  lanches_piloto_NB_refrigeranteseenergeticos         5
# 3                 lanches_piloto_NB_sucosechas         8
# 4                 lanches_piloto_NB_destilados         6
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                   7
# 1                         true  01-06-2023  30-06-2023                   7
# 2                         true  01-06-2023  30-06-2023                   7
# 3                         true  01-06-2023  30-06-2023                   7
# 4                         true  01-06-2023  30-06-2023                   7
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              169562
# 1                      1              169570
# 2                      1              169597
# 3                      1              169599
# 4                      1              169576
#
#                                               sku_id
# 0                 246590#244568#244567#597183#597691
# 1  574156#364852#364853#244749#570654#244750#3637...
# 2  244764#246588#244765#363756#363755#363757#4830...
# 3  397324#397325#244790#244789#244785#248558#2447...
# 4          576210#572844#572845#572852#572853#600091

# %%
#//--------------------------------------------
#//Exporting single file data
global_offer_csv.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS.csv', index = False)

for i,offer in enumerate(len_offer):
    offer.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS_{i}.csv', index = False)

with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
        json.dump(global_segment_list, outfile)    
with open(f'SD/export_data/MS/nb_{city_code}_All_MS.json', 'w') as outfile:
        json.dump(global_segment_list, outfile)
print(f'Done {city_code}')
# Out:
# Done SPO
