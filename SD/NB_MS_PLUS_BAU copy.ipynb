# %%
#//----------------------------
#//LIBRARIES
    #Math
import math
    #Numeric Python
import numpy as np
    #Pandas (dataframes)
import pandas as pd
    #datetime for fate manipulation
from datetime import date, datetime, timedelta  
    #Regex for advanced string matching
import re
    #for time related stuff
import time
    #json library
import json
    #Analyst tools
import sys
sys.path.append('../')
from analysts_tools.growth import *
    #Procurement tools
from analysts_tools.redash_methods import *
    #Frubana libraries
from procurement_lib import redash, dw, send_message, send_slack_notification, GoogleSheet, logging

# %%
#//---------------------------------------------------------------------------------------------------------------------------
#// Parametros
"""Todays date should be the first day of the next month which is going to begin with SD"""

city_code = 'BOG'

# Set today's date to the first day of the next month
today = datetime.today()
first_day_next_month = (today.replace(day=1) + timedelta(days=32)).replace(day=1)

# Calculate non_buyers_date (todays date - 1 month)
non_buyers_date = (first_day_next_month - timedelta(days=1)).replace(day=1)
customer_date_desde = (first_day_next_month - timedelta(days=1)).replace(day=1)

# Calculate sku_date_desde (todays date - 2 months)
sku_date_desde = (first_day_next_month - timedelta(days=60)).replace(day=1)

# Convert the dates to strings in the desired format
todays_date = first_day_next_month.strftime('%Y-%m-%d')
non_buyers_date = non_buyers_date.strftime('%Y-%m-%d')
customer_date_desde = customer_date_desde.strftime('%Y-%m-%d')
sku_date_desde = sku_date_desde.strftime('%Y-%m-%d')

print(todays_date) # Output: e.g. 2023-04-01
print(non_buyers_date) # Output: e.g. 2023-03-01
print(sku_date_desde) # Output: e.g. 2023-02-01

tasas = {'BOG': 3776,
         'BAQ': 3776,
         'MDE': 3776,
         'CMX': 19.65,
         'GDL': 19.65,
         'PBC': 19.65,
         'SPO': 4.75,
         'BHZ': 4.75,
         'CWB': 4.75,
         'VCP': 4.75}

t_cambio = tasas[city_code]
# Out:
# 2023-07-01
# 2023-06-01
# 2023-05-01

# %%
query="""
With microsegment as (

SELECT DISTINCT c.customer_id AS user_id,
                c.site_type AS region_code_ms,
                
                (case 
                    -- Colombia
                    when m.microsegment_id not in (1,3,4,28,5,6,7,8,2) and c.site_type = 'BOG' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1,3,4,28,5,11,10,9,2,12) and c.site_type = 'BAQ' then 'Sin Microsegmento'
                    when m.microsegment_id not in (3,4,28,1,24,11,5,2,27) and c.site_type = 'MDE' then 'Sin Microsegmento'
    
                    -- Mexico
                    when m.microsegment_id not in (1,13,14,30,15,16,29,17,6,7,2) and c.site_type = 'CMX' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1, 13,14,30, 15,16,29, 6, 33, 2, 31) and c.site_type = 'GDL' then 'Sin Microsegmento'
                    when m.microsegment_id not in (13,14,30, 15,16,29, 32,2,6,33) and c.site_type = 'PBC' then 'Sin Microsegmento'
                    
                    -- Brasil
                    when m.microsegment_id not in (21,34,38,37,35,36,39,26) and c.site_type in ('SPO','BHZ','CWB','VCP') then 'Sin Microsegmento'
                        
                else m.description end) as microsegment_ok,
                
                m.microsegment_id,
                mo.name as ms_method
                
                
FROM postgres_main_federate."growth_microsegmentation.customer_microsegment" AS cm
INNER JOIN postgres_main_federate."growth_microsegmentation.microsegment" m ON cm.microsegment_id = m.id
INNER JOIN postgres_main_federate."growth_microsegmentation.customer" c ON cm.customer_id = c.id
INNER JOIN postgres_main_federate."growth_microsegmentation.models" mo ON mo.id = cm.model_type_id


)

select m.user_id,
m.region_code_ms,
--m.microsegment_id,

(case 
        when m.microsegment_ok in ('Corrientazo c/desayuno','Corrientazo s/desayuno','Tienda/Restaurante') then 'Corrientazo' 
        when m.microsegment_ok in ('Fonda c/desayuno','Fonda s/desayuno') then 'Fonda'
        when m.microsegment_ok in ('Taquería en calle','Taquería en local') then 'Taquería'

else m.microsegment_ok end) as microsegment,

m.ms_method

from microsegment m
where m.microsegment_ok != 'Sin Microsegmento'
"""

segmentos_fulll = read_connection_data_warehouse.runQuery(query)

segmentos_fulll.columns = ['customer_id', 'city', 'microsegment','NA']
segmentos_fulll = segmentos_fulll[['customer_id', 'city', 'microsegment']]

# %% [markdown]
# ### Loading COSTUMERS INFO

# %%
users_eliminar_kam = get_fresh_query_result("https://internal-redash.federate.frubana.com/",150812,'SeoGHWmDUaaBi7VXje1s9zYNiMD1VHQ1K1DYOxiF',{},20)
users_eliminar = users_eliminar_kam.loc[users_eliminar_kam.registered_city == city_code]['customer_id'].unique().tolist()
# Out:
# 200

# %% [markdown]
# ### Loading FORCED_SKUS // Cleaning SEGMENT_NAMES

# %% [markdown]
# ### Loading DATA_VENTAS // Removing SKUs /\ CUSTOMERS_ID

# %%
#//Remove skus 
#It is used because some SKUs can get in trouble with supplier for the SD or to exclude them for another activity   
skus_remove = GoogleSheet("1Z0T_c36oRHmOHIgEG8_ANcwFykaHgXGAizYAYCKCqtY")
skus_remove = skus_remove.get_as_dataframe('SKUS')

skus_remove = skus_remove['sku_id'].unique().astype(int).tolist()

# %%
query = """
SELECT DISTINCT
    split_part(bs.upc, '-', 1) as region,
    bs.sku_id

FROM postgres_broadleaf_federate."broadleaf.blc_sku"            bs 
LEFT JOIN postgres_broadleaf_federate."broadleaf.blc_product"   bp ON bp.product_id = bs.addl_product_id

WHERE bs.archived = 'N'
    AND bs.sndbx_id is NULL
    AND bp.archived = 'N'
    AND bs.catalog_disc < 0
    AND ((bp.archived = 'N' AND bp.sndbx_id is NULL) OR (bp.archived is NULL))
"""
frida_products = read_connection_data_warehouse.runQuery(query)

# %%
good_skus = frida_products.sku_id.unique()

# %%
#Loading SELL'S DATA from a function
data_ventas = data_ventas_query(ciudad=city_code, tipo_cambio=t_cambio, desde=customer_date_desde, hasta = todays_date, tipo_negocio=1)

# %%
data_ventas = data_ventas[(~data_ventas['sku_id'].isin(skus_remove)) & (data_ventas['sku_id'].isin(good_skus))]

# %%
segmentos_full = segmentos_fulll[segmentos_fulll.city == city_code].copy()

# %%
#//customers for offers */(has further uses)*/
microsegmentacion_df = segmentos_full[(~segmentos_full['customer_id'].isin(users_eliminar))]
data_ventas = data_ventas[(~data_ventas['customer_id'].isin(users_eliminar))]

# %% [markdown]
# ### Create the MS "Other" for BAU

# %%
data_full = data_ventas.merge(microsegmentacion_df[['customer_id','microsegment']], how = 'left', on = 'customer_id')

# %%
data_full['microsegment'] = data_full['microsegment'].fillna('Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#            microsegment  customer_id
# 0             Cafetería         1594
# 1  Comida especializada         1210
# 2         Comida rápida         1791
# 3           Corrientazo         3710
# 4      Empanadas/Arepas         1126
# 5                 Other          741
# 6  Panadería/Pastelería         2870
# 7      Parrilla/Asadero         1224

# %%
segments_validation = data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()

# %%
for ms in segments_validation[segments_validation.customer_id < 180]['microsegment'].unique():
    data_full['microsegment'] = data_full['microsegment'].str.replace(ms,'Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#            microsegment  customer_id
# 0             Cafetería         1594
# 1  Comida especializada         1210
# 2         Comida rápida         1791
# 3           Corrientazo         3710
# 4      Empanadas/Arepas         1126
# 5                 Other          741
# 6  Panadería/Pastelería         2870
# 7      Parrilla/Asadero         1224

# %%
#Get the same variable to do the process job
data_ventas = data_full

# %% [markdown]
# ### PARAMETERS // SOME FUNCTIONS - GET READY TO PROCESSING

# %%
def ms_data(city_code):
  
    paramss_csv=GoogleSheet("1k0ckgkLddxc5lY8NUVGCkvDLTuulLaJm-N535oMNZNw")
    city_paramss = paramss_csv.get_as_dataframe(city_code)
    
    parametros = {}
    parametros[city_code] = {}
    
    for i,ms in enumerate(city_paramss.iloc[:,4:].columns):
        parametros[city_code][ms] = [(value[1],value[2],value[3],value[4+i]) for value in city_paramss.values if value[4+i]>0]
        
    return parametros

# %%
parametros = ms_data(city_code)

# %%
def normalize_text(raw_text):
    """
    Removes common accent characters and normalize text.
    """
    raw_text = raw_text.replace(" ", "")
    raw_text = raw_text.replace("�", "")
    raw_text = raw_text.replace("/", "")
    raw_text = re.sub(r'\s*', '', raw_text)
    raw_text = re.sub(r"[àáâãäå]", 'a', raw_text)
    raw_text = re.sub(r"[èéêë]", 'e', raw_text)
    raw_text = re.sub(r"[ìíîï]", 'i', raw_text) 
    raw_text = re.sub(r"[òóôõö]", 'o', raw_text)
    raw_text = re.sub(r"[ùúûü]", 'u', raw_text)
    raw_text = re.sub(r"[ýÿ]", 'y', raw_text)
    raw_text = re.sub(r"[ß]", 'ss', raw_text)
    raw_text = re.sub(r"[ñ]", 'n', raw_text)
    raw_text = re.sub(r"[ç]", 'c', raw_text)
    raw_text = raw_text.lower()
    return raw_text

# %%
#Sacar de aca los microsegmentos
msg = data_full.microsegment.unique()
msg
# Out:
# array(['Panadería/Pastelería', 'Cafetería', 'Comida especializada',
#        'Corrientazo', 'Empanadas/Arepas', 'Parrilla/Asadero',
#        'Comida rápida', 'Other'], dtype=object)

# %% [markdown]
# ### END

# %% [markdown]
# # Aca Empieza la Experimentacion

# %%
from sklearn.model_selection import train_test_split

# %%
#//Variables to store all the segments and offers of the city
global_offer_csv = pd.DataFrame()
global_segment_list = [] #//for procesing

# %%
#//----------------------------------------------------------------------------
#//Big loop for creating each city segments/offers files
aux_df = pd.DataFrame()
aux_df['aux']=6000*[0]

for microsegment in msg:
    print('//-------------------------------------------------------------------------------')
    print(microsegment)

    #//Customers per microsegment
    customers_ms = data_ventas[(data_ventas['microsegment'] == microsegment)]['customer_id'].unique()
    #//Customers to give them the skus
    customers_for_skus_ms =  data_ventas[['microsegment','customer_id']][(data_ventas.microsegment == microsegment) & (~data_ventas.customer_id.isin(users_eliminar))]['customer_id'].unique()
    
    #----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_PILOTO" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    rand=1
    customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state=rand)
    
    while abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())) > 0.05:
        #print(data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean(),data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean(),abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())))
        rand+=1
        customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state = rand)
        
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_1)].copy() #le quite la s!!
    
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()
    
    subcats = list(map(lambda x: x[0], parametros[city_code][microsegment]))
    max_uses = list(map(lambda x: int(x[1]), parametros[city_code][microsegment]))
    max_order = list(map(lambda x: int(x[2]), parametros[city_code][microsegment]))
    discount = list(map(lambda x: int(x[3]), parametros[city_code][microsegment]))

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    a, b, c = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
            non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                        limite=0.75, data_ventas_skus = data_skus)

    print(b.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(a)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in b.columns:
        id_list = b[seg].dropna().astype(int)
        d = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)

        lst.append(d)
        
    #//appending to global list    
        global_segment_list.append(d)
    
    print(f'Done {city_code} {ms_name}')

#----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------


#----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_CONTROL" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_2)].copy() #le quite la s!!
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    print('//-------------------------------------------------------------------------------')
    print(f'{microsegment} Experimento50%')
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    e, f, g = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
                non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                          limite=0.75, data_ventas_skus = data_skus)
      
    print(f.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(e)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in f.columns:
        id_list = f[seg].dropna().astype(int)
        h = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)
        
        lst.append(h)
        
        
    #//appending to global list    
        global_segment_list.append(h)
    
    print(f'Done {city_code} {ms_name}')
    #----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#//End of big loop and start of data bundle
# Out:
# //-------------------------------------------------------------------------------
# Panadería/Pastelería
# 2296
# Uso de data externa
# 20230701_BOG_panaderiapasteleria_piloto_NB_aceitesygrasas_W26                 1557
# 20230701_BOG_panaderiapasteleria_piloto_NB_arroz_W26                          1478
# 20230701_BOG_panaderiapasteleria_piloto_NB_azucaryendulzantes_W26              629
# 20230701_BOG_panaderiapasteleria_piloto_NB_cafechocolateeinfusiones_W26       2121
# 20230701_BOG_panaderiapasteleria_piloto_NB_enlatadosyconservas_W26            2272
# 20230701_BOG_panaderiapasteleria_piloto_NB_granos_W26                         2089
# 20230701_BOG_panaderiapasteleria_piloto_NB_pasta_W26                          2198
# 20230701_BOG_panaderiapasteleria_piloto_NB_salysazonadores_W26                2179
# 20230701_BOG_panaderiapasteleria_piloto_NB_salsas_W26                         2214
# 20230701_BOG_panaderiapasteleria_piloto_NB_desinfectantesysanitizantes_W26    1999
# 20230701_BOG_panaderiapasteleria_piloto_NB_detergentejabonylavalozas_W26      1566
# 20230701_BOG_panaderiapasteleria_piloto_NB_implementosdeaseo_W26              2184
# 20230701_BOG_panaderiapasteleria_piloto_NB_papelytoallas_W26                  1438
# 20230701_BOG_panaderiapasteleria_piloto_NB_aguas_W26                          2173
# 20230701_BOG_panaderiapasteleria_piloto_NB_cervezasylicores_W26               2191
# 20230701_BOG_panaderiapasteleria_piloto_NB_gaseosas_W26                       1913
# 20230701_BOG_panaderiapasteleria_piloto_NB_jugos_W26                          2076
# 20230701_BOG_panaderiapasteleria_piloto_NB_cerdo_W26                          2109
# 20230701_BOG_panaderiapasteleria_piloto_NB_pescadosymariscoscongelado_W26     2205
# 20230701_BOG_panaderiapasteleria_piloto_NB_pollo_W26                          1975
# 20230701_BOG_panaderiapasteleria_piloto_NB_res_W26                            2097
# 20230701_BOG_panaderiapasteleria_piloto_NB_alimentoscongelados_W26            2192
# 20230701_BOG_panaderiapasteleria_piloto_NB_pulpasdefruta_W26                  2150
# 20230701_BOG_panaderiapasteleria_piloto_NB_bolsas_W26                         1985
# 20230701_BOG_panaderiapasteleria_piloto_NB_contenedores_W26                   1811
# 20230701_BOG_panaderiapasteleria_piloto_NB_cubiertosypitillos_W26             1556
# 20230701_BOG_panaderiapasteleria_piloto_NB_platosybandejas_W26                2221
# 20230701_BOG_panaderiapasteleria_piloto_NB_vasos_W26                          1716
# 20230701_BOG_panaderiapasteleria_piloto_NB_frutas_W26                         1642
# 20230701_BOG_panaderiapasteleria_piloto_NB_frutasjugo_W26                     2142
# 20230701_BOG_panaderiapasteleria_piloto_NB_tuberculos_W26                     2018
# 20230701_BOG_panaderiapasteleria_piloto_NB_verduras_W26                       1060
# 20230701_BOG_panaderiapasteleria_piloto_NB_cremas_W26                         2193
# 20230701_BOG_panaderiapasteleria_piloto_NB_derivadoslacteos_W26               2254
# 20230701_BOG_panaderiapasteleria_piloto_NB_leches_W26                         2195
# 20230701_BOG_panaderiapasteleria_piloto_NB_quesos_W26                         2250
# dtype: int64
# Done BOG panaderiapasteleria_PILOTO
# //-------------------------------------------------------------------------------
# Panadería/Pastelería Experimento50%
# 574
# Uso de data externa
# 20230701_BOG_panaderiapasteleria_control_NB_aceitesygrasas_W26                 389
# 20230701_BOG_panaderiapasteleria_control_NB_arroz_W26                          389
# 20230701_BOG_panaderiapasteleria_control_NB_azucaryendulzantes_W26             145
# 20230701_BOG_panaderiapasteleria_control_NB_cafechocolateeinfusiones_W26       534
# 20230701_BOG_panaderiapasteleria_control_NB_enlatadosyconservas_W26            566
# 20230701_BOG_panaderiapasteleria_control_NB_granos_W26                         521
# 20230701_BOG_panaderiapasteleria_control_NB_pasta_W26                          546
# 20230701_BOG_panaderiapasteleria_control_NB_salysazonadores_W26                543
# 20230701_BOG_panaderiapasteleria_control_NB_salsas_W26                         558
# 20230701_BOG_panaderiapasteleria_control_NB_desinfectantesysanitizantes_W26    489
# 20230701_BOG_panaderiapasteleria_control_NB_detergentejabonylavalozas_W26      380
# 20230701_BOG_panaderiapasteleria_control_NB_implementosdeaseo_W26              554
# 20230701_BOG_panaderiapasteleria_control_NB_papelytoallas_W26                  361
# 20230701_BOG_panaderiapasteleria_control_NB_aguas_W26                          546
# 20230701_BOG_panaderiapasteleria_control_NB_cervezasylicores_W26               559
# 20230701_BOG_panaderiapasteleria_control_NB_gaseosas_W26                       494
# 20230701_BOG_panaderiapasteleria_control_NB_jugos_W26                          525
# 20230701_BOG_panaderiapasteleria_control_NB_cerdo_W26                          533
# 20230701_BOG_panaderiapasteleria_control_NB_pescadosymariscoscongelado_W26     553
# 20230701_BOG_panaderiapasteleria_control_NB_pollo_W26                          499
# 20230701_BOG_panaderiapasteleria_control_NB_res_W26                            524
# 20230701_BOG_panaderiapasteleria_control_NB_alimentoscongelados_W26            547
# 20230701_BOG_panaderiapasteleria_control_NB_pulpasdefruta_W26                  530
# 20230701_BOG_panaderiapasteleria_control_NB_bolsas_W26                         515
# 20230701_BOG_panaderiapasteleria_control_NB_contenedores_W26                   458
# 20230701_BOG_panaderiapasteleria_control_NB_cubiertosypitillos_W26             402
# 20230701_BOG_panaderiapasteleria_control_NB_platosybandejas_W26                565
# 20230701_BOG_panaderiapasteleria_control_NB_vasos_W26                          456
# 20230701_BOG_panaderiapasteleria_control_NB_frutas_W26                         421
# 20230701_BOG_panaderiapasteleria_control_NB_frutasjugo_W26                     531
# 20230701_BOG_panaderiapasteleria_control_NB_tuberculos_W26                     517
# 20230701_BOG_panaderiapasteleria_control_NB_verduras_W26                       263
# 20230701_BOG_panaderiapasteleria_control_NB_cremas_W26                         550
# 20230701_BOG_panaderiapasteleria_control_NB_derivadoslacteos_W26               564
# 20230701_BOG_panaderiapasteleria_control_NB_leches_W26                         555
# 20230701_BOG_panaderiapasteleria_control_NB_quesos_W26                         567
# dtype: int64
# Done BOG panaderiapasteleria_CONTROL
# //-------------------------------------------------------------------------------
# Cafetería
# 1276
# Uso de data externa
# 20230701_BOG_cafeteria_piloto_NB_aceitesygrasas_W26                  760
# 20230701_BOG_cafeteria_piloto_NB_arroz_W26                           755
# 20230701_BOG_cafeteria_piloto_NB_azucaryendulzantes_W26              596
# 20230701_BOG_cafeteria_piloto_NB_cafechocolateeinfusiones_W26       1137
# 20230701_BOG_cafeteria_piloto_NB_enlatadosyconservas_W26            1251
# 20230701_BOG_cafeteria_piloto_NB_granos_W26                         1086
# 20230701_BOG_cafeteria_piloto_NB_pasta_W26                          1191
# 20230701_BOG_cafeteria_piloto_NB_salysazonadores_W26                1187
# 20230701_BOG_cafeteria_piloto_NB_salsas_W26                         1206
# 20230701_BOG_cafeteria_piloto_NB_desinfectantesysanitizantes_W26    1097
# 20230701_BOG_cafeteria_piloto_NB_detergentejabonylavalozas_W26       799
# 20230701_BOG_cafeteria_piloto_NB_implementosdeaseo_W26              1180
# 20230701_BOG_cafeteria_piloto_NB_papelytoallas_W26                   758
# 20230701_BOG_cafeteria_piloto_NB_aguas_W26                          1176
# 20230701_BOG_cafeteria_piloto_NB_cervezasylicores_W26               1217
# 20230701_BOG_cafeteria_piloto_NB_gaseosas_W26                       1004
# 20230701_BOG_cafeteria_piloto_NB_jugos_W26                          1149
# 20230701_BOG_cafeteria_piloto_NB_cerdo_W26                          1145
# 20230701_BOG_cafeteria_piloto_NB_pescadosymariscoscongelado_W26     1226
# 20230701_BOG_cafeteria_piloto_NB_pollo_W26                          1077
# 20230701_BOG_cafeteria_piloto_NB_res_W26                            1122
# 20230701_BOG_cafeteria_piloto_NB_alimentoscongelados_W26            1201
# 20230701_BOG_cafeteria_piloto_NB_pulpasdefruta_W26                  1150
# 20230701_BOG_cafeteria_piloto_NB_bolsas_W26                         1111
# 20230701_BOG_cafeteria_piloto_NB_contenedores_W26                    973
# 20230701_BOG_cafeteria_piloto_NB_cubiertosypitillos_W26              861
# 20230701_BOG_cafeteria_piloto_NB_platosybandejas_W26                1240
# 20230701_BOG_cafeteria_piloto_NB_vasos_W26                           888
# 20230701_BOG_cafeteria_piloto_NB_frutas_W26                          852
# 20230701_BOG_cafeteria_piloto_NB_frutasjugo_W26                     1152
# 20230701_BOG_cafeteria_piloto_NB_tuberculos_W26                     1045
# 20230701_BOG_cafeteria_piloto_NB_verduras_W26                        512
# 20230701_BOG_cafeteria_piloto_NB_cremas_W26                         1229
# 20230701_BOG_cafeteria_piloto_NB_derivadoslacteos_W26               1251
# 20230701_BOG_cafeteria_piloto_NB_leches_W26                         1198
# 20230701_BOG_cafeteria_piloto_NB_quesos_W26                         1230
# dtype: int64
# Done BOG cafeteria_PILOTO
# //-------------------------------------------------------------------------------
# Cafetería Experimento50%
# 318
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)
# Uso de data externa
# 20230701_BOG_cafeteria_control_NB_aceitesygrasas_W26                 209
# 20230701_BOG_cafeteria_control_NB_arroz_W26                          200
# 20230701_BOG_cafeteria_control_NB_azucaryendulzantes_W26             148
# 20230701_BOG_cafeteria_control_NB_cafechocolateeinfusiones_W26       288
# 20230701_BOG_cafeteria_control_NB_enlatadosyconservas_W26            316
# 20230701_BOG_cafeteria_control_NB_granos_W26                         274
# 20230701_BOG_cafeteria_control_NB_pasta_W26                          300
# 20230701_BOG_cafeteria_control_NB_salysazonadores_W26                300
# 20230701_BOG_cafeteria_control_NB_salsas_W26                         299
# 20230701_BOG_cafeteria_control_NB_desinfectantesysanitizantes_W26    277
# 20230701_BOG_cafeteria_control_NB_detergentejabonylavalozas_W26      200
# 20230701_BOG_cafeteria_control_NB_implementosdeaseo_W26              302
# 20230701_BOG_cafeteria_control_NB_papelytoallas_W26                  179
# 20230701_BOG_cafeteria_control_NB_aguas_W26                          292
# 20230701_BOG_cafeteria_control_NB_cervezasylicores_W26               310
# 20230701_BOG_cafeteria_control_NB_gaseosas_W26                       253
# 20230701_BOG_cafeteria_control_NB_jugos_W26                          278
# 20230701_BOG_cafeteria_control_NB_cerdo_W26                          283
# 20230701_BOG_cafeteria_control_NB_pescadosymariscoscongelado_W26     309
# 20230701_BOG_cafeteria_control_NB_pollo_W26                          266
# 20230701_BOG_cafeteria_control_NB_res_W26                            280
# 20230701_BOG_cafeteria_control_NB_alimentoscongelados_W26            301
# 20230701_BOG_cafeteria_control_NB_pulpasdefruta_W26                  294
# 20230701_BOG_cafeteria_control_NB_bolsas_W26                         282
# 20230701_BOG_cafeteria_control_NB_contenedores_W26                   243
# 20230701_BOG_cafeteria_control_NB_cubiertosypitillos_W26             208
# 20230701_BOG_cafeteria_control_NB_platosybandejas_W26                311
# 20230701_BOG_cafeteria_control_NB_vasos_W26                          219
# 20230701_BOG_cafeteria_control_NB_frutas_W26                         217
# 20230701_BOG_cafeteria_control_NB_frutasjugo_W26                     294
# 20230701_BOG_cafeteria_control_NB_tuberculos_W26                     275
# 20230701_BOG_cafeteria_control_NB_verduras_W26                       132
# 20230701_BOG_cafeteria_control_NB_cremas_W26                         308
# 20230701_BOG_cafeteria_control_NB_derivadoslacteos_W26               310
# 20230701_BOG_cafeteria_control_NB_leches_W26                         297
# 20230701_BOG_cafeteria_control_NB_quesos_W26                         306
# dtype: int64
# Done BOG cafeteria_CONTROL
# //-------------------------------------------------------------------------------
# Comida especializada
# 968
# Uso de data externa
# 20230701_BOG_comidaespecializada_piloto_NB_aceitesygrasas_W26                 537
# 20230701_BOG_comidaespecializada_piloto_NB_arroz_W26                          595
# 20230701_BOG_comidaespecializada_piloto_NB_azucaryendulzantes_W26             605
# 20230701_BOG_comidaespecializada_piloto_NB_cafechocolateeinfusiones_W26       906
# 20230701_BOG_comidaespecializada_piloto_NB_enlatadosyconservas_W26            952
# 20230701_BOG_comidaespecializada_piloto_NB_granos_W26                         814
# 20230701_BOG_comidaespecializada_piloto_NB_pasta_W26                          874
# 20230701_BOG_comidaespecializada_piloto_NB_salysazonadores_W26                857
# 20230701_BOG_comidaespecializada_piloto_NB_salsas_W26                         813
# 20230701_BOG_comidaespecializada_piloto_NB_desinfectantesysanitizantes_W26    792
# 20230701_BOG_comidaespecializada_piloto_NB_detergentejabonylavalozas_W26      604
# 20230701_BOG_comidaespecializada_piloto_NB_implementosdeaseo_W26              880
# 20230701_BOG_comidaespecializada_piloto_NB_papelytoallas_W26                  566
# 20230701_BOG_comidaespecializada_piloto_NB_aguas_W26                          902
# 20230701_BOG_comidaespecializada_piloto_NB_cervezasylicores_W26               909
# 20230701_BOG_comidaespecializada_piloto_NB_gaseosas_W26                       776
# 20230701_BOG_comidaespecializada_piloto_NB_jugos_W26                          902
# 20230701_BOG_comidaespecializada_piloto_NB_cerdo_W26                          854
# 20230701_BOG_comidaespecializada_piloto_NB_embutidos_W26                      910
# 20230701_BOG_comidaespecializada_piloto_NB_pescadosymariscoscongelado_W26     931
# 20230701_BOG_comidaespecializada_piloto_NB_pollo_W26                          832
# 20230701_BOG_comidaespecializada_piloto_NB_res_W26                            848
# 20230701_BOG_comidaespecializada_piloto_NB_alimentoscongelados_W26            856
# 20230701_BOG_comidaespecializada_piloto_NB_pulpasdefruta_W26                  870
# 20230701_BOG_comidaespecializada_piloto_NB_bolsas_W26                         850
# 20230701_BOG_comidaespecializada_piloto_NB_contenedores_W26                   601
# 20230701_BOG_comidaespecializada_piloto_NB_cubiertosypitillos_W26             711
# 20230701_BOG_comidaespecializada_piloto_NB_platosybandejas_W26                945
# 20230701_BOG_comidaespecializada_piloto_NB_vasos_W26                          741
# 20230701_BOG_comidaespecializada_piloto_NB_frutas_W26                         552
# 20230701_BOG_comidaespecializada_piloto_NB_frutasjugo_W26                     869
# 20230701_BOG_comidaespecializada_piloto_NB_tuberculos_W26                     755
# 20230701_BOG_comidaespecializada_piloto_NB_verduras_W26                       355
# 20230701_BOG_comidaespecializada_piloto_NB_cremas_W26                         910
# 20230701_BOG_comidaespecializada_piloto_NB_derivadoslacteos_W26               936
# 20230701_BOG_comidaespecializada_piloto_NB_leches_W26                         895
# 20230701_BOG_comidaespecializada_piloto_NB_quesos_W26                         934
# dtype: int64
# Done BOG comidaespecializada_PILOTO
# //-------------------------------------------------------------------------------
# Comida especializada Experimento50%
# 242
# Uso de data externa
# 20230701_BOG_comidaespecializada_control_NB_aceitesygrasas_W26                 134
# 20230701_BOG_comidaespecializada_control_NB_arroz_W26                          148
# 20230701_BOG_comidaespecializada_control_NB_azucaryendulzantes_W26             147
# 20230701_BOG_comidaespecializada_control_NB_cafechocolateeinfusiones_W26       216
# 20230701_BOG_comidaespecializada_control_NB_enlatadosyconservas_W26            238
# 20230701_BOG_comidaespecializada_control_NB_granos_W26                         213
# 20230701_BOG_comidaespecializada_control_NB_pasta_W26                          222
# 20230701_BOG_comidaespecializada_control_NB_salysazonadores_W26                210
# 20230701_BOG_comidaespecializada_control_NB_salsas_W26                         201
# 20230701_BOG_comidaespecializada_control_NB_desinfectantesysanitizantes_W26    199
# 20230701_BOG_comidaespecializada_control_NB_detergentejabonylavalozas_W26      160
# 20230701_BOG_comidaespecializada_control_NB_implementosdeaseo_W26              220
# 20230701_BOG_comidaespecializada_control_NB_papelytoallas_W26                  149
# 20230701_BOG_comidaespecializada_control_NB_aguas_W26                          226
# 20230701_BOG_comidaespecializada_control_NB_cervezasylicores_W26               230
# 20230701_BOG_comidaespecializada_control_NB_gaseosas_W26                       198
# 20230701_BOG_comidaespecializada_control_NB_jugos_W26                          224
# 20230701_BOG_comidaespecializada_control_NB_cerdo_W26                          213
# 20230701_BOG_comidaespecializada_control_NB_embutidos_W26                      222
# 20230701_BOG_comidaespecializada_control_NB_pescadosymariscoscongelado_W26     231
# 20230701_BOG_comidaespecializada_control_NB_pollo_W26                          207
# 20230701_BOG_comidaespecializada_control_NB_res_W26                            213
# 20230701_BOG_comidaespecializada_control_NB_alimentoscongelados_W26            212
# 20230701_BOG_comidaespecializada_control_NB_pulpasdefruta_W26                  221
# 20230701_BOG_comidaespecializada_control_NB_bolsas_W26                         209
# 20230701_BOG_comidaespecializada_control_NB_contenedores_W26                   163
# 20230701_BOG_comidaespecializada_control_NB_cubiertosypitillos_W26             172
# 20230701_BOG_comidaespecializada_control_NB_platosybandejas_W26                237
# 20230701_BOG_comidaespecializada_control_NB_vasos_W26                          195
# 20230701_BOG_comidaespecializada_control_NB_frutas_W26                         141
# 20230701_BOG_comidaespecializada_control_NB_frutasjugo_W26                     220
# 20230701_BOG_comidaespecializada_control_NB_tuberculos_W26                     183
# 20230701_BOG_comidaespecializada_control_NB_verduras_W26                        97
# 20230701_BOG_comidaespecializada_control_NB_cremas_W26                         235
# 20230701_BOG_comidaespecializada_control_NB_derivadoslacteos_W26               240
# 20230701_BOG_comidaespecializada_control_NB_leches_W26                         233
# 20230701_BOG_comidaespecializada_control_NB_quesos_W26                         233
# dtype: int64
# Done BOG comidaespecializada_CONTROL
# //-------------------------------------------------------------------------------
# Corrientazo
# 2968
# Uso de data externa
# 20230701_BOG_corrientazo_piloto_NB_aceitesygrasas_W26                 1504
# 20230701_BOG_corrientazo_piloto_NB_arroz_W26                          1365
# 20230701_BOG_corrientazo_piloto_NB_azucaryendulzantes_W26             2024
# 20230701_BOG_corrientazo_piloto_NB_cafechocolateeinfusiones_W26       2696
# 20230701_BOG_corrientazo_piloto_NB_enlatadosyconservas_W26            2927
# 20230701_BOG_corrientazo_piloto_NB_granos_W26                         2133
# 20230701_BOG_corrientazo_piloto_NB_pasta_W26                          2517
# 20230701_BOG_corrientazo_piloto_NB_salysazonadores_W26                2546
# 20230701_BOG_corrientazo_piloto_NB_salsas_W26                         2593
# 20230701_BOG_corrientazo_piloto_NB_desinfectantesysanitizantes_W26    2426
# 20230701_BOG_corrientazo_piloto_NB_detergentejabonylavalozas_W26      1715
# 20230701_BOG_corrientazo_piloto_NB_implementosdeaseo_W26              2735
# 20230701_BOG_corrientazo_piloto_NB_papelytoallas_W26                  1698
# 20230701_BOG_corrientazo_piloto_NB_aguas_W26                          2831
# 20230701_BOG_corrientazo_piloto_NB_cervezasylicores_W26               2882
# 20230701_BOG_corrientazo_piloto_NB_gaseosas_W26                       2555
# 20230701_BOG_corrientazo_piloto_NB_jugos_W26                          2794
# 20230701_BOG_corrientazo_piloto_NB_cerdo_W26                          2374
# 20230701_BOG_corrientazo_piloto_NB_embutidos_W26                      2792
# 20230701_BOG_corrientazo_piloto_NB_pescadosymariscoscongelado_W26     2784
# 20230701_BOG_corrientazo_piloto_NB_pollo_W26                          2447
# 20230701_BOG_corrientazo_piloto_NB_res_W26                            2480
# 20230701_BOG_corrientazo_piloto_NB_alimentoscongelados_W26            2578
# 20230701_BOG_corrientazo_piloto_NB_pulpasdefruta_W26                  2715
# 20230701_BOG_corrientazo_piloto_NB_bolsas_W26                         2523
# 20230701_BOG_corrientazo_piloto_NB_contenedores_W26                   1402
# 20230701_BOG_corrientazo_piloto_NB_cubiertosypitillos_W26             2093
# 20230701_BOG_corrientazo_piloto_NB_platosybandejas_W26                2901
# 20230701_BOG_corrientazo_piloto_NB_vasos_W26                          1978
# 20230701_BOG_corrientazo_piloto_NB_frutas_W26                         1706
# 20230701_BOG_corrientazo_piloto_NB_frutasjugo_W26                     2549
# 20230701_BOG_corrientazo_piloto_NB_tuberculos_W26                     2096
# 20230701_BOG_corrientazo_piloto_NB_verduras_W26                        939
# 20230701_BOG_corrientazo_piloto_NB_cremas_W26                         2857
# 20230701_BOG_corrientazo_piloto_NB_derivadoslacteos_W26               2880
# 20230701_BOG_corrientazo_piloto_NB_leches_W26                         2817
# 20230701_BOG_corrientazo_piloto_NB_quesos_W26                         2871
# dtype: int64
# Done BOG corrientazo_PILOTO
# //-------------------------------------------------------------------------------
# Corrientazo Experimento50%
# 742
# Uso de data externa
# 20230701_BOG_corrientazo_control_NB_aceitesygrasas_W26                 356
# 20230701_BOG_corrientazo_control_NB_arroz_W26                          341
# 20230701_BOG_corrientazo_control_NB_azucaryendulzantes_W26             533
# 20230701_BOG_corrientazo_control_NB_cafechocolateeinfusiones_W26       675
# 20230701_BOG_corrientazo_control_NB_enlatadosyconservas_W26            730
# 20230701_BOG_corrientazo_control_NB_granos_W26                         547
# 20230701_BOG_corrientazo_control_NB_pasta_W26                          639
# 20230701_BOG_corrientazo_control_NB_salysazonadores_W26                652
# 20230701_BOG_corrientazo_control_NB_salsas_W26                         645
# 20230701_BOG_corrientazo_control_NB_desinfectantesysanitizantes_W26    611
# 20230701_BOG_corrientazo_control_NB_detergentejabonylavalozas_W26      445
# 20230701_BOG_corrientazo_control_NB_implementosdeaseo_W26              687
# 20230701_BOG_corrientazo_control_NB_papelytoallas_W26                  405
# 20230701_BOG_corrientazo_control_NB_aguas_W26                          717
# 20230701_BOG_corrientazo_control_NB_cervezasylicores_W26               711
# 20230701_BOG_corrientazo_control_NB_gaseosas_W26                       647
# 20230701_BOG_corrientazo_control_NB_jugos_W26                          706
# 20230701_BOG_corrientazo_control_NB_cerdo_W26                          583
# 20230701_BOG_corrientazo_control_NB_embutidos_W26                      701
# 20230701_BOG_corrientazo_control_NB_pescadosymariscoscongelado_W26     709
# 20230701_BOG_corrientazo_control_NB_pollo_W26                          609
# 20230701_BOG_corrientazo_control_NB_res_W26                            623
# 20230701_BOG_corrientazo_control_NB_alimentoscongelados_W26            648
# 20230701_BOG_corrientazo_control_NB_pulpasdefruta_W26                  678
# 20230701_BOG_corrientazo_control_NB_bolsas_W26                         637
# 20230701_BOG_corrientazo_control_NB_contenedores_W26                   349
# 20230701_BOG_corrientazo_control_NB_cubiertosypitillos_W26             510
# 20230701_BOG_corrientazo_control_NB_platosybandejas_W26                722
# 20230701_BOG_corrientazo_control_NB_vasos_W26                          513
# 20230701_BOG_corrientazo_control_NB_frutas_W26                         433
# 20230701_BOG_corrientazo_control_NB_frutasjugo_W26                     623
# 20230701_BOG_corrientazo_control_NB_tuberculos_W26                     528
# 20230701_BOG_corrientazo_control_NB_verduras_W26                       247
# 20230701_BOG_corrientazo_control_NB_cremas_W26                         720
# 20230701_BOG_corrientazo_control_NB_derivadoslacteos_W26               712
# 20230701_BOG_corrientazo_control_NB_leches_W26                         694
# 20230701_BOG_corrientazo_control_NB_quesos_W26                         719
# dtype: int64
# Done BOG corrientazo_CONTROL
# //-------------------------------------------------------------------------------
# Empanadas/Arepas
# 901
# Uso de data externa
# 20230701_BOG_empanadasarepas_piloto_NB_aceitesygrasas_W26                 416
# 20230701_BOG_empanadasarepas_piloto_NB_arroz_W26                          484
# 20230701_BOG_empanadasarepas_piloto_NB_azucaryendulzantes_W26             622
# 20230701_BOG_empanadasarepas_piloto_NB_cafechocolateeinfusiones_W26       788
# 20230701_BOG_empanadasarepas_piloto_NB_enlatadosyconservas_W26            889
# 20230701_BOG_empanadasarepas_piloto_NB_granos_W26                         795
# 20230701_BOG_empanadasarepas_piloto_NB_pasta_W26                          851
# 20230701_BOG_empanadasarepas_piloto_NB_salysazonadores_W26                786
# 20230701_BOG_empanadasarepas_piloto_NB_salsas_W26                         829
# 20230701_BOG_empanadasarepas_piloto_NB_desinfectantesysanitizantes_W26    758
# 20230701_BOG_empanadasarepas_piloto_NB_detergentejabonylavalozas_W26      595
# 20230701_BOG_empanadasarepas_piloto_NB_implementosdeaseo_W26              850
# 20230701_BOG_empanadasarepas_piloto_NB_papelytoallas_W26                  495
# 20230701_BOG_empanadasarepas_piloto_NB_aguas_W26                          833
# 20230701_BOG_empanadasarepas_piloto_NB_cervezasylicores_W26               862
# 20230701_BOG_empanadasarepas_piloto_NB_gaseosas_W26                       686
# 20230701_BOG_empanadasarepas_piloto_NB_jugos_W26                          827
# 20230701_BOG_empanadasarepas_piloto_NB_cerdo_W26                          799
# 20230701_BOG_empanadasarepas_piloto_NB_embutidos_W26                      850
# 20230701_BOG_empanadasarepas_piloto_NB_pescadosymariscoscongelado_W26     871
# 20230701_BOG_empanadasarepas_piloto_NB_pollo_W26                          714
# 20230701_BOG_empanadasarepas_piloto_NB_res_W26                            781
# 20230701_BOG_empanadasarepas_piloto_NB_alimentoscongelados_W26            840
# 20230701_BOG_empanadasarepas_piloto_NB_pulpasdefruta_W26                  853
# 20230701_BOG_empanadasarepas_piloto_NB_bolsas_W26                         768
# 20230701_BOG_empanadasarepas_piloto_NB_contenedores_W26                   800
# 20230701_BOG_empanadasarepas_piloto_NB_cubiertosypitillos_W26             665
# 20230701_BOG_empanadasarepas_piloto_NB_platosybandejas_W26                876
# 20230701_BOG_empanadasarepas_piloto_NB_vasos_W26                          641
# 20230701_BOG_empanadasarepas_piloto_NB_frutas_W26                         619
# 20230701_BOG_empanadasarepas_piloto_NB_frutasjugo_W26                     848
# 20230701_BOG_empanadasarepas_piloto_NB_tuberculos_W26                     736
# 20230701_BOG_empanadasarepas_piloto_NB_verduras_W26                       329
# 20230701_BOG_empanadasarepas_piloto_NB_derivadoslacteos_W26               880
# 20230701_BOG_empanadasarepas_piloto_NB_leches_W26                         831
# 20230701_BOG_empanadasarepas_piloto_NB_quesos_W26                         872
# dtype: int64
# Done BOG empanadasarepas_PILOTO
# //-------------------------------------------------------------------------------
# Empanadas/Arepas Experimento50%
# 225
# Uso de data externa
# 20230701_BOG_empanadasarepas_control_NB_aceitesygrasas_W26                 103
# 20230701_BOG_empanadasarepas_control_NB_arroz_W26                          136
# 20230701_BOG_empanadasarepas_control_NB_azucaryendulzantes_W26             158
# 20230701_BOG_empanadasarepas_control_NB_cafechocolateeinfusiones_W26       202
# 20230701_BOG_empanadasarepas_control_NB_enlatadosyconservas_W26            222
# 20230701_BOG_empanadasarepas_control_NB_granos_W26                         197
# 20230701_BOG_empanadasarepas_control_NB_pasta_W26                          215
# 20230701_BOG_empanadasarepas_control_NB_salysazonadores_W26                200
# 20230701_BOG_empanadasarepas_control_NB_salsas_W26                         211
# 20230701_BOG_empanadasarepas_control_NB_desinfectantesysanitizantes_W26    188
# 20230701_BOG_empanadasarepas_control_NB_detergentejabonylavalozas_W26      147
# 20230701_BOG_empanadasarepas_control_NB_implementosdeaseo_W26              212
# 20230701_BOG_empanadasarepas_control_NB_papelytoallas_W26                  128
# 20230701_BOG_empanadasarepas_control_NB_aguas_W26                          216
# 20230701_BOG_empanadasarepas_control_NB_cervezasylicores_W26               215
# 20230701_BOG_empanadasarepas_control_NB_gaseosas_W26                       179
# 20230701_BOG_empanadasarepas_control_NB_jugos_W26                          207
# 20230701_BOG_empanadasarepas_control_NB_cerdo_W26                          195
# 20230701_BOG_empanadasarepas_control_NB_embutidos_W26                      214
# 20230701_BOG_empanadasarepas_control_NB_pescadosymariscoscongelado_W26     215
# 20230701_BOG_empanadasarepas_control_NB_pollo_W26                          179
# 20230701_BOG_empanadasarepas_control_NB_res_W26                            194
# 20230701_BOG_empanadasarepas_control_NB_alimentoscongelados_W26            209
# 20230701_BOG_empanadasarepas_control_NB_pulpasdefruta_W26                  214
# 20230701_BOG_empanadasarepas_control_NB_bolsas_W26                         202
# 20230701_BOG_empanadasarepas_control_NB_contenedores_W26                   199
# 20230701_BOG_empanadasarepas_control_NB_cubiertosypitillos_W26             164
# 20230701_BOG_empanadasarepas_control_NB_platosybandejas_W26                217
# 20230701_BOG_empanadasarepas_control_NB_vasos_W26                          157
# 20230701_BOG_empanadasarepas_control_NB_frutas_W26                         156
# 20230701_BOG_empanadasarepas_control_NB_frutasjugo_W26                     209
# 20230701_BOG_empanadasarepas_control_NB_tuberculos_W26                     197
# 20230701_BOG_empanadasarepas_control_NB_verduras_W26                        79
# 20230701_BOG_empanadasarepas_control_NB_derivadoslacteos_W26               218
# 20230701_BOG_empanadasarepas_control_NB_leches_W26                         208
# 20230701_BOG_empanadasarepas_control_NB_quesos_W26                         222
# dtype: int64
# Done BOG empanadasarepas_CONTROL
# //-------------------------------------------------------------------------------
# Parrilla/Asadero
# 980
# Uso de data externa
# 20230701_BOG_parrillaasadero_piloto_NB_aceitesygrasas_W26                 550
# 20230701_BOG_parrillaasadero_piloto_NB_arroz_W26                          446
# 20230701_BOG_parrillaasadero_piloto_NB_azucaryendulzantes_W26             774
# 20230701_BOG_parrillaasadero_piloto_NB_cafechocolateeinfusiones_W26       933
# 20230701_BOG_parrillaasadero_piloto_NB_enlatadosyconservas_W26            974
# 20230701_BOG_parrillaasadero_piloto_NB_granos_W26                         839
# 20230701_BOG_parrillaasadero_piloto_NB_pasta_W26                          912
# 20230701_BOG_parrillaasadero_piloto_NB_salysazonadores_W26                821
# 20230701_BOG_parrillaasadero_piloto_NB_salsas_W26                         877
# 20230701_BOG_parrillaasadero_piloto_NB_desinfectantesysanitizantes_W26    847
# 20230701_BOG_parrillaasadero_piloto_NB_detergentejabonylavalozas_W26      623
# 20230701_BOG_parrillaasadero_piloto_NB_implementosdeaseo_W26              914
# 20230701_BOG_parrillaasadero_piloto_NB_papelytoallas_W26                  530
# 20230701_BOG_parrillaasadero_piloto_NB_aguas_W26                          956
# 20230701_BOG_parrillaasadero_piloto_NB_cervezasylicores_W26               936
# 20230701_BOG_parrillaasadero_piloto_NB_gaseosas_W26                       822
# 20230701_BOG_parrillaasadero_piloto_NB_jugos_W26                          921
# 20230701_BOG_parrillaasadero_piloto_NB_cerdo_W26                          882
# 20230701_BOG_parrillaasadero_piloto_NB_embutidos_W26                      936
# 20230701_BOG_parrillaasadero_piloto_NB_pescadosymariscoscongelado_W26     950
# 20230701_BOG_parrillaasadero_piloto_NB_pollo_W26                          894
# 20230701_BOG_parrillaasadero_piloto_NB_res_W26                            905
# 20230701_BOG_parrillaasadero_piloto_NB_alimentoscongelados_W26            893
# 20230701_BOG_parrillaasadero_piloto_NB_pulpasdefruta_W26                  921
# 20230701_BOG_parrillaasadero_piloto_NB_bolsas_W26                         854
# 20230701_BOG_parrillaasadero_piloto_NB_contenedores_W26                   374
# 20230701_BOG_parrillaasadero_piloto_NB_cubiertosypitillos_W26             722
# 20230701_BOG_parrillaasadero_piloto_NB_platosybandejas_W26                939
# 20230701_BOG_parrillaasadero_piloto_NB_vasos_W26                          676
# 20230701_BOG_parrillaasadero_piloto_NB_frutas_W26                         641
# 20230701_BOG_parrillaasadero_piloto_NB_frutasjugo_W26                     915
# 20230701_BOG_parrillaasadero_piloto_NB_tuberculos_W26                     789
# 20230701_BOG_parrillaasadero_piloto_NB_verduras_W26                       381
# 20230701_BOG_parrillaasadero_piloto_NB_leches_W26                         927
# dtype: int64
# Done BOG parrillaasadero_PILOTO
# //-------------------------------------------------------------------------------
# Parrilla/Asadero Experimento50%
# 244
# Uso de data externa
# 20230701_BOG_parrillaasadero_control_NB_aceitesygrasas_W26                 138
# 20230701_BOG_parrillaasadero_control_NB_arroz_W26                          100
# 20230701_BOG_parrillaasadero_control_NB_azucaryendulzantes_W26             190
# 20230701_BOG_parrillaasadero_control_NB_cafechocolateeinfusiones_W26       229
# 20230701_BOG_parrillaasadero_control_NB_enlatadosyconservas_W26            242
# 20230701_BOG_parrillaasadero_control_NB_granos_W26                         209
# 20230701_BOG_parrillaasadero_control_NB_pasta_W26                          218
# 20230701_BOG_parrillaasadero_control_NB_salysazonadores_W26                198
# 20230701_BOG_parrillaasadero_control_NB_salsas_W26                         210
# 20230701_BOG_parrillaasadero_control_NB_desinfectantesysanitizantes_W26    202
# 20230701_BOG_parrillaasadero_control_NB_detergentejabonylavalozas_W26      140
# 20230701_BOG_parrillaasadero_control_NB_implementosdeaseo_W26              232
# 20230701_BOG_parrillaasadero_control_NB_papelytoallas_W26                  131
# 20230701_BOG_parrillaasadero_control_NB_aguas_W26                          240
# 20230701_BOG_parrillaasadero_control_NB_cervezasylicores_W26               235
# 20230701_BOG_parrillaasadero_control_NB_gaseosas_W26                       208
# 20230701_BOG_parrillaasadero_control_NB_jugos_W26                          221
# 20230701_BOG_parrillaasadero_control_NB_cerdo_W26                          220
# 20230701_BOG_parrillaasadero_control_NB_embutidos_W26                      231
# 20230701_BOG_parrillaasadero_control_NB_pescadosymariscoscongelado_W26     238
# 20230701_BOG_parrillaasadero_control_NB_pollo_W26                          215
# 20230701_BOG_parrillaasadero_control_NB_res_W26                            233
# 20230701_BOG_parrillaasadero_control_NB_alimentoscongelados_W26            221
# 20230701_BOG_parrillaasadero_control_NB_pulpasdefruta_W26                  223
# 20230701_BOG_parrillaasadero_control_NB_bolsas_W26                         209
# 20230701_BOG_parrillaasadero_control_NB_contenedores_W26                    85
# 20230701_BOG_parrillaasadero_control_NB_cubiertosypitillos_W26             165
# 20230701_BOG_parrillaasadero_control_NB_platosybandejas_W26                231
# 20230701_BOG_parrillaasadero_control_NB_vasos_W26                          169
# 20230701_BOG_parrillaasadero_control_NB_frutas_W26                         158
# 20230701_BOG_parrillaasadero_control_NB_frutasjugo_W26                     230
# 20230701_BOG_parrillaasadero_control_NB_tuberculos_W26                     183
# 20230701_BOG_parrillaasadero_control_NB_verduras_W26                       110
# 20230701_BOG_parrillaasadero_control_NB_leches_W26                         230
# dtype: int64
# Done BOG parrillaasadero_CONTROL
# //-------------------------------------------------------------------------------
# Comida rápida
# 1433
# Uso de data externa
# 20230701_BOG_comidarapida_piloto_NB_aceitesygrasas_W26                  675
# 20230701_BOG_comidarapida_piloto_NB_arroz_W26                           964
# 20230701_BOG_comidarapida_piloto_NB_azucaryendulzantes_W26             1028
# 20230701_BOG_comidarapida_piloto_NB_cafechocolateeinfusiones_W26       1354
# 20230701_BOG_comidarapida_piloto_NB_enlatadosyconservas_W26            1411
# 20230701_BOG_comidarapida_piloto_NB_granos_W26                         1253
# 20230701_BOG_comidarapida_piloto_NB_pasta_W26                          1305
# 20230701_BOG_comidarapida_piloto_NB_salysazonadores_W26                1287
# 20230701_BOG_comidarapida_piloto_NB_salsas_W26                         1252
# 20230701_BOG_comidarapida_piloto_NB_desinfectantesysanitizantes_W26    1146
# 20230701_BOG_comidarapida_piloto_NB_detergentejabonylavalozas_W26       914
# 20230701_BOG_comidarapida_piloto_NB_implementosdeaseo_W26              1319
# 20230701_BOG_comidarapida_piloto_NB_papelytoallas_W26                   821
# 20230701_BOG_comidarapida_piloto_NB_aguas_W26                          1374
# 20230701_BOG_comidarapida_piloto_NB_cervezasylicores_W26               1369
# 20230701_BOG_comidarapida_piloto_NB_gaseosas_W26                       1115
# 20230701_BOG_comidarapida_piloto_NB_jugos_W26                          1332
# 20230701_BOG_comidarapida_piloto_NB_cerdo_W26                          1243
# 20230701_BOG_comidarapida_piloto_NB_embutidos_W26                      1321
# 20230701_BOG_comidarapida_piloto_NB_pescadosymariscoscongelado_W26     1378
# 20230701_BOG_comidarapida_piloto_NB_pollo_W26                          1133
# 20230701_BOG_comidarapida_piloto_NB_res_W26                            1213
# 20230701_BOG_comidarapida_piloto_NB_alimentoscongelados_W26            1204
# 20230701_BOG_comidarapida_piloto_NB_pulpasdefruta_W26                  1295
# 20230701_BOG_comidarapida_piloto_NB_bolsas_W26                         1249
# 20230701_BOG_comidarapida_piloto_NB_contenedores_W26                    976
# 20230701_BOG_comidarapida_piloto_NB_cubiertosypitillos_W26             1030
# 20230701_BOG_comidarapida_piloto_NB_platosybandejas_W26                1390
# 20230701_BOG_comidarapida_piloto_NB_vasos_W26                          1118
# 20230701_BOG_comidarapida_piloto_NB_frutas_W26                          872
# 20230701_BOG_comidarapida_piloto_NB_frutasjugo_W26                     1327
# 20230701_BOG_comidarapida_piloto_NB_tuberculos_W26                     1167
# 20230701_BOG_comidarapida_piloto_NB_verduras_W26                        473
# 20230701_BOG_comidarapida_piloto_NB_cremas_W26                         1365
# 20230701_BOG_comidarapida_piloto_NB_leches_W26                         1353
# 20230701_BOG_comidarapida_piloto_NB_quesos_W26                         1347
# dtype: int64
# Done BOG comidarapida_PILOTO
# //-------------------------------------------------------------------------------
# Comida rápida Experimento50%
# 358
# Uso de data externa
# 20230701_BOG_comidarapida_control_NB_aceitesygrasas_W26                 192
# 20230701_BOG_comidarapida_control_NB_arroz_W26                          240
# 20230701_BOG_comidarapida_control_NB_azucaryendulzantes_W26             266
# 20230701_BOG_comidarapida_control_NB_cafechocolateeinfusiones_W26       338
# 20230701_BOG_comidarapida_control_NB_enlatadosyconservas_W26            352
# 20230701_BOG_comidarapida_control_NB_granos_W26                         316
# 20230701_BOG_comidarapida_control_NB_pasta_W26                          327
# 20230701_BOG_comidarapida_control_NB_salysazonadores_W26                325
# 20230701_BOG_comidarapida_control_NB_salsas_W26                         320
# 20230701_BOG_comidarapida_control_NB_desinfectantesysanitizantes_W26    297
# 20230701_BOG_comidarapida_control_NB_detergentejabonylavalozas_W26      236
# 20230701_BOG_comidarapida_control_NB_implementosdeaseo_W26              330
# 20230701_BOG_comidarapida_control_NB_papelytoallas_W26                  208
# 20230701_BOG_comidarapida_control_NB_aguas_W26                          340
# 20230701_BOG_comidarapida_control_NB_cervezasylicores_W26               337
# 20230701_BOG_comidarapida_control_NB_gaseosas_W26                       271
# 20230701_BOG_comidarapida_control_NB_jugos_W26                          336
# 20230701_BOG_comidarapida_control_NB_cerdo_W26                          312
# 20230701_BOG_comidarapida_control_NB_embutidos_W26                      334
# 20230701_BOG_comidarapida_control_NB_pescadosymariscoscongelado_W26     346
# 20230701_BOG_comidarapida_control_NB_pollo_W26                          304
# 20230701_BOG_comidarapida_control_NB_res_W26                            308
# 20230701_BOG_comidarapida_control_NB_alimentoscongelados_W26            303
# 20230701_BOG_comidarapida_control_NB_pulpasdefruta_W26                  332
# 20230701_BOG_comidarapida_control_NB_bolsas_W26                         299
# 20230701_BOG_comidarapida_control_NB_contenedores_W26                   234
# 20230701_BOG_comidarapida_control_NB_cubiertosypitillos_W26             248
# 20230701_BOG_comidarapida_control_NB_platosybandejas_W26                345
# 20230701_BOG_comidarapida_control_NB_vasos_W26                          277
# 20230701_BOG_comidarapida_control_NB_frutas_W26                         217
# 20230701_BOG_comidarapida_control_NB_frutasjugo_W26                     343
# 20230701_BOG_comidarapida_control_NB_tuberculos_W26                     306
# 20230701_BOG_comidarapida_control_NB_verduras_W26                       119
# 20230701_BOG_comidarapida_control_NB_cremas_W26                         348
# 20230701_BOG_comidarapida_control_NB_leches_W26                         338
# 20230701_BOG_comidarapida_control_NB_quesos_W26                         341
# dtype: int64
# Done BOG comidarapida_CONTROL
# //-------------------------------------------------------------------------------
# Other
# 593
# Uso de data externa
# 20230701_BOG_other_piloto_NB_aceitesygrasas_W26                 297
# 20230701_BOG_other_piloto_NB_arroz_W26                          300
# 20230701_BOG_other_piloto_NB_azucaryendulzantes_W26             333
# 20230701_BOG_other_piloto_NB_cafechocolateeinfusiones_W26       529
# 20230701_BOG_other_piloto_NB_enlatadosyconservas_W26            582
# 20230701_BOG_other_piloto_NB_granos_W26                         430
# 20230701_BOG_other_piloto_NB_pasta_W26                          484
# 20230701_BOG_other_piloto_NB_salysazonadores_W26                487
# 20230701_BOG_other_piloto_NB_salsas_W26                         491
# 20230701_BOG_other_piloto_NB_desinfectantesysanitizantes_W26    480
# 20230701_BOG_other_piloto_NB_detergentejabonylavalozas_W26      374
# 20230701_BOG_other_piloto_NB_implementosdeaseo_W26              545
# 20230701_BOG_other_piloto_NB_papelytoallas_W26                  339
# 20230701_BOG_other_piloto_NB_aguas_W26                          550
# 20230701_BOG_other_piloto_NB_cervezasylicores_W26               557
# 20230701_BOG_other_piloto_NB_gaseosas_W26                       501
# 20230701_BOG_other_piloto_NB_jugos_W26                          561
# 20230701_BOG_other_piloto_NB_cerdo_W26                          470
# 20230701_BOG_other_piloto_NB_embutidos_W26                      541
# 20230701_BOG_other_piloto_NB_pescadosymariscoscongelado_W26     547
# 20230701_BOG_other_piloto_NB_pollo_W26                          442
# 20230701_BOG_other_piloto_NB_res_W26                            469
# 20230701_BOG_other_piloto_NB_alimentoscongelados_W26            501
# 20230701_BOG_other_piloto_NB_pulpasdefruta_W26                  510
# 20230701_BOG_other_piloto_NB_bolsas_W26                         496
# 20230701_BOG_other_piloto_NB_contenedores_W26                   388
# 20230701_BOG_other_piloto_NB_cubiertosypitillos_W26             461
# 20230701_BOG_other_piloto_NB_platosybandejas_W26                569
# 20230701_BOG_other_piloto_NB_vasos_W26                          440
# 20230701_BOG_other_piloto_NB_frutas_W26                         270
# 20230701_BOG_other_piloto_NB_frutasjugo_W26                     489
# 20230701_BOG_other_piloto_NB_tuberculos_W26                     372
# 20230701_BOG_other_piloto_NB_verduras_W26                       164
# 20230701_BOG_other_piloto_NB_cremas_W26                         554
# 20230701_BOG_other_piloto_NB_derivadoslacteos_W26               567
# 20230701_BOG_other_piloto_NB_leches_W26                         542
# 20230701_BOG_other_piloto_NB_quesos_W26                         543
# dtype: int64
# Done BOG other_PILOTO
# //-------------------------------------------------------------------------------
# Other Experimento50%
# 148
# Uso de data externa
# 20230701_BOG_other_control_NB_aceitesygrasas_W26                  73
# 20230701_BOG_other_control_NB_arroz_W26                           79
# 20230701_BOG_other_control_NB_azucaryendulzantes_W26             101
# 20230701_BOG_other_control_NB_cafechocolateeinfusiones_W26       129
# 20230701_BOG_other_control_NB_enlatadosyconservas_W26            146
# 20230701_BOG_other_control_NB_granos_W26                         113
# 20230701_BOG_other_control_NB_pasta_W26                          129
# 20230701_BOG_other_control_NB_salysazonadores_W26                126
# 20230701_BOG_other_control_NB_salsas_W26                         131
# 20230701_BOG_other_control_NB_desinfectantesysanitizantes_W26    124
# 20230701_BOG_other_control_NB_detergentejabonylavalozas_W26      101
# 20230701_BOG_other_control_NB_implementosdeaseo_W26              135
# 20230701_BOG_other_control_NB_papelytoallas_W26                  101
# 20230701_BOG_other_control_NB_aguas_W26                          138
# 20230701_BOG_other_control_NB_cervezasylicores_W26               136
# 20230701_BOG_other_control_NB_gaseosas_W26                       115
# 20230701_BOG_other_control_NB_jugos_W26                          141
# 20230701_BOG_other_control_NB_cerdo_W26                          122
# 20230701_BOG_other_control_NB_embutidos_W26                      131
# 20230701_BOG_other_control_NB_pescadosymariscoscongelado_W26     137
# 20230701_BOG_other_control_NB_pollo_W26                          107
# 20230701_BOG_other_control_NB_res_W26                            111
# 20230701_BOG_other_control_NB_alimentoscongelados_W26            127
# 20230701_BOG_other_control_NB_pulpasdefruta_W26                  127
# 20230701_BOG_other_control_NB_bolsas_W26                         129
# 20230701_BOG_other_control_NB_contenedores_W26                   102
# 20230701_BOG_other_control_NB_cubiertosypitillos_W26             117
# 20230701_BOG_other_control_NB_platosybandejas_W26                142
# 20230701_BOG_other_control_NB_vasos_W26                          107
# 20230701_BOG_other_control_NB_frutas_W26                          71
# 20230701_BOG_other_control_NB_frutasjugo_W26                     116
# 20230701_BOG_other_control_NB_tuberculos_W26                      98
# 20230701_BOG_other_control_NB_verduras_W26                        50
# 20230701_BOG_other_control_NB_cremas_W26                         135
# 20230701_BOG_other_control_NB_derivadoslacteos_W26               144
# 20230701_BOG_other_control_NB_leches_W26                         136
# 20230701_BOG_other_control_NB_quesos_W26                         135
# dtype: int64
# Done BOG other_CONTROL

# %% [markdown]
# ## Aca creo el archivo para R&D

# %%
# customers =  pd.DataFrame()
# for column,i in enumerate(aux_df.columns):
#     #if ('verduras' in i or 'frutas' in i or 'arroz' in i or 'aceitesygrasas' in i or 'harinasymezclas' in i or 'azucaryendulzantes' in i or 'pollo' in i or 'huevos' in i) and not 'frutasjugo' in i:
#     #if ('verduras' in i or 'frutas' in i) and not 'frutasjugo' in i:
#     customers[i] = aux_df[i]

# %%
# customers.iloc[:6000].to_csv(f'SD/export_data/MS/csv_{city_code}_CLIENTS_PRUEBA_R&D.csv', index = False)

# with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
#        json.dump(global_segment_list, outfile)

# %%
# aux_seg = pd.read_csv(f"prueba_tuberculos_BAQ.csv")
# aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

# aux_seg["final_group2"] = ["piloto" if x == "Super Descuentos" else "control" for x in aux_seg.grupos]
# aux_seg['offer_name'] = f"20230301_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W9"

# aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()

# %%
# lst = []
# for x in aux_seg2.values:
#     h = {'name':x[0], 'customersIds': list(x[1])}
#     lst.append(h)
    
# for x in lst:
#     print(x['name'])
#     #break
#     for i,value in enumerate(global_segment_list):
#         if value['name'] == x['name']:
#             global_segment_list[i]['customersIds'] = x['customersIds']
#             print(i)

# %%
aux_seg = pd.read_csv(f"csv_{city_code}_CLIENTS_FINAL_JULIO_R&D.csv")
aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

aux_seg["final_group2"] = ["piloto" if x == "Treatment" else "control" for x in aux_seg.final_group]
aux_seg['offer_name'] = f"20230701_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W26"

aux_seg["quartile"] = ["Q0" if x == "-" else x for x in aux_seg.quartile.values]
aux_seg["quartile_name"] = f"20230701_{city_code}_" + aux_seg.subcategory + "_" + aux_seg.quartile + "_" + aux_seg.case

aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()
aux_seg3 = aux_seg.groupby(by = ["quartile_name"])["customer_source_id"].apply(list).reset_index()

# %%
aux_seg.head()
# Out:
#       subcategory  customer_source_id                   ms previous_group  \
# 0  aceitesygrasas           175489245  panaderiapasteleria      Treatment
# 1  aceitesygrasas             -250137          corrientazo      Treatment
# 2  aceitesygrasas            16238261          corrientazo      Treatment
# 3  aceitesygrasas            21941112                other      Treatment
# 4  aceitesygrasas             -247488          corrientazo      Treatment
#
#          case quartile  random final_group final_group2  \
# 0  positivity       Q4       0   Treatment       piloto
# 1  positivity       Q4       0   Treatment       piloto
# 2  positivity       Q4       1     Control      control
# 3  positivity       Q4       0   Treatment       piloto
# 4  positivity       Q4       0   Treatment       piloto
#
#                                           offer_name  \
# 0  20230701_BOG_panaderiapasteleria_piloto_NB_ace...
# 1  20230701_BOG_corrientazo_piloto_NB_aceitesygra...
# 2  20230701_BOG_corrientazo_control_NB_aceitesygr...
# 3    20230701_BOG_other_piloto_NB_aceitesygrasas_W26
# 4  20230701_BOG_corrientazo_piloto_NB_aceitesygra...
#
#                                quartile_name
# 0  20230701_BOG_aceitesygrasas_Q4_positivity
# 1  20230701_BOG_aceitesygrasas_Q4_positivity
# 2  20230701_BOG_aceitesygrasas_Q4_positivity
# 3  20230701_BOG_aceitesygrasas_Q4_positivity
# 4  20230701_BOG_aceitesygrasas_Q4_positivity

# %%
lst = []
for x in aux_seg2.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst.append(h)

global_segment_list = lst

# %%
lst2 = []
for x in aux_seg3.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst2.append(h)

# %% [markdown]
# # Aca tengo que volver a cargar el archivo de arriba y dejarlo como lista para traer lo otro

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_BOG_panaderiapasteleria_piloto_NB_ace...
# 1  20230701_BOG_panaderiapasteleria_piloto_NB_arr...
# 2  20230701_BOG_panaderiapasteleria_piloto_NB_azu...
# 3  20230701_BOG_panaderiapasteleria_piloto_NB_caf...
# 4  20230701_BOG_panaderiapasteleria_piloto_NB_enl...
#
#                                    offer_description  discount  \
# 0       panaderiapasteleria_piloto_NB_aceitesygrasas         3
# 1                panaderiapasteleria_piloto_NB_arroz         3
# 2   panaderiapasteleria_piloto_NB_azucaryendulzantes         3
# 3  panaderiapasteleria_piloto_NB_cafechocolateein...         5
# 4  panaderiapasteleria_piloto_NB_enlatadosyconservas         7
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                   7
# 1                         true  01-07-2023  31-07-2023                   7
# 2                         true  01-07-2023  31-07-2023                   5
# 3                         true  01-07-2023  31-07-2023                  30
# 4                         true  01-07-2023  31-07-2023                  20
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1                None
# 1                      1                None
# 2                      1                None
# 3                      1                None
# 4                      1                None
#
#                                       sku_id
# 0  283255#542653#630610#593807#222689#528639
# 1         613669#227790#234361#234359#635919
# 2                -301701#23102#600123#606547
# 3                       338866#47547#-300180
# 4                              613469#607717

# %%
#len_seg =int(len(global_segment_list)/10)
#len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %% [markdown]
# ## Crear segments offers y segments types

# %%
import requests
import json

def create_segments(segment_list):
    
    url = f"https://{city_code}.frubana.com/api/v1/segments/create?api-key=00_growth-team-zzz-qqq_001"

    payload = json.dumps(segment_list)


    headers = {
    'Cookie': 'AWSALB=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALBCORS=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALB=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI; AWSALBCORS=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI',
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.status_code)
    sgt = [(int(x[:6]),x[7:]) for x in list(map(str.strip, response.text[32:].strip('][').replace('"', '').split(',')))]
    time.sleep(40)
    return sgt

# %%
len_seg =int(len(global_segment_list)/10)
len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %%
#offers
sgt=[]

for i in len_seg_list:
    sgt.append(create_segments(i))
    
sgt_end =[item for lista in sgt for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len_seg2 =int(len(lst2)/10)
len_seg_list2 = [lst2[:len_seg2],lst2[len_seg2:len_seg2*2],lst2[len_seg2*2:len_seg2*3],lst2[len_seg2*3:len_seg2*4],lst2[len_seg2*4:len_seg2*5],lst2[len_seg2*5:len_seg2*6],lst2[len_seg2*6:len_seg2*7],lst2[len_seg2*7:len_seg2*8],lst2[len_seg2*8:len_seg2*9],lst2[len_seg2*9:]]

# %%
#types
sgt2=[]

for i in len_seg_list2:
    sgt2.append(create_segments(i))
    
sgt_end2 =[item for lista in sgt2 for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#unir offers con segments
for i in global_offer_csv.offer_name:
    for j,z in sgt_end:
        if z==i:
            global_offer_csv.loc[global_offer_csv.offer_name == i, ('customer_segment_id')] = j

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_BOG_panaderiapasteleria_piloto_NB_ace...
# 1  20230701_BOG_panaderiapasteleria_piloto_NB_arr...
# 2  20230701_BOG_panaderiapasteleria_piloto_NB_azu...
# 3  20230701_BOG_panaderiapasteleria_piloto_NB_caf...
# 4  20230701_BOG_panaderiapasteleria_piloto_NB_enl...
#
#                                    offer_description  discount  \
# 0       panaderiapasteleria_piloto_NB_aceitesygrasas         3
# 1                panaderiapasteleria_piloto_NB_arroz         3
# 2   panaderiapasteleria_piloto_NB_azucaryendulzantes         3
# 3  panaderiapasteleria_piloto_NB_cafechocolateein...         5
# 4  panaderiapasteleria_piloto_NB_enlatadosyconservas         7
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                   7
# 1                         true  01-07-2023  31-07-2023                   7
# 2                         true  01-07-2023  31-07-2023                   5
# 3                         true  01-07-2023  31-07-2023                  30
# 4                         true  01-07-2023  31-07-2023                  20
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              183691
# 1                      1              183694
# 2                      1              183695
# 3                      1              183697
# 4                      1                None
#
#                                       sku_id
# 0  283255#542653#630610#593807#222689#528639
# 1         613669#227790#234361#234359#635919
# 2                -301701#23102#600123#606547
# 3                       338866#47547#-300180
# 4                              613469#607717

# %%
global_offer_csv = global_offer_csv.loc[~global_offer_csv.customer_segment_id.isnull()].reset_index(drop=True)
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('discount','max_uses_per_order')]=1
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('start_date','end_date')]='01-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('end_date')]='02-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('sku_id')]= global_offer_csv.loc[~global_offer_csv['offer_name'].str.contains("piloto", case=False), ('sku_id')].tolist()

# %%
len_offer =int(len(global_offer_csv)/4)
len_offer = [global_offer_csv[:len_seg],global_offer_csv[len_seg:len_seg*2],global_offer_csv[len_seg*2:len_seg*3],global_offer_csv[len_seg*3:]]

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230701_BOG_panaderiapasteleria_piloto_NB_ace...
# 1  20230701_BOG_panaderiapasteleria_piloto_NB_arr...
# 2  20230701_BOG_panaderiapasteleria_piloto_NB_azu...
# 3  20230701_BOG_panaderiapasteleria_piloto_NB_caf...
# 4  20230701_BOG_panaderiapasteleria_piloto_NB_gra...
#
#                                    offer_description  discount  \
# 0       panaderiapasteleria_piloto_NB_aceitesygrasas         3
# 1                panaderiapasteleria_piloto_NB_arroz         3
# 2   panaderiapasteleria_piloto_NB_azucaryendulzantes         3
# 3  panaderiapasteleria_piloto_NB_cafechocolateein...         5
# 4               panaderiapasteleria_piloto_NB_granos         6
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-07-2023  31-07-2023                   7
# 1                         true  01-07-2023  31-07-2023                   7
# 2                         true  01-07-2023  31-07-2023                   5
# 3                         true  01-07-2023  31-07-2023                  30
# 4                         true  01-07-2023  31-07-2023                  50
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              183691
# 1                      1              183694
# 2                      1              183695
# 3                      1              183697
# 4                      1              184209
#
#                                       sku_id
# 0  283255#542653#630610#593807#222689#528639
# 1         613669#227790#234361#234359#635919
# 2                -301701#23102#600123#606547
# 3                       338866#47547#-300180
# 4         226189#604775#226209#226083#226074

# %%
#//--------------------------------------------
#//Exporting single file data
global_offer_csv.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS.csv', index = False)

for i,offer in enumerate(len_offer):
    offer.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS_{i}.csv', index = False)

with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
        json.dump(global_segment_list, outfile)    
with open(f'SD/export_data/MS/nb_{city_code}_All_MS.json', 'w') as outfile:
        json.dump(global_segment_list, outfile)
print(f'Done {city_code}')
# Out:
# Done BOG
