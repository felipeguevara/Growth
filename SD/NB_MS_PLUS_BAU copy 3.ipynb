# %%
#//----------------------------
#//LIBRARIES
    #Math
import math
    #Numeric Python
import numpy as np
    #Pandas (dataframes)
import pandas as pd
    #datetime for fate manipulation
from datetime import date, datetime, timedelta  
    #Regex for advanced string matching
import re
    #for time related stuff
import time
    #json library
import json
    #Analyst tools
import sys
sys.path.append('../')
from analysts_tools.growth import *
    #Procurement tools
from analysts_tools.redash_methods import *
    #Frubana libraries
from procurement_lib import redash, dw, send_message, send_slack_notification, GoogleSheet, logging

# %%
query="""
With microsegment as (

SELECT DISTINCT c.customer_id AS user_id,
                c.site_type AS region_code_ms,
                
                (case 
                    -- Colombia
                    when m.microsegment_id not in (1,3,4,28,5,6,7,8,2) and c.site_type = 'BOG' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1,3,4,28,5,11,10,9,2,12) and c.site_type = 'BAQ' then 'Sin Microsegmento'
                    when m.microsegment_id not in (3,4,28,1,24,11,5,2,27) and c.site_type = 'MDE' then 'Sin Microsegmento'
    
                    -- Mexico
                    when m.microsegment_id not in (1,13,14,30,15,16,29,17,6,7,2) and c.site_type = 'CMX' then 'Sin Microsegmento'
                    when m.microsegment_id not in (1, 13,14,30, 15,16,29, 6, 33, 2, 31) and c.site_type = 'GDL' then 'Sin Microsegmento'
                    when m.microsegment_id not in (13,14,30, 15,16,29, 32,2,6,33) and c.site_type = 'PBC' then 'Sin Microsegmento'
                    
                    -- Brasil
                    when m.microsegment_id not in (21,34,38,37,35,36,39,26) and c.site_type in ('SPO','BHZ','CWB','VCP') then 'Sin Microsegmento'
                        
                else m.description end) as microsegment_ok,
                
                m.microsegment_id,
                mo.name as ms_method
                
                
FROM postgres_main_federate."growth_microsegmentation.customer_microsegment" AS cm
INNER JOIN postgres_main_federate."growth_microsegmentation.microsegment" m ON cm.microsegment_id = m.id
INNER JOIN postgres_main_federate."growth_microsegmentation.customer" c ON cm.customer_id = c.id
INNER JOIN postgres_main_federate."growth_microsegmentation.models" mo ON mo.id = cm.model_type_id


)

select m.user_id,
m.region_code_ms,
--m.microsegment_id,

(case 
        when m.microsegment_ok in ('Corrientazo c/desayuno','Corrientazo s/desayuno','Tienda/Restaurante') then 'Corrientazo' 
        when m.microsegment_ok in ('Fonda c/desayuno','Fonda s/desayuno') then 'Fonda'
        when m.microsegment_ok in ('Taquería en calle','Taquería en local') then 'Taquería'

else m.microsegment_ok end) as microsegment,

m.ms_method

from microsegment m
where m.microsegment_ok != 'Sin Microsegmento'
"""

segmentos_fulll = read_connection_data_warehouse.runQuery(query)

segmentos_fulll.columns = ['customer_id', 'city', 'microsegment','NA']
segmentos_fulll = segmentos_fulll[['customer_id', 'city', 'microsegment']]

# %%
#//---------------------------------------------------------------------------------------------------------------------------
#// Parametros
"""Todays date should be the first day of the next month which is going to begin with SD"""

city_code = 'CMX'

# Set today's date to the first day of the next month
today = datetime.today()
first_day_next_month = (today.replace(day=1) + timedelta(days=32)).replace(day=1)

# Calculate non_buyers_date (todays date - 1 month)
non_buyers_date = (first_day_next_month - timedelta(days=1)).replace(day=1)
customer_date_desde = (first_day_next_month - timedelta(days=1)).replace(day=1)

# Calculate sku_date_desde (todays date - 2 months)
sku_date_desde = (first_day_next_month - timedelta(days=60)).replace(day=1)

# Convert the dates to strings in the desired format
todays_date = first_day_next_month.strftime('%Y-%m-%d')
non_buyers_date = non_buyers_date.strftime('%Y-%m-%d')
customer_date_desde = customer_date_desde.strftime('%Y-%m-%d')
sku_date_desde = sku_date_desde.strftime('%Y-%m-%d')

print(todays_date) # Output: e.g. 2023-04-01
print(non_buyers_date) # Output: e.g. 2023-03-01
print(sku_date_desde) # Output: e.g. 2023-02-01

tasas = {'BOG': 3776,
         'BAQ': 3776,
         'MDE': 3776,
         'CMX': 19.65,
         'GDL': 19.65,
         'PBC': 19.65,
         'SPO': 4.75,
         'BHZ': 4.75,
         'CWB': 4.75,
         'VCP': 4.75}

t_cambio = tasas[city_code]
# Out:
# 2023-06-01
# 2023-05-01
# 2023-04-01

# %% [markdown]
# ### Loading COSTUMERS INFO

# %%
users_eliminar_kam = get_fresh_query_result("https://internal-redash.federate.frubana.com/",150812,'SeoGHWmDUaaBi7VXje1s9zYNiMD1VHQ1K1DYOxiF',{},20)
users_eliminar = users_eliminar_kam.loc[users_eliminar_kam.registered_city == city_code]['customer_id'].unique().tolist()
# Out:
# 200

# %% [markdown]
# ### Loading FORCED_SKUS // Cleaning SEGMENT_NAMES

# %% [markdown]
# ### Loading DATA_VENTAS // Removing SKUs /\ CUSTOMERS_ID

# %%
#//Remove skus 
#It is used because some SKUs can get in trouble with supplier for the SD or to exclude them for another activity   
skus_remove = GoogleSheet("1Z0T_c36oRHmOHIgEG8_ANcwFykaHgXGAizYAYCKCqtY")
skus_remove = skus_remove.get_as_dataframe('SKUS')

skus_remove = skus_remove['sku_id'].unique().astype(int).tolist()

# %%
query = """
SELECT DISTINCT
    split_part(bs.upc, '-', 1) as region,
    bs.sku_id

FROM postgres_broadleaf_federate."broadleaf.blc_sku"            bs 
LEFT JOIN postgres_broadleaf_federate."broadleaf.blc_product"   bp ON bp.product_id = bs.addl_product_id

WHERE bs.archived = 'N'
    AND bs.sndbx_id is NULL
    AND bp.archived = 'N'
    AND bs.catalog_disc < 0
    AND ((bp.archived = 'N' AND bp.sndbx_id is NULL) OR (bp.archived is NULL))
"""
frida_products = read_connection_data_warehouse.runQuery(query)

# %%
good_skus = frida_products.sku_id.unique()

# %%
#Loading SELL'S DATA from a function
data_ventas = data_ventas_query(ciudad=city_code, tipo_cambio=t_cambio, desde=customer_date_desde, hasta = todays_date, tipo_negocio=1)

# %%
data_ventas = data_ventas[(~data_ventas['sku_id'].isin(skus_remove)) & (data_ventas['sku_id'].isin(good_skus))]

# %%
segmentos_full = segmentos_fulll[segmentos_fulll.city == city_code].copy()

# %%
#//customers for offers */(has further uses)*/
microsegmentacion_df = segmentos_full[(~segmentos_full['customer_id'].isin(users_eliminar))]
data_ventas = data_ventas[(~data_ventas['customer_id'].isin(users_eliminar))]

# %% [markdown]
# ### Create the MS "Other" for BAU

# %%
data_full = data_ventas.merge(microsegmentacion_df[['customer_id','microsegment']], how = 'left', on = 'customer_id')

# %%
data_full['microsegment'] = data_full['microsegment'].fillna('Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                 microsegment  customer_id
# 0                  Cafetería          465
# 1       Comida especializada          737
# 2              Comida rápida         1142
# 3                      Fonda         2633
# 4  Juguería/Comida saludable          828
# 5                      Other          584
# 6       Panadería/Pastelería         1031
# 7                   Taquería         2279

# %%
segments_validation = data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()

# %%
for ms in segments_validation[segments_validation.customer_id < 180]['microsegment'].unique():
    data_full['microsegment'] = data_full['microsegment'].str.replace(ms,'Other')

# %%
data_full[['customer_id','microsegment']].groupby(['microsegment']).nunique().reset_index()
# Out:
#                 microsegment  customer_id
# 0                  Cafetería          465
# 1       Comida especializada          737
# 2              Comida rápida         1142
# 3                      Fonda         2633
# 4  Juguería/Comida saludable          828
# 5                      Other          584
# 6       Panadería/Pastelería         1031
# 7                   Taquería         2279

# %%
#Get the same variable to do the process job
data_ventas = data_full

# %% [markdown]
# ### PARAMETERS // SOME FUNCTIONS - GET READY TO PROCESSING

# %%
def ms_data(city_code):
  
    paramss_csv=GoogleSheet("1k0ckgkLddxc5lY8NUVGCkvDLTuulLaJm-N535oMNZNw")
    city_paramss = paramss_csv.get_as_dataframe(city_code)
    
    parametros = {}
    parametros[city_code] = {}
    
    for i,ms in enumerate(city_paramss.iloc[:,4:].columns):
        parametros[city_code][ms] = [(value[1],value[2],value[3],value[4+i]) for value in city_paramss.values if value[4+i]>0]
        
    return parametros

# %%
parametros = ms_data(city_code)

# %%
def normalize_text(raw_text):
    """
    Removes common accent characters and normalize text.
    """
    raw_text = raw_text.replace(" ", "")
    raw_text = raw_text.replace("�", "")
    raw_text = raw_text.replace("/", "")
    raw_text = re.sub(r'\s*', '', raw_text)
    raw_text = re.sub(r"[àáâãäå]", 'a', raw_text)
    raw_text = re.sub(r"[èéêë]", 'e', raw_text)
    raw_text = re.sub(r"[ìíîï]", 'i', raw_text) 
    raw_text = re.sub(r"[òóôõö]", 'o', raw_text)
    raw_text = re.sub(r"[ùúûü]", 'u', raw_text)
    raw_text = re.sub(r"[ýÿ]", 'y', raw_text)
    raw_text = re.sub(r"[ß]", 'ss', raw_text)
    raw_text = re.sub(r"[ñ]", 'n', raw_text)
    raw_text = re.sub(r"[ç]", 'c', raw_text)
    raw_text = raw_text.lower()
    return raw_text

# %%
#Sacar de aca los microsegmentos
msg = data_full.microsegment.unique()
msg
# Out:
# array(['Fonda', 'Cafetería', 'Comida rápida', 'Taquería', 'Other',
#        'Panadería/Pastelería', 'Juguería/Comida saludable',
#        'Comida especializada'], dtype=object)

# %% [markdown]
# ### END

# %% [markdown]
# # Aca Empieza la Experimentacion

# %%
from sklearn.model_selection import train_test_split

# %%
#//Variables to store all the segments and offers of the city
global_offer_csv = pd.DataFrame()
global_segment_list = [] #//for procesing

# %%
#//----------------------------------------------------------------------------
#//Big loop for creating each city segments/offers files
aux_df = pd.DataFrame()
aux_df['aux']=6000*[0]

for microsegment in msg:
    print('//-------------------------------------------------------------------------------')
    print(microsegment)

    #//Customers per microsegment
    customers_ms = data_ventas[(data_ventas['microsegment'] == microsegment)]['customer_id'].unique()
    #//Customers to give them the skus
    customers_for_skus_ms =  data_ventas[['microsegment','customer_id']][(data_ventas.microsegment == microsegment) & (~data_ventas.customer_id.isin(users_eliminar))]['customer_id'].unique()
    
    #----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_PILOTO" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    rand=1
    customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state=rand)
    
    while abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())) > 0.05:
        #print(data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean(),data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean(),abs(1-(data_ventas[data_ventas['customer_id'].isin(customer_ms_2)]['gmv_usd'].mean()/data_ventas[data_ventas['customer_id'].isin(customer_ms_1)]['gmv_usd'].mean())))
        rand+=1
        customer_ms_2, customer_ms_1 = train_test_split(customers_ms, test_size = 0.80, random_state = rand)
        
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_1)].copy() #le quite la s!!
    
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()
    
    subcats = list(map(lambda x: x[0], parametros[city_code][microsegment]))
    max_uses = list(map(lambda x: int(x[1]), parametros[city_code][microsegment]))
    max_order = list(map(lambda x: int(x[2]), parametros[city_code][microsegment]))
    discount = list(map(lambda x: int(x[3]), parametros[city_code][microsegment]))

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    a, b, c = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
            non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                        limite=0.75, data_ventas_skus = data_skus)

    print(b.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(a)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in b.columns:
        id_list = b[seg].dropna().astype(int)
        d = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)

        lst.append(d)
        
    #//appending to global list    
        global_segment_list.append(d)
    
    print(f'Done {city_code} {ms_name}')

#----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------
#////////////-------------------------------------------Here We Start With The Second Group-----------------------------------------------------------------------------------------------------------------


#----------------------------------------------------------- START OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #//----------------------------------------------------------------------------------------------------------------------------
    ms_name = normalize_text(microsegment)+"_CONTROL" #NORMALIZE TEXT FORMAT
    #//----------------------------------------------------------------------------------------------------------------------------
    
    #// Separation of types of sales (non_buyers/skus for offers)
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    data_buyers = data_ventas[data_ventas['customer_id'].isin(customer_ms_2)].copy() #le quite la s!!
    #//////////////////////////////// THIS IS FOR CREATE EXPERIMENTS //////////////////////////////////////////////
    
    print('//-------------------------------------------------------------------------------')
    print(f'{microsegment} Experimento50%')
    print(data_buyers.customer_id.nunique())
    data_skus = data_ventas[data_ventas['customer_id'].isin(customers_for_skus_ms)].copy()

    #----------------------------------------------------------- END OF GETTING READY THE DATA --------------------------------------------------------------------------------------
    
    
    #----------------------------------------------------------- START OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    e, f, g = proceso_para_csv(data_ventas=data_buyers, todays_date=todays_date, 
                non_buyers_date=non_buyers_date, city=city_code, list_to_filter=subcats, offer_discount=discount, offer_max_uses=max_uses, offer_max_order=max_order, level='subcat', additional_words=ms_name,
                          limite=0.75, data_ventas_skus = data_skus)
      
    print(f.nunique())
    #//appending to global data frame
    global_offer_csv = global_offer_csv.append(e)
    
    #//Data formating
    lst = []
    name = 'export_data/MS/nb_'+city_code+'_'+ms_name+'.txt'
    for seg in f.columns:
        id_list = f[seg].dropna().astype(int)
        h = {'name':seg, 'customersIds': list(id_list)}
        aux_df.loc[range(len(list(id_list))),seg] = list(id_list)
        
        lst.append(h)
        
        
    #//appending to global list    
        global_segment_list.append(h)
    
    print(f'Done {city_code} {ms_name}')
    #----------------------------------------------------------- END OF THE GENERATION OF OFFERS --------------------------------------------------------------------------------------
    
#//End of big loop and start of data bundle
# Out:
# //-------------------------------------------------------------------------------
# Fonda
# 2107
# Uso de data externa
# 20230601_CMX_fonda_piloto_NB_azucaryendulzantes_W22                1360
# 20230601_CMX_fonda_piloto_NB_aceitesygrasas_W22                    1466
# 20230601_CMX_fonda_piloto_NB_cafechocolateeinfusiones_W22          1922
# 20230601_CMX_fonda_piloto_NB_enlatados_W22                         1822
# 20230601_CMX_fonda_piloto_NB_salsas_W22                            1838
# 20230601_CMX_fonda_piloto_NB_arroz_W22                             1260
# 20230601_CMX_fonda_piloto_NB_frutossecos_W22                       1818
# 20230601_CMX_fonda_piloto_NB_panaderiaytortilleria_W22             1870
# 20230601_CMX_fonda_piloto_NB_granos_W22                            1712
# 20230601_CMX_fonda_piloto_NB_pasta_W22                             1523
# 20230601_CMX_fonda_piloto_NB_salysazonadores_W22                   1677
# 20230601_CMX_fonda_piloto_NB_chilessecos_W22                       1617
# 20230601_CMX_fonda_piloto_NB_mermeladasyconfituras_W22             2079
# 20230601_CMX_fonda_piloto_NB_papelytoallas_W22                     1640
# 20230601_CMX_fonda_piloto_NB_detergentejabonylavatrastes_W22       1622
# 20230601_CMX_fonda_piloto_NB_desinfectantesysanitizantes_W22       1842
# 20230601_CMX_fonda_piloto_NB_implementosdeaseo_W22                 1927
# 20230601_CMX_fonda_piloto_NB_refrescos_W22                         1690
# 20230601_CMX_fonda_piloto_NB_jugos_W22                             2066
# 20230601_CMX_fonda_piloto_NB_bebidasenergeticasehidratantes_W22    2099
# 20230601_CMX_fonda_piloto_NB_pollo_W22                             1940
# 20230601_CMX_fonda_piloto_NB_embutidos_W22                         1933
# 20230601_CMX_fonda_piloto_NB_cerdo_W22                             1926
# 20230601_CMX_fonda_piloto_NB_res_W22                               1909
# 20230601_CMX_fonda_piloto_NB_alimentoscongelados_W22               1941
# 20230601_CMX_fonda_piloto_NB_vasoscontenedoresyplatos_W22          1308
# 20230601_CMX_fonda_piloto_NB_empaqueyenvoltura_W22                 1936
# 20230601_CMX_fonda_piloto_NB_bolsas_W22                            2034
# 20230601_CMX_fonda_piloto_NB_cubiertos_W22                         1814
# 20230601_CMX_fonda_piloto_NB_verduras_W22                           748
# 20230601_CMX_fonda_piloto_NB_frutas_W22                            1145
# 20230601_CMX_fonda_piloto_NB_tuberculos_W22                        1360
# 20230601_CMX_fonda_piloto_NB_leches_W22                            1747
# 20230601_CMX_fonda_piloto_NB_derivadoslacteos_W22                  1845
# 20230601_CMX_fonda_piloto_NB_huevos_W22                            1784
# 20230601_CMX_fonda_piloto_NB_cremas_W22                            1524
# 20230601_CMX_fonda_piloto_NB_quesos_W22                            1876
# 20230601_CMX_fonda_piloto_NB_mantequillasymargarinas_W22           1949
# dtype: int64
# Done CMX fonda_PILOTO
# //-------------------------------------------------------------------------------
# Fonda Experimento50%
# 526
# Uso de data externa
# 20230601_CMX_fonda_control_NB_azucaryendulzantes_W22                318
# 20230601_CMX_fonda_control_NB_aceitesygrasas_W22                    360
# 20230601_CMX_fonda_control_NB_cafechocolateeinfusiones_W22          482
# 20230601_CMX_fonda_control_NB_enlatados_W22                         445
# 20230601_CMX_fonda_control_NB_salsas_W22                            453
# 20230601_CMX_fonda_control_NB_arroz_W22                             307
# 20230601_CMX_fonda_control_NB_frutossecos_W22                       438
# 20230601_CMX_fonda_control_NB_panaderiaytortilleria_W22             462
# 20230601_CMX_fonda_control_NB_granos_W22                            425
# 20230601_CMX_fonda_control_NB_pasta_W22                             391
# 20230601_CMX_fonda_control_NB_salysazonadores_W22                   408
# 20230601_CMX_fonda_control_NB_chilessecos_W22                       418
# 20230601_CMX_fonda_control_NB_mermeladasyconfituras_W22             521
# 20230601_CMX_fonda_control_NB_papelytoallas_W22                     409
# 20230601_CMX_fonda_control_NB_detergentejabonylavatrastes_W22       391
# 20230601_CMX_fonda_control_NB_desinfectantesysanitizantes_W22       461
# 20230601_CMX_fonda_control_NB_implementosdeaseo_W22                 479
# 20230601_CMX_fonda_control_NB_refrescos_W22                         426
# 20230601_CMX_fonda_control_NB_jugos_W22                             517
# 20230601_CMX_fonda_control_NB_bebidasenergeticasehidratantes_W22    524
# 20230601_CMX_fonda_control_NB_pollo_W22                             486
# 20230601_CMX_fonda_control_NB_embutidos_W22                         473
# 20230601_CMX_fonda_control_NB_cerdo_W22                             473
# 20230601_CMX_fonda_control_NB_res_W22                               478
# 20230601_CMX_fonda_control_NB_alimentoscongelados_W22               481
# 20230601_CMX_fonda_control_NB_vasoscontenedoresyplatos_W22          340
# 20230601_CMX_fonda_control_NB_empaqueyenvoltura_W22                 475
# 20230601_CMX_fonda_control_NB_bolsas_W22                            510
# 20230601_CMX_fonda_control_NB_cubiertos_W22                         463
# 20230601_CMX_fonda_control_NB_verduras_W22                          191
# 20230601_CMX_fonda_control_NB_frutas_W22                            290
# 20230601_CMX_fonda_control_NB_tuberculos_W22                        343
# 20230601_CMX_fonda_control_NB_leches_W22                            422
# 20230601_CMX_fonda_control_NB_derivadoslacteos_W22                  466
# 20230601_CMX_fonda_control_NB_huevos_W22                            442
# 20230601_CMX_fonda_control_NB_cremas_W22                            392
# 20230601_CMX_fonda_control_NB_quesos_W22                            458
# 20230601_CMX_fonda_control_NB_mantequillasymargarinas_W22           486
# dtype: int64
# Done CMX fonda_CONTROL
# //-------------------------------------------------------------------------------
# Cafetería
# 372
# Uso de data externa
# 20230601_CMX_cafeteria_piloto_NB_azucaryendulzantes_W22                215
# 20230601_CMX_cafeteria_piloto_NB_aceitesygrasas_W22                    277
# 20230601_CMX_cafeteria_piloto_NB_cafechocolateeinfusiones_W22          309
# 20230601_CMX_cafeteria_piloto_NB_enlatados_W22                         286
# 20230601_CMX_cafeteria_piloto_NB_salsas_W22                            299
# 20230601_CMX_cafeteria_piloto_NB_arroz_W22                             305
# 20230601_CMX_cafeteria_piloto_NB_frutossecos_W22                       298
# 20230601_CMX_cafeteria_piloto_NB_panaderiaytortilleria_W22             332
# 20230601_CMX_cafeteria_piloto_NB_granos_W22                            320
# 20230601_CMX_cafeteria_piloto_NB_pasta_W22                             330
# 20230601_CMX_cafeteria_piloto_NB_salysazonadores_W22                   312
# 20230601_CMX_cafeteria_piloto_NB_chilessecos_W22                       329
# 20230601_CMX_cafeteria_piloto_NB_mermeladasyconfituras_W22             357
# 20230601_CMX_cafeteria_piloto_NB_papelytoallas_W22                     285
# 20230601_CMX_cafeteria_piloto_NB_detergentejabonylavatrastes_W22       297
# 20230601_CMX_cafeteria_piloto_NB_desinfectantesysanitizantes_W22       294
# 20230601_CMX_cafeteria_piloto_NB_implementosdeaseo_W22                 330
# 20230601_CMX_cafeteria_piloto_NB_refrescos_W22                         243
# 20230601_CMX_cafeteria_piloto_NB_jugos_W22                             362
# 20230601_CMX_cafeteria_piloto_NB_bebidasenergeticasehidratantes_W22    368
# 20230601_CMX_cafeteria_piloto_NB_pollo_W22                             329
# 20230601_CMX_cafeteria_piloto_NB_embutidos_W22                         333
# 20230601_CMX_cafeteria_piloto_NB_cerdo_W22                             349
# 20230601_CMX_cafeteria_piloto_NB_res_W22                               336
# 20230601_CMX_cafeteria_piloto_NB_alimentoscongelados_W22               304
# 20230601_CMX_cafeteria_piloto_NB_vasoscontenedoresyplatos_W22          251
# 20230601_CMX_cafeteria_piloto_NB_empaqueyenvoltura_W22                 353
# 20230601_CMX_cafeteria_piloto_NB_bolsas_W22                            345
# 20230601_CMX_cafeteria_piloto_NB_cubiertos_W22                         325
# 20230601_CMX_cafeteria_piloto_NB_verduras_W22                          151
# 20230601_CMX_cafeteria_piloto_NB_frutas_W22                            182
# 20230601_CMX_cafeteria_piloto_NB_tuberculos_W22                        268
# 20230601_CMX_cafeteria_piloto_NB_leches_W22                            262
# 20230601_CMX_cafeteria_piloto_NB_derivadoslacteos_W22                  301
# 20230601_CMX_cafeteria_piloto_NB_huevos_W22                            319
# 20230601_CMX_cafeteria_piloto_NB_cremas_W22                            294
# 20230601_CMX_cafeteria_piloto_NB_quesos_W22                            310
# 20230601_CMX_cafeteria_piloto_NB_mantequillasymargarinas_W22           334
# dtype: int64
# Done CMX cafeteria_PILOTO
# //-------------------------------------------------------------------------------
# Cafetería Experimento50%
# 93
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)
# Uso de data externa
# 20230601_CMX_cafeteria_control_NB_azucaryendulzantes_W22                62
# 20230601_CMX_cafeteria_control_NB_aceitesygrasas_W22                    70
# 20230601_CMX_cafeteria_control_NB_cafechocolateeinfusiones_W22          77
# 20230601_CMX_cafeteria_control_NB_enlatados_W22                         73
# 20230601_CMX_cafeteria_control_NB_salsas_W22                            70
# 20230601_CMX_cafeteria_control_NB_arroz_W22                             84
# 20230601_CMX_cafeteria_control_NB_frutossecos_W22                       76
# 20230601_CMX_cafeteria_control_NB_panaderiaytortilleria_W22             86
# 20230601_CMX_cafeteria_control_NB_granos_W22                            84
# 20230601_CMX_cafeteria_control_NB_pasta_W22                             86
# 20230601_CMX_cafeteria_control_NB_salysazonadores_W22                   81
# 20230601_CMX_cafeteria_control_NB_chilessecos_W22                       87
# 20230601_CMX_cafeteria_control_NB_mermeladasyconfituras_W22             91
# 20230601_CMX_cafeteria_control_NB_papelytoallas_W22                     69
# 20230601_CMX_cafeteria_control_NB_detergentejabonylavatrastes_W22       74
# 20230601_CMX_cafeteria_control_NB_desinfectantesysanitizantes_W22       77
# 20230601_CMX_cafeteria_control_NB_implementosdeaseo_W22                 81
# 20230601_CMX_cafeteria_control_NB_refrescos_W22                         71
# 20230601_CMX_cafeteria_control_NB_jugos_W22                             92
# 20230601_CMX_cafeteria_control_NB_bebidasenergeticasehidratantes_W22    93
# 20230601_CMX_cafeteria_control_NB_pollo_W22                             81
# 20230601_CMX_cafeteria_control_NB_embutidos_W22                         84
# 20230601_CMX_cafeteria_control_NB_cerdo_W22                             92
# 20230601_CMX_cafeteria_control_NB_res_W22                               88
# 20230601_CMX_cafeteria_control_NB_alimentoscongelados_W22               84
# 20230601_CMX_cafeteria_control_NB_vasoscontenedoresyplatos_W22          65
# 20230601_CMX_cafeteria_control_NB_empaqueyenvoltura_W22                 85
# 20230601_CMX_cafeteria_control_NB_bolsas_W22                            86
# 20230601_CMX_cafeteria_control_NB_cubiertos_W22                         87
# 20230601_CMX_cafeteria_control_NB_verduras_W22                          35
# 20230601_CMX_cafeteria_control_NB_frutas_W22                            45
# 20230601_CMX_cafeteria_control_NB_tuberculos_W22                        69
# 20230601_CMX_cafeteria_control_NB_leches_W22                            63
# 20230601_CMX_cafeteria_control_NB_derivadoslacteos_W22                  76
# 20230601_CMX_cafeteria_control_NB_huevos_W22                            79
# 20230601_CMX_cafeteria_control_NB_cremas_W22                            75
# 20230601_CMX_cafeteria_control_NB_quesos_W22                            81
# 20230601_CMX_cafeteria_control_NB_mantequillasymargarinas_W22           80
# dtype: int64
# Done CMX cafeteria_CONTROL
# //-------------------------------------------------------------------------------
# Comida rápida
# 914
# Uso de data externa
# 20230601_CMX_comidarapida_piloto_NB_azucaryendulzantes_W22                675
# 20230601_CMX_comidarapida_piloto_NB_aceitesygrasas_W22                    663
# 20230601_CMX_comidarapida_piloto_NB_cafechocolateeinfusiones_W22          836
# 20230601_CMX_comidarapida_piloto_NB_enlatados_W22                         734
# 20230601_CMX_comidarapida_piloto_NB_salsas_W22                            699
# 20230601_CMX_comidarapida_piloto_NB_arroz_W22                             779
# 20230601_CMX_comidarapida_piloto_NB_frutossecos_W22                       833
# 20230601_CMX_comidarapida_piloto_NB_panaderiaytortilleria_W22             799
# 20230601_CMX_comidarapida_piloto_NB_granos_W22                            835
# 20230601_CMX_comidarapida_piloto_NB_pasta_W22                             811
# 20230601_CMX_comidarapida_piloto_NB_salysazonadores_W22                   769
# 20230601_CMX_comidarapida_piloto_NB_chilessecos_W22                       790
# 20230601_CMX_comidarapida_piloto_NB_mermeladasyconfituras_W22             899
# 20230601_CMX_comidarapida_piloto_NB_papelytoallas_W22                     700
# 20230601_CMX_comidarapida_piloto_NB_detergentejabonylavatrastes_W22       735
# 20230601_CMX_comidarapida_piloto_NB_desinfectantesysanitizantes_W22       797
# 20230601_CMX_comidarapida_piloto_NB_implementosdeaseo_W22                 808
# 20230601_CMX_comidarapida_piloto_NB_refrescos_W22                         661
# 20230601_CMX_comidarapida_piloto_NB_jugos_W22                             886
# 20230601_CMX_comidarapida_piloto_NB_bebidasenergeticasehidratantes_W22    911
# 20230601_CMX_comidarapida_piloto_NB_pollo_W22                             813
# 20230601_CMX_comidarapida_piloto_NB_embutidos_W22                         792
# 20230601_CMX_comidarapida_piloto_NB_cerdo_W22                             839
# 20230601_CMX_comidarapida_piloto_NB_res_W22                               823
# 20230601_CMX_comidarapida_piloto_NB_alimentoscongelados_W22               761
# 20230601_CMX_comidarapida_piloto_NB_vasoscontenedoresyplatos_W22          618
# 20230601_CMX_comidarapida_piloto_NB_empaqueyenvoltura_W22                 852
# 20230601_CMX_comidarapida_piloto_NB_bolsas_W22                            875
# 20230601_CMX_comidarapida_piloto_NB_cubiertos_W22                         828
# 20230601_CMX_comidarapida_piloto_NB_verduras_W22                          356
# 20230601_CMX_comidarapida_piloto_NB_frutas_W22                            516
# 20230601_CMX_comidarapida_piloto_NB_tuberculos_W22                        632
# 20230601_CMX_comidarapida_piloto_NB_leches_W22                            760
# 20230601_CMX_comidarapida_piloto_NB_derivadoslacteos_W22                  811
# 20230601_CMX_comidarapida_piloto_NB_huevos_W22                            812
# 20230601_CMX_comidarapida_piloto_NB_cremas_W22                            760
# 20230601_CMX_comidarapida_piloto_NB_quesos_W22                            808
# 20230601_CMX_comidarapida_piloto_NB_mantequillasymargarinas_W22           880
# dtype: int64
# Done CMX comidarapida_PILOTO
# //-------------------------------------------------------------------------------
# Comida rápida Experimento50%
# 228
# Uso de data externa
# 20230601_CMX_comidarapida_control_NB_azucaryendulzantes_W22                160
# 20230601_CMX_comidarapida_control_NB_aceitesygrasas_W22                    156
# 20230601_CMX_comidarapida_control_NB_cafechocolateeinfusiones_W22          208
# 20230601_CMX_comidarapida_control_NB_enlatados_W22                         180
# 20230601_CMX_comidarapida_control_NB_salsas_W22                            168
# 20230601_CMX_comidarapida_control_NB_arroz_W22                             200
# 20230601_CMX_comidarapida_control_NB_frutossecos_W22                       203
# 20230601_CMX_comidarapida_control_NB_panaderiaytortilleria_W22             191
# 20230601_CMX_comidarapida_control_NB_granos_W22                            204
# 20230601_CMX_comidarapida_control_NB_pasta_W22                             206
# 20230601_CMX_comidarapida_control_NB_salysazonadores_W22                   188
# 20230601_CMX_comidarapida_control_NB_chilessecos_W22                       207
# 20230601_CMX_comidarapida_control_NB_mermeladasyconfituras_W22             222
# 20230601_CMX_comidarapida_control_NB_papelytoallas_W22                     164
# 20230601_CMX_comidarapida_control_NB_detergentejabonylavatrastes_W22       180
# 20230601_CMX_comidarapida_control_NB_desinfectantesysanitizantes_W22       194
# 20230601_CMX_comidarapida_control_NB_implementosdeaseo_W22                 206
# 20230601_CMX_comidarapida_control_NB_refrescos_W22                         167
# 20230601_CMX_comidarapida_control_NB_jugos_W22                             223
# 20230601_CMX_comidarapida_control_NB_bebidasenergeticasehidratantes_W22    228
# 20230601_CMX_comidarapida_control_NB_pollo_W22                             201
# 20230601_CMX_comidarapida_control_NB_embutidos_W22                         203
# 20230601_CMX_comidarapida_control_NB_cerdo_W22                             213
# 20230601_CMX_comidarapida_control_NB_res_W22                               199
# 20230601_CMX_comidarapida_control_NB_alimentoscongelados_W22               202
# 20230601_CMX_comidarapida_control_NB_vasoscontenedoresyplatos_W22          158
# 20230601_CMX_comidarapida_control_NB_empaqueyenvoltura_W22                 212
# 20230601_CMX_comidarapida_control_NB_bolsas_W22                            218
# 20230601_CMX_comidarapida_control_NB_cubiertos_W22                         208
# 20230601_CMX_comidarapida_control_NB_verduras_W22                           95
# 20230601_CMX_comidarapida_control_NB_frutas_W22                            128
# 20230601_CMX_comidarapida_control_NB_tuberculos_W22                        171
# 20230601_CMX_comidarapida_control_NB_leches_W22                            190
# 20230601_CMX_comidarapida_control_NB_derivadoslacteos_W22                  206
# 20230601_CMX_comidarapida_control_NB_huevos_W22                            206
# 20230601_CMX_comidarapida_control_NB_cremas_W22                            195
# 20230601_CMX_comidarapida_control_NB_quesos_W22                            207
# 20230601_CMX_comidarapida_control_NB_mantequillasymargarinas_W22           218
# dtype: int64
# Done CMX comidarapida_CONTROL
# //-------------------------------------------------------------------------------
# Taquería
# 1824
# Uso de data externa
# 20230601_CMX_taqueria_piloto_NB_azucaryendulzantes_W22                1284
# 20230601_CMX_taqueria_piloto_NB_aceitesygrasas_W22                    1305
# 20230601_CMX_taqueria_piloto_NB_cafechocolateeinfusiones_W22          1680
# 20230601_CMX_taqueria_piloto_NB_enlatados_W22                         1621
# 20230601_CMX_taqueria_piloto_NB_salsas_W22                            1641
# 20230601_CMX_taqueria_piloto_NB_arroz_W22                             1416
# 20230601_CMX_taqueria_piloto_NB_frutossecos_W22                       1610
# 20230601_CMX_taqueria_piloto_NB_panaderiaytortilleria_W22             1670
# 20230601_CMX_taqueria_piloto_NB_granos_W22                            1627
# 20230601_CMX_taqueria_piloto_NB_pasta_W22                             1610
# 20230601_CMX_taqueria_piloto_NB_salysazonadores_W22                   1444
# 20230601_CMX_taqueria_piloto_NB_chilessecos_W22                       1320
# 20230601_CMX_taqueria_piloto_NB_mermeladasyconfituras_W22             1806
# 20230601_CMX_taqueria_piloto_NB_papelytoallas_W22                     1366
# 20230601_CMX_taqueria_piloto_NB_detergentejabonylavatrastes_W22       1425
# 20230601_CMX_taqueria_piloto_NB_desinfectantesysanitizantes_W22       1597
# 20230601_CMX_taqueria_piloto_NB_implementosdeaseo_W22                 1660
# 20230601_CMX_taqueria_piloto_NB_refrescos_W22                         1376
# 20230601_CMX_taqueria_piloto_NB_jugos_W22                             1777
# 20230601_CMX_taqueria_piloto_NB_bebidasenergeticasehidratantes_W22    1816
# 20230601_CMX_taqueria_piloto_NB_pollo_W22                             1673
# 20230601_CMX_taqueria_piloto_NB_embutidos_W22                         1657
# 20230601_CMX_taqueria_piloto_NB_cerdo_W22                             1644
# 20230601_CMX_taqueria_piloto_NB_res_W22                               1658
# 20230601_CMX_taqueria_piloto_NB_alimentoscongelados_W22               1714
# 20230601_CMX_taqueria_piloto_NB_vasoscontenedoresyplatos_W22          1129
# 20230601_CMX_taqueria_piloto_NB_empaqueyenvoltura_W22                 1688
# 20230601_CMX_taqueria_piloto_NB_bolsas_W22                            1748
# 20230601_CMX_taqueria_piloto_NB_cubiertos_W22                         1624
# 20230601_CMX_taqueria_piloto_NB_verduras_W22                           538
# 20230601_CMX_taqueria_piloto_NB_frutas_W22                             909
# 20230601_CMX_taqueria_piloto_NB_tuberculos_W22                        1154
# 20230601_CMX_taqueria_piloto_NB_leches_W22                            1563
# 20230601_CMX_taqueria_piloto_NB_derivadoslacteos_W22                  1580
# 20230601_CMX_taqueria_piloto_NB_huevos_W22                            1649
# 20230601_CMX_taqueria_piloto_NB_cremas_W22                            1491
# 20230601_CMX_taqueria_piloto_NB_quesos_W22                            1660
# 20230601_CMX_taqueria_piloto_NB_mantequillasymargarinas_W22           1767
# dtype: int64
# Done CMX taqueria_PILOTO
# //-------------------------------------------------------------------------------
# Taquería Experimento50%
# 455
# Uso de data externa
# 20230601_CMX_taqueria_control_NB_azucaryendulzantes_W22                330
# 20230601_CMX_taqueria_control_NB_aceitesygrasas_W22                    322
# 20230601_CMX_taqueria_control_NB_cafechocolateeinfusiones_W22          419
# 20230601_CMX_taqueria_control_NB_enlatados_W22                         403
# 20230601_CMX_taqueria_control_NB_salsas_W22                            404
# 20230601_CMX_taqueria_control_NB_arroz_W22                             349
# 20230601_CMX_taqueria_control_NB_frutossecos_W22                       390
# 20230601_CMX_taqueria_control_NB_panaderiaytortilleria_W22             418
# 20230601_CMX_taqueria_control_NB_granos_W22                            391
# 20230601_CMX_taqueria_control_NB_pasta_W22                             400
# 20230601_CMX_taqueria_control_NB_salysazonadores_W22                   357
# 20230601_CMX_taqueria_control_NB_chilessecos_W22                       330
# 20230601_CMX_taqueria_control_NB_mermeladasyconfituras_W22             447
# 20230601_CMX_taqueria_control_NB_papelytoallas_W22                     335
# 20230601_CMX_taqueria_control_NB_detergentejabonylavatrastes_W22       340
# 20230601_CMX_taqueria_control_NB_desinfectantesysanitizantes_W22       395
# 20230601_CMX_taqueria_control_NB_implementosdeaseo_W22                 407
# 20230601_CMX_taqueria_control_NB_refrescos_W22                         341
# 20230601_CMX_taqueria_control_NB_jugos_W22                             443
# 20230601_CMX_taqueria_control_NB_bebidasenergeticasehidratantes_W22    454
# 20230601_CMX_taqueria_control_NB_pollo_W22                             416
# 20230601_CMX_taqueria_control_NB_embutidos_W22                         416
# 20230601_CMX_taqueria_control_NB_cerdo_W22                             414
# 20230601_CMX_taqueria_control_NB_res_W22                               406
# 20230601_CMX_taqueria_control_NB_alimentoscongelados_W22               421
# 20230601_CMX_taqueria_control_NB_vasoscontenedoresyplatos_W22          297
# 20230601_CMX_taqueria_control_NB_empaqueyenvoltura_W22                 429
# 20230601_CMX_taqueria_control_NB_bolsas_W22                            439
# 20230601_CMX_taqueria_control_NB_cubiertos_W22                         423
# 20230601_CMX_taqueria_control_NB_verduras_W22                          135
# 20230601_CMX_taqueria_control_NB_frutas_W22                            213
# 20230601_CMX_taqueria_control_NB_tuberculos_W22                        279
# 20230601_CMX_taqueria_control_NB_leches_W22                            393
# 20230601_CMX_taqueria_control_NB_derivadoslacteos_W22                  404
# 20230601_CMX_taqueria_control_NB_huevos_W22                            406
# 20230601_CMX_taqueria_control_NB_cremas_W22                            372
# 20230601_CMX_taqueria_control_NB_quesos_W22                            397
# 20230601_CMX_taqueria_control_NB_mantequillasymargarinas_W22           430
# dtype: int64
# Done CMX taqueria_CONTROL
# //-------------------------------------------------------------------------------
# Other
# 468
# Uso de data externa
# 20230601_CMX_other_piloto_NB_azucaryendulzantes_W22                283
# 20230601_CMX_other_piloto_NB_aceitesygrasas_W22                    339
# 20230601_CMX_other_piloto_NB_cafechocolateeinfusiones_W22          426
# 20230601_CMX_other_piloto_NB_enlatados_W22                         367
# 20230601_CMX_other_piloto_NB_salsas_W22                            373
# 20230601_CMX_other_piloto_NB_arroz_W22                             356
# 20230601_CMX_other_piloto_NB_frutossecos_W22                       344
# 20230601_CMX_other_piloto_NB_panaderiaytortilleria_W22             394
# 20230601_CMX_other_piloto_NB_granos_W22                            369
# 20230601_CMX_other_piloto_NB_pasta_W22                             396
# 20230601_CMX_other_piloto_NB_salysazonadores_W22                   369
# 20230601_CMX_other_piloto_NB_chilessecos_W22                       336
# 20230601_CMX_other_piloto_NB_mermeladasyconfituras_W22             452
# 20230601_CMX_other_piloto_NB_papelytoallas_W22                     357
# 20230601_CMX_other_piloto_NB_detergentejabonylavatrastes_W22       361
# 20230601_CMX_other_piloto_NB_desinfectantesysanitizantes_W22       390
# 20230601_CMX_other_piloto_NB_implementosdeaseo_W22                 422
# 20230601_CMX_other_piloto_NB_refrescos_W22                         360
# 20230601_CMX_other_piloto_NB_jugos_W22                             439
# 20230601_CMX_other_piloto_NB_bebidasenergeticasehidratantes_W22    467
# 20230601_CMX_other_piloto_NB_pollo_W22                             405
# 20230601_CMX_other_piloto_NB_embutidos_W22                         398
# 20230601_CMX_other_piloto_NB_cerdo_W22                             420
# 20230601_CMX_other_piloto_NB_res_W22                               405
# 20230601_CMX_other_piloto_NB_alimentoscongelados_W22               387
# 20230601_CMX_other_piloto_NB_vasoscontenedoresyplatos_W22          321
# 20230601_CMX_other_piloto_NB_empaqueyenvoltura_W22                 425
# 20230601_CMX_other_piloto_NB_bolsas_W22                            423
# 20230601_CMX_other_piloto_NB_cubiertos_W22                         413
# 20230601_CMX_other_piloto_NB_verduras_W22                          123
# 20230601_CMX_other_piloto_NB_frutas_W22                            164
# 20230601_CMX_other_piloto_NB_tuberculos_W22                        248
# 20230601_CMX_other_piloto_NB_leches_W22                            382
# 20230601_CMX_other_piloto_NB_derivadoslacteos_W22                  380
# 20230601_CMX_other_piloto_NB_huevos_W22                            372
# 20230601_CMX_other_piloto_NB_cremas_W22                            342
# 20230601_CMX_other_piloto_NB_quesos_W22                            377
# 20230601_CMX_other_piloto_NB_mantequillasymargarinas_W22           412
# dtype: int64
# Done CMX other_PILOTO
# //-------------------------------------------------------------------------------
# Other Experimento50%
# 116
# Uso de data externa
# 20230601_CMX_other_control_NB_azucaryendulzantes_W22                 49
# 20230601_CMX_other_control_NB_aceitesygrasas_W22                     72
# 20230601_CMX_other_control_NB_cafechocolateeinfusiones_W22          102
# 20230601_CMX_other_control_NB_enlatados_W22                          92
# 20230601_CMX_other_control_NB_salsas_W22                             88
# 20230601_CMX_other_control_NB_arroz_W22                              79
# 20230601_CMX_other_control_NB_frutossecos_W22                        83
# 20230601_CMX_other_control_NB_panaderiaytortilleria_W22              99
# 20230601_CMX_other_control_NB_granos_W22                             85
# 20230601_CMX_other_control_NB_pasta_W22                              96
# 20230601_CMX_other_control_NB_salysazonadores_W22                    80
# 20230601_CMX_other_control_NB_chilessecos_W22                        87
# 20230601_CMX_other_control_NB_mermeladasyconfituras_W22             112
# 20230601_CMX_other_control_NB_papelytoallas_W22                      92
# 20230601_CMX_other_control_NB_detergentejabonylavatrastes_W22        83
# 20230601_CMX_other_control_NB_desinfectantesysanitizantes_W22        92
# 20230601_CMX_other_control_NB_implementosdeaseo_W22                  96
# 20230601_CMX_other_control_NB_refrescos_W22                          94
# 20230601_CMX_other_control_NB_jugos_W22                             113
# 20230601_CMX_other_control_NB_bebidasenergeticasehidratantes_W22    116
# 20230601_CMX_other_control_NB_pollo_W22                              96
# 20230601_CMX_other_control_NB_embutidos_W22                          99
# 20230601_CMX_other_control_NB_cerdo_W22                             101
# 20230601_CMX_other_control_NB_res_W22                                99
# 20230601_CMX_other_control_NB_alimentoscongelados_W22                95
# 20230601_CMX_other_control_NB_vasoscontenedoresyplatos_W22           85
# 20230601_CMX_other_control_NB_empaqueyenvoltura_W22                 101
# 20230601_CMX_other_control_NB_bolsas_W22                            106
# 20230601_CMX_other_control_NB_cubiertos_W22                         106
# 20230601_CMX_other_control_NB_verduras_W22                           38
# 20230601_CMX_other_control_NB_frutas_W22                             42
# 20230601_CMX_other_control_NB_tuberculos_W22                         66
# 20230601_CMX_other_control_NB_leches_W22                             86
# 20230601_CMX_other_control_NB_derivadoslacteos_W22                   92
# 20230601_CMX_other_control_NB_huevos_W22                             92
# 20230601_CMX_other_control_NB_cremas_W22                             81
# 20230601_CMX_other_control_NB_quesos_W22                             94
# 20230601_CMX_other_control_NB_mantequillasymargarinas_W22           101
# dtype: int64
# Done CMX other_CONTROL
# //-------------------------------------------------------------------------------
# Panadería/Pastelería
# 825
# Uso de data externa
# 20230601_CMX_panaderiapasteleria_piloto_NB_azucaryendulzantes_W22                342
# 20230601_CMX_panaderiapasteleria_piloto_NB_aceitesygrasas_W22                    637
# 20230601_CMX_panaderiapasteleria_piloto_NB_cafechocolateeinfusiones_W22          760
# 20230601_CMX_panaderiapasteleria_piloto_NB_enlatados_W22                         742
# 20230601_CMX_panaderiapasteleria_piloto_NB_salsas_W22                            770
# 20230601_CMX_panaderiapasteleria_piloto_NB_arroz_W22                             749
# 20230601_CMX_panaderiapasteleria_piloto_NB_frutossecos_W22                       743
# 20230601_CMX_panaderiapasteleria_piloto_NB_panaderiaytortilleria_W22             798
# 20230601_CMX_panaderiapasteleria_piloto_NB_granos_W22                            798
# 20230601_CMX_panaderiapasteleria_piloto_NB_pasta_W22                             774
# 20230601_CMX_panaderiapasteleria_piloto_NB_salysazonadores_W22                   763
# 20230601_CMX_panaderiapasteleria_piloto_NB_chilessecos_W22                       778
# 20230601_CMX_panaderiapasteleria_piloto_NB_mermeladasyconfituras_W22             815
# 20230601_CMX_panaderiapasteleria_piloto_NB_papelytoallas_W22                     685
# 20230601_CMX_panaderiapasteleria_piloto_NB_detergentejabonylavatrastes_W22       682
# 20230601_CMX_panaderiapasteleria_piloto_NB_desinfectantesysanitizantes_W22       718
# 20230601_CMX_panaderiapasteleria_piloto_NB_implementosdeaseo_W22                 736
# 20230601_CMX_panaderiapasteleria_piloto_NB_refrescos_W22                         725
# 20230601_CMX_panaderiapasteleria_piloto_NB_jugos_W22                             816
# 20230601_CMX_panaderiapasteleria_piloto_NB_bebidasenergeticasehidratantes_W22    823
# 20230601_CMX_panaderiapasteleria_piloto_NB_pollo_W22                             792
# 20230601_CMX_panaderiapasteleria_piloto_NB_embutidos_W22                         784
# 20230601_CMX_panaderiapasteleria_piloto_NB_cerdo_W22                             799
# 20230601_CMX_panaderiapasteleria_piloto_NB_res_W22                               796
# 20230601_CMX_panaderiapasteleria_piloto_NB_alimentoscongelados_W22               795
# 20230601_CMX_panaderiapasteleria_piloto_NB_vasoscontenedoresyplatos_W22          701
# 20230601_CMX_panaderiapasteleria_piloto_NB_empaqueyenvoltura_W22                 802
# 20230601_CMX_panaderiapasteleria_piloto_NB_bolsas_W22                            800
# 20230601_CMX_panaderiapasteleria_piloto_NB_cubiertos_W22                         775
# 20230601_CMX_panaderiapasteleria_piloto_NB_verduras_W22                          544
# 20230601_CMX_panaderiapasteleria_piloto_NB_frutas_W22                            595
# 20230601_CMX_panaderiapasteleria_piloto_NB_tuberculos_W22                        731
# 20230601_CMX_panaderiapasteleria_piloto_NB_leches_W22                            629
# 20230601_CMX_panaderiapasteleria_piloto_NB_derivadoslacteos_W22                  679
# 20230601_CMX_panaderiapasteleria_piloto_NB_huevos_W22                            641
# 20230601_CMX_panaderiapasteleria_piloto_NB_cremas_W22                            747
# 20230601_CMX_panaderiapasteleria_piloto_NB_quesos_W22                            764
# 20230601_CMX_panaderiapasteleria_piloto_NB_mantequillasymargarinas_W22           778
# dtype: int64
# Done CMX panaderiapasteleria_PILOTO
# //-------------------------------------------------------------------------------
# Panadería/Pastelería Experimento50%
# 206
# Uso de data externa
# 20230601_CMX_panaderiapasteleria_control_NB_azucaryendulzantes_W22                 85
# 20230601_CMX_panaderiapasteleria_control_NB_aceitesygrasas_W22                    153
# 20230601_CMX_panaderiapasteleria_control_NB_cafechocolateeinfusiones_W22          187
# 20230601_CMX_panaderiapasteleria_control_NB_enlatados_W22                         188
# 20230601_CMX_panaderiapasteleria_control_NB_salsas_W22                            190
# 20230601_CMX_panaderiapasteleria_control_NB_arroz_W22                             183
# 20230601_CMX_panaderiapasteleria_control_NB_frutossecos_W22                       187
# 20230601_CMX_panaderiapasteleria_control_NB_panaderiaytortilleria_W22             199
# 20230601_CMX_panaderiapasteleria_control_NB_granos_W22                            197
# 20230601_CMX_panaderiapasteleria_control_NB_pasta_W22                             189
# 20230601_CMX_panaderiapasteleria_control_NB_salysazonadores_W22                   189
# 20230601_CMX_panaderiapasteleria_control_NB_chilessecos_W22                       192
# 20230601_CMX_panaderiapasteleria_control_NB_mermeladasyconfituras_W22             204
# 20230601_CMX_panaderiapasteleria_control_NB_papelytoallas_W22                     178
# 20230601_CMX_panaderiapasteleria_control_NB_detergentejabonylavatrastes_W22       173
# 20230601_CMX_panaderiapasteleria_control_NB_desinfectantesysanitizantes_W22       182
# 20230601_CMX_panaderiapasteleria_control_NB_implementosdeaseo_W22                 187
# 20230601_CMX_panaderiapasteleria_control_NB_refrescos_W22                         178
# 20230601_CMX_panaderiapasteleria_control_NB_jugos_W22                             202
# 20230601_CMX_panaderiapasteleria_control_NB_bebidasenergeticasehidratantes_W22    206
# 20230601_CMX_panaderiapasteleria_control_NB_pollo_W22                             197
# 20230601_CMX_panaderiapasteleria_control_NB_embutidos_W22                         201
# 20230601_CMX_panaderiapasteleria_control_NB_cerdo_W22                             201
# 20230601_CMX_panaderiapasteleria_control_NB_res_W22                               197
# 20230601_CMX_panaderiapasteleria_control_NB_alimentoscongelados_W22               195
# 20230601_CMX_panaderiapasteleria_control_NB_vasoscontenedoresyplatos_W22          168
# 20230601_CMX_panaderiapasteleria_control_NB_empaqueyenvoltura_W22                 195
# 20230601_CMX_panaderiapasteleria_control_NB_bolsas_W22                            200
# 20230601_CMX_panaderiapasteleria_control_NB_cubiertos_W22                         192
# 20230601_CMX_panaderiapasteleria_control_NB_verduras_W22                          118
# 20230601_CMX_panaderiapasteleria_control_NB_frutas_W22                            152
# 20230601_CMX_panaderiapasteleria_control_NB_tuberculos_W22                        180
# 20230601_CMX_panaderiapasteleria_control_NB_leches_W22                            163
# 20230601_CMX_panaderiapasteleria_control_NB_derivadoslacteos_W22                  169
# 20230601_CMX_panaderiapasteleria_control_NB_huevos_W22                            167
# 20230601_CMX_panaderiapasteleria_control_NB_cremas_W22                            189
# 20230601_CMX_panaderiapasteleria_control_NB_quesos_W22                            194
# 20230601_CMX_panaderiapasteleria_control_NB_mantequillasymargarinas_W22           191
# dtype: int64
# Done CMX panaderiapasteleria_CONTROL
# //-------------------------------------------------------------------------------
# Juguería/Comida saludable
# 663
# Uso de data externa
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_azucaryendulzantes_W22                293
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_aceitesygrasas_W22                    557
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_cafechocolateeinfusiones_W22          595
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_enlatados_W22                         586
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_salsas_W22                            593
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_arroz_W22                             575
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_frutossecos_W22                       535
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_panaderiaytortilleria_W22             630
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_granos_W22                            592
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_pasta_W22                             595
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_salysazonadores_W22                   604
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_chilessecos_W22                       605
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_mermeladasyconfituras_W22             653
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_papelytoallas_W22                     543
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_detergentejabonylavatrastes_W22       538
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_desinfectantesysanitizantes_W22       567
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_implementosdeaseo_W22                 612
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_refrescos_W22                         555
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_jugos_W22                             649
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_bebidasenergeticasehidratantes_W22    659
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_pollo_W22                             633
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_embutidos_W22                         622
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_cerdo_W22                             641
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_res_W22                               638
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_alimentoscongelados_W22               625
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_vasoscontenedoresyplatos_W22          418
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_empaqueyenvoltura_W22                 649
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_bolsas_W22                            644
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_cubiertos_W22                         623
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_verduras_W22                          359
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_frutas_W22                            431
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_tuberculos_W22                        529
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_leches_W22                            521
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_derivadoslacteos_W22                  545
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_huevos_W22                            605
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_cremas_W22                            584
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_quesos_W22                            612
# 20230601_CMX_jugueriacomidasaludable_piloto_NB_mantequillasymargarinas_W22           645
# dtype: int64
# Done CMX jugueriacomidasaludable_PILOTO
# //-------------------------------------------------------------------------------
# Juguería/Comida saludable Experimento50%
# 165
# Uso de data externa
# 20230601_CMX_jugueriacomidasaludable_control_NB_azucaryendulzantes_W22                 79
# 20230601_CMX_jugueriacomidasaludable_control_NB_aceitesygrasas_W22                    132
# 20230601_CMX_jugueriacomidasaludable_control_NB_cafechocolateeinfusiones_W22          150
# 20230601_CMX_jugueriacomidasaludable_control_NB_enlatados_W22                         138
# 20230601_CMX_jugueriacomidasaludable_control_NB_salsas_W22                            145
# 20230601_CMX_jugueriacomidasaludable_control_NB_arroz_W22                             144
# 20230601_CMX_jugueriacomidasaludable_control_NB_frutossecos_W22                       136
# 20230601_CMX_jugueriacomidasaludable_control_NB_panaderiaytortilleria_W22             157
# 20230601_CMX_jugueriacomidasaludable_control_NB_granos_W22                            140
# 20230601_CMX_jugueriacomidasaludable_control_NB_pasta_W22                             148
# 20230601_CMX_jugueriacomidasaludable_control_NB_salysazonadores_W22                   150
# 20230601_CMX_jugueriacomidasaludable_control_NB_chilessecos_W22                       152
# 20230601_CMX_jugueriacomidasaludable_control_NB_mermeladasyconfituras_W22             160
# 20230601_CMX_jugueriacomidasaludable_control_NB_papelytoallas_W22                     130
# 20230601_CMX_jugueriacomidasaludable_control_NB_detergentejabonylavatrastes_W22       140
# 20230601_CMX_jugueriacomidasaludable_control_NB_desinfectantesysanitizantes_W22       138
# 20230601_CMX_jugueriacomidasaludable_control_NB_implementosdeaseo_W22                 151
# 20230601_CMX_jugueriacomidasaludable_control_NB_refrescos_W22                         140
# 20230601_CMX_jugueriacomidasaludable_control_NB_jugos_W22                             161
# 20230601_CMX_jugueriacomidasaludable_control_NB_bebidasenergeticasehidratantes_W22    163
# 20230601_CMX_jugueriacomidasaludable_control_NB_pollo_W22                             155
# 20230601_CMX_jugueriacomidasaludable_control_NB_embutidos_W22                         155
# 20230601_CMX_jugueriacomidasaludable_control_NB_cerdo_W22                             155
# 20230601_CMX_jugueriacomidasaludable_control_NB_res_W22                               155
# 20230601_CMX_jugueriacomidasaludable_control_NB_alimentoscongelados_W22               154
# 20230601_CMX_jugueriacomidasaludable_control_NB_vasoscontenedoresyplatos_W22          114
# 20230601_CMX_jugueriacomidasaludable_control_NB_empaqueyenvoltura_W22                 157
# 20230601_CMX_jugueriacomidasaludable_control_NB_bolsas_W22                            162
# 20230601_CMX_jugueriacomidasaludable_control_NB_cubiertos_W22                         149
# 20230601_CMX_jugueriacomidasaludable_control_NB_verduras_W22                           97
# 20230601_CMX_jugueriacomidasaludable_control_NB_frutas_W22                            113
# 20230601_CMX_jugueriacomidasaludable_control_NB_tuberculos_W22                        135
# 20230601_CMX_jugueriacomidasaludable_control_NB_leches_W22                            125
# 20230601_CMX_jugueriacomidasaludable_control_NB_derivadoslacteos_W22                  139
# 20230601_CMX_jugueriacomidasaludable_control_NB_huevos_W22                            152
# 20230601_CMX_jugueriacomidasaludable_control_NB_cremas_W22                            143
# 20230601_CMX_jugueriacomidasaludable_control_NB_quesos_W22                            150
# 20230601_CMX_jugueriacomidasaludable_control_NB_mantequillasymargarinas_W22           160
# dtype: int64
# Done CMX jugueriacomidasaludable_CONTROL
# //-------------------------------------------------------------------------------
# Comida especializada
# 590
# Uso de data externa
# 20230601_CMX_comidaespecializada_piloto_NB_azucaryendulzantes_W22                361
# 20230601_CMX_comidaespecializada_piloto_NB_aceitesygrasas_W22                    420
# 20230601_CMX_comidaespecializada_piloto_NB_cafechocolateeinfusiones_W22          537
# 20230601_CMX_comidaespecializada_piloto_NB_enlatados_W22                         514
# 20230601_CMX_comidaespecializada_piloto_NB_salsas_W22                            459
# 20230601_CMX_comidaespecializada_piloto_NB_arroz_W22                             453
# 20230601_CMX_comidaespecializada_piloto_NB_frutossecos_W22                       512
# 20230601_CMX_comidaespecializada_piloto_NB_panaderiaytortilleria_W22             548
# 20230601_CMX_comidaespecializada_piloto_NB_granos_W22                            527
# 20230601_CMX_comidaespecializada_piloto_NB_pasta_W22                             522
# 20230601_CMX_comidaespecializada_piloto_NB_salysazonadores_W22                   494
# 20230601_CMX_comidaespecializada_piloto_NB_chilessecos_W22                       504
# 20230601_CMX_comidaespecializada_piloto_NB_mermeladasyconfituras_W22             584
# 20230601_CMX_comidaespecializada_piloto_NB_papelytoallas_W22                     455
# 20230601_CMX_comidaespecializada_piloto_NB_detergentejabonylavatrastes_W22       454
# 20230601_CMX_comidaespecializada_piloto_NB_desinfectantesysanitizantes_W22       510
# 20230601_CMX_comidaespecializada_piloto_NB_implementosdeaseo_W22                 523
# 20230601_CMX_comidaespecializada_piloto_NB_refrescos_W22                         458
# 20230601_CMX_comidaespecializada_piloto_NB_jugos_W22                             554
# 20230601_CMX_comidaespecializada_piloto_NB_bebidasenergeticasehidratantes_W22    588
# 20230601_CMX_comidaespecializada_piloto_NB_pollo_W22                             545
# 20230601_CMX_comidaespecializada_piloto_NB_embutidos_W22                         537
# 20230601_CMX_comidaespecializada_piloto_NB_cerdo_W22                             540
# 20230601_CMX_comidaespecializada_piloto_NB_res_W22                               539
# 20230601_CMX_comidaespecializada_piloto_NB_alimentoscongelados_W22               546
# 20230601_CMX_comidaespecializada_piloto_NB_vasoscontenedoresyplatos_W22          403
# 20230601_CMX_comidaespecializada_piloto_NB_empaqueyenvoltura_W22                 545
# 20230601_CMX_comidaespecializada_piloto_NB_bolsas_W22                            561
# 20230601_CMX_comidaespecializada_piloto_NB_cubiertos_W22                         535
# 20230601_CMX_comidaespecializada_piloto_NB_verduras_W22                          268
# 20230601_CMX_comidaespecializada_piloto_NB_frutas_W22                            338
# 20230601_CMX_comidaespecializada_piloto_NB_tuberculos_W22                        440
# 20230601_CMX_comidaespecializada_piloto_NB_leches_W22                            494
# 20230601_CMX_comidaespecializada_piloto_NB_derivadoslacteos_W22                  499
# 20230601_CMX_comidaespecializada_piloto_NB_huevos_W22                            522
# 20230601_CMX_comidaespecializada_piloto_NB_cremas_W22                            493
# 20230601_CMX_comidaespecializada_piloto_NB_quesos_W22                            523
# 20230601_CMX_comidaespecializada_piloto_NB_mantequillasymargarinas_W22           556
# dtype: int64
# Done CMX comidaespecializada_PILOTO
# //-------------------------------------------------------------------------------
# Comida especializada Experimento50%
# 147
# Uso de data externa
# 20230601_CMX_comidaespecializada_control_NB_azucaryendulzantes_W22                 81
# 20230601_CMX_comidaespecializada_control_NB_aceitesygrasas_W22                    101
# 20230601_CMX_comidaespecializada_control_NB_cafechocolateeinfusiones_W22          136
# 20230601_CMX_comidaespecializada_control_NB_enlatados_W22                         127
# 20230601_CMX_comidaespecializada_control_NB_salsas_W22                            118
# 20230601_CMX_comidaespecializada_control_NB_arroz_W22                             116
# 20230601_CMX_comidaespecializada_control_NB_frutossecos_W22                       127
# 20230601_CMX_comidaespecializada_control_NB_panaderiaytortilleria_W22             134
# 20230601_CMX_comidaespecializada_control_NB_granos_W22                            135
# 20230601_CMX_comidaespecializada_control_NB_pasta_W22                             128
# 20230601_CMX_comidaespecializada_control_NB_salysazonadores_W22                   118
# 20230601_CMX_comidaespecializada_control_NB_chilessecos_W22                       125
# 20230601_CMX_comidaespecializada_control_NB_mermeladasyconfituras_W22             143
# 20230601_CMX_comidaespecializada_control_NB_papelytoallas_W22                     115
# 20230601_CMX_comidaespecializada_control_NB_detergentejabonylavatrastes_W22       107
# 20230601_CMX_comidaespecializada_control_NB_desinfectantesysanitizantes_W22       122
# 20230601_CMX_comidaespecializada_control_NB_implementosdeaseo_W22                 134
# 20230601_CMX_comidaespecializada_control_NB_refrescos_W22                         117
# 20230601_CMX_comidaespecializada_control_NB_jugos_W22                             140
# 20230601_CMX_comidaespecializada_control_NB_bebidasenergeticasehidratantes_W22    144
# 20230601_CMX_comidaespecializada_control_NB_pollo_W22                             125
# 20230601_CMX_comidaespecializada_control_NB_embutidos_W22                         131
# 20230601_CMX_comidaespecializada_control_NB_cerdo_W22                             132
# 20230601_CMX_comidaespecializada_control_NB_res_W22                               127
# 20230601_CMX_comidaespecializada_control_NB_alimentoscongelados_W22               128
# 20230601_CMX_comidaespecializada_control_NB_vasoscontenedoresyplatos_W22           98
# 20230601_CMX_comidaespecializada_control_NB_empaqueyenvoltura_W22                 137
# 20230601_CMX_comidaespecializada_control_NB_bolsas_W22                            141
# 20230601_CMX_comidaespecializada_control_NB_cubiertos_W22                         136
# 20230601_CMX_comidaespecializada_control_NB_verduras_W22                           61
# 20230601_CMX_comidaespecializada_control_NB_frutas_W22                             80
# 20230601_CMX_comidaespecializada_control_NB_tuberculos_W22                        107
# 20230601_CMX_comidaespecializada_control_NB_leches_W22                            118
# 20230601_CMX_comidaespecializada_control_NB_derivadoslacteos_W22                  129
# 20230601_CMX_comidaespecializada_control_NB_huevos_W22                            133
# 20230601_CMX_comidaespecializada_control_NB_cremas_W22                            116
# 20230601_CMX_comidaespecializada_control_NB_quesos_W22                            127
# 20230601_CMX_comidaespecializada_control_NB_mantequillasymargarinas_W22           132
# dtype: int64
# Done CMX comidaespecializada_CONTROL

# %% [markdown]
# ## Aca creo el archivo para R&D

# %%
# customers =  pd.DataFrame()
# for column,i in enumerate(aux_df.columns):
#     #if ('verduras' in i or 'frutas' in i or 'arroz' in i or 'aceitesygrasas' in i or 'harinasymezclas' in i or 'azucaryendulzantes' in i or 'pollo' in i or 'huevos' in i) and not 'frutasjugo' in i:
#     #if ('verduras' in i or 'frutas' in i) and not 'frutasjugo' in i:
#     customers[i] = aux_df[i]

# %%
# customers.iloc[:6000].to_csv(f'SD/export_data/MS/csv_{city_code}_CLIENTS_PRUEBA_R&D.csv', index = False)

# with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
#        json.dump(global_segment_list, outfile)

# %%
# aux_seg = pd.read_csv(f"prueba_tuberculos_BAQ.csv")
# aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

# aux_seg["final_group2"] = ["piloto" if x == "Super Descuentos" else "control" for x in aux_seg.grupos]
# aux_seg['offer_name'] = f"20230301_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W9"

# aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()

# %%
# lst = []
# for x in aux_seg2.values:
#     h = {'name':x[0], 'customersIds': list(x[1])}
#     lst.append(h)
    
# for x in lst:
#     print(x['name'])
#     #break
#     for i,value in enumerate(global_segment_list):
#         if value['name'] == x['name']:
#             global_segment_list[i]['customersIds'] = x['customersIds']
#             print(i)

# %%
aux_seg = pd.read_csv(f"csv_{city_code}_CLIENTS_FINAL_JUNIO_R&D.csv")
aux_seg["customer_source_id"] = aux_seg.customer_source_id.astype(int)

aux_seg["final_group2"] = ["piloto" if x == "Treatment" else "control" for x in aux_seg.final_group]
aux_seg['offer_name'] = f"20230601_{city_code}_" + aux_seg.ms + "_" + aux_seg.final_group2 + "_NB_" + aux_seg.subcategory + "_W22"

aux_seg["quartile"] = ["Q0" if x == "-" else x for x in aux_seg.quartile.values]
aux_seg["quartile_name"] = f"20230601_{city_code}_" + aux_seg.subcategory + "_" + aux_seg.quartile + "_" + aux_seg.case

aux_seg2 = aux_seg.groupby(by = ["offer_name"])["customer_source_id"].apply(list).reset_index()
aux_seg3 = aux_seg.groupby(by = ["quartile_name"])["customer_source_id"].apply(list).reset_index()

# %%
aux_seg.head()
# Out:
#       subcategory  customer_source_id                       ms previous_group  \
# 0  aceitesygrasas           145442408                 taqueria      Treatment
# 1  aceitesygrasas           171245164                    fonda        Control
# 2  aceitesygrasas            23872702                    other      Treatment
# 3  aceitesygrasas            36394617  jugueriacomidasaludable        Control
# 4  aceitesygrasas           141686067      comidaespecializada      Treatment
#
#          case quartile  random final_group final_group2  \
# 0  positivity       Q4       0   Treatment       piloto
# 1  positivity       Q4       1     Control      control
# 2  positivity       Q4       0   Treatment       piloto
# 3  positivity       Q4       0   Treatment       piloto
# 4  positivity       Q4       0   Treatment       piloto
#
#                                           offer_name  \
# 0  20230601_CMX_taqueria_piloto_NB_aceitesygrasas...
# 1   20230601_CMX_fonda_control_NB_aceitesygrasas_W22
# 2    20230601_CMX_other_piloto_NB_aceitesygrasas_W22
# 3  20230601_CMX_jugueriacomidasaludable_piloto_NB...
# 4  20230601_CMX_comidaespecializada_piloto_NB_ace...
#
#                                quartile_name
# 0  20230601_CMX_aceitesygrasas_Q4_positivity
# 1  20230601_CMX_aceitesygrasas_Q4_positivity
# 2  20230601_CMX_aceitesygrasas_Q4_positivity
# 3  20230601_CMX_aceitesygrasas_Q4_positivity
# 4  20230601_CMX_aceitesygrasas_Q4_positivity

# %%
lst = []
for x in aux_seg2.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst.append(h)

global_segment_list = lst

# %%
lst2 = []
for x in aux_seg3.values:
    h = {'name':x[0], 'customersIds': list(x[1])}
    lst2.append(h)

# %% [markdown]
# # Aca tengo que volver a cargar el archivo de arriba y dejarlo como lista para traer lo otro

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230601_CMX_fonda_piloto_NB_azucaryendulzante...
# 1    20230601_CMX_fonda_piloto_NB_aceitesygrasas_W22
# 2  20230601_CMX_fonda_piloto_NB_cafechocolateeinf...
# 3         20230601_CMX_fonda_piloto_NB_enlatados_W22
# 4            20230601_CMX_fonda_piloto_NB_salsas_W22
#
#                           offer_description  discount  \
# 0        fonda_piloto_NB_azucaryendulzantes         3
# 1            fonda_piloto_NB_aceitesygrasas         7
# 2  fonda_piloto_NB_cafechocolateeinfusiones         7
# 3                 fonda_piloto_NB_enlatados         8
# 4                    fonda_piloto_NB_salsas         6
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                  15
# 1                         true  01-06-2023  30-06-2023                  20
# 2                         true  01-06-2023  30-06-2023                  18
# 3                         true  01-06-2023  30-06-2023                  20
# 4                         true  01-06-2023  30-06-2023                  15
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1                None
# 1                      1                None
# 2                      1                None
# 3                      1                None
# 4                      1                None
#
#                                               sku_id
# 0                                66553#101151#101175
# 1   101239#-303954#117709#117707#368168#622099#54288
# 2                  26031#377839#628110#313259#313251
# 3  359342#359346#359344#359348#134385#126703#1267...
# 4                    92952#37434#440374#342267#56316

# %%
#len_seg =int(len(global_segment_list)/10)
#len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %% [markdown]
# ## Crear segments offers y segments types

# %%
import requests
import json

def create_segments(segment_list):
    
    url = f"https://{city_code}.frubana.com/api/v1/segments/create?api-key=00_growth-team-zzz-qqq_001"

    payload = json.dumps(segment_list)


    headers = {
    'Cookie': 'AWSALB=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALBCORS=WGKrKvA1CFOY0m92xSENGAseuE4LrcfQh9y8jK/loGBJdizNm+FvjOqUqVghxdfLkH6Jsa9sfWft2NELchGAP/LNZMXMYhrOE70qDnUuOHATpdJj1UZBMEUBSIN1; AWSALB=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI; AWSALBCORS=jLY02FPysvF1vTrKLhXbk3ibzmyiAqFJ1ezYVu5PjodkU2QmPHDpRJhb9CvOlOyQ1Ix0mJR1ig+eH9zwJ9i5EOtgsgx79NSROogQb2Ua6yLX/I3bJJ6xtcVO3puI',
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.status_code)
    sgt = [(int(x[:6]),x[7:]) for x in list(map(str.strip, response.text[32:].strip('][').replace('"', '').split(',')))]
    time.sleep(60)
    return sgt

# %%
len_seg =int(len(global_segment_list)/10)
len_seg_list = [global_segment_list[:len_seg],global_segment_list[len_seg:len_seg*2],global_segment_list[len_seg*2:len_seg*3],global_segment_list[len_seg*3:len_seg*4],global_segment_list[len_seg*4:len_seg*5],global_segment_list[len_seg*5:len_seg*6],global_segment_list[len_seg*6:len_seg*7],global_segment_list[len_seg*7:len_seg*8],global_segment_list[len_seg*8:len_seg*9],global_segment_list[len_seg*9:]]

# %%
#offers
sgt=[]

for i in len_seg_list:
    sgt.append(create_segments(i))
    
sgt_end =[item for lista in sgt for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len_seg2 =int(len(lst2)/10)
len_seg_list2 = [lst2[:len_seg2],lst2[len_seg2:len_seg2*2],lst2[len_seg2*2:len_seg2*3],lst2[len_seg2*3:len_seg2*4],lst2[len_seg2*4:len_seg2*5],lst2[len_seg2*5:len_seg2*6],lst2[len_seg2*6:len_seg2*7],lst2[len_seg2*7:len_seg2*8],lst2[len_seg2*8:len_seg2*9],lst2[len_seg2*9:]]

# %%
#types
sgt2=[]

for i in len_seg_list2:
    sgt2.append(create_segments(i))
    
sgt_end2 =[item for lista in sgt2 for item in lista]
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#unir offers con segments
for i in global_offer_csv.offer_name:
    for j,z in sgt_end:
        if z==i:
            global_offer_csv.loc[global_offer_csv.offer_name == i, ('customer_segment_id')] = j

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230601_CMX_fonda_piloto_NB_azucaryendulzante...
# 1    20230601_CMX_fonda_piloto_NB_aceitesygrasas_W22
# 2  20230601_CMX_fonda_piloto_NB_cafechocolateeinf...
# 3         20230601_CMX_fonda_piloto_NB_enlatados_W22
# 4            20230601_CMX_fonda_piloto_NB_salsas_W22
#
#                           offer_description  discount  \
# 0        fonda_piloto_NB_azucaryendulzantes         3
# 1            fonda_piloto_NB_aceitesygrasas         7
# 2  fonda_piloto_NB_cafechocolateeinfusiones         7
# 3                 fonda_piloto_NB_enlatados         8
# 4                    fonda_piloto_NB_salsas         6
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                  15
# 1                         true  01-06-2023  30-06-2023                  20
# 2                         true  01-06-2023  30-06-2023                  18
# 3                         true  01-06-2023  30-06-2023                  20
# 4                         true  01-06-2023  30-06-2023                  15
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              167477
# 1                      1              167474
# 2                      1              167480
# 3                      1              167490
# 4                      1              167507
#
#                                               sku_id
# 0                                66553#101151#101175
# 1   101239#-303954#117709#117707#368168#622099#54288
# 2                  26031#377839#628110#313259#313251
# 3  359342#359346#359344#359348#134385#126703#1267...
# 4                    92952#37434#440374#342267#56316

# %%
global_offer_csv = global_offer_csv.loc[~global_offer_csv.customer_segment_id.isnull()].reset_index(drop=True)
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('discount','max_uses_per_order')]=1
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('start_date','end_date')]='01-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('end_date')]='02-01-2028'
global_offer_csv.loc[global_offer_csv['offer_name'].str.contains("control", case=False), ('sku_id')]= global_offer_csv.loc[~global_offer_csv['offer_name'].str.contains("piloto", case=False), ('sku_id')].tolist()

# %%
len_offer =int(len(global_offer_csv)/4)
len_offer = [global_offer_csv[:len_seg],global_offer_csv[len_seg:len_seg*2],global_offer_csv[len_seg*2:len_seg*3],global_offer_csv[len_seg*3:]]

# %%
global_offer_csv.head()
# Out:
#                                           offer_name  \
# 0  20230601_CMX_fonda_piloto_NB_azucaryendulzante...
# 1    20230601_CMX_fonda_piloto_NB_aceitesygrasas_W22
# 2  20230601_CMX_fonda_piloto_NB_cafechocolateeinf...
# 3         20230601_CMX_fonda_piloto_NB_enlatados_W22
# 4            20230601_CMX_fonda_piloto_NB_salsas_W22
#
#                           offer_description  discount  \
# 0        fonda_piloto_NB_azucaryendulzantes         3
# 1            fonda_piloto_NB_aceitesygrasas         7
# 2  fonda_piloto_NB_cafechocolateeinfusiones         7
# 3                 fonda_piloto_NB_enlatados         8
# 4                    fonda_piloto_NB_salsas         6
#
#   automatically_consider_offer  start_date    end_date  max_uses_per_order  \
# 0                         true  01-06-2023  30-06-2023                  15
# 1                         true  01-06-2023  30-06-2023                  20
# 2                         true  01-06-2023  30-06-2023                  18
# 3                         true  01-06-2023  30-06-2023                  20
# 4                         true  01-06-2023  30-06-2023                  15
#
#    max_uses_per_customer customer_segment_id  \
# 0                      1              167477
# 1                      1              167474
# 2                      1              167480
# 3                      1              167490
# 4                      1              167507
#
#                                               sku_id
# 0                                66553#101151#101175
# 1   101239#-303954#117709#117707#368168#622099#54288
# 2                  26031#377839#628110#313259#313251
# 3  359342#359346#359344#359348#134385#126703#1267...
# 4                    92952#37434#440374#342267#56316

# %%
#//--------------------------------------------
#//Exporting single file data
global_offer_csv.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS.csv', index = False)

for i,offer in enumerate(len_offer):
    offer.to_csv(f'SD/export_data/MS/csv_{city_code}_All_MS_{i}.csv', index = False)

with open(f'SD/export_data/MS/nb_{city_code}_All_MS.txt', 'w') as outfile:
        json.dump(global_segment_list, outfile)    
with open(f'SD/export_data/MS/nb_{city_code}_All_MS.json', 'w') as outfile:
        json.dump(global_segment_list, outfile)
print(f'Done {city_code}')
# Out:
# Done CMX
